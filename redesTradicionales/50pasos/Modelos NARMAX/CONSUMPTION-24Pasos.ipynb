# %% [markdown]
# Prueba

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from hyperopt import hp, fmin, tpe, Trials, STATUS_OK
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU, InputLayer, Flatten, LSTM
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import os
from datetime import datetime, timedelta
import plotly.express as px
import plotly.graph_objects as go
import random

# %% [markdown]
# LEER DATASET

# %%
import pandas as pd

datosMLP = pd.read_csv("C:\\Users\\wamt1\\Desktop\\pruebas_collab\\datosNarmax\\24pasos_mlp_consumption.csv")
datosLSTM = pd.read_csv("C:\\Users\\wamt1\\Desktop\\pruebas_collab\\datosNarmax\\24pasos_lstm_consumption.csv")
datosGRU = pd.read_csv("C:\\Users\\wamt1\\Desktop\\pruebas_collab\\datosNarmax\\24pasos_gru_consumption.csv")

datosMLP['date'] = pd.to_datetime(datosMLP['date'])
datosLSTM['date'] = pd.to_datetime(datosLSTM['date'])
datosGRU['date'] = pd.to_datetime(datosGRU['date'])

# Se establece la columna date como index
datosMLP.set_index('date', inplace=True)
datosLSTM.set_index('date', inplace=True)
datosGRU.set_index('date', inplace=True)

# %%
#Se verifica que el index está en formato de dato "datetime64"
print("El index del dataframe MLP input es un tipo de dato: ", datosMLP.index.dtype)
print("El index del dataframe LSTM input es un tipo de dato: ", datosLSTM.index.dtype)
print("El index del dataframe GRU input es un tipo de dato: ", datosGRU.index.dtype)
# Out:
# El index del dataframe MLP input es un tipo de dato:  datetime64[ns]
# El index del dataframe LSTM input es un tipo de dato:  datetime64[ns]
# El index del dataframe GRU input es un tipo de dato:  datetime64[ns]

# %% [markdown]
# Se establece el formato de datos de entrada para redes GRU y LSTM, es decir [observaciones, retardos, caracteristicas]

# %%
futuros = 24
pasados  = 12

# %%
datosMLPX = []
datosMLPY = []
for i in range(pasados, len(datosMLP) - futuros + 1):
  datosMLPX.append(datosMLP.iloc[i-pasados:i, 0:datosMLP.shape[1]])
  datosMLPY.append(datosMLP.iloc[i+futuros-1:i+futuros, 1])

# %%
datosLSTMX = []
datosLSTMY = []
for i in range(pasados, len(datosLSTM) - futuros + 1):
  datosLSTMX.append(datosLSTM.iloc[i-pasados:i, 0:datosLSTM.shape[1]])
  datosLSTMY.append(datosLSTM.iloc[i+futuros-1:i+futuros, 1])

# %%
datosGRUX = []
datosGRUY = []
for i in range(pasados, len(datosGRU) - futuros + 1):
  datosGRUX.append(datosGRU.iloc[i-pasados:i, 0:datosGRU.shape[1]])
  datosGRUY.append(datosGRU.iloc[i+futuros-1:i+futuros, 1])

# %%
# Convertir las listas en arrays numpy
datosMLPX = np.array(datosMLPX)
datosMLPY = np.array(datosMLPY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de MLP X:", datosMLPX.shape)  
print("Dimensiones de MLP Y:", datosMLPY.shape)
# Out:
# Dimensiones de MLP X: (52381, 12, 6)
# Dimensiones de MLP Y: (52381, 1)

# %%
# Convertir las listas en arrays numpy
datosLSTMX = np.array(datosLSTMX)
datosLSTMY = np.array(datosLSTMY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de LSTM X:", datosLSTMX.shape)  
print("Dimensiones de LSTM Y:", datosLSTMY.shape)
# Out:
# Dimensiones de LSTM X: (52381, 12, 6)
# Dimensiones de LSTM Y: (52381, 1)

# %%
# Convertir las listas en arrays numpy
datosGRUX = np.array(datosGRUX)
datosGRUY = np.array(datosGRUY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de GRU X:", datosGRUX.shape)  
print("Dimensiones de GRU Y:", datosGRUY.shape)
# Out:
# Dimensiones de GRU X: (52381, 12, 6)
# Dimensiones de GRU Y: (52381, 1)

# %%
inputs = datosMLPX.shape[1] * datosMLPX.shape[2]
datosMLPX = datosMLPX.reshape(datosMLPX.shape[0], inputs)

# %% [markdown]
# Se dividen nuevamente los conjuntos de datos

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainMLPX, testMLPX = train_test_split(datosMLPX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testMLPX, valMLPX = train_test_split(testMLPX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainMLPX son: ", trainMLPX.shape)
print("Las dimensiones de testMLPX son: ", testMLPX.shape)
print("Las dimensiones de valMLPX son: ", valMLPX.shape)
# Out:
# Las dimensiones de trainMLPX son:  (36666, 72)
# Las dimensiones de testMLPX son:  (10529, 72)
# Las dimensiones de valMLPX son:  (5186, 72)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainLSTMX, testLSTMX = train_test_split(datosLSTMX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testLSTMX, valLSTMX = train_test_split(testLSTMX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainLSTMX son: ", trainLSTMX.shape)
print("Las dimensiones de testLSTMX son: ", testLSTMX.shape)
print("Las dimensiones de valLSTMX son: ", valLSTMX.shape)
# Out:
# Las dimensiones de trainLSTMX son:  (36666, 12, 6)
# Las dimensiones de testLSTMX son:  (10529, 12, 6)
# Las dimensiones de valLSTMX son:  (5186, 12, 6)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainGRUX, testGRUX = train_test_split(datosGRUX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testGRUX, valGRUX = train_test_split(testGRUX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainGRUX son: ", trainGRUX.shape)
print("Las dimensiones de testGRUX son: ", testGRUX.shape)
print("Las dimensiones de valGRUX son: ", valGRUX.shape)
# Out:
# Las dimensiones de trainGRUX son:  (36666, 12, 6)
# Las dimensiones de testGRUX son:  (10529, 12, 6)
# Las dimensiones de valGRUX son:  (5186, 12, 6)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainY, testY = train_test_split(datosMLPY, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testY, valY = train_test_split(testY, test_size=0.33, shuffle=False)

print("Las dimensiones de trainY son: ", trainY.shape)
print("Las dimensiones de testY son: ", testY.shape)
print("Las dimensiones de valY son: ", valY.shape)
# Out:
# Las dimensiones de trainY son:  (36666, 1)
# Las dimensiones de testY son:  (10529, 1)
# Las dimensiones de valY son:  (5186, 1)

# %% [markdown]
# Se crean métricas para medir desempeño

# %%
import tensorflow.keras.backend as K

def smape(y_true, y_pred):
    """
    Define la función SMAPE (Error Porcentual Absoluto Medio Simétrico).
    """
    summ = K.abs(y_true) + K.abs(y_pred)
    smape_val = K.abs(y_pred - y_true) / summ * 2.0
    return K.mean(smape_val, axis=-1)

def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

def ia(y_true, y_pred):
    numerator = K.sum(K.abs(y_true - y_pred))
    denominator = K.sum(K.abs(y_true - K.mean(y_true)) + K.abs(y_pred - K.mean(y_true)))
    return 1 - (numerator / denominator)

# %% [markdown]
# Se define el index del conjunto de validación para utilizarlo posteriormente para graficar.

# %%
# Fecha y hora de término del conjunto de datos de prueba
end_date = datosMLP.index[-1]
n_observations = valY.shape[0]  # Cambia esto al número de observaciones en tu conjunto de prueba

# Calcular la fecha y hora de inicio
start_date = end_date - timedelta(minutes=10 * (n_observations - 1))

# Crear la serie de fechas y horas
val_date = pd.date_range(start=start_date, end=end_date, freq='10T')

val_date
# Out:
# C:\Users\wamt1\AppData\Local\Temp\ipykernel_11904\572609118.py:9: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   val_date = pd.date_range(start=start_date, end=end_date, freq='10T')
# DatetimeIndex(['2017-11-24 23:40:00', '2017-11-24 23:50:00',
#                '2017-11-25 00:00:00', '2017-11-25 00:10:00',
#                '2017-11-25 00:20:00', '2017-11-25 00:30:00',
#                '2017-11-25 00:40:00', '2017-11-25 00:50:00',
#                '2017-11-25 01:00:00', '2017-11-25 01:10:00',
#                ...
#                '2017-12-30 22:20:00', '2017-12-30 22:30:00',
#                '2017-12-30 22:40:00', '2017-12-30 22:50:00',
#                '2017-12-30 23:00:00', '2017-12-30 23:10:00',
#                '2017-12-30 23:20:00', '2017-12-30 23:30:00',
#                '2017-12-30 23:40:00', '2017-12-30 23:50:00'],
#               dtype='datetime64[ns]', length=5186, freq='10min')

# %% [markdown]
# Se guardan los índices de las observaciones a utilizar para predecir

# %%
indices = []
for i in range(pasados, len(datosMLP) - futuros + 1):
  indices.append(datosMLP.index[i+futuros-2])

# %% [markdown]
# # Modelos

# %% [markdown]
# ## MLP

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelMLP = Sequential()
modelMLP.add(InputLayer(input_shape=(testMLPX.shape[1],)))

modelMLP.add(Dense(units=16, activation="tanh"))
modelMLP.add(Dropout(0.0))

modelMLP.add(Dense(units=16, activation="tanh"))
modelMLP.add(Dropout(0.0))

modelMLP.add(Dense(1))

opt = Adam(learning_rate=0.006065391920254659)

modelMLP.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelMLP.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,457 (5.69 KB)
#  Trainable params: 1,457 (5.69 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyMLP = modelMLP.fit(testMLPX, testY, epochs=64,
                        validation_split=0.3,
                        verbose = 2, batch_size=16, callbacks=[early_stopping])

prediccionMLP = modelMLP.predict(valMLPX)
# Out:
# Epoch 1/64
# 461/461 - 2s - 5ms/step - ia: 0.8032 - loss: 0.1285 - mae: 0.2575 - rmse: 0.3247 - smape: 0.5627 - val_ia: 0.3356 - val_loss: 0.1919 - val_mae: 0.3328 - val_rmse: 0.3662 - val_smape: 0.6267
# Epoch 2/64
# 461/461 - 1s - 1ms/step - ia: 0.8773 - loss: 0.0510 - mae: 0.1678 - rmse: 0.2178 - smape: 0.4304 - val_ia: 0.3694 - val_loss: 0.1154 - val_mae: 0.2634 - val_rmse: 0.2935 - val_smape: 0.5340
# Epoch 3/64
# 461/461 - 1s - 1ms/step - ia: 0.8887 - loss: 0.0428 - mae: 0.1520 - rmse: 0.1994 - smape: 0.4028 - val_ia: 0.4016 - val_loss: 0.0891 - val_mae: 0.2309 - val_rmse: 0.2580 - val_smape: 0.4820
# Epoch 4/64
# 461/461 - 1s - 1ms/step - ia: 0.8940 - loss: 0.0394 - mae: 0.1448 - rmse: 0.1910 - smape: 0.3866 - val_ia: 0.4182 - val_loss: 0.0795 - val_mae: 0.2173 - val_rmse: 0.2434 - val_smape: 0.4552
# Epoch 5/64
# 461/461 - 1s - 1ms/step - ia: 0.8969 - loss: 0.0374 - mae: 0.1408 - rmse: 0.1859 - smape: 0.3785 - val_ia: 0.4284 - val_loss: 0.0763 - val_mae: 0.2108 - val_rmse: 0.2364 - val_smape: 0.4398
# Epoch 6/64
# 461/461 - 0s - 1ms/step - ia: 0.8984 - loss: 0.0363 - mae: 0.1389 - rmse: 0.1832 - smape: 0.3741 - val_ia: 0.4316 - val_loss: 0.0755 - val_mae: 0.2088 - val_rmse: 0.2349 - val_smape: 0.4313
# Epoch 7/64
# 461/461 - 1s - 1ms/step - ia: 0.8999 - loss: 0.0353 - mae: 0.1369 - rmse: 0.1806 - smape: 0.3707 - val_ia: 0.4293 - val_loss: 0.0780 - val_mae: 0.2108 - val_rmse: 0.2377 - val_smape: 0.4320
# Epoch 8/64
# 461/461 - 1s - 1ms/step - ia: 0.9011 - loss: 0.0344 - mae: 0.1353 - rmse: 0.1785 - smape: 0.3704 - val_ia: 0.4272 - val_loss: 0.0827 - val_mae: 0.2157 - val_rmse: 0.2436 - val_smape: 0.4386
# Epoch 9/64
# 461/461 - 1s - 2ms/step - ia: 0.9021 - loss: 0.0337 - mae: 0.1339 - rmse: 0.1765 - smape: 0.3656 - val_ia: 0.4199 - val_loss: 0.0927 - val_mae: 0.2265 - val_rmse: 0.2558 - val_smape: 0.4653
# Epoch 10/64
# 461/461 - 1s - 1ms/step - ia: 0.9026 - loss: 0.0331 - mae: 0.1331 - rmse: 0.1753 - smape: 0.3651 - val_ia: 0.4203 - val_loss: 0.1005 - val_mae: 0.2330 - val_rmse: 0.2625 - val_smape: 0.4814
# Epoch 11/64
# 461/461 - 1s - 1ms/step - ia: 0.9036 - loss: 0.0325 - mae: 0.1318 - rmse: 0.1736 - smape: 0.3625 - val_ia: 0.4213 - val_loss: 0.1053 - val_mae: 0.2361 - val_rmse: 0.2665 - val_smape: 0.4819
# Epoch 12/64
# 461/461 - 1s - 1ms/step - ia: 0.9046 - loss: 0.0318 - mae: 0.1304 - rmse: 0.1718 - smape: 0.3601 - val_ia: 0.4234 - val_loss: 0.1041 - val_mae: 0.2337 - val_rmse: 0.2639 - val_smape: 0.4775
# Epoch 13/64
# 461/461 - 1s - 1ms/step - ia: 0.9050 - loss: 0.0313 - mae: 0.1298 - rmse: 0.1709 - smape: 0.3578 - val_ia: 0.4228 - val_loss: 0.1122 - val_mae: 0.2390 - val_rmse: 0.2702 - val_smape: 0.4833
# Epoch 14/64
# 461/461 - 0s - 1ms/step - ia: 0.9052 - loss: 0.0311 - mae: 0.1295 - rmse: 0.1704 - smape: 0.3573 - val_ia: 0.4275 - val_loss: 0.1074 - val_mae: 0.2340 - val_rmse: 0.2648 - val_smape: 0.4747
# Epoch 15/64
# 461/461 - 1s - 1ms/step - ia: 0.9058 - loss: 0.0308 - mae: 0.1288 - rmse: 0.1694 - smape: 0.3567 - val_ia: 0.4203 - val_loss: 0.1052 - val_mae: 0.2346 - val_rmse: 0.2647 - val_smape: 0.4776
# Epoch 16/64
# 461/461 - 1s - 1ms/step - ia: 0.9063 - loss: 0.0304 - mae: 0.1282 - rmse: 0.1683 - smape: 0.3534 - val_ia: 0.4326 - val_loss: 0.0997 - val_mae: 0.2252 - val_rmse: 0.2551 - val_smape: 0.4577
# Epoch 17/64
# 461/461 - 1s - 1ms/step - ia: 0.9075 - loss: 0.0296 - mae: 0.1265 - rmse: 0.1662 - smape: 0.3527 - val_ia: 0.4306 - val_loss: 0.0984 - val_mae: 0.2240 - val_rmse: 0.2548 - val_smape: 0.4556
# Epoch 18/64
# 461/461 - 1s - 2ms/step - ia: 0.9081 - loss: 0.0291 - mae: 0.1257 - rmse: 0.1649 - smape: 0.3514 - val_ia: 0.4326 - val_loss: 0.0950 - val_mae: 0.2201 - val_rmse: 0.2499 - val_smape: 0.4456
# Epoch 19/64
# 461/461 - 1s - 1ms/step - ia: 0.9083 - loss: 0.0289 - mae: 0.1255 - rmse: 0.1644 - smape: 0.3492 - val_ia: 0.4344 - val_loss: 0.0900 - val_mae: 0.2161 - val_rmse: 0.2452 - val_smape: 0.4391
# Epoch 20/64
# 461/461 - 1s - 1ms/step - ia: 0.9087 - loss: 0.0286 - mae: 0.1249 - rmse: 0.1635 - smape: 0.3479 - val_ia: 0.4324 - val_loss: 0.1009 - val_mae: 0.2217 - val_rmse: 0.2517 - val_smape: 0.4458
# Epoch 21/64
# 461/461 - 1s - 1ms/step - ia: 0.9089 - loss: 0.0284 - mae: 0.1246 - rmse: 0.1630 - smape: 0.3468 - val_ia: 0.4331 - val_loss: 0.1018 - val_mae: 0.2211 - val_rmse: 0.2516 - val_smape: 0.4425
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step

# %%
metricasMLP = modelMLP.evaluate(valMLPX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasMLP}")
# Out:
# 163/163 - 0s - 1ms/step - ia: 0.6105 - loss: 0.0701 - mae: 0.2065 - rmse: 0.2475 - smape: 0.4569
# Métricas en el conjunto de validación: [0.07014773041009903, 0.20651093125343323, 0.4569483995437622, 0.24751466512680054, 0.6105142831802368]

# %%
historyMLP = historyMLP.history

ejeXMLP = range(1, len(historyMLP['loss']) + 1)

plt.figure(figsize=(12, 8))
plt.plot(ejeXMLP, historyMLP['loss'], label='Train Loss')
plt.plot(ejeXMLP, historyMLP['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyMLP['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyMLP['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.028394483029842377
# Último valor de Test Loss: 0.10175199061632156

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionMLP.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfMLP = df
fig.show()

# %%
dfMLP.to_csv('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\evaluacion\\narmax\\24pasos_mlp_consumption.csv', index=True)

# %%
modelMLP.save('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\modelosEntrenadosNarmax\\24pasos_mlp_consumption.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## LSTM

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelLSTM = Sequential()
modelLSTM.add(InputLayer(input_shape=(testLSTMX.shape[1], testLSTMX.shape[2])))

modelLSTM.add(LSTM(units=8, activation="tanh", return_sequences=True))
modelLSTM.add(Dropout(0.1))

modelLSTM.add(LSTM(units=8, activation="tanh", return_sequences=True))
modelLSTM.add(Dropout(0.1))

modelLSTM.add(LSTM(units=8, activation="tanh", return_sequences=False))
modelLSTM.add(Dropout(0.1))

modelLSTM.add(Dense(1))


opt = Adam(learning_rate=0.002646330986430552)
modelLSTM.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelLSTM.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 12, 8)          │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 12, 8)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 12, 8)          │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 12, 8)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 8)              │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,577 (6.16 KB)
#  Trainable params: 1,577 (6.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyLSTM = modelLSTM.fit(testLSTMX, testY, epochs=128,
                        validation_split=0.3,
                        verbose = 2, batch_size=16, callbacks=[early_stopping])

prediccionLSTM = modelLSTM.predict(valLSTMX)
# Out:
# Epoch 1/128
# 461/461 - 8s - 17ms/step - ia: 0.7345 - loss: 0.2000 - mae: 0.3406 - rmse: 0.4283 - smape: 0.6687 - val_ia: 0.3070 - val_loss: 0.2295 - val_mae: 0.3860 - val_rmse: 0.4165 - val_smape: 0.6815
# Epoch 2/128
# 461/461 - 3s - 7ms/step - ia: 0.8307 - loss: 0.0870 - mae: 0.2299 - rmse: 0.2879 - smape: 0.5245 - val_ia: 0.3341 - val_loss: 0.1977 - val_mae: 0.3498 - val_rmse: 0.3772 - val_smape: 0.6251
# Epoch 3/128
# 461/461 - 3s - 7ms/step - ia: 0.8525 - loss: 0.0664 - mae: 0.2000 - rmse: 0.2519 - smape: 0.4721 - val_ia: 0.3527 - val_loss: 0.1575 - val_mae: 0.3104 - val_rmse: 0.3369 - val_smape: 0.5635
# Epoch 4/128
# 461/461 - 3s - 7ms/step - ia: 0.8604 - loss: 0.0600 - mae: 0.1896 - rmse: 0.2390 - smape: 0.4545 - val_ia: 0.3654 - val_loss: 0.1339 - val_mae: 0.2901 - val_rmse: 0.3158 - val_smape: 0.5308
# Epoch 5/128
# 461/461 - 3s - 7ms/step - ia: 0.8649 - loss: 0.0570 - mae: 0.1834 - rmse: 0.2331 - smape: 0.4451 - val_ia: 0.3778 - val_loss: 0.1243 - val_mae: 0.2745 - val_rmse: 0.3017 - val_smape: 0.5118
# Epoch 6/128
# 461/461 - 3s - 8ms/step - ia: 0.8664 - loss: 0.0558 - mae: 0.1817 - rmse: 0.2305 - smape: 0.4383 - val_ia: 0.3783 - val_loss: 0.1371 - val_mae: 0.2800 - val_rmse: 0.3099 - val_smape: 0.5190
# Epoch 7/128
# 461/461 - 4s - 8ms/step - ia: 0.8682 - loss: 0.0538 - mae: 0.1789 - rmse: 0.2265 - smape: 0.4335 - val_ia: 0.4079 - val_loss: 0.0999 - val_mae: 0.2400 - val_rmse: 0.2671 - val_smape: 0.4543
# Epoch 8/128
# 461/461 - 3s - 7ms/step - ia: 0.8724 - loss: 0.0520 - mae: 0.1743 - rmse: 0.2220 - smape: 0.4245 - val_ia: 0.4268 - val_loss: 0.0868 - val_mae: 0.2227 - val_rmse: 0.2497 - val_smape: 0.4253
# Epoch 9/128
# 461/461 - 3s - 7ms/step - ia: 0.8723 - loss: 0.0511 - mae: 0.1739 - rmse: 0.2210 - smape: 0.4235 - val_ia: 0.4227 - val_loss: 0.0985 - val_mae: 0.2328 - val_rmse: 0.2596 - val_smape: 0.4460
# Epoch 10/128
# 461/461 - 3s - 7ms/step - ia: 0.8722 - loss: 0.0506 - mae: 0.1741 - rmse: 0.2196 - smape: 0.4210 - val_ia: 0.4250 - val_loss: 0.0928 - val_mae: 0.2286 - val_rmse: 0.2556 - val_smape: 0.4319
# Epoch 11/128
# 461/461 - 3s - 7ms/step - ia: 0.8765 - loss: 0.0478 - mae: 0.1678 - rmse: 0.2127 - smape: 0.4114 - val_ia: 0.4356 - val_loss: 0.0795 - val_mae: 0.2118 - val_rmse: 0.2363 - val_smape: 0.4049
# Epoch 12/128
# 461/461 - 4s - 8ms/step - ia: 0.8784 - loss: 0.0467 - mae: 0.1655 - rmse: 0.2107 - smape: 0.4079 - val_ia: 0.4374 - val_loss: 0.0877 - val_mae: 0.2189 - val_rmse: 0.2454 - val_smape: 0.4241
# Epoch 13/128
# 461/461 - 3s - 7ms/step - ia: 0.8780 - loss: 0.0475 - mae: 0.1662 - rmse: 0.2124 - smape: 0.4073 - val_ia: 0.4419 - val_loss: 0.0960 - val_mae: 0.2202 - val_rmse: 0.2467 - val_smape: 0.4152
# Epoch 14/128
# 461/461 - 4s - 8ms/step - ia: 0.8774 - loss: 0.0476 - mae: 0.1668 - rmse: 0.2126 - smape: 0.4089 - val_ia: 0.4478 - val_loss: 0.0828 - val_mae: 0.2101 - val_rmse: 0.2363 - val_smape: 0.4109
# Epoch 15/128
# 461/461 - 3s - 7ms/step - ia: 0.8815 - loss: 0.0451 - mae: 0.1614 - rmse: 0.2066 - smape: 0.3989 - val_ia: 0.4503 - val_loss: 0.0892 - val_mae: 0.2090 - val_rmse: 0.2357 - val_smape: 0.4072
# Epoch 16/128
# 461/461 - 3s - 7ms/step - ia: 0.8827 - loss: 0.0440 - mae: 0.1600 - rmse: 0.2049 - smape: 0.3933 - val_ia: 0.4438 - val_loss: 0.0784 - val_mae: 0.2028 - val_rmse: 0.2289 - val_smape: 0.4058
# Epoch 17/128
# 461/461 - 3s - 8ms/step - ia: 0.8845 - loss: 0.0434 - mae: 0.1578 - rmse: 0.2024 - smape: 0.3904 - val_ia: 0.4494 - val_loss: 0.0856 - val_mae: 0.2049 - val_rmse: 0.2310 - val_smape: 0.4049
# Epoch 18/128
# 461/461 - 4s - 8ms/step - ia: 0.8859 - loss: 0.0421 - mae: 0.1562 - rmse: 0.1997 - smape: 0.3862 - val_ia: 0.4427 - val_loss: 0.0828 - val_mae: 0.2082 - val_rmse: 0.2340 - val_smape: 0.4125
# Epoch 19/128
# 461/461 - 3s - 7ms/step - ia: 0.8866 - loss: 0.0416 - mae: 0.1550 - rmse: 0.1985 - smape: 0.3826 - val_ia: 0.4889 - val_loss: 0.0837 - val_mae: 0.1884 - val_rmse: 0.2143 - val_smape: 0.4002
# Epoch 20/128
# 461/461 - 3s - 7ms/step - ia: 0.8873 - loss: 0.0409 - mae: 0.1542 - rmse: 0.1970 - smape: 0.3809 - val_ia: 0.4759 - val_loss: 0.0876 - val_mae: 0.1960 - val_rmse: 0.2215 - val_smape: 0.3976
# Epoch 21/128
# 461/461 - 3s - 7ms/step - ia: 0.8875 - loss: 0.0411 - mae: 0.1536 - rmse: 0.1975 - smape: 0.3760 - val_ia: 0.4517 - val_loss: 0.1032 - val_mae: 0.2184 - val_rmse: 0.2445 - val_smape: 0.4233
# Epoch 22/128
# 461/461 - 3s - 7ms/step - ia: 0.8892 - loss: 0.0404 - mae: 0.1518 - rmse: 0.1956 - smape: 0.3719 - val_ia: 0.4503 - val_loss: 0.1025 - val_mae: 0.2122 - val_rmse: 0.2389 - val_smape: 0.4161
# Epoch 23/128
# 461/461 - 4s - 8ms/step - ia: 0.8888 - loss: 0.0405 - mae: 0.1518 - rmse: 0.1957 - smape: 0.3704 - val_ia: 0.4644 - val_loss: 0.1019 - val_mae: 0.2095 - val_rmse: 0.2359 - val_smape: 0.4183
# Epoch 24/128
# 461/461 - 3s - 8ms/step - ia: 0.8899 - loss: 0.0401 - mae: 0.1509 - rmse: 0.1949 - smape: 0.3686 - val_ia: 0.4548 - val_loss: 0.1006 - val_mae: 0.2119 - val_rmse: 0.2390 - val_smape: 0.4196
# Epoch 25/128
# 461/461 - 4s - 8ms/step - ia: 0.8911 - loss: 0.0396 - mae: 0.1490 - rmse: 0.1931 - smape: 0.3631 - val_ia: 0.4660 - val_loss: 0.1047 - val_mae: 0.2166 - val_rmse: 0.2422 - val_smape: 0.4403
# Epoch 26/128
# 461/461 - 3s - 7ms/step - ia: 0.8923 - loss: 0.0381 - mae: 0.1474 - rmse: 0.1894 - smape: 0.3625 - val_ia: 0.4469 - val_loss: 0.1028 - val_mae: 0.2176 - val_rmse: 0.2456 - val_smape: 0.4308
# Epoch 27/128
# 461/461 - 3s - 7ms/step - ia: 0.8937 - loss: 0.0372 - mae: 0.1457 - rmse: 0.1874 - smape: 0.3570 - val_ia: 0.4665 - val_loss: 0.1095 - val_mae: 0.2118 - val_rmse: 0.2383 - val_smape: 0.4229
# Epoch 28/128
# 461/461 - 3s - 7ms/step - ia: 0.8922 - loss: 0.0381 - mae: 0.1471 - rmse: 0.1895 - smape: 0.3615 - val_ia: 0.4410 - val_loss: 0.1115 - val_mae: 0.2269 - val_rmse: 0.2541 - val_smape: 0.4342
# Epoch 29/128
# 461/461 - 3s - 7ms/step - ia: 0.8934 - loss: 0.0379 - mae: 0.1459 - rmse: 0.1892 - smape: 0.3561 - val_ia: 0.4365 - val_loss: 0.1188 - val_mae: 0.2340 - val_rmse: 0.2602 - val_smape: 0.4332
# Epoch 30/128
# 461/461 - 3s - 6ms/step - ia: 0.8944 - loss: 0.0371 - mae: 0.1448 - rmse: 0.1868 - smape: 0.3591 - val_ia: 0.4334 - val_loss: 0.1182 - val_mae: 0.2332 - val_rmse: 0.2615 - val_smape: 0.4364
# Epoch 31/128
# 461/461 - 4s - 8ms/step - ia: 0.8955 - loss: 0.0354 - mae: 0.1430 - rmse: 0.1833 - smape: 0.3560 - val_ia: 0.4796 - val_loss: 0.1153 - val_mae: 0.2074 - val_rmse: 0.2345 - val_smape: 0.4060
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 16.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
metricasLSTM = modelLSTM.evaluate(valLSTMX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasLSTM}")
# Out:
# 163/163 - 0s - 3ms/step - ia: 0.6003 - loss: 0.0694 - mae: 0.2013 - rmse: 0.2490 - smape: 0.4036
# Métricas en el conjunto de validación: [0.0694054663181305, 0.2012752741575241, 0.40357664227485657, 0.24903742969036102, 0.6003319025039673]

# %%
historyLSTM = historyLSTM.history

ejeXLSTM = range(1, len(historyLSTM['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXLSTM, historyLSTM['loss'], label='Train Loss')
plt.plot(ejeXLSTM, historyLSTM['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyLSTM['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyLSTM['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.03542487323284149
# Último valor de Test Loss: 0.11532118171453476

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionLSTM.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfLSTM = df
fig.show()

# %%
dfLSTM.to_csv('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\evaluacion\\narmax\\24pasos_lstm_consumption.csv', index=True)

# %%
modelLSTM.save('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\modelosEntrenadosNarmax\\24pasos_lstm_consumption.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## GRU

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelGRU = Sequential()
modelGRU.add(InputLayer(input_shape=(testGRUX.shape[1], testGRUX.shape[2])))

modelGRU.add(GRU(units=128, activation="sigmoid", return_sequences=True))
modelGRU.add(Dropout(0.3))

modelGRU.add(GRU(units=128, activation="sigmoid", return_sequences=False))
modelGRU.add(Dropout(0.3))

modelGRU.add(Dense(1))


opt = Adam(learning_rate=0.006238028275242282)
modelGRU.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelGRU.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 12, 128)        │        52,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 128)            │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 151,425 (591.50 KB)
#  Trainable params: 151,425 (591.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)

early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyGRU = modelGRU.fit(testGRUX, testY, epochs=128,
                        validation_split=0.3,
                        verbose = 2, batch_size=256, callbacks=[early_stopping])

prediccionGRU = modelGRU.predict(valGRUX)
# Out:
# Epoch 1/128
# 29/29 - 5s - 184ms/step - ia: 0.2813 - loss: 1.3083 - mae: 0.9162 - rmse: 1.1133 - smape: 1.4502 - val_ia: 0.3561 - val_loss: 1.1699 - val_mae: 0.9148 - val_rmse: 1.0498 - val_smape: 1.7266
# Epoch 2/128
# 29/29 - 2s - 52ms/step - ia: 0.2916 - loss: 0.7837 - mae: 0.7257 - rmse: 0.8834 - smape: 1.4384 - val_ia: 0.4238 - val_loss: 0.7938 - val_mae: 0.7352 - val_rmse: 0.8618 - val_smape: 1.2928
# Epoch 3/128
# 29/29 - 2s - 54ms/step - ia: 0.5227 - loss: 0.4905 - mae: 0.5621 - rmse: 0.6952 - smape: 1.0569 - val_ia: 0.6652 - val_loss: 0.3206 - val_mae: 0.4552 - val_rmse: 0.5533 - val_smape: 0.7538
# Epoch 4/128
# 29/29 - 2s - 52ms/step - ia: 0.6982 - loss: 0.2920 - mae: 0.4310 - rmse: 0.5391 - smape: 0.7485 - val_ia: 0.7344 - val_loss: 0.1835 - val_mae: 0.3459 - val_rmse: 0.4222 - val_smape: 0.6869
# Epoch 5/128
# 29/29 - 1s - 50ms/step - ia: 0.7524 - loss: 0.2083 - mae: 0.3556 - rmse: 0.4548 - smape: 0.6516 - val_ia: 0.7776 - val_loss: 0.1264 - val_mae: 0.2825 - val_rmse: 0.3491 - val_smape: 0.6189
# Epoch 6/128
# 29/29 - 2s - 54ms/step - ia: 0.7908 - loss: 0.1526 - mae: 0.3042 - rmse: 0.3896 - smape: 0.6041 - val_ia: 0.7903 - val_loss: 0.1097 - val_mae: 0.2634 - val_rmse: 0.3274 - val_smape: 0.5711
# Epoch 7/128
# 29/29 - 2s - 54ms/step - ia: 0.8108 - loss: 0.1245 - mae: 0.2740 - rmse: 0.3520 - smape: 0.5768 - val_ia: 0.7926 - val_loss: 0.1142 - val_mae: 0.2660 - val_rmse: 0.3350 - val_smape: 0.5837
# Epoch 8/128
# 29/29 - 2s - 58ms/step - ia: 0.8311 - loss: 0.0984 - mae: 0.2448 - rmse: 0.3131 - smape: 0.5509 - val_ia: 0.7830 - val_loss: 0.1199 - val_mae: 0.2711 - val_rmse: 0.3420 - val_smape: 0.5926
# Epoch 9/128
# 29/29 - 2s - 53ms/step - ia: 0.8396 - loss: 0.0897 - mae: 0.2320 - rmse: 0.2986 - smape: 0.5313 - val_ia: 0.7749 - val_loss: 0.1228 - val_mae: 0.2789 - val_rmse: 0.3453 - val_smape: 0.6214
# Epoch 10/128
# 29/29 - 2s - 52ms/step - ia: 0.8488 - loss: 0.0802 - mae: 0.2190 - rmse: 0.2825 - smape: 0.5122 - val_ia: 0.7913 - val_loss: 0.1076 - val_mae: 0.2610 - val_rmse: 0.3218 - val_smape: 0.5770
# Epoch 11/128
# 29/29 - 2s - 54ms/step - ia: 0.8586 - loss: 0.0699 - mae: 0.2050 - rmse: 0.2637 - smape: 0.4916 - val_ia: 0.8002 - val_loss: 0.0987 - val_mae: 0.2484 - val_rmse: 0.3086 - val_smape: 0.5648
# Epoch 12/128
# 29/29 - 1s - 51ms/step - ia: 0.8634 - loss: 0.0652 - mae: 0.1980 - rmse: 0.2550 - smape: 0.4808 - val_ia: 0.8119 - val_loss: 0.0890 - val_mae: 0.2352 - val_rmse: 0.2932 - val_smape: 0.5416
# Epoch 13/128
# 29/29 - 1s - 51ms/step - ia: 0.8685 - loss: 0.0615 - mae: 0.1912 - rmse: 0.2475 - smape: 0.4702 - val_ia: 0.7971 - val_loss: 0.0974 - val_mae: 0.2482 - val_rmse: 0.3065 - val_smape: 0.5602
# Epoch 14/128
# 29/29 - 2s - 52ms/step - ia: 0.8732 - loss: 0.0566 - mae: 0.1839 - rmse: 0.2377 - smape: 0.4583 - val_ia: 0.8131 - val_loss: 0.0859 - val_mae: 0.2300 - val_rmse: 0.2885 - val_smape: 0.5138
# Epoch 15/128
# 29/29 - 2s - 53ms/step - ia: 0.8745 - loss: 0.0549 - mae: 0.1820 - rmse: 0.2340 - smape: 0.4550 - val_ia: 0.8139 - val_loss: 0.0858 - val_mae: 0.2292 - val_rmse: 0.2883 - val_smape: 0.5163
# Epoch 16/128
# 29/29 - 1s - 50ms/step - ia: 0.8768 - loss: 0.0530 - mae: 0.1790 - rmse: 0.2299 - smape: 0.4518 - val_ia: 0.8244 - val_loss: 0.0794 - val_mae: 0.2189 - val_rmse: 0.2774 - val_smape: 0.4967
# Epoch 17/128
# 29/29 - 1s - 49ms/step - ia: 0.8795 - loss: 0.0515 - mae: 0.1752 - rmse: 0.2267 - smape: 0.4417 - val_ia: 0.8203 - val_loss: 0.0810 - val_mae: 0.2210 - val_rmse: 0.2804 - val_smape: 0.5016
# Epoch 18/128
# 29/29 - 1s - 50ms/step - ia: 0.8818 - loss: 0.0496 - mae: 0.1716 - rmse: 0.2225 - smape: 0.4387 - val_ia: 0.8177 - val_loss: 0.0825 - val_mae: 0.2218 - val_rmse: 0.2836 - val_smape: 0.4924
# Epoch 19/128
# 29/29 - 1s - 52ms/step - ia: 0.8814 - loss: 0.0505 - mae: 0.1725 - rmse: 0.2243 - smape: 0.4385 - val_ia: 0.8194 - val_loss: 0.0810 - val_mae: 0.2210 - val_rmse: 0.2807 - val_smape: 0.4983
# Epoch 20/128
# 29/29 - 1s - 51ms/step - ia: 0.8837 - loss: 0.0483 - mae: 0.1691 - rmse: 0.2192 - smape: 0.4288 - val_ia: 0.8322 - val_loss: 0.0754 - val_mae: 0.2111 - val_rmse: 0.2698 - val_smape: 0.4664
# Epoch 21/128
# 29/29 - 1s - 51ms/step - ia: 0.8852 - loss: 0.0472 - mae: 0.1672 - rmse: 0.2170 - smape: 0.4296 - val_ia: 0.8258 - val_loss: 0.0796 - val_mae: 0.2181 - val_rmse: 0.2768 - val_smape: 0.4855
# Epoch 22/128
# 29/29 - 1s - 49ms/step - ia: 0.8863 - loss: 0.0465 - mae: 0.1653 - rmse: 0.2153 - smape: 0.4251 - val_ia: 0.8324 - val_loss: 0.0777 - val_mae: 0.2129 - val_rmse: 0.2735 - val_smape: 0.4753
# Epoch 23/128
# 29/29 - 1s - 50ms/step - ia: 0.8883 - loss: 0.0449 - mae: 0.1625 - rmse: 0.2115 - smape: 0.4207 - val_ia: 0.8405 - val_loss: 0.0709 - val_mae: 0.2024 - val_rmse: 0.2620 - val_smape: 0.4565
# Epoch 24/128
# 29/29 - 1s - 47ms/step - ia: 0.8881 - loss: 0.0449 - mae: 0.1629 - rmse: 0.2116 - smape: 0.4204 - val_ia: 0.8335 - val_loss: 0.0761 - val_mae: 0.2128 - val_rmse: 0.2691 - val_smape: 0.4662
# Epoch 25/128
# 29/29 - 1s - 51ms/step - ia: 0.8890 - loss: 0.0450 - mae: 0.1615 - rmse: 0.2117 - smape: 0.4162 - val_ia: 0.8364 - val_loss: 0.0740 - val_mae: 0.2074 - val_rmse: 0.2670 - val_smape: 0.4623
# Epoch 26/128
# 29/29 - 1s - 49ms/step - ia: 0.8905 - loss: 0.0433 - mae: 0.1594 - rmse: 0.2078 - smape: 0.4157 - val_ia: 0.8321 - val_loss: 0.0753 - val_mae: 0.2116 - val_rmse: 0.2688 - val_smape: 0.4735
# Epoch 27/128
# 29/29 - 1s - 47ms/step - ia: 0.8908 - loss: 0.0432 - mae: 0.1589 - rmse: 0.2077 - smape: 0.4133 - val_ia: 0.8388 - val_loss: 0.0720 - val_mae: 0.2057 - val_rmse: 0.2627 - val_smape: 0.4594
# Epoch 28/128
# 29/29 - 1s - 49ms/step - ia: 0.8923 - loss: 0.0427 - mae: 0.1570 - rmse: 0.2062 - smape: 0.4096 - val_ia: 0.8330 - val_loss: 0.0767 - val_mae: 0.2119 - val_rmse: 0.2712 - val_smape: 0.4712
# Epoch 29/128
# 29/29 - 2s - 53ms/step - ia: 0.8920 - loss: 0.0430 - mae: 0.1573 - rmse: 0.2068 - smape: 0.4098 - val_ia: 0.8341 - val_loss: 0.0748 - val_mae: 0.2074 - val_rmse: 0.2692 - val_smape: 0.4673
# Epoch 30/128
# 29/29 - 1s - 49ms/step - ia: 0.8915 - loss: 0.0430 - mae: 0.1580 - rmse: 0.2073 - smape: 0.4053 - val_ia: 0.8362 - val_loss: 0.0710 - val_mae: 0.2034 - val_rmse: 0.2626 - val_smape: 0.4505
# Epoch 31/128
# 29/29 - 1s - 46ms/step - ia: 0.8919 - loss: 0.0430 - mae: 0.1576 - rmse: 0.2070 - smape: 0.4079 - val_ia: 0.8417 - val_loss: 0.0663 - val_mae: 0.1973 - val_rmse: 0.2535 - val_smape: 0.4452
# Epoch 32/128
# 29/29 - 1s - 51ms/step - ia: 0.8936 - loss: 0.0416 - mae: 0.1551 - rmse: 0.2036 - smape: 0.4010 - val_ia: 0.8483 - val_loss: 0.0655 - val_mae: 0.1957 - val_rmse: 0.2501 - val_smape: 0.4253
# Epoch 33/128
# 29/29 - 1s - 47ms/step - ia: 0.8934 - loss: 0.0420 - mae: 0.1553 - rmse: 0.2046 - smape: 0.4005 - val_ia: 0.8468 - val_loss: 0.0656 - val_mae: 0.1956 - val_rmse: 0.2511 - val_smape: 0.4282
# Epoch 34/128
# 29/29 - 1s - 48ms/step - ia: 0.8959 - loss: 0.0400 - mae: 0.1518 - rmse: 0.1996 - smape: 0.3956 - val_ia: 0.8415 - val_loss: 0.0685 - val_mae: 0.2020 - val_rmse: 0.2560 - val_smape: 0.4499
# Epoch 35/128
# 29/29 - 1s - 51ms/step - ia: 0.8972 - loss: 0.0396 - mae: 0.1500 - rmse: 0.1986 - smape: 0.3912 - val_ia: 0.8510 - val_loss: 0.0634 - val_mae: 0.1931 - val_rmse: 0.2458 - val_smape: 0.4251
# Epoch 36/128
# 29/29 - 2s - 52ms/step - ia: 0.8977 - loss: 0.0389 - mae: 0.1492 - rmse: 0.1967 - smape: 0.3901 - val_ia: 0.8431 - val_loss: 0.0666 - val_mae: 0.1985 - val_rmse: 0.2535 - val_smape: 0.4366
# Epoch 37/128
# 29/29 - 1s - 48ms/step - ia: 0.8965 - loss: 0.0402 - mae: 0.1510 - rmse: 0.2001 - smape: 0.3913 - val_ia: 0.8472 - val_loss: 0.0627 - val_mae: 0.1934 - val_rmse: 0.2456 - val_smape: 0.4335
# Epoch 38/128
# 29/29 - 1s - 49ms/step - ia: 0.8966 - loss: 0.0402 - mae: 0.1506 - rmse: 0.2001 - smape: 0.3933 - val_ia: 0.8475 - val_loss: 0.0634 - val_mae: 0.1933 - val_rmse: 0.2470 - val_smape: 0.4206
# Epoch 39/128
# 29/29 - 2s - 53ms/step - ia: 0.8967 - loss: 0.0400 - mae: 0.1507 - rmse: 0.1997 - smape: 0.3901 - val_ia: 0.8466 - val_loss: 0.0655 - val_mae: 0.1978 - val_rmse: 0.2488 - val_smape: 0.4276
# Epoch 40/128
# 29/29 - 1s - 48ms/step - ia: 0.8991 - loss: 0.0379 - mae: 0.1473 - rmse: 0.1942 - smape: 0.3849 - val_ia: 0.8542 - val_loss: 0.0601 - val_mae: 0.1875 - val_rmse: 0.2391 - val_smape: 0.4032
# Epoch 41/128
# 29/29 - 1s - 49ms/step - ia: 0.9001 - loss: 0.0372 - mae: 0.1459 - rmse: 0.1924 - smape: 0.3777 - val_ia: 0.8496 - val_loss: 0.0629 - val_mae: 0.1939 - val_rmse: 0.2429 - val_smape: 0.4155
# Epoch 42/128
# 29/29 - 1s - 46ms/step - ia: 0.9012 - loss: 0.0368 - mae: 0.1443 - rmse: 0.1915 - smape: 0.3773 - val_ia: 0.8474 - val_loss: 0.0640 - val_mae: 0.1946 - val_rmse: 0.2466 - val_smape: 0.4098
# Epoch 43/128
# 29/29 - 1s - 47ms/step - ia: 0.9020 - loss: 0.0366 - mae: 0.1432 - rmse: 0.1909 - smape: 0.3736 - val_ia: 0.8501 - val_loss: 0.0632 - val_mae: 0.1933 - val_rmse: 0.2444 - val_smape: 0.4039
# Epoch 44/128
# 29/29 - 1s - 50ms/step - ia: 0.9026 - loss: 0.0357 - mae: 0.1421 - rmse: 0.1885 - smape: 0.3731 - val_ia: 0.8515 - val_loss: 0.0628 - val_mae: 0.1924 - val_rmse: 0.2433 - val_smape: 0.4100
# Epoch 45/128
# 29/29 - 1s - 50ms/step - ia: 0.9049 - loss: 0.0346 - mae: 0.1390 - rmse: 0.1854 - smape: 0.3662 - val_ia: 0.8494 - val_loss: 0.0615 - val_mae: 0.1897 - val_rmse: 0.2422 - val_smape: 0.4064
# Epoch 46/128
# 29/29 - 1s - 52ms/step - ia: 0.9038 - loss: 0.0351 - mae: 0.1407 - rmse: 0.1865 - smape: 0.3675 - val_ia: 0.8594 - val_loss: 0.0571 - val_mae: 0.1822 - val_rmse: 0.2323 - val_smape: 0.3968
# Epoch 47/128
# 29/29 - 1s - 51ms/step - ia: 0.9041 - loss: 0.0352 - mae: 0.1400 - rmse: 0.1870 - smape: 0.3630 - val_ia: 0.8553 - val_loss: 0.0570 - val_mae: 0.1858 - val_rmse: 0.2326 - val_smape: 0.4049
# Epoch 48/128
# 29/29 - 1s - 50ms/step - ia: 0.9060 - loss: 0.0341 - mae: 0.1375 - rmse: 0.1842 - smape: 0.3588 - val_ia: 0.8579 - val_loss: 0.0585 - val_mae: 0.1863 - val_rmse: 0.2332 - val_smape: 0.3979
# Epoch 49/128
# 29/29 - 1s - 49ms/step - ia: 0.9068 - loss: 0.0326 - mae: 0.1362 - rmse: 0.1802 - smape: 0.3568 - val_ia: 0.8619 - val_loss: 0.0549 - val_mae: 0.1808 - val_rmse: 0.2271 - val_smape: 0.4062
# Epoch 50/128
# 29/29 - 1s - 49ms/step - ia: 0.9067 - loss: 0.0331 - mae: 0.1364 - rmse: 0.1815 - smape: 0.3593 - val_ia: 0.8602 - val_loss: 0.0560 - val_mae: 0.1828 - val_rmse: 0.2294 - val_smape: 0.4120
# Epoch 51/128
# 29/29 - 1s - 46ms/step - ia: 0.9063 - loss: 0.0332 - mae: 0.1370 - rmse: 0.1817 - smape: 0.3593 - val_ia: 0.8631 - val_loss: 0.0546 - val_mae: 0.1765 - val_rmse: 0.2273 - val_smape: 0.3843
# Epoch 52/128
# 29/29 - 1s - 51ms/step - ia: 0.9065 - loss: 0.0338 - mae: 0.1366 - rmse: 0.1835 - smape: 0.3551 - val_ia: 0.8533 - val_loss: 0.0597 - val_mae: 0.1882 - val_rmse: 0.2357 - val_smape: 0.4011
# Epoch 53/128
# 29/29 - 1s - 47ms/step - ia: 0.9074 - loss: 0.0329 - mae: 0.1354 - rmse: 0.1810 - smape: 0.3529 - val_ia: 0.8544 - val_loss: 0.0585 - val_mae: 0.1863 - val_rmse: 0.2343 - val_smape: 0.3998
# Epoch 54/128
# 29/29 - 1s - 47ms/step - ia: 0.9088 - loss: 0.0314 - mae: 0.1336 - rmse: 0.1768 - smape: 0.3476 - val_ia: 0.8543 - val_loss: 0.0573 - val_mae: 0.1878 - val_rmse: 0.2310 - val_smape: 0.4154
# Epoch 55/128
# 29/29 - 2s - 54ms/step - ia: 0.9090 - loss: 0.0311 - mae: 0.1332 - rmse: 0.1759 - smape: 0.3469 - val_ia: 0.8676 - val_loss: 0.0529 - val_mae: 0.1729 - val_rmse: 0.2214 - val_smape: 0.3852
# Epoch 56/128
# 29/29 - 1s - 48ms/step - ia: 0.9110 - loss: 0.0303 - mae: 0.1305 - rmse: 0.1736 - smape: 0.3426 - val_ia: 0.8649 - val_loss: 0.0565 - val_mae: 0.1793 - val_rmse: 0.2277 - val_smape: 0.3978
# Epoch 57/128
# 29/29 - 2s - 55ms/step - ia: 0.9107 - loss: 0.0305 - mae: 0.1310 - rmse: 0.1743 - smape: 0.3437 - val_ia: 0.8593 - val_loss: 0.0556 - val_mae: 0.1813 - val_rmse: 0.2282 - val_smape: 0.4016
# Epoch 58/128
# 29/29 - 2s - 52ms/step - ia: 0.9114 - loss: 0.0303 - mae: 0.1299 - rmse: 0.1735 - smape: 0.3392 - val_ia: 0.8602 - val_loss: 0.0556 - val_mae: 0.1831 - val_rmse: 0.2266 - val_smape: 0.4113
# Epoch 59/128
# 29/29 - 2s - 52ms/step - ia: 0.9110 - loss: 0.0300 - mae: 0.1304 - rmse: 0.1728 - smape: 0.3398 - val_ia: 0.8535 - val_loss: 0.0599 - val_mae: 0.1906 - val_rmse: 0.2347 - val_smape: 0.4148
# Epoch 60/128
# 29/29 - 2s - 52ms/step - ia: 0.9113 - loss: 0.0296 - mae: 0.1297 - rmse: 0.1718 - smape: 0.3358 - val_ia: 0.8482 - val_loss: 0.0616 - val_mae: 0.1963 - val_rmse: 0.2387 - val_smape: 0.4323
# Epoch 61/128
# 29/29 - 1s - 46ms/step - ia: 0.9116 - loss: 0.0300 - mae: 0.1297 - rmse: 0.1727 - smape: 0.3360 - val_ia: 0.8559 - val_loss: 0.0567 - val_mae: 0.1863 - val_rmse: 0.2286 - val_smape: 0.4052
# Epoch 62/128
# 29/29 - 2s - 52ms/step - ia: 0.9117 - loss: 0.0294 - mae: 0.1292 - rmse: 0.1708 - smape: 0.3373 - val_ia: 0.8556 - val_loss: 0.0581 - val_mae: 0.1882 - val_rmse: 0.2312 - val_smape: 0.4201
# Epoch 63/128
# 29/29 - 1s - 52ms/step - ia: 0.9120 - loss: 0.0297 - mae: 0.1290 - rmse: 0.1716 - smape: 0.3351 - val_ia: 0.8523 - val_loss: 0.0589 - val_mae: 0.1903 - val_rmse: 0.2337 - val_smape: 0.4179
# Epoch 64/128
# 29/29 - 1s - 50ms/step - ia: 0.9127 - loss: 0.0289 - mae: 0.1278 - rmse: 0.1694 - smape: 0.3328 - val_ia: 0.8492 - val_loss: 0.0603 - val_mae: 0.1944 - val_rmse: 0.2374 - val_smape: 0.4373
# Epoch 65/128
# 29/29 - 1s - 48ms/step - ia: 0.9127 - loss: 0.0291 - mae: 0.1281 - rmse: 0.1702 - smape: 0.3317 - val_ia: 0.8549 - val_loss: 0.0562 - val_mae: 0.1839 - val_rmse: 0.2296 - val_smape: 0.4105
# Epoch 66/128
# 29/29 - 1s - 50ms/step - ia: 0.9123 - loss: 0.0290 - mae: 0.1285 - rmse: 0.1698 - smape: 0.3321 - val_ia: 0.8482 - val_loss: 0.0608 - val_mae: 0.1941 - val_rmse: 0.2378 - val_smape: 0.4234
# Epoch 67/128
# 29/29 - 1s - 52ms/step - ia: 0.9135 - loss: 0.0285 - mae: 0.1266 - rmse: 0.1684 - smape: 0.3327 - val_ia: 0.8544 - val_loss: 0.0573 - val_mae: 0.1877 - val_rmse: 0.2313 - val_smape: 0.4254
# Epoch 68/128
# 29/29 - 1s - 49ms/step - ia: 0.9146 - loss: 0.0278 - mae: 0.1253 - rmse: 0.1663 - smape: 0.3261 - val_ia: 0.8498 - val_loss: 0.0612 - val_mae: 0.1940 - val_rmse: 0.2389 - val_smape: 0.4312
# Epoch 69/128
# 29/29 - 1s - 48ms/step - ia: 0.9145 - loss: 0.0277 - mae: 0.1255 - rmse: 0.1658 - smape: 0.3239 - val_ia: 0.8571 - val_loss: 0.0560 - val_mae: 0.1846 - val_rmse: 0.2285 - val_smape: 0.4089
# Epoch 70/128
# 29/29 - 2s - 59ms/step - ia: 0.9149 - loss: 0.0277 - mae: 0.1249 - rmse: 0.1660 - smape: 0.3252 - val_ia: 0.8560 - val_loss: 0.0568 - val_mae: 0.1853 - val_rmse: 0.2303 - val_smape: 0.4130
# Epoch 70: early stopping
# Restoring model weights from the end of the best epoch: 55.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %%
metricasGRU = modelGRU.evaluate(valGRUX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasGRU}")
# Out:
# 163/163 - 1s - 4ms/step - ia: 0.6405 - loss: 0.0501 - mae: 0.1740 - rmse: 0.2071 - smape: 0.3874
# Métricas en el conjunto de validación: [0.05011466518044472, 0.17397595942020416, 0.38738372921943665, 0.20713219046592712, 0.6404716372489929]

# %%
historyGRU = historyGRU.history

ejeXGRU = range(1, len(historyGRU['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXGRU, historyGRU['loss'], label='Train Loss')
plt.plot(ejeXGRU, historyGRU['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyGRU['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyGRU['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.027676913887262344
# Último valor de Test Loss: 0.05680321156978607

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionGRU.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfGRU = df
fig.show()

# %%
dfGRU.to_csv('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\evaluacion\\narmax\\24pasos_gru_consumption.csv', index=True)

# %%
modelGRU.save('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\modelosEntrenadosNarmax\\24pasos_gru_consumption.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
