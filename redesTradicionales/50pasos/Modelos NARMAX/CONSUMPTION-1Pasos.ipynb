# %% [markdown]
# Prueba

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from hyperopt import hp, fmin, tpe, Trials, STATUS_OK
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU, InputLayer, Flatten, LSTM
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import os
from datetime import datetime, timedelta
import plotly.express as px
import plotly.graph_objects as go
import random

# %% [markdown]
# LEER DATASET

# %%
import pandas as pd

datosMLP = pd.read_csv("C:\\Users\\wamt1\\Desktop\\pruebas_collab\\datosNarmax\\1pasos_mlp_consumption.csv")
datosLSTM = pd.read_csv("C:\\Users\\wamt1\\Desktop\\pruebas_collab\\datosNarmax\\1pasos_lstm_consumption.csv")
datosGRU = pd.read_csv("C:\\Users\\wamt1\\Desktop\\pruebas_collab\\datosNarmax\\1pasos_gru_consumption.csv")

datosMLP['date'] = pd.to_datetime(datosMLP['date'])
datosLSTM['date'] = pd.to_datetime(datosLSTM['date'])
datosGRU['date'] = pd.to_datetime(datosGRU['date'])

# Se establece la columna date como index
datosMLP.set_index('date', inplace=True)
datosLSTM.set_index('date', inplace=True)
datosGRU.set_index('date', inplace=True)

# %%
#Se verifica que el index está en formato de dato "datetime64"
print("El index del dataframe MLP input es un tipo de dato: ", datosMLP.index.dtype)
print("El index del dataframe LSTM input es un tipo de dato: ", datosLSTM.index.dtype)
print("El index del dataframe GRU input es un tipo de dato: ", datosGRU.index.dtype)
# Out:
# El index del dataframe MLP input es un tipo de dato:  datetime64[ns]
# El index del dataframe LSTM input es un tipo de dato:  datetime64[ns]
# El index del dataframe GRU input es un tipo de dato:  datetime64[ns]

# %% [markdown]
# Se establece el formato de datos de entrada para redes GRU y LSTM, es decir [observaciones, retardos, caracteristicas]

# %%
futuros = 1
pasados  = 12

# %%
datosMLPX = []
datosMLPY = []
for i in range(pasados, len(datosMLP) - futuros + 1):
  datosMLPX.append(datosMLP.iloc[i-pasados:i, 0:datosMLP.shape[1]])
  datosMLPY.append(datosMLP.iloc[i+futuros-1:i+futuros, 1])

# %%
datosLSTMX = []
datosLSTMY = []
for i in range(pasados, len(datosLSTM) - futuros + 1):
  datosLSTMX.append(datosLSTM.iloc[i-pasados:i, 0:datosLSTM.shape[1]])
  datosLSTMY.append(datosLSTM.iloc[i+futuros-1:i+futuros, 1])

# %%
datosGRUX = []
datosGRUY = []
for i in range(pasados, len(datosGRU) - futuros + 1):
  datosGRUX.append(datosGRU.iloc[i-pasados:i, 0:datosGRU.shape[1]])
  datosGRUY.append(datosGRU.iloc[i+futuros-1:i+futuros, 1])

# %%
# Convertir las listas en arrays numpy
datosMLPX = np.array(datosMLPX)
datosMLPY = np.array(datosMLPY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de MLP X:", datosMLPX.shape)  
print("Dimensiones de MLP Y:", datosMLPY.shape)
# Out:
# Dimensiones de MLP X: (52404, 12, 6)
# Dimensiones de MLP Y: (52404, 1)

# %%
# Convertir las listas en arrays numpy
datosLSTMX = np.array(datosLSTMX)
datosLSTMY = np.array(datosLSTMY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de LSTM X:", datosLSTMX.shape)  
print("Dimensiones de LSTM Y:", datosLSTMY.shape)
# Out:
# Dimensiones de LSTM X: (52404, 12, 6)
# Dimensiones de LSTM Y: (52404, 1)

# %%
# Convertir las listas en arrays numpy
datosGRUX = np.array(datosGRUX)
datosGRUY = np.array(datosGRUY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de GRU X:", datosGRUX.shape)  
print("Dimensiones de GRU Y:", datosGRUY.shape)
# Out:
# Dimensiones de GRU X: (52404, 12, 6)
# Dimensiones de GRU Y: (52404, 1)

# %%
inputs = datosMLPX.shape[1] * datosMLPX.shape[2]
datosMLPX = datosMLPX.reshape(datosMLPX.shape[0], inputs)

# %% [markdown]
# Se dividen nuevamente los conjuntos de datos

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainMLPX, testMLPX = train_test_split(datosMLPX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testMLPX, valMLPX = train_test_split(testMLPX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainMLPX son: ", trainMLPX.shape)
print("Las dimensiones de testMLPX son: ", testMLPX.shape)
print("Las dimensiones de valMLPX son: ", valMLPX.shape)
# Out:
# Las dimensiones de trainMLPX son:  (36682, 72)
# Las dimensiones de testMLPX son:  (10533, 72)
# Las dimensiones de valMLPX son:  (5189, 72)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainLSTMX, testLSTMX = train_test_split(datosLSTMX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testLSTMX, valLSTMX = train_test_split(testLSTMX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainLSTMX son: ", trainLSTMX.shape)
print("Las dimensiones de testLSTMX son: ", testLSTMX.shape)
print("Las dimensiones de valLSTMX son: ", valLSTMX.shape)
# Out:
# Las dimensiones de trainLSTMX son:  (36682, 12, 6)
# Las dimensiones de testLSTMX son:  (10533, 12, 6)
# Las dimensiones de valLSTMX son:  (5189, 12, 6)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainGRUX, testGRUX = train_test_split(datosGRUX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testGRUX, valGRUX = train_test_split(testGRUX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainGRUX son: ", trainGRUX.shape)
print("Las dimensiones de testGRUX son: ", testGRUX.shape)
print("Las dimensiones de valGRUX son: ", valGRUX.shape)
# Out:
# Las dimensiones de trainGRUX son:  (36682, 12, 6)
# Las dimensiones de testGRUX son:  (10533, 12, 6)
# Las dimensiones de valGRUX son:  (5189, 12, 6)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainY, testY = train_test_split(datosMLPY, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testY, valY = train_test_split(testY, test_size=0.33, shuffle=False)

print("Las dimensiones de trainY son: ", trainY.shape)
print("Las dimensiones de testY son: ", testY.shape)
print("Las dimensiones de valY son: ", valY.shape)
# Out:
# Las dimensiones de trainY son:  (36682, 1)
# Las dimensiones de testY son:  (10533, 1)
# Las dimensiones de valY son:  (5189, 1)

# %% [markdown]
# Se crean métricas para medir desempeño

# %%
import tensorflow.keras.backend as K

def smape(y_true, y_pred):
    """
    Define la función SMAPE (Error Porcentual Absoluto Medio Simétrico).
    """
    summ = K.abs(y_true) + K.abs(y_pred)
    smape_val = K.abs(y_pred - y_true) / summ * 2.0
    return K.mean(smape_val, axis=-1)

def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

def ia(y_true, y_pred):
    numerator = K.sum(K.abs(y_true - y_pred))
    denominator = K.sum(K.abs(y_true - K.mean(y_true)) + K.abs(y_pred - K.mean(y_true)))
    return 1 - (numerator / denominator)

# %% [markdown]
# Se define el index del conjunto de validación para utilizarlo posteriormente para graficar.

# %%
# Fecha y hora de término del conjunto de datos de prueba
end_date = datosMLP.index[-1]
n_observations = valY.shape[0]  # Cambia esto al número de observaciones en tu conjunto de prueba

# Calcular la fecha y hora de inicio
start_date = end_date - timedelta(minutes=10 * (n_observations - 1))

# Crear la serie de fechas y horas
val_date = pd.date_range(start=start_date, end=end_date, freq='10T')

val_date
# Out:
# C:\Users\wamt1\AppData\Local\Temp\ipykernel_3936\572609118.py:9: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   val_date = pd.date_range(start=start_date, end=end_date, freq='10T')
# DatetimeIndex(['2017-11-24 23:10:00', '2017-11-24 23:20:00',
#                '2017-11-24 23:30:00', '2017-11-24 23:40:00',
#                '2017-11-24 23:50:00', '2017-11-25 00:00:00',
#                '2017-11-25 00:10:00', '2017-11-25 00:20:00',
#                '2017-11-25 00:30:00', '2017-11-25 00:40:00',
#                ...
#                '2017-12-30 22:20:00', '2017-12-30 22:30:00',
#                '2017-12-30 22:40:00', '2017-12-30 22:50:00',
#                '2017-12-30 23:00:00', '2017-12-30 23:10:00',
#                '2017-12-30 23:20:00', '2017-12-30 23:30:00',
#                '2017-12-30 23:40:00', '2017-12-30 23:50:00'],
#               dtype='datetime64[ns]', length=5189, freq='10min')

# %% [markdown]
# Se guardan los índices de las observaciones a utilizar para predecir

# %%
indices = []
for i in range(pasados, len(datosMLP) - futuros + 1):
  indices.append(datosMLP.index[i+futuros-2])

# %% [markdown]
# # Modelos

# %% [markdown]
# ## MLP

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelMLP = Sequential()
modelMLP.add(InputLayer(input_shape=(testMLPX.shape[1],)))

modelMLP.add(Dense(units=128, activation="relu"))
modelMLP.add(Dropout(0.3))

modelMLP.add(Dense(1))

opt = Adam(learning_rate=0.00027534929346813096)

modelMLP.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelMLP.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         9,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,473 (37.00 KB)
#  Trainable params: 9,473 (37.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyMLP = modelMLP.fit(testMLPX, testY, epochs=32,
                        validation_split=0.3,
                        verbose = 2, batch_size=8, callbacks=[early_stopping])

prediccionMLP = modelMLP.predict(valMLPX)
# Out:
# Epoch 1/32
# 922/922 - 2s - 3ms/step - ia: 0.8077 - loss: 0.1221 - mae: 0.2527 - rmse: 0.3133 - smape: 0.5422 - val_ia: 0.4692 - val_loss: 0.0184 - val_mae: 0.1068 - val_rmse: 0.1209 - val_smape: 0.2771
# Epoch 2/32
# 922/922 - 1s - 1ms/step - ia: 0.8975 - loss: 0.0313 - mae: 0.1347 - rmse: 0.1681 - smape: 0.3247 - val_ia: 0.5373 - val_loss: 0.0107 - val_mae: 0.0762 - val_rmse: 0.0888 - val_smape: 0.1995
# Epoch 3/32
# 922/922 - 1s - 1ms/step - ia: 0.9164 - loss: 0.0220 - mae: 0.1103 - rmse: 0.1407 - smape: 0.2690 - val_ia: 0.5772 - val_loss: 0.0074 - val_mae: 0.0638 - val_rmse: 0.0756 - val_smape: 0.1657
# Epoch 4/32
# 922/922 - 1s - 1ms/step - ia: 0.9234 - loss: 0.0189 - mae: 0.1015 - rmse: 0.1295 - smape: 0.2402 - val_ia: 0.5489 - val_loss: 0.0092 - val_mae: 0.0746 - val_rmse: 0.0853 - val_smape: 0.1700
# Epoch 5/32
# 922/922 - 1s - 1ms/step - ia: 0.9281 - loss: 0.0165 - mae: 0.0952 - rmse: 0.1215 - smape: 0.2282 - val_ia: 0.5838 - val_loss: 0.0076 - val_mae: 0.0659 - val_rmse: 0.0768 - val_smape: 0.1770
# Epoch 6/32
# 922/922 - 1s - 1ms/step - ia: 0.9311 - loss: 0.0157 - mae: 0.0910 - rmse: 0.1179 - smape: 0.2129 - val_ia: 0.6077 - val_loss: 0.0056 - val_mae: 0.0561 - val_rmse: 0.0669 - val_smape: 0.1487
# Epoch 7/32
# 922/922 - 1s - 967us/step - ia: 0.9344 - loss: 0.0143 - mae: 0.0872 - rmse: 0.1124 - smape: 0.2062 - val_ia: 0.6003 - val_loss: 0.0059 - val_mae: 0.0581 - val_rmse: 0.0686 - val_smape: 0.1433
# Epoch 8/32
# 922/922 - 1s - 994us/step - ia: 0.9355 - loss: 0.0137 - mae: 0.0854 - rmse: 0.1106 - smape: 0.1994 - val_ia: 0.6235 - val_loss: 0.0055 - val_mae: 0.0539 - val_rmse: 0.0644 - val_smape: 0.1397
# Epoch 9/32
# 922/922 - 1s - 946us/step - ia: 0.9378 - loss: 0.0126 - mae: 0.0823 - rmse: 0.1061 - smape: 0.1924 - val_ia: 0.6437 - val_loss: 0.0048 - val_mae: 0.0498 - val_rmse: 0.0606 - val_smape: 0.1470
# Epoch 10/32
# 922/922 - 1s - 1ms/step - ia: 0.9373 - loss: 0.0130 - mae: 0.0831 - rmse: 0.1071 - smape: 0.1911 - val_ia: 0.6661 - val_loss: 0.0041 - val_mae: 0.0449 - val_rmse: 0.0554 - val_smape: 0.1330
# Epoch 11/32
# 922/922 - 1s - 958us/step - ia: 0.9393 - loss: 0.0123 - mae: 0.0809 - rmse: 0.1045 - smape: 0.1882 - val_ia: 0.6656 - val_loss: 0.0041 - val_mae: 0.0448 - val_rmse: 0.0552 - val_smape: 0.1267
# Epoch 12/32
# 922/922 - 1s - 986us/step - ia: 0.9394 - loss: 0.0123 - mae: 0.0805 - rmse: 0.1041 - smape: 0.1888 - val_ia: 0.6781 - val_loss: 0.0037 - val_mae: 0.0421 - val_rmse: 0.0526 - val_smape: 0.1215
# Epoch 13/32
# 922/922 - 1s - 1ms/step - ia: 0.9399 - loss: 0.0124 - mae: 0.0802 - rmse: 0.1046 - smape: 0.1834 - val_ia: 0.5846 - val_loss: 0.0069 - val_mae: 0.0642 - val_rmse: 0.0740 - val_smape: 0.1512
# Epoch 14/32
# 922/922 - 1s - 1ms/step - ia: 0.9415 - loss: 0.0116 - mae: 0.0782 - rmse: 0.1014 - smape: 0.1790 - val_ia: 0.6653 - val_loss: 0.0039 - val_mae: 0.0446 - val_rmse: 0.0546 - val_smape: 0.1190
# Epoch 15/32
# 922/922 - 1s - 1ms/step - ia: 0.9406 - loss: 0.0118 - mae: 0.0789 - rmse: 0.1020 - smape: 0.1794 - val_ia: 0.6475 - val_loss: 0.0048 - val_mae: 0.0496 - val_rmse: 0.0594 - val_smape: 0.1544
# Epoch 16/32
# 922/922 - 1s - 935us/step - ia: 0.9420 - loss: 0.0116 - mae: 0.0774 - rmse: 0.1011 - smape: 0.1760 - val_ia: 0.6738 - val_loss: 0.0037 - val_mae: 0.0426 - val_rmse: 0.0524 - val_smape: 0.1280
# Epoch 17/32
# 922/922 - 1s - 983us/step - ia: 0.9440 - loss: 0.0106 - mae: 0.0748 - rmse: 0.0969 - smape: 0.1716 - val_ia: 0.6409 - val_loss: 0.0046 - val_mae: 0.0502 - val_rmse: 0.0601 - val_smape: 0.1331
# Epoch 18/32
# 922/922 - 1s - 1ms/step - ia: 0.9430 - loss: 0.0110 - mae: 0.0760 - rmse: 0.0989 - smape: 0.1730 - val_ia: 0.6195 - val_loss: 0.0050 - val_mae: 0.0526 - val_rmse: 0.0625 - val_smape: 0.1306
# Epoch 19/32
# 922/922 - 1s - 1ms/step - ia: 0.9426 - loss: 0.0112 - mae: 0.0765 - rmse: 0.0995 - smape: 0.1722 - val_ia: 0.6558 - val_loss: 0.0041 - val_mae: 0.0462 - val_rmse: 0.0561 - val_smape: 0.1163
# Epoch 20/32
# 922/922 - 1s - 995us/step - ia: 0.9416 - loss: 0.0116 - mae: 0.0777 - rmse: 0.1008 - smape: 0.1753 - val_ia: 0.6859 - val_loss: 0.0033 - val_mae: 0.0397 - val_rmse: 0.0494 - val_smape: 0.1143
# Epoch 21/32
# 922/922 - 1s - 1ms/step - ia: 0.9436 - loss: 0.0108 - mae: 0.0752 - rmse: 0.0979 - smape: 0.1676 - val_ia: 0.6680 - val_loss: 0.0040 - val_mae: 0.0454 - val_rmse: 0.0552 - val_smape: 0.1385
# Epoch 22/32
# 922/922 - 1s - 1ms/step - ia: 0.9433 - loss: 0.0111 - mae: 0.0757 - rmse: 0.0985 - smape: 0.1726 - val_ia: 0.6982 - val_loss: 0.0031 - val_mae: 0.0381 - val_rmse: 0.0478 - val_smape: 0.1141
# Epoch 23/32
# 922/922 - 1s - 1ms/step - ia: 0.9437 - loss: 0.0108 - mae: 0.0752 - rmse: 0.0976 - smape: 0.1719 - val_ia: 0.6010 - val_loss: 0.0057 - val_mae: 0.0592 - val_rmse: 0.0685 - val_smape: 0.1327
# Epoch 24/32
# 922/922 - 1s - 1ms/step - ia: 0.9428 - loss: 0.0111 - mae: 0.0760 - rmse: 0.0992 - smape: 0.1726 - val_ia: 0.6603 - val_loss: 0.0036 - val_mae: 0.0431 - val_rmse: 0.0526 - val_smape: 0.1194
# Epoch 25/32
# 922/922 - 1s - 1ms/step - ia: 0.9449 - loss: 0.0106 - mae: 0.0736 - rmse: 0.0960 - smape: 0.1674 - val_ia: 0.6754 - val_loss: 0.0037 - val_mae: 0.0430 - val_rmse: 0.0529 - val_smape: 0.1214
# Epoch 26/32
# 922/922 - 1s - 1ms/step - ia: 0.9452 - loss: 0.0103 - mae: 0.0730 - rmse: 0.0947 - smape: 0.1649 - val_ia: 0.6927 - val_loss: 0.0033 - val_mae: 0.0397 - val_rmse: 0.0495 - val_smape: 0.1130
# Epoch 27/32
# 922/922 - 1s - 1ms/step - ia: 0.9446 - loss: 0.0105 - mae: 0.0739 - rmse: 0.0962 - smape: 0.1657 - val_ia: 0.6314 - val_loss: 0.0044 - val_mae: 0.0500 - val_rmse: 0.0594 - val_smape: 0.1301
# Epoch 28/32
# 922/922 - 1s - 1ms/step - ia: 0.9448 - loss: 0.0105 - mae: 0.0738 - rmse: 0.0961 - smape: 0.1662 - val_ia: 0.6818 - val_loss: 0.0035 - val_mae: 0.0414 - val_rmse: 0.0511 - val_smape: 0.1267
# Epoch 29/32
# 922/922 - 1s - 1ms/step - ia: 0.9451 - loss: 0.0103 - mae: 0.0731 - rmse: 0.0953 - smape: 0.1636 - val_ia: 0.6496 - val_loss: 0.0038 - val_mae: 0.0454 - val_rmse: 0.0550 - val_smape: 0.1244
# Epoch 30/32
# 922/922 - 1s - 1ms/step - ia: 0.9450 - loss: 0.0104 - mae: 0.0733 - rmse: 0.0952 - smape: 0.1673 - val_ia: 0.6711 - val_loss: 0.0037 - val_mae: 0.0429 - val_rmse: 0.0523 - val_smape: 0.1139
# Epoch 31/32
# 922/922 - 1s - 1ms/step - ia: 0.9450 - loss: 0.0105 - mae: 0.0735 - rmse: 0.0960 - smape: 0.1658 - val_ia: 0.6178 - val_loss: 0.0048 - val_mae: 0.0521 - val_rmse: 0.0613 - val_smape: 0.1220
# Epoch 32/32
# 922/922 - 1s - 931us/step - ia: 0.9446 - loss: 0.0105 - mae: 0.0740 - rmse: 0.0957 - smape: 0.1647 - val_ia: 0.6848 - val_loss: 0.0033 - val_mae: 0.0399 - val_rmse: 0.0495 - val_smape: 0.1193
# Restoring model weights from the end of the best epoch: 22.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step

# %%
metricasMLP = modelMLP.evaluate(valMLPX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasMLP}")
# Out:
# 163/163 - 0s - 1ms/step - ia: 0.9175 - loss: 0.0021 - mae: 0.0346 - rmse: 0.0445 - smape: 0.1144
# Métricas en el conjunto de validación: [0.0021173825953155756, 0.034554533660411835, 0.11437508463859558, 0.044534485787153244, 0.9174803495407104]

# %%
historyMLP = historyMLP.history

ejeXMLP = range(1, len(historyMLP['loss']) + 1)

plt.figure(figsize=(12, 8))
plt.plot(ejeXMLP, historyMLP['loss'], label='Train Loss')
plt.plot(ejeXMLP, historyMLP['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyMLP['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyMLP['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.010495168156921864
# Último valor de Test Loss: 0.0033342689275741577

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionMLP.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfMLP = df
fig.show()

# %%
dfMLP.to_csv('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\evaluacion\\narmax\\1pasos_mlp_consumption.csv', index=True)

# %%
modelMLP.save('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\modelosEntrenadosNarmax\\1pasos_mlp_consumption.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## LSTM

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelLSTM = Sequential()
modelLSTM.add(InputLayer(input_shape=(testLSTMX.shape[1], testLSTMX.shape[2])))

modelLSTM.add(LSTM(units=128, activation="sigmoid", return_sequences=True))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(LSTM(units=128, activation="sigmoid", return_sequences=False))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(Dense(1))


opt = Adam(learning_rate=0.0004934777489968929)
modelLSTM.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelLSTM.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 12, 128)        │        69,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 200,833 (784.50 KB)
#  Trainable params: 200,833 (784.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyLSTM = modelLSTM.fit(testLSTMX, testY, epochs=256,
                        validation_split=0.3,
                        verbose = 2, batch_size=16, callbacks=[early_stopping])

prediccionLSTM = modelLSTM.predict(valLSTMX)
# Out:
# Epoch 1/256
# 461/461 - 7s - 16ms/step - ia: 0.7416 - loss: 0.1904 - mae: 0.3017 - rmse: 0.3723 - smape: 0.6866 - val_ia: 0.4435 - val_loss: 0.0677 - val_mae: 0.2272 - val_rmse: 0.2393 - val_smape: 0.5436
# Epoch 2/256
# 461/461 - 4s - 8ms/step - ia: 0.9339 - loss: 0.0164 - mae: 0.0925 - rmse: 0.1187 - smape: 0.2594 - val_ia: 0.7004 - val_loss: 0.0076 - val_mae: 0.0694 - val_rmse: 0.0816 - val_smape: 0.1867
# Epoch 3/256
# 461/461 - 4s - 9ms/step - ia: 0.9616 - loss: 0.0057 - mae: 0.0538 - rmse: 0.0713 - smape: 0.1638 - val_ia: 0.7770 - val_loss: 0.0044 - val_mae: 0.0479 - val_rmse: 0.0604 - val_smape: 0.1261
# Epoch 4/256
# 461/461 - 4s - 9ms/step - ia: 0.9630 - loss: 0.0052 - mae: 0.0520 - rmse: 0.0681 - smape: 0.1619 - val_ia: 0.7927 - val_loss: 0.0040 - val_mae: 0.0444 - val_rmse: 0.0565 - val_smape: 0.1188
# Epoch 5/256
# 461/461 - 4s - 8ms/step - ia: 0.9640 - loss: 0.0049 - mae: 0.0506 - rmse: 0.0661 - smape: 0.1590 - val_ia: 0.7984 - val_loss: 0.0038 - val_mae: 0.0431 - val_rmse: 0.0549 - val_smape: 0.1159
# Epoch 6/256
# 461/461 - 4s - 9ms/step - ia: 0.9649 - loss: 0.0047 - mae: 0.0493 - rmse: 0.0643 - smape: 0.1557 - val_ia: 0.8007 - val_loss: 0.0038 - val_mae: 0.0425 - val_rmse: 0.0542 - val_smape: 0.1138
# Epoch 7/256
# 461/461 - 4s - 9ms/step - ia: 0.9658 - loss: 0.0044 - mae: 0.0481 - rmse: 0.0626 - smape: 0.1516 - val_ia: 0.8017 - val_loss: 0.0037 - val_mae: 0.0422 - val_rmse: 0.0538 - val_smape: 0.1119
# Epoch 8/256
# 461/461 - 4s - 9ms/step - ia: 0.9665 - loss: 0.0042 - mae: 0.0470 - rmse: 0.0611 - smape: 0.1483 - val_ia: 0.8019 - val_loss: 0.0037 - val_mae: 0.0420 - val_rmse: 0.0535 - val_smape: 0.1107
# Epoch 9/256
# 461/461 - 4s - 9ms/step - ia: 0.9672 - loss: 0.0040 - mae: 0.0460 - rmse: 0.0598 - smape: 0.1458 - val_ia: 0.8016 - val_loss: 0.0037 - val_mae: 0.0419 - val_rmse: 0.0534 - val_smape: 0.1099
# Epoch 10/256
# 461/461 - 4s - 8ms/step - ia: 0.9678 - loss: 0.0039 - mae: 0.0452 - rmse: 0.0586 - smape: 0.1443 - val_ia: 0.8009 - val_loss: 0.0037 - val_mae: 0.0419 - val_rmse: 0.0534 - val_smape: 0.1092
# Epoch 11/256
# 461/461 - 4s - 9ms/step - ia: 0.9684 - loss: 0.0037 - mae: 0.0444 - rmse: 0.0575 - smape: 0.1427 - val_ia: 0.7995 - val_loss: 0.0037 - val_mae: 0.0421 - val_rmse: 0.0536 - val_smape: 0.1088
# Epoch 12/256
# 461/461 - 4s - 8ms/step - ia: 0.9689 - loss: 0.0036 - mae: 0.0436 - rmse: 0.0565 - smape: 0.1406 - val_ia: 0.7974 - val_loss: 0.0037 - val_mae: 0.0425 - val_rmse: 0.0540 - val_smape: 0.1085
# Epoch 13/256
# 461/461 - 4s - 9ms/step - ia: 0.9694 - loss: 0.0035 - mae: 0.0429 - rmse: 0.0556 - smape: 0.1388 - val_ia: 0.7949 - val_loss: 0.0038 - val_mae: 0.0429 - val_rmse: 0.0544 - val_smape: 0.1088
# Epoch 14/256
# 461/461 - 4s - 9ms/step - ia: 0.9699 - loss: 0.0033 - mae: 0.0422 - rmse: 0.0547 - smape: 0.1372 - val_ia: 0.7923 - val_loss: 0.0038 - val_mae: 0.0434 - val_rmse: 0.0550 - val_smape: 0.1093
# Epoch 15/256
# 461/461 - 4s - 9ms/step - ia: 0.9703 - loss: 0.0032 - mae: 0.0416 - rmse: 0.0539 - smape: 0.1357 - val_ia: 0.7895 - val_loss: 0.0039 - val_mae: 0.0440 - val_rmse: 0.0555 - val_smape: 0.1100
# Epoch 16/256
# 461/461 - 4s - 10ms/step - ia: 0.9707 - loss: 0.0031 - mae: 0.0410 - rmse: 0.0532 - smape: 0.1343 - val_ia: 0.7867 - val_loss: 0.0039 - val_mae: 0.0445 - val_rmse: 0.0562 - val_smape: 0.1110
# Epoch 17/256
# 461/461 - 4s - 10ms/step - ia: 0.9711 - loss: 0.0031 - mae: 0.0405 - rmse: 0.0525 - smape: 0.1331 - val_ia: 0.7838 - val_loss: 0.0040 - val_mae: 0.0452 - val_rmse: 0.0568 - val_smape: 0.1120
# Epoch 18/256
# 461/461 - 4s - 9ms/step - ia: 0.9714 - loss: 0.0030 - mae: 0.0400 - rmse: 0.0518 - smape: 0.1321 - val_ia: 0.7806 - val_loss: 0.0041 - val_mae: 0.0459 - val_rmse: 0.0576 - val_smape: 0.1146
# Epoch 19/256
# 461/461 - 4s - 9ms/step - ia: 0.9717 - loss: 0.0029 - mae: 0.0396 - rmse: 0.0513 - smape: 0.1309 - val_ia: 0.7773 - val_loss: 0.0042 - val_mae: 0.0466 - val_rmse: 0.0583 - val_smape: 0.1170
# Epoch 20/256
# 461/461 - 4s - 8ms/step - ia: 0.9720 - loss: 0.0029 - mae: 0.0392 - rmse: 0.0508 - smape: 0.1300 - val_ia: 0.7736 - val_loss: 0.0043 - val_mae: 0.0475 - val_rmse: 0.0592 - val_smape: 0.1197
# Epoch 21/256
# 461/461 - 4s - 9ms/step - ia: 0.9722 - loss: 0.0028 - mae: 0.0389 - rmse: 0.0503 - smape: 0.1294 - val_ia: 0.7697 - val_loss: 0.0044 - val_mae: 0.0484 - val_rmse: 0.0601 - val_smape: 0.1226
# Epoch 22/256
# 461/461 - 4s - 9ms/step - ia: 0.9725 - loss: 0.0028 - mae: 0.0386 - rmse: 0.0499 - smape: 0.1289 - val_ia: 0.7659 - val_loss: 0.0045 - val_mae: 0.0493 - val_rmse: 0.0610 - val_smape: 0.1253
# Epoch 23/256
# 461/461 - 4s - 9ms/step - ia: 0.9727 - loss: 0.0027 - mae: 0.0383 - rmse: 0.0496 - smape: 0.1282 - val_ia: 0.7627 - val_loss: 0.0046 - val_mae: 0.0501 - val_rmse: 0.0617 - val_smape: 0.1276
# Epoch 24/256
# 461/461 - 4s - 9ms/step - ia: 0.9728 - loss: 0.0027 - mae: 0.0381 - rmse: 0.0493 - smape: 0.1275 - val_ia: 0.7605 - val_loss: 0.0046 - val_mae: 0.0506 - val_rmse: 0.0622 - val_smape: 0.1294
# Epoch 25/256
# 461/461 - 4s - 9ms/step - ia: 0.9730 - loss: 0.0027 - mae: 0.0378 - rmse: 0.0490 - smape: 0.1268 - val_ia: 0.7594 - val_loss: 0.0047 - val_mae: 0.0508 - val_rmse: 0.0624 - val_smape: 0.1305
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
metricasLSTM = modelLSTM.evaluate(valLSTMX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasLSTM}")
# Out:
# 163/163 - 1s - 4ms/step - ia: 0.8948 - loss: 0.0027 - mae: 0.0391 - rmse: 0.0496 - smape: 0.1125
# Métricas en el conjunto de validación: [0.0027050855569541454, 0.03913047909736633, 0.11250718683004379, 0.049606211483478546, 0.894797682762146]

# %%
historyLSTM = historyLSTM.history

ejeXLSTM = range(1, len(historyLSTM['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXLSTM, historyLSTM['loss'], label='Train Loss')
plt.plot(ejeXLSTM, historyLSTM['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyLSTM['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyLSTM['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.00266227126121521
# Último valor de Test Loss: 0.004660783801227808

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionLSTM.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfLSTM = df
fig.show()

# %%
dfLSTM.to_csv('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\evaluacion\\narmax\\1pasos_lstm_consumption.csv', index=True)

# %%
modelLSTM.save('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\modelosEntrenadosNarmax\\1pasos_lstm_consumption.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## GRU

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelGRU = Sequential()
modelGRU.add(InputLayer(input_shape=(testGRUX.shape[1], testGRUX.shape[2])))

modelGRU.add(GRU(units=128, activation="sigmoid", return_sequences=False))
modelGRU.add(Dropout(0.0))

modelGRU.add(Dense(1))


opt = Adam(learning_rate=0.0005454046615408651)
modelGRU.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelGRU.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 128)            │        52,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 52,353 (204.50 KB)
#  Trainable params: 52,353 (204.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)

early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyGRU = modelGRU.fit(testGRUX, testY, epochs=128,
                        validation_split=0.3,
                        verbose = 2, batch_size=32, callbacks=[early_stopping])

prediccionGRU = modelGRU.predict(valGRUX)
# Out:
# Epoch 1/128
# 231/231 - 3s - 14ms/step - ia: 0.7268 - loss: 0.1982 - mae: 0.3180 - rmse: 0.3974 - smape: 0.7136 - val_ia: 0.5732 - val_loss: 0.1009 - val_mae: 0.2667 - val_rmse: 0.2925 - val_smape: 0.6508
# Epoch 2/128
# 231/231 - 1s - 6ms/step - ia: 0.8979 - loss: 0.0360 - mae: 0.1466 - rmse: 0.1863 - smape: 0.4019 - val_ia: 0.6905 - val_loss: 0.0375 - val_mae: 0.1627 - val_rmse: 0.1790 - val_smape: 0.4252
# Epoch 3/128
# 231/231 - 1s - 6ms/step - ia: 0.9382 - loss: 0.0139 - mae: 0.0891 - rmse: 0.1158 - smape: 0.2646 - val_ia: 0.7864 - val_loss: 0.0138 - val_mae: 0.0951 - val_rmse: 0.1100 - val_smape: 0.2653
# Epoch 4/128
# 231/231 - 1s - 5ms/step - ia: 0.9595 - loss: 0.0067 - mae: 0.0588 - rmse: 0.0793 - smape: 0.1759 - val_ia: 0.8113 - val_loss: 0.0101 - val_mae: 0.0800 - val_rmse: 0.0947 - val_smape: 0.2263
# Epoch 5/128
# 231/231 - 1s - 5ms/step - ia: 0.9660 - loss: 0.0050 - mae: 0.0493 - rmse: 0.0682 - smape: 0.1520 - val_ia: 0.8442 - val_loss: 0.0073 - val_mae: 0.0644 - val_rmse: 0.0798 - val_smape: 0.1809
# Epoch 6/128
# 231/231 - 1s - 5ms/step - ia: 0.9681 - loss: 0.0045 - mae: 0.0464 - rmse: 0.0646 - smape: 0.1451 - val_ia: 0.8575 - val_loss: 0.0063 - val_mae: 0.0583 - val_rmse: 0.0738 - val_smape: 0.1603
# Epoch 7/128
# 231/231 - 1s - 6ms/step - ia: 0.9691 - loss: 0.0042 - mae: 0.0449 - rmse: 0.0627 - smape: 0.1420 - val_ia: 0.8631 - val_loss: 0.0058 - val_mae: 0.0557 - val_rmse: 0.0710 - val_smape: 0.1514
# Epoch 8/128
# 231/231 - 1s - 6ms/step - ia: 0.9698 - loss: 0.0040 - mae: 0.0440 - rmse: 0.0613 - smape: 0.1397 - val_ia: 0.8703 - val_loss: 0.0053 - val_mae: 0.0525 - val_rmse: 0.0677 - val_smape: 0.1423
# Epoch 9/128
# 231/231 - 1s - 6ms/step - ia: 0.9703 - loss: 0.0039 - mae: 0.0432 - rmse: 0.0602 - smape: 0.1375 - val_ia: 0.8767 - val_loss: 0.0049 - val_mae: 0.0497 - val_rmse: 0.0647 - val_smape: 0.1356
# Epoch 10/128
# 231/231 - 1s - 5ms/step - ia: 0.9708 - loss: 0.0038 - mae: 0.0425 - rmse: 0.0592 - smape: 0.1349 - val_ia: 0.8818 - val_loss: 0.0046 - val_mae: 0.0474 - val_rmse: 0.0624 - val_smape: 0.1301
# Epoch 11/128
# 231/231 - 1s - 5ms/step - ia: 0.9712 - loss: 0.0037 - mae: 0.0419 - rmse: 0.0583 - smape: 0.1333 - val_ia: 0.8854 - val_loss: 0.0043 - val_mae: 0.0458 - val_rmse: 0.0606 - val_smape: 0.1263
# Epoch 12/128
# 231/231 - 1s - 6ms/step - ia: 0.9716 - loss: 0.0036 - mae: 0.0413 - rmse: 0.0575 - smape: 0.1319 - val_ia: 0.8878 - val_loss: 0.0042 - val_mae: 0.0446 - val_rmse: 0.0594 - val_smape: 0.1234
# Epoch 13/128
# 231/231 - 1s - 6ms/step - ia: 0.9719 - loss: 0.0035 - mae: 0.0408 - rmse: 0.0567 - smape: 0.1307 - val_ia: 0.8893 - val_loss: 0.0040 - val_mae: 0.0438 - val_rmse: 0.0585 - val_smape: 0.1209
# Epoch 14/128
# 231/231 - 1s - 6ms/step - ia: 0.9722 - loss: 0.0034 - mae: 0.0404 - rmse: 0.0561 - smape: 0.1294 - val_ia: 0.8901 - val_loss: 0.0039 - val_mae: 0.0433 - val_rmse: 0.0579 - val_smape: 0.1190
# Epoch 15/128
# 231/231 - 1s - 6ms/step - ia: 0.9725 - loss: 0.0033 - mae: 0.0400 - rmse: 0.0555 - smape: 0.1284 - val_ia: 0.8904 - val_loss: 0.0039 - val_mae: 0.0430 - val_rmse: 0.0575 - val_smape: 0.1182
# Epoch 16/128
# 231/231 - 1s - 6ms/step - ia: 0.9728 - loss: 0.0032 - mae: 0.0396 - rmse: 0.0549 - smape: 0.1275 - val_ia: 0.8904 - val_loss: 0.0038 - val_mae: 0.0428 - val_rmse: 0.0572 - val_smape: 0.1175
# Epoch 17/128
# 231/231 - 1s - 6ms/step - ia: 0.9730 - loss: 0.0032 - mae: 0.0393 - rmse: 0.0544 - smape: 0.1267 - val_ia: 0.8901 - val_loss: 0.0038 - val_mae: 0.0427 - val_rmse: 0.0570 - val_smape: 0.1169
# Epoch 18/128
# 231/231 - 1s - 6ms/step - ia: 0.9732 - loss: 0.0031 - mae: 0.0390 - rmse: 0.0540 - smape: 0.1259 - val_ia: 0.8897 - val_loss: 0.0038 - val_mae: 0.0427 - val_rmse: 0.0570 - val_smape: 0.1165
# Epoch 19/128
# 231/231 - 1s - 6ms/step - ia: 0.9733 - loss: 0.0031 - mae: 0.0388 - rmse: 0.0536 - smape: 0.1252 - val_ia: 0.8892 - val_loss: 0.0038 - val_mae: 0.0427 - val_rmse: 0.0569 - val_smape: 0.1163
# Epoch 20/128
# 231/231 - 1s - 5ms/step - ia: 0.9735 - loss: 0.0030 - mae: 0.0385 - rmse: 0.0532 - smape: 0.1247 - val_ia: 0.8889 - val_loss: 0.0038 - val_mae: 0.0427 - val_rmse: 0.0568 - val_smape: 0.1160
# Epoch 21/128
# 231/231 - 1s - 5ms/step - ia: 0.9736 - loss: 0.0030 - mae: 0.0383 - rmse: 0.0528 - smape: 0.1241 - val_ia: 0.8887 - val_loss: 0.0037 - val_mae: 0.0427 - val_rmse: 0.0567 - val_smape: 0.1158
# Epoch 22/128
# 231/231 - 1s - 6ms/step - ia: 0.9738 - loss: 0.0030 - mae: 0.0381 - rmse: 0.0525 - smape: 0.1235 - val_ia: 0.8888 - val_loss: 0.0037 - val_mae: 0.0425 - val_rmse: 0.0564 - val_smape: 0.1153
# Epoch 23/128
# 231/231 - 1s - 6ms/step - ia: 0.9739 - loss: 0.0029 - mae: 0.0379 - rmse: 0.0521 - smape: 0.1230 - val_ia: 0.8891 - val_loss: 0.0037 - val_mae: 0.0423 - val_rmse: 0.0562 - val_smape: 0.1150
# Epoch 24/128
# 231/231 - 1s - 5ms/step - ia: 0.9741 - loss: 0.0029 - mae: 0.0377 - rmse: 0.0518 - smape: 0.1226 - val_ia: 0.8896 - val_loss: 0.0036 - val_mae: 0.0421 - val_rmse: 0.0559 - val_smape: 0.1144
# Epoch 25/128
# 231/231 - 1s - 6ms/step - ia: 0.9742 - loss: 0.0028 - mae: 0.0375 - rmse: 0.0514 - smape: 0.1222 - val_ia: 0.8903 - val_loss: 0.0036 - val_mae: 0.0418 - val_rmse: 0.0555 - val_smape: 0.1139
# Epoch 26/128
# 231/231 - 1s - 6ms/step - ia: 0.9743 - loss: 0.0028 - mae: 0.0373 - rmse: 0.0511 - smape: 0.1218 - val_ia: 0.8910 - val_loss: 0.0035 - val_mae: 0.0415 - val_rmse: 0.0552 - val_smape: 0.1139
# Epoch 27/128
# 231/231 - 1s - 6ms/step - ia: 0.9745 - loss: 0.0028 - mae: 0.0371 - rmse: 0.0508 - smape: 0.1213 - val_ia: 0.8919 - val_loss: 0.0035 - val_mae: 0.0412 - val_rmse: 0.0548 - val_smape: 0.1140
# Epoch 28/128
# 231/231 - 1s - 6ms/step - ia: 0.9746 - loss: 0.0027 - mae: 0.0369 - rmse: 0.0505 - smape: 0.1213 - val_ia: 0.8928 - val_loss: 0.0034 - val_mae: 0.0408 - val_rmse: 0.0544 - val_smape: 0.1141
# Epoch 29/128
# 231/231 - 1s - 6ms/step - ia: 0.9747 - loss: 0.0027 - mae: 0.0367 - rmse: 0.0503 - smape: 0.1209 - val_ia: 0.8938 - val_loss: 0.0034 - val_mae: 0.0405 - val_rmse: 0.0540 - val_smape: 0.1142
# Epoch 30/128
# 231/231 - 1s - 6ms/step - ia: 0.9748 - loss: 0.0027 - mae: 0.0366 - rmse: 0.0500 - smape: 0.1206 - val_ia: 0.8948 - val_loss: 0.0034 - val_mae: 0.0401 - val_rmse: 0.0536 - val_smape: 0.1143
# Epoch 31/128
# 231/231 - 1s - 6ms/step - ia: 0.9750 - loss: 0.0026 - mae: 0.0364 - rmse: 0.0497 - smape: 0.1203 - val_ia: 0.8957 - val_loss: 0.0033 - val_mae: 0.0398 - val_rmse: 0.0533 - val_smape: 0.1143
# Epoch 32/128
# 231/231 - 1s - 6ms/step - ia: 0.9751 - loss: 0.0026 - mae: 0.0362 - rmse: 0.0495 - smape: 0.1199 - val_ia: 0.8965 - val_loss: 0.0033 - val_mae: 0.0395 - val_rmse: 0.0529 - val_smape: 0.1142
# Epoch 33/128
# 231/231 - 1s - 6ms/step - ia: 0.9752 - loss: 0.0026 - mae: 0.0360 - rmse: 0.0492 - smape: 0.1196 - val_ia: 0.8973 - val_loss: 0.0032 - val_mae: 0.0393 - val_rmse: 0.0527 - val_smape: 0.1143
# Epoch 34/128
# 231/231 - 1s - 6ms/step - ia: 0.9753 - loss: 0.0026 - mae: 0.0359 - rmse: 0.0490 - smape: 0.1192 - val_ia: 0.8981 - val_loss: 0.0032 - val_mae: 0.0390 - val_rmse: 0.0523 - val_smape: 0.1141
# Epoch 35/128
# 231/231 - 1s - 6ms/step - ia: 0.9754 - loss: 0.0025 - mae: 0.0357 - rmse: 0.0487 - smape: 0.1189 - val_ia: 0.8986 - val_loss: 0.0032 - val_mae: 0.0388 - val_rmse: 0.0521 - val_smape: 0.1141
# Epoch 36/128
# 231/231 - 1s - 6ms/step - ia: 0.9755 - loss: 0.0025 - mae: 0.0356 - rmse: 0.0485 - smape: 0.1185 - val_ia: 0.8990 - val_loss: 0.0032 - val_mae: 0.0387 - val_rmse: 0.0520 - val_smape: 0.1153
# Epoch 37/128
# 231/231 - 1s - 6ms/step - ia: 0.9756 - loss: 0.0025 - mae: 0.0354 - rmse: 0.0483 - smape: 0.1182 - val_ia: 0.8993 - val_loss: 0.0032 - val_mae: 0.0386 - val_rmse: 0.0519 - val_smape: 0.1159
# Epoch 38/128
# 231/231 - 1s - 6ms/step - ia: 0.9757 - loss: 0.0025 - mae: 0.0353 - rmse: 0.0481 - smape: 0.1179 - val_ia: 0.8995 - val_loss: 0.0031 - val_mae: 0.0385 - val_rmse: 0.0518 - val_smape: 0.1166
# Epoch 39/128
# 231/231 - 1s - 6ms/step - ia: 0.9758 - loss: 0.0025 - mae: 0.0352 - rmse: 0.0479 - smape: 0.1176 - val_ia: 0.8996 - val_loss: 0.0031 - val_mae: 0.0385 - val_rmse: 0.0518 - val_smape: 0.1175
# Epoch 40/128
# 231/231 - 1s - 6ms/step - ia: 0.9759 - loss: 0.0024 - mae: 0.0350 - rmse: 0.0477 - smape: 0.1173 - val_ia: 0.8995 - val_loss: 0.0031 - val_mae: 0.0385 - val_rmse: 0.0518 - val_smape: 0.1184
# Epoch 41/128
# 231/231 - 1s - 6ms/step - ia: 0.9760 - loss: 0.0024 - mae: 0.0349 - rmse: 0.0475 - smape: 0.1171 - val_ia: 0.8993 - val_loss: 0.0031 - val_mae: 0.0386 - val_rmse: 0.0518 - val_smape: 0.1195
# Epoch 42/128
# 231/231 - 1s - 6ms/step - ia: 0.9760 - loss: 0.0024 - mae: 0.0348 - rmse: 0.0474 - smape: 0.1168 - val_ia: 0.8991 - val_loss: 0.0032 - val_mae: 0.0387 - val_rmse: 0.0519 - val_smape: 0.1205
# Epoch 43/128
# 231/231 - 1s - 6ms/step - ia: 0.9761 - loss: 0.0024 - mae: 0.0347 - rmse: 0.0472 - smape: 0.1166 - val_ia: 0.8988 - val_loss: 0.0032 - val_mae: 0.0388 - val_rmse: 0.0520 - val_smape: 0.1216
# Epoch 44/128
# 231/231 - 1s - 6ms/step - ia: 0.9762 - loss: 0.0024 - mae: 0.0346 - rmse: 0.0470 - smape: 0.1163 - val_ia: 0.8985 - val_loss: 0.0032 - val_mae: 0.0389 - val_rmse: 0.0521 - val_smape: 0.1228
# Epoch 45/128
# 231/231 - 1s - 6ms/step - ia: 0.9763 - loss: 0.0024 - mae: 0.0345 - rmse: 0.0469 - smape: 0.1161 - val_ia: 0.8980 - val_loss: 0.0032 - val_mae: 0.0390 - val_rmse: 0.0522 - val_smape: 0.1241
# Epoch 46/128
# 231/231 - 1s - 6ms/step - ia: 0.9763 - loss: 0.0023 - mae: 0.0344 - rmse: 0.0467 - smape: 0.1160 - val_ia: 0.8975 - val_loss: 0.0032 - val_mae: 0.0392 - val_rmse: 0.0524 - val_smape: 0.1252
# Epoch 47/128
# 231/231 - 1s - 6ms/step - ia: 0.9764 - loss: 0.0023 - mae: 0.0343 - rmse: 0.0466 - smape: 0.1158 - val_ia: 0.8971 - val_loss: 0.0032 - val_mae: 0.0394 - val_rmse: 0.0525 - val_smape: 0.1264
# Epoch 48/128
# 231/231 - 2s - 7ms/step - ia: 0.9765 - loss: 0.0023 - mae: 0.0342 - rmse: 0.0464 - smape: 0.1156 - val_ia: 0.8967 - val_loss: 0.0032 - val_mae: 0.0396 - val_rmse: 0.0527 - val_smape: 0.1274
# Epoch 49/128
# 231/231 - 2s - 7ms/step - ia: 0.9765 - loss: 0.0023 - mae: 0.0341 - rmse: 0.0463 - smape: 0.1154 - val_ia: 0.8962 - val_loss: 0.0033 - val_mae: 0.0398 - val_rmse: 0.0529 - val_smape: 0.1283
# Epoch 50/128
# 231/231 - 1s - 6ms/step - ia: 0.9766 - loss: 0.0023 - mae: 0.0340 - rmse: 0.0462 - smape: 0.1152 - val_ia: 0.8958 - val_loss: 0.0033 - val_mae: 0.0399 - val_rmse: 0.0530 - val_smape: 0.1291
# Epoch 51/128
# 231/231 - 1s - 6ms/step - ia: 0.9767 - loss: 0.0023 - mae: 0.0339 - rmse: 0.0461 - smape: 0.1150 - val_ia: 0.8953 - val_loss: 0.0033 - val_mae: 0.0401 - val_rmse: 0.0532 - val_smape: 0.1299
# Epoch 52/128
# 231/231 - 1s - 6ms/step - ia: 0.9767 - loss: 0.0023 - mae: 0.0338 - rmse: 0.0459 - smape: 0.1148 - val_ia: 0.8951 - val_loss: 0.0033 - val_mae: 0.0402 - val_rmse: 0.0533 - val_smape: 0.1307
# Epoch 53/128
# 231/231 - 1s - 6ms/step - ia: 0.9768 - loss: 0.0023 - mae: 0.0337 - rmse: 0.0458 - smape: 0.1146 - val_ia: 0.8946 - val_loss: 0.0033 - val_mae: 0.0404 - val_rmse: 0.0534 - val_smape: 0.1315
# Epoch 54/128
# 231/231 - 1s - 6ms/step - ia: 0.9768 - loss: 0.0022 - mae: 0.0336 - rmse: 0.0457 - smape: 0.1144 - val_ia: 0.8942 - val_loss: 0.0033 - val_mae: 0.0406 - val_rmse: 0.0536 - val_smape: 0.1323
# Epoch 54: early stopping
# Restoring model weights from the end of the best epoch: 39.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
metricasGRU = modelGRU.evaluate(valGRUX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasGRU}")
# Out:
# 163/163 - 0s - 2ms/step - ia: 0.9063 - loss: 0.0022 - mae: 0.0356 - rmse: 0.0448 - smape: 0.1172
# Métricas en el conjunto de validación: [0.0021714530885219574, 0.03557155653834343, 0.11717312783002853, 0.04481470584869385, 0.9062603712081909]

# %%
historyGRU = historyGRU.history

ejeXGRU = range(1, len(historyGRU['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXGRU, historyGRU['loss'], label='Train Loss')
plt.plot(ejeXGRU, historyGRU['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyGRU['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyGRU['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.002239815890789032
# Último valor de Test Loss: 0.0033447756431996822

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionGRU.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfGRU = df
fig.show()

# %%
dfGRU.to_csv('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\evaluacion\\narmax\\1pasos_gru_consumption.csv', index=True)

# %%
modelGRU.save('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\modelosEntrenadosNarmax\\1pasos_gru_consumption.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
