# %% [markdown]
# Prueba

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from hyperopt import hp, fmin, tpe, Trials, STATUS_OK
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU, InputLayer, Flatten, LSTM
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import os
from datetime import datetime, timedelta
import plotly.express as px
import plotly.graph_objects as go
import random

# %% [markdown]
# LEER DATASET

# %%
import pandas as pd

datos = pd.read_csv("C:\\Users\\wamt1\\Desktop\\pruebas_collab\\SNpollutionFinal.csv")

datos['date'] = pd.to_datetime(datos['date'])

# Se establece la columna date como index
datos.set_index('date', inplace=True)

# %%
datos.head()
# Out:
#                      pollution  dew  temp   press  wnd_dir  wnd_spd
# date
# 2010-01-01 00:00:00      129.0  -21 -11.0  1021.0        2     1.79
# 2010-01-01 01:00:00      129.0  -21 -12.0  1020.0        2     4.92
# 2010-01-01 02:00:00      129.0  -21 -11.0  1019.0        2     6.71
# 2010-01-01 03:00:00      129.0  -21 -14.0  1019.0        2     9.84
# 2010-01-01 04:00:00      129.0  -20 -12.0  1018.0        2    12.97

# %%
datos = datos.drop(datos.index[:24])

datos
# Out:
#                      pollution  dew  temp   press  wnd_dir  wnd_spd
# date
# 2010-01-02 00:00:00      129.0  -16  -4.0  1020.0        1     1.79
# 2010-01-02 01:00:00      148.0  -15  -4.0  1020.0        1     2.68
# 2010-01-02 02:00:00      159.0  -11  -5.0  1021.0        1     3.57
# 2010-01-02 03:00:00      181.0   -7  -5.0  1022.0        1     5.36
# 2010-01-02 04:00:00      138.0   -7  -5.0  1022.0        1     6.25
# ...                        ...  ...   ...     ...      ...      ...
# 2014-12-31 19:00:00        8.0  -23  -2.0  1034.0        2   231.97
# 2014-12-31 20:00:00       10.0  -22  -3.0  1034.0        2   237.78
# 2014-12-31 21:00:00       10.0  -22  -3.0  1034.0        2   242.70
# 2014-12-31 22:00:00        8.0  -22  -4.0  1034.0        2   246.72
# 2014-12-31 23:00:00       12.0  -21  -3.0  1034.0        2   249.85
#
# [43800 rows x 6 columns]

# %%
#Se verifica que el index está en formato de dato "datetime64"
print("El index del dataframe input es un tipo de dato: ", datos.index.dtype)
# Out:
# El index del dataframe input es un tipo de dato:  datetime64[ns]

# %% [markdown]
# Se divide el dataset

# %%
# Dividir el conjunto de datos en entrenamiento y prueba
train, test = train_test_split(datos, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
test, val = train_test_split(test, test_size=0.33, shuffle=False)

print("Las dimensiones de train son: ", train.shape)
print("Las dimensiones de test son: ", test.shape)
print("Las dimensiones de val son: ", val.shape)
# Out:
# Las dimensiones de train son:  (30660, 6)
# Las dimensiones de test son:  (8803, 6)
# Las dimensiones de val son:  (4337, 6)

# %% [markdown]
# Se normalizan los datos

# %%
from sklearn.preprocessing import StandardScaler


# Normalizar solo con los datos de entrenamiento
scaler = StandardScaler()
train = scaler.fit_transform(train)

# Aplicar la transformación a test y val usando los parámetros de train
test = scaler.transform(test)
val = scaler.transform(val)

train = pd.DataFrame(train, columns=datos.columns)
test = pd.DataFrame(test, columns=datos.columns)
val = pd.DataFrame(val, columns=datos.columns)

# %% [markdown]
# Se unen los datos nuevamente, ahora normalizados, en un único conjunto.

# %%
datosNormalizados = pd.concat([train, test, val])

datosNormalizados.index = datos.index

# %%
datosNormalizados.shape
# Out:
# (43800, 6)

# %%
datosNormalizados.head(13)
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 00:00:00   0.317681 -1.214023 -1.268524  0.329687 -0.380944
# 2010-01-02 01:00:00   0.526152 -1.144302 -1.268524  0.329687 -0.380944
# 2010-01-02 02:00:00   0.646846 -0.865419 -1.349314  0.426127 -0.380944
# 2010-01-02 03:00:00   0.888234 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 04:00:00   0.416431 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 05:00:00   0.098238 -0.586536 -1.430104  0.522567 -0.380944
# 2010-01-02 06:00:00   0.054349 -0.586536 -1.430104  0.619008 -0.380944
# 2010-01-02 07:00:00   0.262820 -0.586536 -1.349314  0.715448 -0.380944
# 2010-01-02 08:00:00   0.218931 -0.656257 -1.430104  0.715448 -0.380944
# 2010-01-02 09:00:00   0.350598 -0.586536 -1.349314  0.811888 -0.380944
# 2010-01-02 10:00:00   0.438375 -0.586536 -1.349314  0.908328 -0.380944
# 2010-01-02 11:00:00   0.570041 -0.656257 -1.349314  0.908328 -0.380944
# 2010-01-02 12:00:00   0.526152 -0.656257 -1.349314  0.908328 -0.380944
#
#                       wnd_spd
# date
# 2010-01-02 00:00:00 -0.464048
# 2010-01-02 01:00:00 -0.446575
# 2010-01-02 02:00:00 -0.429103
# 2010-01-02 03:00:00 -0.393962
# 2010-01-02 04:00:00 -0.376489
# 2010-01-02 05:00:00 -0.359017
# 2010-01-02 06:00:00 -0.323876
# 2010-01-02 07:00:00 -0.288735
# 2010-01-02 08:00:00 -0.253594
# 2010-01-02 09:00:00 -0.218452
# 2010-01-02 10:00:00 -0.157004
# 2010-01-02 11:00:00 -0.095557
# 2010-01-02 12:00:00 -0.034109

# %% [markdown]
# Se establece el formato de datos de entrada para redes GRU y LSTM, es decir [observaciones, retardos, caracteristicas]

# %%
futuros = 24
pasados  = 48

# %%
datosX = []
datosY = []
for i in range(pasados, len(datosNormalizados) - futuros + 1):
  datosX.append(datosNormalizados.iloc[i-pasados:i, 0:datosNormalizados.shape[1]])
  datosY.append(datosNormalizados.iloc[i+futuros-1:i+futuros, 0])

# %%
# Convertir las listas en arrays numpy
datosX = np.array(datosX)
datosY = np.array(datosY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de X:", datosX.shape)  # (n_muestras, pasos_de_tiempo, n_características)
print("Dimensiones de Y:", datosY.shape)  # (n_muestras, n_características)
# Out:
# Dimensiones de X: (43729, 48, 6)
# Dimensiones de Y: (43729, 1)

# %%
inputs = datosX.shape[1] * datosX.shape[2]
datosMLPX = datosX.reshape(datosX.shape[0], inputs)

# %%
print(datosX[0])
print(datosMLPX[0])
# Out:
# [[ 0.31768099 -1.2140229  -1.26852411  0.32968671 -0.38094383 -0.46404777]
#  [ 0.52615226 -1.14430217 -1.26852411  0.32968671 -0.38094383 -0.44657536]
#  [ 0.64684616 -0.86541928 -1.34931411  0.42612698 -0.38094383 -0.42910295]
#  [ 0.88823396 -0.58653639 -1.34931411  0.52256725 -0.38094383 -0.39396181]
#  [ 0.41643054 -0.58653639 -1.34931411  0.52256725 -0.38094383 -0.3764894 ]
#  [ 0.09823754 -0.58653639 -1.4301041   0.52256725 -0.38094383 -0.35901698]
#  [ 0.05434885 -0.58653639 -1.4301041   0.61900753 -0.38094383 -0.32387584]
#  [ 0.26282012 -0.58653639 -1.34931411  0.7154478  -0.38094383 -0.2887347 ]
#  [ 0.21893143 -0.65625711 -1.4301041   0.7154478  -0.38094383 -0.25359356]
#  [ 0.3505975  -0.58653639 -1.34931411  0.81188808 -0.38094383 -0.21845241]
#  [ 0.43837488 -0.58653639 -1.34931411  0.90832835 -0.38094383 -0.15700449]
#  [ 0.57004095 -0.65625711 -1.34931411  0.90832835 -0.38094383 -0.09555657]
#  [ 0.52615226 -0.65625711 -1.34931411  0.90832835 -0.38094383 -0.03410865]
#  [ 0.70170703 -0.65625711 -1.34931411  0.81188808 -0.38094383  0.04481168]
#  [ 0.63587399 -0.72597783 -1.34931411  0.81188808 -0.38094383  0.12373201]
#  [ 0.5919853  -0.72597783 -1.34931411  0.81188808 -0.38094383  0.20265234]
#  [ 0.64684616 -0.72597783 -1.34931411  0.90832835 -0.38094383  0.23779348]
#  [ 0.70170703 -0.65625711 -1.34931411  1.00476862 -0.38094383  0.27293462]
#  [ 0.76754006 -0.65625711 -1.34931411  1.00476862 -0.38094383  0.33438254]
#  [ 0.53712444 -0.65625711 -1.34931411  1.1012089  -0.38094383  0.36952369]
#  [ 0.5919853  -0.58653639 -1.34931411  1.1012089  -0.38094383  0.40466483]
#  [ 0.70170703 -0.58653639 -1.34931411  1.00476862 -0.38094383  0.46611275]
#  [ 0.61392965 -0.65625711 -1.4301041   1.1012089  -0.38094383  0.52756067]
#  [ 0.28476447 -0.65625711 -1.4301041   1.00476862 -0.38094383  0.58900859]
#  [-0.11023374 -0.58653639 -1.4301041   1.00476862 -0.38094383  0.65045651]
#  [-0.4064824  -0.65625711 -1.4301041   0.90832835 -0.38094383  0.71190443]
#  [-0.38453806 -0.65625711 -1.5108941   0.90832835 -0.38094383  0.79082476]
#  [-0.49425978 -0.65625711 -1.5108941   0.81188808 -0.38094383  0.85227268]
#  [-0.38453806 -0.65625711 -1.5108941   0.7154478  -0.38094383  0.93119301]
#  [-0.18703895 -0.72597783 -1.59168409  0.7154478  -0.38094383  1.01011334]
#  [-0.09926157 -0.79569856 -1.59168409  0.7154478  -0.38094383  1.08903367]
#  [-0.15412243 -0.79569856 -1.67247408  0.7154478  -0.38094383  1.167954  ]
#  [-0.19801112 -0.79569856 -1.67247408  0.7154478  -0.38094383  1.26454307]
#  [-0.15412243 -0.86541928 -1.67247408  0.61900753 -0.38094383  1.3434634 ]
#  [-0.24189981 -0.86541928 -1.67247408  0.61900753 -0.38094383  1.42238373]
#  [-0.02245636 -0.86541928 -1.67247408  0.52256725 -0.38094383  1.51897279]
#  [ 0.07629319 -0.86541928 -1.67247408  0.42612698 -0.38094383  1.58042071]
#  [-0.11023374 -0.86541928 -1.67247408  0.32968671 -0.38094383  1.69448219]
#  [-0.04440071 -0.86541928 -1.67247408  0.32968671 -0.38094383  1.79107125]
#  [-0.05537288 -0.86541928 -1.67247408  0.32968671 -0.38094383  1.88766031]
#  [-0.15412243 -0.86541928 -1.67247408  0.32968671 -0.38094383  1.94910823]
#  [-0.32967719 -0.86541928 -1.67247408  0.32968671 -0.38094383  2.01055615]
#  [-0.42842675 -0.86541928 -1.67247408  0.42612698 -1.45642614 -0.4817165 ]
#  [-0.51620413 -0.86541928 -1.67247408  0.52256725 -1.45642614 -0.46424409]
#  [-0.31870502 -0.79569856 -1.67247408  0.52256725  0.69453847 -0.42026858]
#  [-0.30773285 -0.86541928 -1.75326408  0.61900753  0.69453847 -0.35882066]
#  [-0.26384416 -0.86541928 -1.67247408  0.61900753  0.69453847 -0.27990033]
#  [-0.29676068 -0.93514    -1.83405407  0.61900753  0.69453847 -0.21845241]]
# [ 0.31768099 -1.2140229  -1.26852411  0.32968671 -0.38094383 -0.46404777
#   0.52615226 -1.14430217 -1.26852411  0.32968671 -0.38094383 -0.44657536
#   0.64684616 -0.86541928 -1.34931411  0.42612698 -0.38094383 -0.42910295
#   0.88823396 -0.58653639 -1.34931411  0.52256725 -0.38094383 -0.39396181
#   0.41643054 -0.58653639 -1.34931411  0.52256725 -0.38094383 -0.3764894
#   0.09823754 -0.58653639 -1.4301041   0.52256725 -0.38094383 -0.35901698
#   0.05434885 -0.58653639 -1.4301041   0.61900753 -0.38094383 -0.32387584
#   0.26282012 -0.58653639 -1.34931411  0.7154478  -0.38094383 -0.2887347
#   0.21893143 -0.65625711 -1.4301041   0.7154478  -0.38094383 -0.25359356
#   0.3505975  -0.58653639 -1.34931411  0.81188808 -0.38094383 -0.21845241
#   0.43837488 -0.58653639 -1.34931411  0.90832835 -0.38094383 -0.15700449
#   0.57004095 -0.65625711 -1.34931411  0.90832835 -0.38094383 -0.09555657
#   0.52615226 -0.65625711 -1.34931411  0.90832835 -0.38094383 -0.03410865
#   0.70170703 -0.65625711 -1.34931411  0.81188808 -0.38094383  0.04481168
#   0.63587399 -0.72597783 -1.34931411  0.81188808 -0.38094383  0.12373201
#   0.5919853  -0.72597783 -1.34931411  0.81188808 -0.38094383  0.20265234
#   0.64684616 -0.72597783 -1.34931411  0.90832835 -0.38094383  0.23779348
#   0.70170703 -0.65625711 -1.34931411  1.00476862 -0.38094383  0.27293462
#   0.76754006 -0.65625711 -1.34931411  1.00476862 -0.38094383  0.33438254
#   0.53712444 -0.65625711 -1.34931411  1.1012089  -0.38094383  0.36952369
#   0.5919853  -0.58653639 -1.34931411  1.1012089  -0.38094383  0.40466483
#   0.70170703 -0.58653639 -1.34931411  1.00476862 -0.38094383  0.46611275
#   0.61392965 -0.65625711 -1.4301041   1.1012089  -0.38094383  0.52756067
#   0.28476447 -0.65625711 -1.4301041   1.00476862 -0.38094383  0.58900859
#  -0.11023374 -0.58653639 -1.4301041   1.00476862 -0.38094383  0.65045651
#  -0.4064824  -0.65625711 -1.4301041   0.90832835 -0.38094383  0.71190443
#  -0.38453806 -0.65625711 -1.5108941   0.90832835 -0.38094383  0.79082476
#  -0.49425978 -0.65625711 -1.5108941   0.81188808 -0.38094383  0.85227268
#  -0.38453806 -0.65625711 -1.5108941   0.7154478  -0.38094383  0.93119301
#  -0.18703895 -0.72597783 -1.59168409  0.7154478  -0.38094383  1.01011334
#  -0.09926157 -0.79569856 -1.59168409  0.7154478  -0.38094383  1.08903367
#  -0.15412243 -0.79569856 -1.67247408  0.7154478  -0.38094383  1.167954
#  -0.19801112 -0.79569856 -1.67247408  0.7154478  -0.38094383  1.26454307
#  -0.15412243 -0.86541928 -1.67247408  0.61900753 -0.38094383  1.3434634
#  -0.24189981 -0.86541928 -1.67247408  0.61900753 -0.38094383  1.42238373
#  -0.02245636 -0.86541928 -1.67247408  0.52256725 -0.38094383  1.51897279
#   0.07629319 -0.86541928 -1.67247408  0.42612698 -0.38094383  1.58042071
#  -0.11023374 -0.86541928 -1.67247408  0.32968671 -0.38094383  1.69448219
#  -0.04440071 -0.86541928 -1.67247408  0.32968671 -0.38094383  1.79107125
#  -0.05537288 -0.86541928 -1.67247408  0.32968671 -0.38094383  1.88766031
#  -0.15412243 -0.86541928 -1.67247408  0.32968671 -0.38094383  1.94910823
#  -0.32967719 -0.86541928 -1.67247408  0.32968671 -0.38094383  2.01055615
#  -0.42842675 -0.86541928 -1.67247408  0.42612698 -1.45642614 -0.4817165
#  -0.51620413 -0.86541928 -1.67247408  0.52256725 -1.45642614 -0.46424409
#  -0.31870502 -0.79569856 -1.67247408  0.52256725  0.69453847 -0.42026858
#  -0.30773285 -0.86541928 -1.75326408  0.61900753  0.69453847 -0.35882066
#  -0.26384416 -0.86541928 -1.67247408  0.61900753  0.69453847 -0.27990033
#  -0.29676068 -0.93514    -1.83405407  0.61900753  0.69453847 -0.21845241]

# %% [markdown]
# Se dividen nuevamente los conjuntos de datos

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainX, testX = train_test_split(datosX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testX, valX = train_test_split(testX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainX son: ", trainX.shape)
print("Las dimensiones de testX son: ", testX.shape)
print("Las dimensiones de valX son: ", valX.shape)
# Out:
# Las dimensiones de trainX son:  (30610, 48, 6)
# Las dimensiones de testX son:  (8789, 48, 6)
# Las dimensiones de valX son:  (4330, 48, 6)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainMLPX, testMLPX = train_test_split(datosMLPX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testMLPX, valMLPX = train_test_split(testMLPX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainMLPX son: ", trainMLPX.shape)
print("Las dimensiones de testMLPX son: ", testMLPX.shape)
print("Las dimensiones de valMLPX son: ", valMLPX.shape)
# Out:
# Las dimensiones de trainMLPX son:  (30610, 288)
# Las dimensiones de testMLPX son:  (8789, 288)
# Las dimensiones de valMLPX son:  (4330, 288)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainY, testY = train_test_split(datosY, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testY, valY = train_test_split(testY, test_size=0.33, shuffle=False)

print("Las dimensiones de trainY son: ", trainY.shape)
print("Las dimensiones de testY son: ", testY.shape)
print("Las dimensiones de valY son: ", valY.shape)
# Out:
# Las dimensiones de trainY son:  (30610, 1)
# Las dimensiones de testY son:  (8789, 1)
# Las dimensiones de valY son:  (4330, 1)

# %% [markdown]
# Se crean métricas para medir desempeño

# %%
import tensorflow.keras.backend as K

def smape(y_true, y_pred):
    """
    Define la función SMAPE (Error Porcentual Absoluto Medio Simétrico).
    """
    summ = K.abs(y_true) + K.abs(y_pred)
    smape_val = K.abs(y_pred - y_true) / summ * 2.0
    return K.mean(smape_val, axis=-1)

def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

def ia(y_true, y_pred):
    numerator = K.sum(K.abs(y_true - y_pred))
    denominator = K.sum(K.abs(y_true - K.mean(y_true)) + K.abs(y_pred - K.mean(y_true)))
    return 1 - (numerator / denominator)

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

def graficarPrediccion(modelo, x, y, inicio, final):
  predicciones = modelo.predict(x)
  predicciones = predicciones.flatten()
  df = pd.DataFrame({'Originales': y, 'Predichos': predicciones})
  plt.plot(df.index, df['Originales'][inicio:final], label='Originales')
  plt.plot(df.index, df['Predichos'][inicio:final], label='Predichos')
  return df, mse(y, predicciones),  mae(y, predicciones), rmse(y, predicciones), smape(y,predicciones), ia(y, predicciones)

# %% [markdown]
# Se define el index del conjunto de validación para utilizarlo posteriormente para graficar.

# %%
# Fecha y hora de término del conjunto de datos de prueba
end_date = datosNormalizados.index[-1]
n_observations = valY.shape[0]  # Cambia esto al número de observaciones en tu conjunto de prueba

# Calcular la fecha y hora de inicio
start_date = end_date - timedelta(hours=(n_observations - 1))

# Crear la serie de fechas y horas
val_date = pd.date_range(start=start_date, end=end_date, freq='1H')

val_date
# Out:
# C:\Users\wamt1\AppData\Local\Temp\ipykernel_12716\3958427235.py:9: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   val_date = pd.date_range(start=start_date, end=end_date, freq='1H')
# DatetimeIndex(['2014-07-04 14:00:00', '2014-07-04 15:00:00',
#                '2014-07-04 16:00:00', '2014-07-04 17:00:00',
#                '2014-07-04 18:00:00', '2014-07-04 19:00:00',
#                '2014-07-04 20:00:00', '2014-07-04 21:00:00',
#                '2014-07-04 22:00:00', '2014-07-04 23:00:00',
#                ...
#                '2014-12-31 14:00:00', '2014-12-31 15:00:00',
#                '2014-12-31 16:00:00', '2014-12-31 17:00:00',
#                '2014-12-31 18:00:00', '2014-12-31 19:00:00',
#                '2014-12-31 20:00:00', '2014-12-31 21:00:00',
#                '2014-12-31 22:00:00', '2014-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=4330, freq='h')

# %% [markdown]
# Se guardan los índices de las observaciones a utilizar para predecir

# %%
indices = []
for i in range(pasados, len(datosNormalizados) - futuros + 1):
  indices.append(datosNormalizados.index[i+futuros-1])

# %% [markdown]
# # Modelos

# %% [markdown]
# ## MLP

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelMLP = Sequential()
modelMLP.add(InputLayer(input_shape=(trainMLPX.shape[1],)))

modelMLP.add(Dense(units=8, activation="sigmoid"))
modelMLP.add(Dropout(0.1))

modelMLP.add(Dense(units=8, activation="sigmoid"))
modelMLP.add(Dropout(0.1))

modelMLP.add(Dense(units=8, activation="sigmoid"))
modelMLP.add(Dropout(0.1))

modelMLP.add(Dense(units=8, activation="sigmoid"))
modelMLP.add(Dropout(0.1))

modelMLP.add(Dense(1))

opt = Adam(learning_rate=0.0007115052124615948)

modelMLP.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelMLP.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │         2,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,537 (9.91 KB)
#  Trainable params: 2,537 (9.91 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyMLP = modelMLP.fit(trainMLPX, trainY, epochs=32, validation_data=(testMLPX, testY), verbose = 2, batch_size=8, callbacks=[early_stopping])

prediccionMLP = modelMLP.predict(valMLPX)
# Out:
# Epoch 1/32
# 3827/3827 - 7s - 2ms/step - ia: 0.2815 - loss: 0.9528 - mae: 0.7317 - rmse: 0.9122 - smape: 1.5001 - val_ia: 0.1966 - val_loss: 0.8276 - val_mae: 0.6844 - val_rmse: 0.7252 - val_smape: 1.2943
# Epoch 2/32
# 3827/3827 - 5s - 1ms/step - ia: 0.3489 - loss: 0.8661 - mae: 0.6874 - rmse: 0.8701 - smape: 1.2999 - val_ia: 0.1993 - val_loss: 0.7964 - val_mae: 0.6690 - val_rmse: 0.7114 - val_smape: 1.2502
# Epoch 3/32
# 3827/3827 - 5s - 1ms/step - ia: 0.3612 - loss: 0.8435 - mae: 0.6786 - rmse: 0.8594 - smape: 1.2727 - val_ia: 0.2008 - val_loss: 0.7931 - val_mae: 0.6674 - val_rmse: 0.7107 - val_smape: 1.2449
# Epoch 4/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3663 - loss: 0.8346 - mae: 0.6740 - rmse: 0.8542 - smape: 1.2572 - val_ia: 0.2048 - val_loss: 0.7843 - val_mae: 0.6589 - val_rmse: 0.7027 - val_smape: 1.2002
# Epoch 5/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3705 - loss: 0.8288 - mae: 0.6709 - rmse: 0.8516 - smape: 1.2467 - val_ia: 0.2028 - val_loss: 0.7891 - val_mae: 0.6629 - val_rmse: 0.7069 - val_smape: 1.2179
# Epoch 6/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3757 - loss: 0.8195 - mae: 0.6671 - rmse: 0.8471 - smape: 1.2384 - val_ia: 0.2033 - val_loss: 0.7952 - val_mae: 0.6655 - val_rmse: 0.7098 - val_smape: 1.2167
# Epoch 7/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3771 - loss: 0.8136 - mae: 0.6648 - rmse: 0.8442 - smape: 1.2354 - val_ia: 0.2041 - val_loss: 0.7886 - val_mae: 0.6591 - val_rmse: 0.7043 - val_smape: 1.2051
# Epoch 8/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3788 - loss: 0.8142 - mae: 0.6641 - rmse: 0.8432 - smape: 1.2358 - val_ia: 0.2046 - val_loss: 0.7925 - val_mae: 0.6624 - val_rmse: 0.7075 - val_smape: 1.2110
# Epoch 9/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3833 - loss: 0.8045 - mae: 0.6605 - rmse: 0.8386 - smape: 1.2316 - val_ia: 0.2050 - val_loss: 0.7934 - val_mae: 0.6621 - val_rmse: 0.7076 - val_smape: 1.2086
# Epoch 10/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3876 - loss: 0.7962 - mae: 0.6578 - rmse: 0.8353 - smape: 1.2268 - val_ia: 0.2052 - val_loss: 0.7932 - val_mae: 0.6604 - val_rmse: 0.7066 - val_smape: 1.2044
# Epoch 11/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3861 - loss: 0.7979 - mae: 0.6593 - rmse: 0.8364 - smape: 1.2321 - val_ia: 0.2040 - val_loss: 0.7963 - val_mae: 0.6644 - val_rmse: 0.7107 - val_smape: 1.2322
# Epoch 12/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3894 - loss: 0.7903 - mae: 0.6558 - rmse: 0.8319 - smape: 1.2290 - val_ia: 0.2066 - val_loss: 0.7823 - val_mae: 0.6549 - val_rmse: 0.7012 - val_smape: 1.2121
# Epoch 13/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3915 - loss: 0.7833 - mae: 0.6541 - rmse: 0.8280 - smape: 1.2339 - val_ia: 0.2079 - val_loss: 0.7818 - val_mae: 0.6534 - val_rmse: 0.7002 - val_smape: 1.2004
# Epoch 14/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3901 - loss: 0.7810 - mae: 0.6543 - rmse: 0.8281 - smape: 1.2382 - val_ia: 0.2082 - val_loss: 0.7833 - val_mae: 0.6531 - val_rmse: 0.7004 - val_smape: 1.1996
# Epoch 15/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3888 - loss: 0.7831 - mae: 0.6538 - rmse: 0.8285 - smape: 1.2426 - val_ia: 0.2074 - val_loss: 0.7868 - val_mae: 0.6560 - val_rmse: 0.7034 - val_smape: 1.2126
# Epoch 16/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3917 - loss: 0.7777 - mae: 0.6520 - rmse: 0.8264 - smape: 1.2452 - val_ia: 0.2064 - val_loss: 0.7892 - val_mae: 0.6576 - val_rmse: 0.7054 - val_smape: 1.2347
# Epoch 17/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3943 - loss: 0.7747 - mae: 0.6494 - rmse: 0.8237 - smape: 1.2441 - val_ia: 0.2063 - val_loss: 0.7846 - val_mae: 0.6562 - val_rmse: 0.7035 - val_smape: 1.2326
# Epoch 18/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3926 - loss: 0.7770 - mae: 0.6516 - rmse: 0.8254 - smape: 1.2509 - val_ia: 0.2064 - val_loss: 0.7818 - val_mae: 0.6519 - val_rmse: 0.6993 - val_smape: 1.2291
# Epoch 19/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3963 - loss: 0.7712 - mae: 0.6489 - rmse: 0.8225 - smape: 1.2483 - val_ia: 0.2066 - val_loss: 0.7831 - val_mae: 0.6537 - val_rmse: 0.7017 - val_smape: 1.2397
# Epoch 20/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3985 - loss: 0.7658 - mae: 0.6460 - rmse: 0.8196 - smape: 1.2456 - val_ia: 0.2091 - val_loss: 0.7748 - val_mae: 0.6459 - val_rmse: 0.6939 - val_smape: 1.2141
# Epoch 21/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3946 - loss: 0.7637 - mae: 0.6479 - rmse: 0.8193 - smape: 1.2524 - val_ia: 0.2076 - val_loss: 0.7803 - val_mae: 0.6508 - val_rmse: 0.6990 - val_smape: 1.2306
# Epoch 22/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3953 - loss: 0.7682 - mae: 0.6480 - rmse: 0.8210 - smape: 1.2535 - val_ia: 0.2080 - val_loss: 0.7832 - val_mae: 0.6505 - val_rmse: 0.6993 - val_smape: 1.2251
# Epoch 23/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3988 - loss: 0.7595 - mae: 0.6447 - rmse: 0.8161 - smape: 1.2476 - val_ia: 0.2082 - val_loss: 0.7833 - val_mae: 0.6505 - val_rmse: 0.6998 - val_smape: 1.2277
# Epoch 24/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3979 - loss: 0.7600 - mae: 0.6453 - rmse: 0.8174 - smape: 1.2539 - val_ia: 0.2070 - val_loss: 0.7794 - val_mae: 0.6501 - val_rmse: 0.6987 - val_smape: 1.2344
# Epoch 25/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3978 - loss: 0.7538 - mae: 0.6438 - rmse: 0.8134 - smape: 1.2565 - val_ia: 0.2068 - val_loss: 0.7942 - val_mae: 0.6538 - val_rmse: 0.7034 - val_smape: 1.2285
# Epoch 26/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3982 - loss: 0.7578 - mae: 0.6440 - rmse: 0.8154 - smape: 1.2527 - val_ia: 0.2069 - val_loss: 0.7884 - val_mae: 0.6522 - val_rmse: 0.7019 - val_smape: 1.2322
# Epoch 27/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3987 - loss: 0.7540 - mae: 0.6432 - rmse: 0.8133 - smape: 1.2511 - val_ia: 0.2063 - val_loss: 0.7794 - val_mae: 0.6501 - val_rmse: 0.6990 - val_smape: 1.2445
# Epoch 28/32
# 3827/3827 - 4s - 1ms/step - ia: 0.4019 - loss: 0.7492 - mae: 0.6405 - rmse: 0.8107 - smape: 1.2457 - val_ia: 0.2063 - val_loss: 0.7912 - val_mae: 0.6544 - val_rmse: 0.7042 - val_smape: 1.2358
# Epoch 29/32
# 3827/3827 - 4s - 1ms/step - ia: 0.3999 - loss: 0.7479 - mae: 0.6409 - rmse: 0.8107 - smape: 1.2555 - val_ia: 0.2057 - val_loss: 0.7971 - val_mae: 0.6547 - val_rmse: 0.7049 - val_smape: 1.2379
# Epoch 30/32
# 3827/3827 - 4s - 1ms/step - ia: 0.4012 - loss: 0.7481 - mae: 0.6402 - rmse: 0.8099 - smape: 1.2521 - val_ia: 0.2075 - val_loss: 0.7920 - val_mae: 0.6517 - val_rmse: 0.7021 - val_smape: 1.2181
# Epoch 31/32
# 3827/3827 - 4s - 1ms/step - ia: 0.4035 - loss: 0.7452 - mae: 0.6388 - rmse: 0.8095 - smape: 1.2491 - val_ia: 0.2076 - val_loss: 0.8044 - val_mae: 0.6553 - val_rmse: 0.7067 - val_smape: 1.2240
# Epoch 32/32
# 3827/3827 - 4s - 1ms/step - ia: 0.4034 - loss: 0.7464 - mae: 0.6381 - rmse: 0.8085 - smape: 1.2531 - val_ia: 0.2057 - val_loss: 0.7860 - val_mae: 0.6507 - val_rmse: 0.7007 - val_smape: 1.2404
# Restoring model weights from the end of the best epoch: 20.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
metricasMLP = modelMLP.evaluate(valMLPX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasMLP}")
# Out:
# 136/136 - 0s - 839us/step - ia: 0.2640 - loss: 0.8725 - mae: 0.6842 - rmse: 0.7787 - smape: 1.2303
# Métricas en el conjunto de validación: [0.8725323677062988, 0.6841923594474792, 1.2303307056427002, 0.7786902785301208, 0.2640131115913391]

# %%
historyMLP = historyMLP.history
ejeXMLP = range(1, len(historyMLP['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXMLP, historyMLP['loss'], label='Train Loss')
plt.plot(ejeXMLP, historyMLP['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyMLP['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyMLP['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.7463825941085815
# Último valor de Test Loss: 0.7859736680984497

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionMLP.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfMLP = df
fig.show()

# %% [markdown]
# ### Datos para NARMAX

# %%
prediccionNarmaxMLP = modelMLP.predict(datosMLPX)
erroresMLP = datosY - prediccionNarmaxMLP
# Out:
# 1367/1367 ━━━━━━━━━━━━━━━━━━━━ 1s 674us/step

# %%
dfErroresMLP = pd.DataFrame(erroresMLP, columns = ["e"])
dfErroresMLP.index = indices

# %%
dfNarmaxMLP = datosNormalizados.join(dfErroresMLP, how = 'left')

print(dfNarmaxMLP.head())
print(dfNarmaxMLP.tail())
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 00:00:00   0.317681 -1.214023 -1.268524  0.329687 -0.380944
# 2010-01-02 01:00:00   0.526152 -1.144302 -1.268524  0.329687 -0.380944
# 2010-01-02 02:00:00   0.646846 -0.865419 -1.349314  0.426127 -0.380944
# 2010-01-02 03:00:00   0.888234 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 04:00:00   0.416431 -0.586536 -1.349314  0.522567 -0.380944
#
#                       wnd_spd   e
# date
# 2010-01-02 00:00:00 -0.464048 NaN
# 2010-01-02 01:00:00 -0.446575 NaN
# 2010-01-02 02:00:00 -0.429103 NaN
# 2010-01-02 03:00:00 -0.393962 NaN
# 2010-01-02 04:00:00 -0.376489 NaN
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2014-12-31 19:00:00  -1.009952 -1.702068 -1.106944  1.679851  0.694538
# 2014-12-31 20:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 21:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 22:00:00  -1.009952 -1.632347 -1.268524  1.679851  0.694538
# 2014-12-31 23:00:00  -0.966063 -1.562627 -1.187734  1.679851  0.694538
#
#                       wnd_spd         e
# date
# 2014-12-31 19:00:00  4.054828 -0.647647
# 2014-12-31 20:00:00  4.168890 -0.603530
# 2014-12-31 21:00:00  4.265479 -0.604267
# 2014-12-31 22:00:00  4.344399 -0.619216
# 2014-12-31 23:00:00  4.405847 -0.538245

# %%
dfNarmaxMLP.to_csv('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\datosNarmax\\4824pasos_mlp_pollution.csv', index=True)

# %%
dfMLP.to_csv('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\evaluacion\\4824pasos_mlp_pollution.csv', index=True)

# %%
modelMLP.save('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\modelosEntrenadosNarx\\4824pasos_mlp_pollution.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## LSTM

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelLSTM = Sequential()
modelLSTM.add(InputLayer(input_shape=(trainX.shape[1], trainX.shape[2])))

modelLSTM.add(LSTM(units=128, activation="sigmoid", return_sequences=True))
modelLSTM.add(Dropout(0.3))

modelLSTM.add(LSTM(units=128, activation="sigmoid", return_sequences=True))
modelLSTM.add(Dropout(0.3))

modelLSTM.add(LSTM(units=128, activation="sigmoid", return_sequences=True))
modelLSTM.add(Dropout(0.3))

modelLSTM.add(LSTM(units=128, activation="sigmoid", return_sequences=False))
modelLSTM.add(Dropout(0.3))

modelLSTM.add(Dense(1))


opt = Adam(learning_rate=0.0002283375510850933)
modelLSTM.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelLSTM.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 48, 128)        │        69,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 48, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 48, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 48, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 48, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 48, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 464,001 (1.77 MB)
#  Trainable params: 464,001 (1.77 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyLSTM = modelLSTM.fit(trainX, trainY, epochs=256, validation_data=(testX, testY), verbose = 2, batch_size=32, callbacks=[early_stopping])


prediccionLSTM = modelLSTM.predict(valX)
# Out:
# Epoch 1/256
# 957/957 - 83s - 87ms/step - ia: 0.2480 - loss: 0.9878 - mae: 0.7428 - rmse: 0.9725 - smape: 1.5081 - val_ia: 0.2477 - val_loss: 0.7979 - val_mae: 0.6568 - val_rmse: 0.7513 - val_smape: 1.2164
# Epoch 2/256
# 957/957 - 74s - 77ms/step - ia: 0.3618 - loss: 0.8597 - mae: 0.6857 - rmse: 0.9090 - smape: 1.3003 - val_ia: 0.2512 - val_loss: 0.7757 - val_mae: 0.6435 - val_rmse: 0.7402 - val_smape: 1.1928
# Epoch 3/256
# 957/957 - 72s - 76ms/step - ia: 0.3721 - loss: 0.8410 - mae: 0.6759 - rmse: 0.8992 - smape: 1.2852 - val_ia: 0.2539 - val_loss: 0.7756 - val_mae: 0.6438 - val_rmse: 0.7425 - val_smape: 1.1902
# Epoch 4/256
# 957/957 - 72s - 75ms/step - ia: 0.3768 - loss: 0.8331 - mae: 0.6723 - rmse: 0.8949 - smape: 1.2815 - val_ia: 0.2561 - val_loss: 0.7736 - val_mae: 0.6421 - val_rmse: 0.7414 - val_smape: 1.1951
# Epoch 5/256
# 957/957 - 75s - 79ms/step - ia: 0.3812 - loss: 0.8249 - mae: 0.6685 - rmse: 0.8906 - smape: 1.2776 - val_ia: 0.2584 - val_loss: 0.7713 - val_mae: 0.6392 - val_rmse: 0.7399 - val_smape: 1.1850
# Epoch 6/256
# 957/957 - 72s - 75ms/step - ia: 0.3867 - loss: 0.8174 - mae: 0.6654 - rmse: 0.8864 - smape: 1.2711 - val_ia: 0.2595 - val_loss: 0.7708 - val_mae: 0.6382 - val_rmse: 0.7394 - val_smape: 1.1813
# Epoch 7/256
# 957/957 - 74s - 78ms/step - ia: 0.3877 - loss: 0.8182 - mae: 0.6650 - rmse: 0.8868 - smape: 1.2669 - val_ia: 0.2602 - val_loss: 0.7763 - val_mae: 0.6446 - val_rmse: 0.7460 - val_smape: 1.1939
# Epoch 8/256
# 957/957 - 73s - 76ms/step - ia: 0.3922 - loss: 0.8119 - mae: 0.6622 - rmse: 0.8830 - smape: 1.2627 - val_ia: 0.2600 - val_loss: 0.7663 - val_mae: 0.6352 - val_rmse: 0.7362 - val_smape: 1.1765
# Epoch 9/256
# 957/957 - 71s - 74ms/step - ia: 0.3932 - loss: 0.8100 - mae: 0.6612 - rmse: 0.8821 - smape: 1.2613 - val_ia: 0.2611 - val_loss: 0.7690 - val_mae: 0.6380 - val_rmse: 0.7398 - val_smape: 1.1834
# Epoch 10/256
# 957/957 - 72s - 76ms/step - ia: 0.3959 - loss: 0.8075 - mae: 0.6592 - rmse: 0.8808 - smape: 1.2575 - val_ia: 0.2615 - val_loss: 0.7682 - val_mae: 0.6376 - val_rmse: 0.7395 - val_smape: 1.1820
# Epoch 11/256
# 957/957 - 74s - 77ms/step - ia: 0.3986 - loss: 0.8041 - mae: 0.6582 - rmse: 0.8788 - smape: 1.2540 - val_ia: 0.2616 - val_loss: 0.7605 - val_mae: 0.6343 - val_rmse: 0.7352 - val_smape: 1.1823
# Epoch 12/256
# 957/957 - 74s - 77ms/step - ia: 0.4018 - loss: 0.8018 - mae: 0.6558 - rmse: 0.8773 - smape: 1.2471 - val_ia: 0.2612 - val_loss: 0.7604 - val_mae: 0.6335 - val_rmse: 0.7345 - val_smape: 1.1821
# Epoch 13/256
# 957/957 - 73s - 76ms/step - ia: 0.4007 - loss: 0.7997 - mae: 0.6562 - rmse: 0.8761 - smape: 1.2527 - val_ia: 0.2620 - val_loss: 0.7748 - val_mae: 0.6411 - val_rmse: 0.7443 - val_smape: 1.1801
# Epoch 14/256
# 957/957 - 73s - 76ms/step - ia: 0.4043 - loss: 0.7956 - mae: 0.6539 - rmse: 0.8741 - smape: 1.2463 - val_ia: 0.2608 - val_loss: 0.7616 - val_mae: 0.6321 - val_rmse: 0.7340 - val_smape: 1.1734
# Epoch 15/256
# 957/957 - 73s - 77ms/step - ia: 0.4063 - loss: 0.7943 - mae: 0.6528 - rmse: 0.8729 - smape: 1.2431 - val_ia: 0.2608 - val_loss: 0.7718 - val_mae: 0.6345 - val_rmse: 0.7381 - val_smape: 1.1639
# Epoch 16/256
# 957/957 - 71s - 75ms/step - ia: 0.4072 - loss: 0.7905 - mae: 0.6518 - rmse: 0.8708 - smape: 1.2455 - val_ia: 0.2609 - val_loss: 0.7706 - val_mae: 0.6369 - val_rmse: 0.7397 - val_smape: 1.1786
# Epoch 17/256
# 957/957 - 73s - 76ms/step - ia: 0.4105 - loss: 0.7887 - mae: 0.6496 - rmse: 0.8698 - smape: 1.2386 - val_ia: 0.2612 - val_loss: 0.7749 - val_mae: 0.6371 - val_rmse: 0.7413 - val_smape: 1.1702
# Epoch 18/256
# 957/957 - 74s - 78ms/step - ia: 0.4133 - loss: 0.7843 - mae: 0.6480 - rmse: 0.8673 - smape: 1.2355 - val_ia: 0.2605 - val_loss: 0.7741 - val_mae: 0.6333 - val_rmse: 0.7376 - val_smape: 1.1647
# Epoch 19/256
# 957/957 - 71s - 74ms/step - ia: 0.4150 - loss: 0.7801 - mae: 0.6469 - rmse: 0.8649 - smape: 1.2360 - val_ia: 0.2603 - val_loss: 0.7755 - val_mae: 0.6336 - val_rmse: 0.7380 - val_smape: 1.1658
# Epoch 20/256
# 957/957 - 70s - 73ms/step - ia: 0.4189 - loss: 0.7771 - mae: 0.6447 - rmse: 0.8631 - smape: 1.2292 - val_ia: 0.2619 - val_loss: 0.7763 - val_mae: 0.6360 - val_rmse: 0.7408 - val_smape: 1.1689
# Epoch 21/256
# 957/957 - 73s - 77ms/step - ia: 0.4187 - loss: 0.7757 - mae: 0.6443 - rmse: 0.8625 - smape: 1.2291 - val_ia: 0.2612 - val_loss: 0.7760 - val_mae: 0.6339 - val_rmse: 0.7382 - val_smape: 1.1675
# Epoch 22/256
# 957/957 - 73s - 76ms/step - ia: 0.4207 - loss: 0.7728 - mae: 0.6429 - rmse: 0.8608 - smape: 1.2261 - val_ia: 0.2607 - val_loss: 0.7749 - val_mae: 0.6337 - val_rmse: 0.7372 - val_smape: 1.1725
# Epoch 23/256
# 957/957 - 73s - 77ms/step - ia: 0.4228 - loss: 0.7705 - mae: 0.6416 - rmse: 0.8593 - smape: 1.2227 - val_ia: 0.2611 - val_loss: 0.7872 - val_mae: 0.6362 - val_rmse: 0.7413 - val_smape: 1.1683
# Epoch 24/256
# 957/957 - 72s - 76ms/step - ia: 0.4247 - loss: 0.7666 - mae: 0.6399 - rmse: 0.8571 - smape: 1.2213 - val_ia: 0.2607 - val_loss: 0.7859 - val_mae: 0.6379 - val_rmse: 0.7418 - val_smape: 1.1806
# Epoch 25/256
# 957/957 - 72s - 75ms/step - ia: 0.4278 - loss: 0.7624 - mae: 0.6381 - rmse: 0.8545 - smape: 1.2173 - val_ia: 0.2605 - val_loss: 0.7947 - val_mae: 0.6382 - val_rmse: 0.7432 - val_smape: 1.1749
# Epoch 26/256
# 957/957 - 71s - 75ms/step - ia: 0.4292 - loss: 0.7607 - mae: 0.6370 - rmse: 0.8538 - smape: 1.2162 - val_ia: 0.2621 - val_loss: 0.8119 - val_mae: 0.6433 - val_rmse: 0.7509 - val_smape: 1.1712
# Epoch 27/256
# 957/957 - 71s - 75ms/step - ia: 0.4309 - loss: 0.7589 - mae: 0.6361 - rmse: 0.8526 - smape: 1.2128 - val_ia: 0.2615 - val_loss: 0.8115 - val_mae: 0.6478 - val_rmse: 0.7544 - val_smape: 1.1814
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 12.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step

# %%
metricasLSTM = modelLSTM.evaluate(valX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasLSTM}")
# Out:
# 136/136 - 4s - 27ms/step - ia: 0.2654 - loss: 0.7953 - mae: 0.6552 - rmse: 0.7441 - smape: 1.1831
# Métricas en el conjunto de validación: [0.7952868342399597, 0.6551608443260193, 1.1831440925598145, 0.7440861463546753, 0.26537442207336426]

# %%
historyLSTM = historyLSTM.history

ejeXLSTM = range(1, len(historyLSTM['loss']) + 1)

plt.figure(figsize=(12, 8))
plt.plot(ejeXLSTM, historyLSTM['loss'], label='Train Loss')
plt.plot(ejeXLSTM, historyLSTM['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyLSTM['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyLSTM['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.7589229345321655
# Último valor de Test Loss: 0.8114920258522034

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionLSTM.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfLSTM = df
fig.show()

# %% [markdown]
# ### Datos para NARMAX

# %%
prediccionNarmaxLSTM = modelLSTM.predict(datosX)
erroresLSTM = datosY - prediccionNarmaxLSTM
# Out:
# 1367/1367 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step

# %%
dfErroresLSTM = pd.DataFrame(erroresLSTM, columns = ["e"])
dfErroresLSTM.index = indices

# %%
dfNarmaxLSTM = datosNormalizados.join(dfErroresLSTM, how = 'left')

print(dfNarmaxLSTM.head())
print(dfNarmaxLSTM.tail())
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 00:00:00   0.317681 -1.214023 -1.268524  0.329687 -0.380944
# 2010-01-02 01:00:00   0.526152 -1.144302 -1.268524  0.329687 -0.380944
# 2010-01-02 02:00:00   0.646846 -0.865419 -1.349314  0.426127 -0.380944
# 2010-01-02 03:00:00   0.888234 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 04:00:00   0.416431 -0.586536 -1.349314  0.522567 -0.380944
#
#                       wnd_spd   e
# date
# 2010-01-02 00:00:00 -0.464048 NaN
# 2010-01-02 01:00:00 -0.446575 NaN
# 2010-01-02 02:00:00 -0.429103 NaN
# 2010-01-02 03:00:00 -0.393962 NaN
# 2010-01-02 04:00:00 -0.376489 NaN
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2014-12-31 19:00:00  -1.009952 -1.702068 -1.106944  1.679851  0.694538
# 2014-12-31 20:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 21:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 22:00:00  -1.009952 -1.632347 -1.268524  1.679851  0.694538
# 2014-12-31 23:00:00  -0.966063 -1.562627 -1.187734  1.679851  0.694538
#
#                       wnd_spd         e
# date
# 2014-12-31 19:00:00  4.054828 -0.612633
# 2014-12-31 20:00:00  4.168890 -0.542209
# 2014-12-31 21:00:00  4.265479 -0.505303
# 2014-12-31 22:00:00  4.344399 -0.490646
# 2014-12-31 23:00:00  4.405847 -0.433662

# %%
dfNarmaxLSTM.to_csv('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\datosNarmax\\4824pasos_lstm_pollution.csv', index=True)

# %%
dfLSTM.to_csv('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\evaluacion\\4824pasos_lstm_pollution.csv', index=True)

# %%
modelLSTM.save('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\modelosEntrenadosNarx\\4824pasos_lstm_pollution.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## GRU

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelGRU = Sequential()
modelGRU.add(InputLayer(input_shape=(trainX.shape[1], trainX.shape[2])))

modelGRU.add(GRU(units=128, activation="sigmoid", return_sequences=False))
modelGRU.add(Dropout(0.2))

modelGRU.add(Dense(1))


opt = Adam(learning_rate=0.0002707756079796208)
modelGRU.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelGRU.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 128)            │        52,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 52,353 (204.50 KB)
#  Trainable params: 52,353 (204.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)

early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyGRU = modelGRU.fit(trainX, trainY, epochs=128, validation_data=(testX, testY), verbose = 2, batch_size=32, callbacks=[early_stopping])

prediccionGRU = modelGRU.predict(valX)
# Out:
# Epoch 1/128
# 957/957 - 19s - 20ms/step - ia: 0.3396 - loss: 0.9614 - mae: 0.7294 - rmse: 0.9590 - smape: 1.3607 - val_ia: 0.2510 - val_loss: 0.7878 - val_mae: 0.6700 - val_rmse: 0.7650 - val_smape: 1.3311
# Epoch 2/128
# 957/957 - 16s - 16ms/step - ia: 0.3796 - loss: 0.8595 - mae: 0.6862 - rmse: 0.9095 - smape: 1.2967 - val_ia: 0.2520 - val_loss: 0.7812 - val_mae: 0.6635 - val_rmse: 0.7585 - val_smape: 1.3116
# Epoch 3/128
# 957/957 - 16s - 16ms/step - ia: 0.3822 - loss: 0.8401 - mae: 0.6768 - rmse: 0.8989 - smape: 1.2911 - val_ia: 0.2528 - val_loss: 0.7782 - val_mae: 0.6604 - val_rmse: 0.7559 - val_smape: 1.3000
# Epoch 4/128
# 957/957 - 16s - 17ms/step - ia: 0.3843 - loss: 0.8332 - mae: 0.6729 - rmse: 0.8950 - smape: 1.2870 - val_ia: 0.2542 - val_loss: 0.7722 - val_mae: 0.6547 - val_rmse: 0.7506 - val_smape: 1.2831
# Epoch 5/128
# 957/957 - 15s - 16ms/step - ia: 0.3859 - loss: 0.8261 - mae: 0.6697 - rmse: 0.8913 - smape: 1.2832 - val_ia: 0.2546 - val_loss: 0.7729 - val_mae: 0.6565 - val_rmse: 0.7529 - val_smape: 1.2832
# Epoch 6/128
# 957/957 - 15s - 16ms/step - ia: 0.3886 - loss: 0.8213 - mae: 0.6668 - rmse: 0.8885 - smape: 1.2775 - val_ia: 0.2554 - val_loss: 0.7703 - val_mae: 0.6548 - val_rmse: 0.7515 - val_smape: 1.2784
# Epoch 7/128
# 957/957 - 15s - 16ms/step - ia: 0.3913 - loss: 0.8150 - mae: 0.6642 - rmse: 0.8853 - smape: 1.2733 - val_ia: 0.2561 - val_loss: 0.7695 - val_mae: 0.6547 - val_rmse: 0.7519 - val_smape: 1.2740
# Epoch 8/128
# 957/957 - 18s - 19ms/step - ia: 0.3939 - loss: 0.8112 - mae: 0.6622 - rmse: 0.8830 - smape: 1.2688 - val_ia: 0.2572 - val_loss: 0.7674 - val_mae: 0.6524 - val_rmse: 0.7499 - val_smape: 1.2662
# Epoch 9/128
# 957/957 - 17s - 18ms/step - ia: 0.3947 - loss: 0.8104 - mae: 0.6610 - rmse: 0.8827 - smape: 1.2662 - val_ia: 0.2575 - val_loss: 0.7678 - val_mae: 0.6533 - val_rmse: 0.7509 - val_smape: 1.2669
# Epoch 10/128
# 957/957 - 26s - 27ms/step - ia: 0.3962 - loss: 0.8072 - mae: 0.6597 - rmse: 0.8810 - smape: 1.2648 - val_ia: 0.2575 - val_loss: 0.7698 - val_mae: 0.6555 - val_rmse: 0.7533 - val_smape: 1.2700
# Epoch 11/128
# 957/957 - 25s - 26ms/step - ia: 0.3982 - loss: 0.8042 - mae: 0.6586 - rmse: 0.8792 - smape: 1.2607 - val_ia: 0.2583 - val_loss: 0.7697 - val_mae: 0.6543 - val_rmse: 0.7527 - val_smape: 1.2641
# Epoch 12/128
# 957/957 - 32s - 34ms/step - ia: 0.4012 - loss: 0.8005 - mae: 0.6562 - rmse: 0.8772 - smape: 1.2588 - val_ia: 0.2586 - val_loss: 0.7690 - val_mae: 0.6530 - val_rmse: 0.7519 - val_smape: 1.2590
# Epoch 13/128
# 957/957 - 50s - 52ms/step - ia: 0.4033 - loss: 0.7972 - mae: 0.6543 - rmse: 0.8754 - smape: 1.2539 - val_ia: 0.2592 - val_loss: 0.7684 - val_mae: 0.6516 - val_rmse: 0.7509 - val_smape: 1.2534
# Epoch 14/128
# 957/957 - 33s - 35ms/step - ia: 0.4075 - loss: 0.7914 - mae: 0.6510 - rmse: 0.8719 - smape: 1.2504 - val_ia: 0.2596 - val_loss: 0.7706 - val_mae: 0.6519 - val_rmse: 0.7519 - val_smape: 1.2484
# Epoch 15/128
# 957/957 - 25s - 26ms/step - ia: 0.4089 - loss: 0.7891 - mae: 0.6503 - rmse: 0.8708 - smape: 1.2496 - val_ia: 0.2600 - val_loss: 0.7730 - val_mae: 0.6520 - val_rmse: 0.7528 - val_smape: 1.2452
# Epoch 16/128
# 957/957 - 24s - 25ms/step - ia: 0.4129 - loss: 0.7817 - mae: 0.6476 - rmse: 0.8665 - smape: 1.2459 - val_ia: 0.2603 - val_loss: 0.7763 - val_mae: 0.6521 - val_rmse: 0.7535 - val_smape: 1.2407
# Epoch 17/128
# 957/957 - 25s - 26ms/step - ia: 0.4154 - loss: 0.7790 - mae: 0.6455 - rmse: 0.8647 - smape: 1.2411 - val_ia: 0.2606 - val_loss: 0.7795 - val_mae: 0.6528 - val_rmse: 0.7548 - val_smape: 1.2391
# Epoch 18/128
# 957/957 - 24s - 25ms/step - ia: 0.4185 - loss: 0.7754 - mae: 0.6432 - rmse: 0.8626 - smape: 1.2375 - val_ia: 0.2608 - val_loss: 0.7805 - val_mae: 0.6531 - val_rmse: 0.7552 - val_smape: 1.2423
# Epoch 19/128
# 957/957 - 22s - 23ms/step - ia: 0.4201 - loss: 0.7716 - mae: 0.6423 - rmse: 0.8604 - smape: 1.2375 - val_ia: 0.2615 - val_loss: 0.7871 - val_mae: 0.6559 - val_rmse: 0.7588 - val_smape: 1.2409
# Epoch 20/128
# 957/957 - 24s - 25ms/step - ia: 0.4227 - loss: 0.7687 - mae: 0.6402 - rmse: 0.8586 - smape: 1.2319 - val_ia: 0.2622 - val_loss: 0.7906 - val_mae: 0.6565 - val_rmse: 0.7601 - val_smape: 1.2373
# Epoch 21/128
# 957/957 - 25s - 26ms/step - ia: 0.4257 - loss: 0.7645 - mae: 0.6383 - rmse: 0.8563 - smape: 1.2293 - val_ia: 0.2626 - val_loss: 0.7934 - val_mae: 0.6569 - val_rmse: 0.7606 - val_smape: 1.2357
# Epoch 22/128
# 957/957 - 20s - 21ms/step - ia: 0.4273 - loss: 0.7605 - mae: 0.6371 - rmse: 0.8539 - smape: 1.2273 - val_ia: 0.2635 - val_loss: 0.7946 - val_mae: 0.6533 - val_rmse: 0.7580 - val_smape: 1.2226
# Epoch 23/128
# 957/957 - 17s - 17ms/step - ia: 0.4299 - loss: 0.7556 - mae: 0.6351 - rmse: 0.8514 - smape: 1.2223 - val_ia: 0.2641 - val_loss: 0.8040 - val_mae: 0.6587 - val_rmse: 0.7638 - val_smape: 1.2277
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step

# %%
metricasGRU = modelGRU.evaluate(valX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasGRU}")
# Out:
# 136/136 - 1s - 8ms/step - ia: 0.2601 - loss: 0.8058 - mae: 0.6823 - rmse: 0.7678 - smape: 1.2854
# Métricas en el conjunto de validación: [0.8057841658592224, 0.6823102831840515, 1.2853947877883911, 0.7678296566009521, 0.26009130477905273]

# %%
historyGRU = historyGRU.history

ejeXGRU = range(1, len(historyGRU['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXGRU, historyGRU['loss'], label='Train Loss')
plt.plot(ejeXGRU, historyGRU['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyGRU['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyGRU['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.7556275725364685
# Último valor de Test Loss: 0.8039897680282593

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionGRU.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfGRU= df
fig.show()

# %% [markdown]
# ### Datos para NARMAX

# %%
prediccionNarmaxGRU = modelGRU.predict(datosX)
erroresGRU = datosY - prediccionNarmaxGRU
# Out:
# 1367/1367 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step

# %%
dfErroresGRU = pd.DataFrame(erroresGRU, columns = ["e"])
dfErroresGRU.index = indices

# %%
dfNarmaxGRU = datosNormalizados.join(dfErroresGRU, how = 'left')

print(dfNarmaxGRU.head())
print(dfNarmaxGRU.tail())
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 00:00:00   0.317681 -1.214023 -1.268524  0.329687 -0.380944
# 2010-01-02 01:00:00   0.526152 -1.144302 -1.268524  0.329687 -0.380944
# 2010-01-02 02:00:00   0.646846 -0.865419 -1.349314  0.426127 -0.380944
# 2010-01-02 03:00:00   0.888234 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 04:00:00   0.416431 -0.586536 -1.349314  0.522567 -0.380944
#
#                       wnd_spd   e
# date
# 2010-01-02 00:00:00 -0.464048 NaN
# 2010-01-02 01:00:00 -0.446575 NaN
# 2010-01-02 02:00:00 -0.429103 NaN
# 2010-01-02 03:00:00 -0.393962 NaN
# 2010-01-02 04:00:00 -0.376489 NaN
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2014-12-31 19:00:00  -1.009952 -1.702068 -1.106944  1.679851  0.694538
# 2014-12-31 20:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 21:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 22:00:00  -1.009952 -1.632347 -1.268524  1.679851  0.694538
# 2014-12-31 23:00:00  -0.966063 -1.562627 -1.187734  1.679851  0.694538
#
#                       wnd_spd         e
# date
# 2014-12-31 19:00:00  4.054828 -0.754826
# 2014-12-31 20:00:00  4.168890 -0.673557
# 2014-12-31 21:00:00  4.265479 -0.623478
# 2014-12-31 22:00:00  4.344399 -0.549533
# 2014-12-31 23:00:00  4.405847 -0.510690

# %%
dfNarmaxGRU.to_csv('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\datosNarmax\\4824pasos_gru_pollution.csv', index=True)

# %%
dfGRU.to_csv('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\evaluacion\\4824pasos_gru_pollution.csv', index=True)

# %%
modelGRU.save('C:\\Users\\wamt1\\Desktop\\pruebas_collab\\modelosEntrenadosNarx\\4824pasos_gru_pollution.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
