# %% [markdown]
# Prueba

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from hyperopt import hp, fmin, tpe, Trials, STATUS_OK
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU, InputLayer, Flatten, LSTM
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import os
from datetime import datetime, timedelta
import plotly.express as px
import plotly.graph_objects as go
import random

# %% [markdown]
# LEER DATASET

# %%
import pandas as pd

datos = pd.read_csv("C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\SNpollutionFinal.csv")

datos['date'] = pd.to_datetime(datos['date'])

# Se establece la columna date como index
datos.set_index('date', inplace=True)

# %%
datos.head()
# Out:
#                      pollution  dew  temp   press  wnd_dir  wnd_spd
# date
# 2010-01-01 00:00:00      129.0  -21 -11.0  1021.0        2     1.79
# 2010-01-01 01:00:00      129.0  -21 -12.0  1020.0        2     4.92
# 2010-01-01 02:00:00      129.0  -21 -11.0  1019.0        2     6.71
# 2010-01-01 03:00:00      129.0  -21 -14.0  1019.0        2     9.84
# 2010-01-01 04:00:00      129.0  -20 -12.0  1018.0        2    12.97

# %%
datos = datos.drop(datos.index[:24])

datos
# Out:
#                      pollution  dew  temp   press  wnd_dir  wnd_spd
# date
# 2010-01-02 00:00:00      129.0  -16  -4.0  1020.0        1     1.79
# 2010-01-02 01:00:00      148.0  -15  -4.0  1020.0        1     2.68
# 2010-01-02 02:00:00      159.0  -11  -5.0  1021.0        1     3.57
# 2010-01-02 03:00:00      181.0   -7  -5.0  1022.0        1     5.36
# 2010-01-02 04:00:00      138.0   -7  -5.0  1022.0        1     6.25
# ...                        ...  ...   ...     ...      ...      ...
# 2014-12-31 19:00:00        8.0  -23  -2.0  1034.0        2   231.97
# 2014-12-31 20:00:00       10.0  -22  -3.0  1034.0        2   237.78
# 2014-12-31 21:00:00       10.0  -22  -3.0  1034.0        2   242.70
# 2014-12-31 22:00:00        8.0  -22  -4.0  1034.0        2   246.72
# 2014-12-31 23:00:00       12.0  -21  -3.0  1034.0        2   249.85
#
# [43800 rows x 6 columns]

# %%
#Se verifica que el index está en formato de dato "datetime64"
print("El index del dataframe input es un tipo de dato: ", datos.index.dtype)
# Out:
# El index del dataframe input es un tipo de dato:  datetime64[ns]

# %% [markdown]
# Se divide el dataset

# %%
# Dividir el conjunto de datos en entrenamiento y prueba
train, test = train_test_split(datos, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
test, val = train_test_split(test, test_size=0.33, shuffle=False)

print("Las dimensiones de train son: ", train.shape)
print("Las dimensiones de test son: ", test.shape)
print("Las dimensiones de val son: ", val.shape)
# Out:
# Las dimensiones de train son:  (30660, 6)
# Las dimensiones de test son:  (8803, 6)
# Las dimensiones de val son:  (4337, 6)

# %% [markdown]
# Se normalizan los datos

# %%
from sklearn.preprocessing import StandardScaler


# Normalizar solo con los datos de entrenamiento
scaler = StandardScaler()
train = scaler.fit_transform(train)

# Aplicar la transformación a test y val usando los parámetros de train
test = scaler.transform(test)
val = scaler.transform(val)

train = pd.DataFrame(train, columns=datos.columns)
test = pd.DataFrame(test, columns=datos.columns)
val = pd.DataFrame(val, columns=datos.columns)

# %% [markdown]
# Se unen los datos nuevamente, ahora normalizados, en un único conjunto.

# %%
datosNormalizados = pd.concat([train, test, val])

datosNormalizados.index = datos.index

# %%
datosNormalizados.shape
# Out:
# (43800, 6)

# %%
datosNormalizados.head(13)
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 00:00:00   0.317681 -1.214023 -1.268524  0.329687 -0.380944
# 2010-01-02 01:00:00   0.526152 -1.144302 -1.268524  0.329687 -0.380944
# 2010-01-02 02:00:00   0.646846 -0.865419 -1.349314  0.426127 -0.380944
# 2010-01-02 03:00:00   0.888234 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 04:00:00   0.416431 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 05:00:00   0.098238 -0.586536 -1.430104  0.522567 -0.380944
# 2010-01-02 06:00:00   0.054349 -0.586536 -1.430104  0.619008 -0.380944
# 2010-01-02 07:00:00   0.262820 -0.586536 -1.349314  0.715448 -0.380944
# 2010-01-02 08:00:00   0.218931 -0.656257 -1.430104  0.715448 -0.380944
# 2010-01-02 09:00:00   0.350598 -0.586536 -1.349314  0.811888 -0.380944
# 2010-01-02 10:00:00   0.438375 -0.586536 -1.349314  0.908328 -0.380944
# 2010-01-02 11:00:00   0.570041 -0.656257 -1.349314  0.908328 -0.380944
# 2010-01-02 12:00:00   0.526152 -0.656257 -1.349314  0.908328 -0.380944
#
#                       wnd_spd
# date
# 2010-01-02 00:00:00 -0.464048
# 2010-01-02 01:00:00 -0.446575
# 2010-01-02 02:00:00 -0.429103
# 2010-01-02 03:00:00 -0.393962
# 2010-01-02 04:00:00 -0.376489
# 2010-01-02 05:00:00 -0.359017
# 2010-01-02 06:00:00 -0.323876
# 2010-01-02 07:00:00 -0.288735
# 2010-01-02 08:00:00 -0.253594
# 2010-01-02 09:00:00 -0.218452
# 2010-01-02 10:00:00 -0.157004
# 2010-01-02 11:00:00 -0.095557
# 2010-01-02 12:00:00 -0.034109

# %% [markdown]
# Se establece el formato de datos de entrada para redes GRU y LSTM, es decir [observaciones, retardos, caracteristicas]

# %%
futuros = 24
pasados  = 12

# %%
datosX = []
datosY = []
for i in range(pasados, len(datosNormalizados) - futuros + 1):
  datosX.append(datosNormalizados.iloc[i-pasados:i, 0:datosNormalizados.shape[1]])
  datosY.append(datosNormalizados.iloc[i+futuros-1:i+futuros, 0])

# %%
# Convertir las listas en arrays numpy
datosX = np.array(datosX)
datosY = np.array(datosY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de X:", datosX.shape)  # (n_muestras, pasos_de_tiempo, n_características)
print("Dimensiones de Y:", datosY.shape)  # (n_muestras, n_características)
# Out:
# Dimensiones de X: (43765, 12, 6)
# Dimensiones de Y: (43765, 1)

# %%
inputs = datosX.shape[1] * datosX.shape[2]
datosMLPX = datosX.reshape(datosX.shape[0], inputs)

# %%
print(datosX[0])
print(datosMLPX[0])
# Out:
# [[ 0.31768099 -1.2140229  -1.26852411  0.32968671 -0.38094383 -0.46404777]
#  [ 0.52615226 -1.14430217 -1.26852411  0.32968671 -0.38094383 -0.44657536]
#  [ 0.64684616 -0.86541928 -1.34931411  0.42612698 -0.38094383 -0.42910295]
#  [ 0.88823396 -0.58653639 -1.34931411  0.52256725 -0.38094383 -0.39396181]
#  [ 0.41643054 -0.58653639 -1.34931411  0.52256725 -0.38094383 -0.3764894 ]
#  [ 0.09823754 -0.58653639 -1.4301041   0.52256725 -0.38094383 -0.35901698]
#  [ 0.05434885 -0.58653639 -1.4301041   0.61900753 -0.38094383 -0.32387584]
#  [ 0.26282012 -0.58653639 -1.34931411  0.7154478  -0.38094383 -0.2887347 ]
#  [ 0.21893143 -0.65625711 -1.4301041   0.7154478  -0.38094383 -0.25359356]
#  [ 0.3505975  -0.58653639 -1.34931411  0.81188808 -0.38094383 -0.21845241]
#  [ 0.43837488 -0.58653639 -1.34931411  0.90832835 -0.38094383 -0.15700449]
#  [ 0.57004095 -0.65625711 -1.34931411  0.90832835 -0.38094383 -0.09555657]]
# [ 0.31768099 -1.2140229  -1.26852411  0.32968671 -0.38094383 -0.46404777
#   0.52615226 -1.14430217 -1.26852411  0.32968671 -0.38094383 -0.44657536
#   0.64684616 -0.86541928 -1.34931411  0.42612698 -0.38094383 -0.42910295
#   0.88823396 -0.58653639 -1.34931411  0.52256725 -0.38094383 -0.39396181
#   0.41643054 -0.58653639 -1.34931411  0.52256725 -0.38094383 -0.3764894
#   0.09823754 -0.58653639 -1.4301041   0.52256725 -0.38094383 -0.35901698
#   0.05434885 -0.58653639 -1.4301041   0.61900753 -0.38094383 -0.32387584
#   0.26282012 -0.58653639 -1.34931411  0.7154478  -0.38094383 -0.2887347
#   0.21893143 -0.65625711 -1.4301041   0.7154478  -0.38094383 -0.25359356
#   0.3505975  -0.58653639 -1.34931411  0.81188808 -0.38094383 -0.21845241
#   0.43837488 -0.58653639 -1.34931411  0.90832835 -0.38094383 -0.15700449
#   0.57004095 -0.65625711 -1.34931411  0.90832835 -0.38094383 -0.09555657]

# %% [markdown]
# Se dividen nuevamente los conjuntos de datos

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainX, testX = train_test_split(datosX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testX, valX = train_test_split(testX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainX son: ", trainX.shape)
print("Las dimensiones de testX son: ", testX.shape)
print("Las dimensiones de valX son: ", valX.shape)
# Out:
# Las dimensiones de trainX son:  (30635, 12, 6)
# Las dimensiones de testX son:  (8797, 12, 6)
# Las dimensiones de valX son:  (4333, 12, 6)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainMLPX, testMLPX = train_test_split(datosMLPX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testMLPX, valMLPX = train_test_split(testMLPX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainMLPX son: ", trainMLPX.shape)
print("Las dimensiones de testMLPX son: ", testMLPX.shape)
print("Las dimensiones de valMLPX son: ", valMLPX.shape)
# Out:
# Las dimensiones de trainMLPX son:  (30635, 72)
# Las dimensiones de testMLPX son:  (8797, 72)
# Las dimensiones de valMLPX son:  (4333, 72)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainY, testY = train_test_split(datosY, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testY, valY = train_test_split(testY, test_size=0.33, shuffle=False)

print("Las dimensiones de trainY son: ", trainY.shape)
print("Las dimensiones de testY son: ", testY.shape)
print("Las dimensiones de valY son: ", valY.shape)
# Out:
# Las dimensiones de trainY son:  (30635, 1)
# Las dimensiones de testY son:  (8797, 1)
# Las dimensiones de valY son:  (4333, 1)

# %% [markdown]
# Se crean métricas para medir desempeño

# %%
import tensorflow.keras.backend as K

def smape(y_true, y_pred):
    """
    Define la función SMAPE (Error Porcentual Absoluto Medio Simétrico).
    """
    summ = K.abs(y_true) + K.abs(y_pred)
    smape_val = K.abs(y_pred - y_true) / summ * 2.0
    return K.mean(smape_val, axis=-1)

def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

def ia(y_true, y_pred):
    numerator = K.sum(K.abs(y_true - y_pred))
    denominator = K.sum(K.abs(y_true - K.mean(y_true)) + K.abs(y_pred - K.mean(y_true)))
    return 1 - (numerator / denominator)

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

def graficarPrediccion(modelo, x, y, inicio, final):
  predicciones = modelo.predict(x)
  predicciones = predicciones.flatten()
  df = pd.DataFrame({'Originales': y, 'Predichos': predicciones})
  plt.plot(df.index, df['Originales'][inicio:final], label='Originales')
  plt.plot(df.index, df['Predichos'][inicio:final], label='Predichos')
  return df, mse(y, predicciones),  mae(y, predicciones), rmse(y, predicciones), smape(y,predicciones), ia(y, predicciones)

# %% [markdown]
# Se define el index del conjunto de validación para utilizarlo posteriormente para graficar.

# %%
# Fecha y hora de término del conjunto de datos de prueba
end_date = datosNormalizados.index[-1]
n_observations = valY.shape[0]  # Cambia esto al número de observaciones en tu conjunto de prueba

# Calcular la fecha y hora de inicio
start_date = end_date - timedelta(hours=(n_observations - 1))

# Crear la serie de fechas y horas
val_date = pd.date_range(start=start_date, end=end_date, freq='1H')

val_date
# Out:
# C:\Users\wamt1\AppData\Local\Temp\ipykernel_14504\3958427235.py:9: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   val_date = pd.date_range(start=start_date, end=end_date, freq='1H')
# DatetimeIndex(['2014-07-04 11:00:00', '2014-07-04 12:00:00',
#                '2014-07-04 13:00:00', '2014-07-04 14:00:00',
#                '2014-07-04 15:00:00', '2014-07-04 16:00:00',
#                '2014-07-04 17:00:00', '2014-07-04 18:00:00',
#                '2014-07-04 19:00:00', '2014-07-04 20:00:00',
#                ...
#                '2014-12-31 14:00:00', '2014-12-31 15:00:00',
#                '2014-12-31 16:00:00', '2014-12-31 17:00:00',
#                '2014-12-31 18:00:00', '2014-12-31 19:00:00',
#                '2014-12-31 20:00:00', '2014-12-31 21:00:00',
#                '2014-12-31 22:00:00', '2014-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=4333, freq='h')

# %% [markdown]
# Se guardan los índices de las observaciones a utilizar para predecir

# %%
indices = []
for i in range(pasados, len(datosNormalizados) - futuros + 1):
  indices.append(datosNormalizados.index[i+futuros-1])

# %% [markdown]
# # Modelos

# %% [markdown]
# ## MLP

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelMLP = Sequential()
modelMLP.add(InputLayer(input_shape=(trainMLPX.shape[1],)))

modelMLP.add(Dense(units=128, activation="linear"))
modelMLP.add(Dropout(0.0))

modelMLP.add(Dense(units=128, activation="linear"))
modelMLP.add(Dropout(0.0))

modelMLP.add(Dense(units=128, activation="linear"))
modelMLP.add(Dropout(0.0))

modelMLP.add(Dense(units=128, activation="linear"))
modelMLP.add(Dropout(0.0))

modelMLP.add(Dense(1))

opt = Adam(learning_rate=0.00027101707182655693)

modelMLP.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelMLP.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         9,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 59,009 (230.50 KB)
#  Trainable params: 59,009 (230.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyMLP = modelMLP.fit(trainMLPX, trainY, epochs=128, validation_data=(testMLPX, testY), verbose = 2, batch_size=16, callbacks=[early_stopping])

prediccionMLP = modelMLP.predict(valMLPX)
# Out:
# Epoch 1/128
# 1915/1915 - 7s - 4ms/step - ia: 0.3788 - loss: 0.8618 - mae: 0.6856 - rmse: 0.8950 - smape: 1.3029 - val_ia: 0.2457 - val_loss: 0.7799 - val_mae: 0.6598 - val_rmse: 0.7279 - val_smape: 1.3205
# Epoch 2/128
# 1915/1915 - 5s - 3ms/step - ia: 0.3807 - loss: 0.8322 - mae: 0.6719 - rmse: 0.8789 - smape: 1.2954 - val_ia: 0.2465 - val_loss: 0.7749 - val_mae: 0.6567 - val_rmse: 0.7245 - val_smape: 1.3143
# Epoch 3/128
# 1915/1915 - 4s - 2ms/step - ia: 0.3813 - loss: 0.8280 - mae: 0.6698 - rmse: 0.8766 - smape: 1.2947 - val_ia: 0.2469 - val_loss: 0.7728 - val_mae: 0.6548 - val_rmse: 0.7226 - val_smape: 1.3087
# Epoch 4/128
# 1915/1915 - 5s - 3ms/step - ia: 0.3823 - loss: 0.8251 - mae: 0.6684 - rmse: 0.8750 - smape: 1.2925 - val_ia: 0.2475 - val_loss: 0.7712 - val_mae: 0.6535 - val_rmse: 0.7213 - val_smape: 1.3041
# Epoch 5/128
# 1915/1915 - 4s - 2ms/step - ia: 0.3832 - loss: 0.8226 - mae: 0.6672 - rmse: 0.8736 - smape: 1.2902 - val_ia: 0.2481 - val_loss: 0.7708 - val_mae: 0.6524 - val_rmse: 0.7205 - val_smape: 1.3004
# Epoch 6/128
# 1915/1915 - 4s - 2ms/step - ia: 0.
# Epoch 20/128
# 1915/1915 - 9s - 5ms/step - ia: 0.3872 - loss: 0.8126 - mae: 0.6624 - rmse: 0.8681 - smape: 1.2837 - val_ia: 0.2517 - val_loss: 0.7609 - val_mae: 0.6419 - val_rmse: 0.7114 - val_smape: 1.2620
# Epoch 21/128
# 1915/1915 - 8s - 4ms/step - ia: 0.3872 - loss: 0.8124 - mae: 0.6623 - rmse: 0.8680 - smape: 1.2838 - val_ia: 0.2520 - val_loss: 0.7607 - val_mae: 0.6415 - val_rmse: 0.7113 - val_smape: 1.2600
# Epoch 22/128
# 1915/1915 - 6s - 3ms/step - ia: 0.3873 - loss: 0.8122 - mae: 0.6622 - rmse: 0.8679 - smape: 1.2834 - val_ia: 0.2520 - val_loss: 0.7608 - val_mae: 0.6415 - val_rmse: 0.7112 - val_smape: 1.2599
# Epoch 23/128
# 1915/1915 - 3s - 2ms/step - ia: 0.3874 - loss: 0.8120 - mae: 0.6621 - rmse: 0.8678 - smape: 1.2834 - val_ia: 0.2524 - val_loss: 0.7606 - val_mae: 0.6411 - val_rmse: 0.7110 - val_smape: 1.2576
# Epoch 24/128
# 1915/1915 - 5s - 3ms/step - ia: 0.3874 - loss: 0.8119 - mae: 0.6620 - rmse: 0.8677 - smape: 1.2834 - val_ia: 0.2524 - val_loss: 0.7606 - val_mae: 0.6411 - val_rmse: 0.7110 - val_smape: 1.2567
# Epoch 25/128
# 1915/1915 - 6s - 3ms/step - ia: 0.3875 - loss: 0.8118 - mae: 0.6620 - rmse: 0.8677 - smape: 1.2834 - val_ia: 0.2525 - val_loss: 0.7604 - val_mae: 0.6409 - val_rmse: 0.7108 - val_smape: 1.2565
# Epoch 26/128
# 1915/1915 - 6s - 3ms/step - ia: 0.3875 - loss: 0.8116 - mae: 0.6619 - rmse: 0.8676 - smape: 1.2832 - val_ia: 0.2527 - val_loss: 0.7602 - val_mae: 0.6408 - val_rmse: 0.7108 - val_smape: 1.2558
# Epoch 27/128
# 1915/1915 - 3s - 2ms/step - ia: 0.3876 - loss: 0.8115 - mae: 0.6618 - rmse: 0.8675 - smape: 1.2832 - val_ia: 0.2528 - val_loss: 0.7605 - val_mae: 0.6409 - val_rmse: 0.7111 - val_smape: 1.2558
# Epoch 28/128
# 1915/1915 - 5s - 3ms/step - ia: 0.3877 - loss: 0.8114 - mae: 0.6617 - rmse: 0.8674 - smape: 1.2831 - val_ia: 0.2531 - val_loss: 0.7599 - val_mae: 0.6405 - val_rmse: 0.7107 - val_smape: 1.2545
# Epoch 29/128
# 1915/1915 - 6s - 3ms/step - ia: 0.3878 - loss: 0.8113 - mae: 0.6617 - rmse: 0.8674 - smape: 1.2828 - val_ia: 0.2533 - val_loss: 0.7594 - val_mae: 0.6400 - val_rmse: 0.7101 - val_smape: 1.2524
# Epoch 30/128
# 1915/1915 - 6s - 3ms/step - ia: 0.3878 - loss: 0.8112 - mae: 0.6616 - rmse: 0.8673 - smape: 1.2826 - val_ia: 0.2538 - val_loss: 0.7586 - val_mae: 0.6393 - val_rmse: 0.7095 - val_smape: 1.2506
# Epoch 31/128
# 1915/1915 - 6s - 3ms/step - ia: 0.3879 - loss: 0.8111 - mae: 0.6616 - rmse: 0.8673 - smape: 1.2827 - val_ia: 0.2538 - val_loss: 0.7583 - val_mae: 0.6393 - val_rmse: 0.7095 - val_smape: 1.2502
# Epoch 32/128
# 1915/1915 - 4s - 2ms/step - ia: 0.
128
# 1915/1915 - 4s - 2ms/step - ia: 0.3890 - loss: 0.8098 - mae: 0.6607 - rmse: 0.8665 - smape: 1.2802 - val_ia: 0.2544 - val_loss: 0.7551 - val_mae: 0.6372 - val_rmse: 0.7076 - val_smape: 1.2425
# Epoch 59/128
# 1915/1915 - 4s - 2ms/step - ia: 0.3891 - loss: 0.8097 - mae: 0.6607 - rmse: 0.8665 - smape: 1.2800 - val_ia: 0.2543 - val_loss: 0.7551 - val_mae: 0.6372 - val_rmse: 0.7076 - val_smape: 1.2426
# Epoch 60/128
# 1915/1915 - 5s - 3ms/step - ia: 0.3891 - loss: 0.8097 - mae: 0.6607 - rmse: 0.8665 - smape: 1.2801 - val_ia: 0.2543 - val_loss: 0.7552 - val_mae: 0.6370 - val_rmse: 0.7076 - val_smape: 1.2418
# Epoch 61/128
# 1915/1915 - 4s - 2ms/step - ia: 0.3891 - loss: 0.8097 - mae: 0.6607 - rmse: 0.8664 - smape: 1.2802 - val_ia: 0.2544 - val_loss: 0.7554 - val_mae: 0.6370 - val_rmse: 0.7076 - val_smape: 1.2415
# Epoch 62/128
# 1915/1915 - 6s - 3ms/step - ia: 0.3891 - loss: 0.8097 - mae: 0.6607 - rmse: 0.8664 - smape: 1.2800 - val_ia: 0.2541 - val_loss: 0.7557 - val_mae: 0.6372 - val_rmse: 0.7076 - val_smape: 1.2424
# Epoch 63/128
# 1915/1915 - 10s - 5ms/step - ia: 0.3891 - loss: 0.8096 - mae: 0.6607 - rmse: 0.8664 - smape: 1.2800 - val_ia: 0.2541 - val_loss: 0.7560 - val_mae: 0.6373 - val_rmse: 0.7077 - val_smape: 1.2431
# Epoch 64/128
# 1915/1915 - 10s - 5ms/step - ia: 0.3891 - loss: 0.8096 - mae: 0.6607 - rmse: 0.8664 - smape: 1.2801 - val_ia: 0.2540 - val_loss: 0.7556 - val_mae: 0.6370 - val_rmse: 0.7074 - val_smape: 1.2425
# Epoch 65/128
# 1915/1915 - 5s - 3ms/step - ia: 0.3891 - loss: 0.8096 - mae: 0.6607 - rmse: 0.8664 - smape: 1.2800 - val_ia: 0.2542 - val_loss: 0.7552 - val_mae: 0.6370 - val_rmse: 0.7075 - val_smape: 1.2422
# Epoch 66/128
# 1915/1915 - 5s - 3ms/step - ia: 0.3891 - loss: 0.8096 - mae: 0.6607 - rmse: 0.8664 - smape: 1.2801 - val_ia: 0.2545 - val_loss: 0.7552 - val_mae: 0.6371 - val_rmse: 0.7075 - val_smape: 1.2419
# Epoch 67/128
# 1915/1915 - 7s - 4ms/step - ia: 0.3892 - loss: 0.8096 - mae: 0.6606 - rmse: 0.8664 - smape: 1.2800 - val_ia: 0.2544 - val_loss: 0.7553 - val_mae: 0.6372 - val_rmse: 0.7076 - val_smape: 1.2424
# Epoch 68/128
# 1915/1915 - 6s - 3ms/step - ia: 0.3892 - loss: 0.8095 - mae: 0.6606 - rmse: 0.8664 - smape: 1.2799 - val_ia: 0.2542 - val_loss: 0.7549 - val_mae: 0.6371 - val_rmse: 0.7075 - val_smape: 1.2431
# Epoch 69/128
# 1915/1915 - 7s - 4ms/step - ia: 0.3892 - loss: 0.8095 - mae: 0.6606 - rmse: 0.8664 - smape: 1.2799 - val_ia: 0.2542 - val_loss: 0.7549 - val_mae: 0.6371 - val_rmse: 0.7075 - val_smape: 1.2430
# Epoch 70/128
# 1915/1915 - 7s - 4ms/step - ia: 0.3892 - loss: 0.8095 - mae: 0.6606 - rmse: 0.8663 - smape: 1.2798 - val_ia: 0.2542 - val_loss: 0.7548 - val_mae: 0.6372 - val_rmse: 0.7076 - val_smape: 1.2433
# Epoch 71/128
# 1915/1915 - 10s - 5ms/step - ia: 0.3892 - loss: 0.8095 - mae: 0.6606 - rmse: 0.8663 - smape: 1.2798 - val_ia: 0.2544 - val_loss: 0.7547 - val_mae: 0.6371 - val_rmse: 0.7075 - val_smape: 1.2426
# Epoch 72/128
# 1915/1915 - 10s - 5ms/step - ia: 0.3892 - loss: 0.8094 - mae: 0.6606 - rmse: 0.8663 - smape: 1.2798 - val_ia: 0.2547 - val_loss: 0.7548 - val_mae: 0.6370 - val_rmse: 0.7075 - val_smape: 1.2417
# Epoch 73/128
# 1915/1915 - 10s - 5ms/step - ia: 0.3893 - loss: 0.8093 - mae: 0.6605 - rmse: 0.8663 - smape: 1.2796 - val_ia: 0.2548 - val_loss: 0.7551 - val_mae: 0.6370 - val_rmse: 0.7075 - val_smape: 1.2415
# Epoch 74/128
# 1915/1915 - 10s - 5ms/step - ia: 0.3893 - loss: 0.8093 - mae: 0.6605 - rmse: 0.8663 - smape: 1.2795 - val_ia: 0.2546 - val_loss: 0.7552 - val_mae: 0.6368 - val_rmse: 0.7074 - val_smape: 1.2415
# Epoch 75/128
# 1915/1915 - 6s - 3ms/step - ia: 0.3893 - loss: 0.8092 - mae: 0.6605 - rmse: 0.8662 - smape: 1.2795 - val_ia: 0.2545 - val_loss: 0.7556 - val_mae: 0.6370 - val_rmse: 0.7075 - val_smape: 1.2425
# Epoch 76/128
# 1915/1915 - 10s - 5ms/step - ia: 0.3894 - loss: 0.8092 - mae: 0.6605 - rmse: 0.8662 - smape: 1.2795 - val_ia: 0.2543 - val_loss: 0.7556 - val_mae: 0.6370 - val_rmse: 0.7076 - val_smape: 1.2430
# Epoch 77/128
# 1915/1915 - 10s - 5ms/step - ia: 0.3893 - loss: 0.8093 - mae: 0.6605 - rmse: 0.8663 - smape: 1.2796 - val_ia: 0.2546 - val_loss: 0.7551 - val_mae: 0.6372 - val_rmse: 0.7078 - val_smape: 1.2425
# Epoch 78/128
# 1915/1915 - 6s - 3ms/step - ia: 0.3894 - loss: 0.8093 - mae: 0.6605 - rmse: 0.8663 - smape: 1.2792 - val_ia: 0.2544 - val_loss: 0.7550 - val_mae: 0.6372 - val_rmse: 0.7076 - val_smape: 1.2432
# Epoch 79/128
# 1915/1915 - 6s - 3ms/step - ia: 0.3894 - loss: 0.8093 - mae: 0.6605 - rmse: 0.8663 - smape: 1.2792 - val_ia: 0.2543 - val_loss: 0.7549 - val_mae: 0.6372 - val_rmse: 0.7077 - val_smape: 1.2434
# Epoch 80/128
# 1915/1915 - 9s - 5ms/step - ia: 0.3893 - loss: 0.8093 - mae: 0.6605 - rmse: 0.8663 - smape: 1.2792 - val_ia: 0.2543 - val_loss: 0.7549 - val_mae: 0.6373 - val_rmse: 0.7079 - val_smape: 1.2435
# Epoch 81/128
# 1915/1915 - 3s - 2ms/step - ia: 0.3893 - loss: 0.8093 - mae: 0.6605 - rmse: 0.8662 - smape: 1.2795 - val_ia: 0.2544 - val_loss: 0.7549 - val_mae: 0.6372 - val_rmse: 0.7078 - val_smape: 1.2432
# Epoch 82/128
# 1915/1915 - 3s - 2ms/step - ia: 0.3894 - loss: 0.8093 - mae: 0.6604 - rmse: 0.8662 - smape: 1.2793 - val_ia: 0.2544 - val_loss: 0.7550 - val_mae: 0.6371 - val_rmse: 0.7078 - val_smape: 1.2425
# Epoch 83/128
# 1915/1915 - 5s - 3ms/step - ia: 0.3894 - loss: 0.8093 - mae: 0.6604 - rmse: 0.8662 - smape: 1.2791 - val_ia: 0.2543 - val_loss: 0.7553 - val_mae: 0.6371 - val_rmse: 0.7076 - val_smape: 1.2432
# Epoch 84/128
# 1915/1915 - 4s - 2ms/step - ia: 0.3895 - loss: 0.8092 - mae: 0.6604 - rmse: 0.8662 - smape: 1.2789 - val_ia: 0.2548 - val_loss: 0.7556 - val_mae: 0.6368 - val_rmse: 0.7076 - val_smape: 1.2416
# Epoch 85/128
# 1915/1915 - 6s - 3ms/step - ia: 0.3895 - loss: 0.8092 - mae: 0.6604 - rmse: 0.8662 - smape: 1.2792 - val_ia: 0.2548 - val_loss: 0.7558 - val_mae: 0.6368 - val_rmse: 0.7077 - val_smape: 1.2414
# Epoch 86/128
# 1915/1915 - 6s - 3ms/step - ia: 0.3895 - loss: 0.8092 - mae: 0.6604 - rmse: 0.8662 - smape: 1.2792 - val_ia: 0.2547 - val_loss: 0.7561 - val_mae: 0.6371 - val_rmse: 0.7079 - val_smape: 1.2427
# Epoch 86: early stopping
# Restoring model weights from the end of the best epoch: 71.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
metricasMLP = modelMLP.evaluate(valMLPX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasMLP}")
# Out:
# 136/136 - 1s - 5ms/step - ia: 0.2713 - loss: 0.7778 - mae: 0.6600 - rmse: 0.7484 - smape: 1.2557
# Métricas en el conjunto de validación: [0.7777969241142273, 0.6599528789520264, 1.255655288696289, 0.7483543157577515, 0.2713422179222107]

# %%
historyMLP = historyMLP.history
ejeXMLP = range(1, len(historyMLP['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXMLP, historyMLP['loss'], label='Train Loss')
plt.plot(ejeXMLP, historyMLP['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyMLP['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyMLP['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.8092002868652344
# Último valor de Test Loss: 0.756050705909729

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionMLP.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfMLP = df
fig.show()

# %% [markdown]
# ### Datos para NARMAX

# %%
prediccionNarmaxMLP = modelMLP.predict(datosMLPX)
erroresMLP = datosY - prediccionNarmaxMLP
# Out:
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step

# %%
dfErroresMLP = pd.DataFrame(erroresMLP, columns = ["e"])
dfErroresMLP.index = indices

# %%
dfNarmaxMLP = datosNormalizados.join(dfErroresMLP, how = 'left')

print(dfNarmaxMLP.head())
print(dfNarmaxMLP.tail())
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 00:00:00   0.317681 -1.214023 -1.268524  0.329687 -0.380944
# 2010-01-02 01:00:00   0.526152 -1.144302 -1.268524  0.329687 -0.380944
# 2010-01-02 02:00:00   0.646846 -0.865419 -1.349314  0.426127 -0.380944
# 2010-01-02 03:00:00   0.888234 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 04:00:00   0.416431 -0.586536 -1.349314  0.522567 -0.380944
#
#                       wnd_spd   e
# date
# 2010-01-02 00:00:00 -0.464048 NaN
# 2010-01-02 01:00:00 -0.446575 NaN
# 2010-01-02 02:00:00 -0.429103 NaN
# 2010-01-02 03:00:00 -0.393962 NaN
# 2010-01-02 04:00:00 -0.376489 NaN
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2014-12-31 19:00:00  -1.009952 -1.702068 -1.106944  1.679851  0.694538
# 2014-12-31 20:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 21:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 22:00:00  -1.009952 -1.632347 -1.268524  1.679851  0.694538
# 2014-12-31 23:00:00  -0.966063 -1.562627 -1.187734  1.679851  0.694538
#
#                       wnd_spd         e
# date
# 2014-12-31 19:00:00  4.054828 -0.672097
# 2014-12-31 20:00:00  4.168890 -0.606625
# 2014-12-31 21:00:00  4.265479 -0.597509
# 2014-12-31 22:00:00  4.344399 -0.427131
# 2014-12-31 23:00:00  4.405847 -0.381507

# %%
dfNarmaxMLP.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\24pasos_mlp_pollution.csv', index=True)

# %%
dfMLP.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacion\\24pasos_mlp_pollution.csv', index=True)

# %%
modelMLP.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarx\\24pasos_mlp_pollution.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## LSTM

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelLSTM = Sequential()
modelLSTM.add(InputLayer(input_shape=(trainX.shape[1], trainX.shape[2])))

modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=True))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=True))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=True))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=False))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(Dense(1))


opt = Adam(learning_rate=0.00027101707182655693)
modelLSTM.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelLSTM.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 12, 128)        │        69,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 12, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 12, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 464,001 (1.77 MB)
#  Trainable params: 464,001 (1.77 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyLSTM = modelLSTM.fit(trainX, trainY, epochs=128, validation_data=(testX, testY), verbose = 2, batch_size=16, callbacks=[early_stopping])


prediccionLSTM = modelLSTM.predict(valX)
# Out:
# Epoch 1/128
# 1915/1915 - 72s - 38ms/step - ia: 0.3632 - loss: 0.8341 - mae: 0.6734 - rmse: 0.8788 - smape: 1.3283 - val_ia: 0.2428 - val_loss: 0.7742 - val_mae: 0.6593 - val_rmse: 0.7260 - val_smape: 1.3353
# Epoch 2/128
# 1915/1915 - 49s - 25ms/step - ia: 0.4078 - loss: 0.7834 - mae: 0.6474 - rmse: 0.8515 - smape: 1.2484 - val_ia: 0.2449 - val_loss: 0.7645 - val_mae: 0.6492 - val_rmse: 0.7189 - val_smape: 1.2877
# Epoch 3/128
# 1915/1915 - 48s - 25ms/step - ia: 0.4235 - loss: 0.7655 - mae: 0.6372 - rmse: 0.8414 - smape: 1.2209 - val_ia: 0.2443 - val_loss: 0.7682 - val_mae: 0.6490 - val_rmse: 0.7204 - val_smape: 1.2780
# Epoch 4/128
# 1915/1915 - 48s - 25ms/step - ia: 0.4345 - loss: 0.7501 - mae: 0.6299 - rmse: 0.8330 - smape: 1.2044 - val_ia: 0.2439 - val_loss: 0.8102 - val_mae: 0.6601 - val_rmse: 0.7331 - val_smape: 1.2830
# Epoch 5/128
# 1915/1915 - 48s - 25ms/step - ia: 0.4420 - loss: 0.7372 - mae: 0.6241 - rmse: 0.8261 - smape: 1.1927 - val_ia: 0.2431 - val_loss: 0.8489 - val_mae: 0.6774 - val_rmse: 0.7536 - val_smape: 1.3018
# Epoch 6/128
# 1915/1915 - 45s - 24ms/step - ia: 0.4512 - loss: 0.7199 - mae: 0.6162 - rmse: 0.8167 - smape: 1.1796 - val_ia: 0.2465 - val_loss: 0.8535 - val_mae: 0.6739 - val_rmse: 0.7483 - val_smape: 1.3001
# Epoch 7/128
# 1915/1915 - 49s - 26ms/step - ia: 0.4626 - loss: 0.6975 - mae: 0.6066 - rmse: 0.8044 - smape: 1.1661 - val_ia: 0.2464 - val_loss: 0.8548 - val_mae: 0.6741 - val_rmse: 0.7523 - val_smape: 1.2886
# Epoch 8/128
# 1915/1915 - 47s - 25ms/step - ia: 0.4701 - loss: 0.6876 - mae: 0.6008 - rmse: 0.7976 - smape: 1.1559 - val_ia: 0.2436 - val_loss: 0.8759 - val_mae: 0.6811 - val_rmse: 0.7584 - val_smape: 1.3028
# Epoch 9/128
# 1915/1915 - 82s - 43ms/step - ia: 0.4838 - loss: 0.6535 - mae: 0.5877 - rmse: 0.7792 - smape: 1.1429 - val_ia: 0.2424 - val_loss: 0.8816 - val_mae: 0.6854 - val_rmse: 0.7642 - val_smape: 1.3129
# Epoch 10/128
# 1915/1915 - 44s - 23ms/step - ia: 0.4922 - loss: 0.6370 - mae: 0.5805 - rmse: 0.7696 - smape: 1.1317 - val_ia: 0.2414 - val_loss: 0.8853 - val_mae: 0.6832 - val_rmse: 0.7648 - val_smape: 1.2968
# Epoch 11/128
# 1915/1915 - 49s - 26ms/step - ia: 0.5007 - loss: 0.6226 - mae: 0.5730 - rmse: 0.7607 - smape: 1.1205 - val_ia: 0.2396 - val_loss: 0.9224 - val_mae: 0.6900 - val_rmse: 0.7740 - val_smape: 1.2904
# Epoch 12/128
# 1915/1915 - 49s - 25ms/step - ia: 0.5128 - loss: 0.6000 - mae: 0.5619 - rmse: 0.7463 - smape: 1.1034 - val_ia: 0.2437 - val_loss: 0.8883 - val_mae: 0.6789 - val_rmse: 0.7615 - val_smape: 1.2727
# Epoch 13/128
# 1915/1915 - 48s - 25ms/step - ia: 0.5236 - loss: 0.5786 - mae: 0.5523 - rmse: 0.7329 - smape: 1.0867 - val_ia: 0.2454 - val_loss: 0.9321 - val_mae: 0.6896 - val_rmse: 0.7789 - val_smape: 1.2650
# Epoch 14/128
# 1915/1915 - 48s - 25ms/step - ia: 0.5386 - loss: 0.5519 - mae: 0.5384 - rmse: 0.7157 - smape: 1.0655 - val_ia: 0.2445 - val_loss: 0.9514 - val_mae: 0.6929 - val_rmse: 0.7835 - val_smape: 1.2593
# Epoch 15/128
# 1915/1915 - 48s - 25ms/step - ia: 0.5491 - loss: 0.5412 - mae: 0.5292 - rmse: 0.7053 - smape: 1.0483 - val_ia: 0.2476 - val_loss: 0.9345 - val_mae: 0.6874 - val_rmse: 0.7778 - val_smape: 1.2574
# Epoch 16/128
# 1915/1915 - 55s - 29ms/step - ia: 0.5669 - loss: 0.4962 - mae: 0.5113 - rmse: 0.6783 - smape: 1.0261 - val_ia: 0.2470 - val_loss: 0.9729 - val_mae: 0.6986 - val_rmse: 0.7923 - val_smape: 1.2623
# Epoch 17/128
# 1915/1915 - 47s - 25ms/step - ia: 0.5772 - loss: 0.4756 - mae: 0.5012 - rmse: 0.6648 - smape: 1.0069 - val_ia: 0.2504 - val_loss: 1.0337 - val_mae: 0.7087 - val_rmse: 0.8085 - val_smape: 1.2476
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step

# %%
metricasLSTM = modelLSTM.evaluate(valX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasLSTM}")
# Out:
# 136/136 - 2s - 13ms/step - ia: 0.2676 - loss: 0.7773 - mae: 0.6543 - rmse: 0.7433 - smape: 1.2309
# Métricas en el conjunto de validación: [0.7773153185844421, 0.6542829275131226, 1.2309378385543823, 0.7432780265808105, 0.26762181520462036]

# %%
historyLSTM = historyLSTM.history

ejeXLSTM = range(1, len(historyLSTM['loss']) + 1)

plt.figure(figsize=(12, 8))
plt.plot(ejeXLSTM, historyLSTM['loss'], label='Train Loss')
plt.plot(ejeXLSTM, historyLSTM['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyLSTM['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyLSTM['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.4756436049938202
# Último valor de Test Loss: 1.0337209701538086

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionLSTM.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfLSTM = df
fig.show()

# %% [markdown]
# ### Datos para NARMAX

# %%
prediccionNarmaxLSTM = modelLSTM.predict(datosX)
erroresLSTM = datosY - prediccionNarmaxLSTM
# Out:
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step

# %%
dfErroresLSTM = pd.DataFrame(erroresLSTM, columns = ["e"])
dfErroresLSTM.index = indices

# %%
dfNarmaxLSTM = datosNormalizados.join(dfErroresLSTM, how = 'left')

print(dfNarmaxLSTM.head())
print(dfNarmaxLSTM.tail())
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 00:00:00   0.317681 -1.214023 -1.268524  0.329687 -0.380944
# 2010-01-02 01:00:00   0.526152 -1.144302 -1.268524  0.329687 -0.380944
# 2010-01-02 02:00:00   0.646846 -0.865419 -1.349314  0.426127 -0.380944
# 2010-01-02 03:00:00   0.888234 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 04:00:00   0.416431 -0.586536 -1.349314  0.522567 -0.380944
#
#                       wnd_spd   e
# date
# 2010-01-02 00:00:00 -0.464048 NaN
# 2010-01-02 01:00:00 -0.446575 NaN
# 2010-01-02 02:00:00 -0.429103 NaN
# 2010-01-02 03:00:00 -0.393962 NaN
# 2010-01-02 04:00:00 -0.376489 NaN
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2014-12-31 19:00:00  -1.009952 -1.702068 -1.106944  1.679851  0.694538
# 2014-12-31 20:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 21:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 22:00:00  -1.009952 -1.632347 -1.268524  1.679851  0.694538
# 2014-12-31 23:00:00  -0.966063 -1.562627 -1.187734  1.679851  0.694538
#
#                       wnd_spd         e
# date
# 2014-12-31 19:00:00  4.054828 -0.826614
# 2014-12-31 20:00:00  4.168890 -0.783249
# 2014-12-31 21:00:00  4.265479 -0.735042
# 2014-12-31 22:00:00  4.344399 -0.667675
# 2014-12-31 23:00:00  4.405847 -0.575324

# %%
dfNarmaxLSTM.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\24pasos_lstm_pollution.csv', index=True)

# %%
dfLSTM.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacion\\24pasos_lstm_pollution.csv', index=True)

# %%
modelLSTM.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarx\\24pasos_lstm_pollution.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## GRU

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelGRU = Sequential()
modelGRU.add(InputLayer(input_shape=(trainX.shape[1], trainX.shape[2])))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=True))
modelGRU.add(Dropout(0.0))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=True))
modelGRU.add(Dropout(0.0))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=True))
modelGRU.add(Dropout(0.0))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=False))
modelGRU.add(Dropout(0.0))

modelGRU.add(Dense(1))


opt = Adam(learning_rate=0.00027101707182655693)
modelGRU.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelGRU.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 12, 128)        │        52,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 12, 128)        │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 12, 128)        │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 128)            │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 349,569 (1.33 MB)
#  Trainable params: 349,569 (1.33 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)

early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyGRU = modelGRU.fit(trainX, trainY, epochs=128, validation_data=(testX, testY), verbose = 2, batch_size=16, callbacks=[early_stopping])

prediccionGRU = modelGRU.predict(valX)
# Out:
# Epoch 1/128
# 1915/1915 - 60s - 31ms/step - ia: 0.3815 - loss: 0.8201 - mae: 0.6654 - rmse: 0.8719 - smape: 1.2908 - val_ia: 0.2432 - val_loss: 0.7753 - val_mae: 0.6557 - val_rmse: 0.7236 - val_smape: 1.3009
# Epoch 2/128
# 1915/1915 - 81s - 42ms/step - ia: 0.4101 - loss: 0.7869 - mae: 0.6475 - rmse: 0.8538 - smape: 1.2405 - val_ia: 0.2466 - val_loss: 0.7736 - val_mae: 0.6540 - val_rmse: 0.7233 - val_smape: 1.2897
# Epoch 3/128
# 1915/1915 - 46s - 24ms/step - ia: 0.4200 - loss: 0.7714 - mae: 0.6403 - rmse: 0.8453 - smape: 1.2296 - val_ia: 0.2465 - val_loss: 0.7787 - val_mae: 0.6566 - val_rmse: 0.7260 - val_smape: 1.2993
# Epoch 4/128
# 1915/1915 - 79s - 41ms/step - ia: 0.4291 - loss: 0.7573 - mae: 0.6336 - rmse: 0.8375 - smape: 1.2164 - val_ia: 0.2470 - val_loss: 0.7834 - val_mae: 0.6565 - val_rmse: 0.7264 - val_smape: 1.3007
# Epoch 5/128
# 1915/1915 - 87s - 45ms/step - ia: 0.4384 - loss: 0.7420 - mae: 0.6265 - rmse: 0.8289 - smape: 1.2036 - val_ia: 0.2486 - val_loss: 0.7758 - val_mae: 0.6511 - val_rmse: 0.7219 - val_smape: 1.2993
# Epoch 6/128
# 1915/1915 - 50s - 26ms/step - ia: 0.4482 - loss: 0.7228 - mae: 0.6186 - rmse: 0.8185 - smape: 1.1920 - val_ia: 0.2494 - val_loss: 0.7934 - val_mae: 0.6544 - val_rmse: 0.7274 - val_smape: 1.2848
# Epoch 7/128
# 1915/1915 - 81s - 42ms/step - ia: 0.4588 - loss: 0.6977 - mae: 0.6094 - rmse: 0.8051 - smape: 1.1793 - val_ia: 0.2511 - val_loss: 0.8328 - val_mae: 0.6592 - val_rmse: 0.7361 - val_smape: 1.2701
# Epoch 8/128
# 1915/1915 - 92s - 48ms/step - ia: 0.4701 - loss: 0.6713 - mae: 0.5987 - rmse: 0.7903 - smape: 1.1648 - val_ia: 0.2520 - val_loss: 0.8411 - val_mae: 0.6587 - val_rmse: 0.7358 - val_smape: 1.2712
# Epoch 9/128
# 1915/1915 - 51s - 27ms/step - ia: 0.4849 - loss: 0.6360 - mae: 0.5842 - rmse: 0.7695 - smape: 1.1496 - val_ia: 0.2468 - val_loss: 0.8861 - val_mae: 0.6731 - val_rmse: 0.7521 - val_smape: 1.2890
# Epoch 10/128
# 1915/1915 - 49s - 26ms/step - ia: 0.5007 - loss: 0.6028 - mae: 0.5698 - rmse: 0.7494 - smape: 1.1297 - val_ia: 0.2429 - val_loss: 0.8961 - val_mae: 0.6758 - val_rmse: 0.7553 - val_smape: 1.2930
# Epoch 11/128
# 1915/1915 - 50s - 26ms/step - ia: 0.5209 - loss: 0.5614 - mae: 0.5515 - rmse: 0.7239 - smape: 1.1020 - val_ia: 0.2413 - val_loss: 0.8833 - val_mae: 0.6727 - val_rmse: 0.7543 - val_smape: 1.2920
# Epoch 12/128
# 1915/1915 - 51s - 27ms/step - ia: 0.5394 - loss: 0.5236 - mae: 0.5332 - rmse: 0.6996 - smape: 1.0768 - val_ia: 0.2403 - val_loss: 0.8962 - val_mae: 0.6784 - val_rmse: 0.7627 - val_smape: 1.2959
# Epoch 13/128
# 1915/1915 - 81s - 42ms/step - ia: 0.5585 - loss: 0.4851 - mae: 0.5148 - rmse: 0.6737 - smape: 1.0524 - val_ia: 0.2391 - val_loss: 0.9212 - val_mae: 0.6836 - val_rmse: 0.7700 - val_smape: 1.2960
# Epoch 14/128
# 1915/1915 - 51s - 27ms/step - ia: 0.5828 - loss: 0.4394 - mae: 0.4910 - rmse: 0.6412 - smape: 1.0173 - val_ia: 0.2389 - val_loss: 1.0049 - val_mae: 0.7066 - val_rmse: 0.7996 - val_smape: 1.2870
# Epoch 15/128
# 1915/1915 - 80s - 42ms/step - ia: 0.6084 - loss: 0.3915 - mae: 0.4658 - rmse: 0.6061 - smape: 0.9805 - val_ia: 0.2356 - val_loss: 1.0183 - val_mae: 0.7115 - val_rmse: 0.8064 - val_smape: 1.2905
# Epoch 16/128
# 1915/1915 - 46s - 24ms/step - ia: 0.6303 - loss: 0.3537 - mae: 0.4437 - rmse: 0.5767 - smape: 0.9453 - val_ia: 0.2372 - val_loss: 1.0299 - val_mae: 0.7120 - val_rmse: 0.8074 - val_smape: 1.2787
# Epoch 17/128
# 1915/1915 - 69s - 36ms/step - ia: 0.6528 - loss: 0.3171 - mae: 0.4205 - rmse: 0.5465 - smape: 0.9069 - val_ia: 0.2375 - val_loss: 1.0598 - val_mae: 0.7176 - val_rmse: 0.8156 - val_smape: 1.2618
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step

# %%
metricasGRU = modelGRU.evaluate(valX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasGRU}")
# Out:
# 136/136 - 1s - 7ms/step - ia: 0.2656 - loss: 0.7866 - mae: 0.6614 - rmse: 0.7522 - smape: 1.2268
# Métricas en el conjunto de validación: [0.7866348624229431, 0.6613908410072327, 1.2267799377441406, 0.7522144913673401, 0.2656118869781494]

# %%
historyGRU = historyGRU.history

ejeXGRU = range(1, len(historyGRU['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXGRU, historyGRU['loss'], label='Train Loss')
plt.plot(ejeXGRU, historyGRU['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyGRU['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyGRU['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.31708014011383057
# Último valor de Test Loss: 1.0598362684249878

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionGRU.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfGRU = df
fig.show()

# %% [markdown]
# ### Datos para NARMAX

# %%
prediccionNarmaxGRU = modelGRU.predict(datosX)
erroresGRU = datosY - prediccionNarmaxGRU
# Out:
# 1368/1368 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step

# %%
dfErroresGRU = pd.DataFrame(erroresGRU, columns = ["e"])
dfErroresGRU.index = indices

# %%
dfNarmaxGRU = datosNormalizados.join(dfErroresGRU, how = 'left')

print(dfNarmaxGRU.head())
print(dfNarmaxGRU.tail())
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 00:00:00   0.317681 -1.214023 -1.268524  0.329687 -0.380944
# 2010-01-02 01:00:00   0.526152 -1.144302 -1.268524  0.329687 -0.380944
# 2010-01-02 02:00:00   0.646846 -0.865419 -1.349314  0.426127 -0.380944
# 2010-01-02 03:00:00   0.888234 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 04:00:00   0.416431 -0.586536 -1.349314  0.522567 -0.380944
#
#                       wnd_spd   e
# date
# 2010-01-02 00:00:00 -0.464048 NaN
# 2010-01-02 01:00:00 -0.446575 NaN
# 2010-01-02 02:00:00 -0.429103 NaN
# 2010-01-02 03:00:00 -0.393962 NaN
# 2010-01-02 04:00:00 -0.376489 NaN
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2014-12-31 19:00:00  -1.009952 -1.702068 -1.106944  1.679851  0.694538
# 2014-12-31 20:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 21:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 22:00:00  -1.009952 -1.632347 -1.268524  1.679851  0.694538
# 2014-12-31 23:00:00  -0.966063 -1.562627 -1.187734  1.679851  0.694538
#
#                       wnd_spd         e
# date
# 2014-12-31 19:00:00  4.054828 -0.884729
# 2014-12-31 20:00:00  4.168890 -0.762506
# 2014-12-31 21:00:00  4.265479 -0.682858
# 2014-12-31 22:00:00  4.344399 -0.558328
# 2014-12-31 23:00:00  4.405847 -0.488613

# %%
dfNarmaxGRU.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\24pasos_gru_pollution.csv', index=True)

# %%
dfGRU.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacion\\24pasos_gru_pollution.csv', index=True)

# %%
modelGRU.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarx\\24pasos_gru_pollution.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
