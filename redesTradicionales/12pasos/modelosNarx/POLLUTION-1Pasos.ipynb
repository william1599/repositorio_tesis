# %% [markdown]
# Prueba

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from hyperopt import hp, fmin, tpe, Trials, STATUS_OK
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU, InputLayer, Flatten, LSTM
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import os
from datetime import datetime, timedelta
import plotly.express as px
import plotly.graph_objects as go
import random

# %% [markdown]
# LEER DATASET

# %%
import pandas as pd

datos = pd.read_csv("C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\SNpollutionFinal.csv")

datos['date'] = pd.to_datetime(datos['date'])

# Se establece la columna date como index
datos.set_index('date', inplace=True)

# %%
datos.head()
# Out:
#                      pollution  dew  temp   press  wnd_dir  wnd_spd
# date
# 2010-01-01 00:00:00      129.0  -21 -11.0  1021.0        2     1.79
# 2010-01-01 01:00:00      129.0  -21 -12.0  1020.0        2     4.92
# 2010-01-01 02:00:00      129.0  -21 -11.0  1019.0        2     6.71
# 2010-01-01 03:00:00      129.0  -21 -14.0  1019.0        2     9.84
# 2010-01-01 04:00:00      129.0  -20 -12.0  1018.0        2    12.97

# %%
datos = datos.drop(datos.index[:24])

datos
# Out:
#                      pollution  dew  temp   press  wnd_dir  wnd_spd
# date
# 2010-01-02 00:00:00      129.0  -16  -4.0  1020.0        1     1.79
# 2010-01-02 01:00:00      148.0  -15  -4.0  1020.0        1     2.68
# 2010-01-02 02:00:00      159.0  -11  -5.0  1021.0        1     3.57
# 2010-01-02 03:00:00      181.0   -7  -5.0  1022.0        1     5.36
# 2010-01-02 04:00:00      138.0   -7  -5.0  1022.0        1     6.25
# ...                        ...  ...   ...     ...      ...      ...
# 2014-12-31 19:00:00        8.0  -23  -2.0  1034.0        2   231.97
# 2014-12-31 20:00:00       10.0  -22  -3.0  1034.0        2   237.78
# 2014-12-31 21:00:00       10.0  -22  -3.0  1034.0        2   242.70
# 2014-12-31 22:00:00        8.0  -22  -4.0  1034.0        2   246.72
# 2014-12-31 23:00:00       12.0  -21  -3.0  1034.0        2   249.85
#
# [43800 rows x 6 columns]

# %%
#Se verifica que el index está en formato de dato "datetime64"
print("El index del dataframe input es un tipo de dato: ", datos.index.dtype)
# Out:
# El index del dataframe input es un tipo de dato:  datetime64[ns]

# %% [markdown]
# Se divide el dataset

# %%
# Dividir el conjunto de datos en entrenamiento y prueba
train, test = train_test_split(datos, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
test, val = train_test_split(test, test_size=0.33, shuffle=False)

print("Las dimensiones de train son: ", train.shape)
print("Las dimensiones de test son: ", test.shape)
print("Las dimensiones de val son: ", val.shape)
# Out:
# Las dimensiones de train son:  (30660, 6)
# Las dimensiones de test son:  (8803, 6)
# Las dimensiones de val son:  (4337, 6)

# %% [markdown]
# Se normalizan los datos

# %%
from sklearn.preprocessing import StandardScaler


# Normalizar solo con los datos de entrenamiento
scaler = StandardScaler()
train = scaler.fit_transform(train)

# Aplicar la transformación a test y val usando los parámetros de train
test = scaler.transform(test)
val = scaler.transform(val)

train = pd.DataFrame(train, columns=datos.columns)
test = pd.DataFrame(test, columns=datos.columns)
val = pd.DataFrame(val, columns=datos.columns)

# %%
# Crear un gráfico
plt.figure(figsize=(12, 6))

# Graficar cada conjunto con un color diferente
plt.plot(train['pollution'], label='Train', color='blue')
plt.plot(test['pollution'], label='Test', color='orange')
plt.plot(val['pollution'], label='Validation', color='green')

# Etiquetas y título
plt.title('Pollution por Conjunto')
plt.xlabel('Índice')
plt.ylabel('Pollution')
plt.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Se unen los datos nuevamente, ahora normalizados, en un único conjunto.

# %%
datosNormalizados = pd.concat([train, test, val])

datosNormalizados.index = datos.index

# %%
datosNormalizados.shape
# Out:
# (43800, 6)

# %%
datosNormalizados.head(13)
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 00:00:00   0.317681 -1.214023 -1.268524  0.329687 -0.380944
# 2010-01-02 01:00:00   0.526152 -1.144302 -1.268524  0.329687 -0.380944
# 2010-01-02 02:00:00   0.646846 -0.865419 -1.349314  0.426127 -0.380944
# 2010-01-02 03:00:00   0.888234 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 04:00:00   0.416431 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 05:00:00   0.098238 -0.586536 -1.430104  0.522567 -0.380944
# 2010-01-02 06:00:00   0.054349 -0.586536 -1.430104  0.619008 -0.380944
# 2010-01-02 07:00:00   0.262820 -0.586536 -1.349314  0.715448 -0.380944
# 2010-01-02 08:00:00   0.218931 -0.656257 -1.430104  0.715448 -0.380944
# 2010-01-02 09:00:00   0.350598 -0.586536 -1.349314  0.811888 -0.380944
# 2010-01-02 10:00:00   0.438375 -0.586536 -1.349314  0.908328 -0.380944
# 2010-01-02 11:00:00   0.570041 -0.656257 -1.349314  0.908328 -0.380944
# 2010-01-02 12:00:00   0.526152 -0.656257 -1.349314  0.908328 -0.380944
#
#                       wnd_spd
# date
# 2010-01-02 00:00:00 -0.464048
# 2010-01-02 01:00:00 -0.446575
# 2010-01-02 02:00:00 -0.429103
# 2010-01-02 03:00:00 -0.393962
# 2010-01-02 04:00:00 -0.376489
# 2010-01-02 05:00:00 -0.359017
# 2010-01-02 06:00:00 -0.323876
# 2010-01-02 07:00:00 -0.288735
# 2010-01-02 08:00:00 -0.253594
# 2010-01-02 09:00:00 -0.218452
# 2010-01-02 10:00:00 -0.157004
# 2010-01-02 11:00:00 -0.095557
# 2010-01-02 12:00:00 -0.034109

# %% [markdown]
# Se establece el formato de datos de entrada para redes GRU y LSTM, es decir [observaciones, retardos, caracteristicas]

# %%
futuros = 1
pasados  = 12

# %%
datosX = []
datosY = []
for i in range(pasados, len(datosNormalizados) - futuros + 1):
  datosX.append(datosNormalizados.iloc[i-pasados:i, 0:datosNormalizados.shape[1]])
  datosY.append(datosNormalizados.iloc[i+futuros-1:i+futuros, 0])

# %%
# Convertir las listas en arrays numpy
datosX = np.array(datosX)
datosY = np.array(datosY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de X:", datosX.shape)  # (n_muestras, pasos_de_tiempo, n_características)
print("Dimensiones de Y:", datosY.shape)  # (n_muestras, n_características)
# Out:
# Dimensiones de X: (43788, 12, 6)
# Dimensiones de Y: (43788, 1)

# %%
inputs = datosX.shape[1] * datosX.shape[2]
datosMLPX = datosX.reshape(datosX.shape[0], inputs)

# %%
print(datosX[0])
print(datosMLPX[0])
# Out:
# [[ 0.31768099 -1.2140229  -1.26852411  0.32968671 -0.38094383 -0.46404777]
#  [ 0.52615226 -1.14430217 -1.26852411  0.32968671 -0.38094383 -0.44657536]
#  [ 0.64684616 -0.86541928 -1.34931411  0.42612698 -0.38094383 -0.42910295]
#  [ 0.88823396 -0.58653639 -1.34931411  0.52256725 -0.38094383 -0.39396181]
#  [ 0.41643054 -0.58653639 -1.34931411  0.52256725 -0.38094383 -0.3764894 ]
#  [ 0.09823754 -0.58653639 -1.4301041   0.52256725 -0.38094383 -0.35901698]
#  [ 0.05434885 -0.58653639 -1.4301041   0.61900753 -0.38094383 -0.32387584]
#  [ 0.26282012 -0.58653639 -1.34931411  0.7154478  -0.38094383 -0.2887347 ]
#  [ 0.21893143 -0.65625711 -1.4301041   0.7154478  -0.38094383 -0.25359356]
#  [ 0.3505975  -0.58653639 -1.34931411  0.81188808 -0.38094383 -0.21845241]
#  [ 0.43837488 -0.58653639 -1.34931411  0.90832835 -0.38094383 -0.15700449]
#  [ 0.57004095 -0.65625711 -1.34931411  0.90832835 -0.38094383 -0.09555657]]
# [ 0.31768099 -1.2140229  -1.26852411  0.32968671 -0.38094383 -0.46404777
#   0.52615226 -1.14430217 -1.26852411  0.32968671 -0.38094383 -0.44657536
#   0.64684616 -0.86541928 -1.34931411  0.42612698 -0.38094383 -0.42910295
#   0.88823396 -0.58653639 -1.34931411  0.52256725 -0.38094383 -0.39396181
#   0.41643054 -0.58653639 -1.34931411  0.52256725 -0.38094383 -0.3764894
#   0.09823754 -0.58653639 -1.4301041   0.52256725 -0.38094383 -0.35901698
#   0.05434885 -0.58653639 -1.4301041   0.61900753 -0.38094383 -0.32387584
#   0.26282012 -0.58653639 -1.34931411  0.7154478  -0.38094383 -0.2887347
#   0.21893143 -0.65625711 -1.4301041   0.7154478  -0.38094383 -0.25359356
#   0.3505975  -0.58653639 -1.34931411  0.81188808 -0.38094383 -0.21845241
#   0.43837488 -0.58653639 -1.34931411  0.90832835 -0.38094383 -0.15700449
#   0.57004095 -0.65625711 -1.34931411  0.90832835 -0.38094383 -0.09555657]

# %% [markdown]
# Se dividen nuevamente los conjuntos de datos

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainX, testX = train_test_split(datosX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testX, valX = train_test_split(testX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainX son: ", trainX.shape)
print("Las dimensiones de testX son: ", testX.shape)
print("Las dimensiones de valX son: ", valX.shape)
# Out:
# Las dimensiones de trainX son:  (30651, 12, 6)
# Las dimensiones de testX son:  (8801, 12, 6)
# Las dimensiones de valX son:  (4336, 12, 6)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainMLPX, testMLPX = train_test_split(datosMLPX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testMLPX, valMLPX = train_test_split(testMLPX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainMLPX son: ", trainMLPX.shape)
print("Las dimensiones de testMLPX son: ", testMLPX.shape)
print("Las dimensiones de valMLPX son: ", valMLPX.shape)
# Out:
# Las dimensiones de trainMLPX son:  (30651, 72)
# Las dimensiones de testMLPX son:  (8801, 72)
# Las dimensiones de valMLPX son:  (4336, 72)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainY, testY = train_test_split(datosY, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testY, valY = train_test_split(testY, test_size=0.33, shuffle=False)

print("Las dimensiones de trainY son: ", trainY.shape)
print("Las dimensiones de testY son: ", testY.shape)
print("Las dimensiones de valY son: ", valY.shape)
# Out:
# Las dimensiones de trainY son:  (30651, 1)
# Las dimensiones de testY son:  (8801, 1)
# Las dimensiones de valY son:  (4336, 1)

# %% [markdown]
# Se crean métricas para medir desempeño

# %%
import tensorflow.keras.backend as K

def smape(y_true, y_pred):
    """
    Define la función SMAPE (Error Porcentual Absoluto Medio Simétrico).
    """
    summ = K.abs(y_true) + K.abs(y_pred)
    smape_val = K.abs(y_pred - y_true) / summ * 2.0
    return K.mean(smape_val, axis=-1)

def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

def ia(y_true, y_pred):
    numerator = K.sum(K.abs(y_true - y_pred))
    denominator = K.sum(K.abs(y_true - K.mean(y_true)) + K.abs(y_pred - K.mean(y_true)))
    return 1 - (numerator / denominator)

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

def graficarPrediccion(modelo, x, y, inicio, final):
  predicciones = modelo.predict(x)
  predicciones = predicciones.flatten()
  df = pd.DataFrame({'Originales': y, 'Predichos': predicciones})
  plt.plot(df.index, df['Originales'][inicio:final], label='Originales')
  plt.plot(df.index, df['Predichos'][inicio:final], label='Predichos')
  return df, mse(y, predicciones),  mae(y, predicciones), rmse(y, predicciones), smape(y,predicciones), ia(y, predicciones)

# %% [markdown]
# Se define el index del conjunto de validación para utilizarlo posteriormente para graficar.

# %%
# Fecha y hora de término del conjunto de datos de prueba
end_date = datosNormalizados.index[-1]
n_observations = valY.shape[0]  # Cambia esto al número de observaciones en tu conjunto de prueba

# Calcular la fecha y hora de inicio
start_date = end_date - timedelta(hours=(n_observations - 1))

# Crear la serie de fechas y horas
val_date = pd.date_range(start=start_date, end=end_date, freq='1H')

val_date
# Out:
# C:\Users\wamt1\AppData\Local\Temp\ipykernel_14604\3958427235.py:9: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   val_date = pd.date_range(start=start_date, end=end_date, freq='1H')
# DatetimeIndex(['2014-07-04 08:00:00', '2014-07-04 09:00:00',
#                '2014-07-04 10:00:00', '2014-07-04 11:00:00',
#                '2014-07-04 12:00:00', '2014-07-04 13:00:00',
#                '2014-07-04 14:00:00', '2014-07-04 15:00:00',
#                '2014-07-04 16:00:00', '2014-07-04 17:00:00',
#                ...
#                '2014-12-31 14:00:00', '2014-12-31 15:00:00',
#                '2014-12-31 16:00:00', '2014-12-31 17:00:00',
#                '2014-12-31 18:00:00', '2014-12-31 19:00:00',
#                '2014-12-31 20:00:00', '2014-12-31 21:00:00',
#                '2014-12-31 22:00:00', '2014-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=4336, freq='h')

# %% [markdown]
# Se guardan los índices de las observaciones a utilizar para predecir

# %%
indices = []
for i in range(pasados, len(datosNormalizados) - futuros + 1):
  indices.append(datosNormalizados.index[i+futuros-1])

# %% [markdown]
# # Modelos

# %% [markdown]
# ## MLP

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelMLP = Sequential()
modelMLP.add(InputLayer(input_shape=(trainMLPX.shape[1],)))

modelMLP.add(Dense(units=128, activation="sigmoid"))
modelMLP.add(Dropout(0.2))

modelMLP.add(Dense(1))

opt = Adam(learning_rate=0.0002707756079796208)

modelMLP.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelMLP.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         9,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,473 (37.00 KB)
#  Trainable params: 9,473 (37.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyMLP = modelMLP.fit(trainMLPX, trainY, epochs=128, validation_data=(testMLPX, testY), verbose = 2, batch_size=128, callbacks=[early_stopping])

prediccionMLP = modelMLP.predict(valMLPX)
# Out:
# Epoch 1/128
# 240/240 - 4s - 15ms/step - ia: 0.6009 - loss: 0.5589 - mae: 0.5325 - rmse: 0.7291 - smape: 0.9865 - val_ia: 0.7124 - val_loss: 0.2107 - val_mae: 0.2982 - val_rmse: 0.4110 - val_smape: 0.6446
# Epoch 2/128
# 240/240 - 1s - 3ms/step - ia: 0.7155 - loss: 0.3179 - mae: 0.4118 - rmse: 0.5591 - smape: 0.8036 - val_ia: 0.7676 - val_loss: 0.1452 - val_mae: 0.2427 - val_rmse: 0.3428 - val_smape: 0.5520
# Epoch 3/128
# 240/240 - 1s - 3ms/step - ia: 0.7449 - loss: 0.2588 - mae: 0.3720 - rmse: 0.5046 - smape: 0.7470 - val_ia: 0.7950 - val_loss: 0.1180 - val_mae: 0.2147 - val_rmse: 0.3098 - val_smape: 0.5021
# Epoch 4/128
# 240/240 - 1s - 2ms/step - ia: 0.7682 - loss: 0.2182 - mae: 0.3393 - rmse: 0.4629 - smape: 0.6993 - val_ia: 0.8097 - val_loss: 0.1032 - val_mae: 0.1970 - val_rmse: 0.2910 - val_smape: 0.4758
# Epoch 5/128
# 240/240 - 1s - 3ms/step - ia: 0.7830 - loss: 0.1956 - mae: 0.3178 - rmse: 0.4379 - smape: 0.6688 - val_ia: 0.8217 - val_loss: 0.0949 - val_mae: 0.1859 - val_rmse: 0.2782 - val_smape: 0.4523
# Epoch 6/128
# 240/240 - 1s - 3ms/step - ia: 0.7940 - loss: 0.1777 - mae: 0.3019 - rmse: 0.4168 - smape: 0.6443 - val_ia: 0.8245 - val_loss: 0.0908 - val_mae: 0.1816 - val_rmse: 0.2733 - val_smape: 0.4465
# Epoch 7/128
# 240/240 - 1s - 2ms/step - ia: 0.8032 - loss: 0.1654 - mae: 0.2882 - rmse: 0.4016 - smape: 0.6222 - val_ia: 0.8340 - val_loss: 0.0872 - val_mae: 0.1757 - val_rmse: 0.2655 - val_smape: 0.4254
# Epoch 8/128
# 240/240 - 1s - 3ms/step - ia: 0.8124 - loss: 0.1544 - mae: 0.2750 - rmse: 0.3873 - smape: 0.5991 - val_ia: 0.8399 - val_loss: 0.0839 - val_mae: 0.1696 - val_rmse: 0.2594 - val_smape: 0.4141
# Epoch 9/128
# 240/240 - 0s - 2ms/step - ia: 0.8184 - loss: 0.1457 - mae: 0.2664 - rmse: 0.3767 - smape: 0.5844 - val_ia: 0.8417 - val_loss: 0.0824 - val_mae: 0.1674 - val_rmse: 0.2572 - val_smape: 0.4097
# Epoch 10/128
# 240/240 - 0s - 2ms/step - ia: 0.8238 - loss: 0.1399 - mae: 0.2584 - rmse: 0.3682 - smape: 0.5709 - val_ia: 0.8465 - val_loss: 0.0797 - val_mae: 0.1622 - val_rmse: 0.2526 - val_smape: 0.4002
# Epoch 11/128
# 240/240 - 1s - 3ms/step - ia: 0.8285 - loss: 0.1337 - mae: 0.2516 - rmse: 0.3600 - smape: 0.5599 - val_ia: 0.8472 - val_loss: 0.0791 - val_mae: 0.1623 - val_rmse: 0.2511 - val_smape: 0.3979
# Epoch 12/128
# 240/240 - 0s - 2ms/step - ia: 0.8320 - loss: 0.1299 - mae: 0.2466 - rmse: 0.3545 - smape: 0.5486 - val_ia: 0.8484 - val_loss: 0.0775 - val_mae: 0.1599 - val_rmse: 0.2492 - val_smape: 0.3955
# Epoch 13/128
# 240/240 - 1s - 4ms/step - ia: 0.8357 - loss: 0.1268 - mae: 0.2416 - rmse: 0.3502 - smape: 0.5421 - val_ia: 0.8530 - val_loss: 0.0756 - val_mae: 0.1550 - val_rmse: 0.2453 - val_smape: 0.3863
# Epoch 14/128
# 240/240 - 1s - 3ms/step - ia: 0.8383 - loss: 0.1228 - mae: 0.2378 - rmse: 0.3443 - smape: 0.5372 - val_ia: 0.8544 - val_loss: 0.0747 - val_mae: 0.1548 - val_rmse: 0.2433 - val_smape: 0.3844
# Epoch 15/128
# 240/240 - 1s - 4ms/step - ia: 0.8414 - loss: 0.1204 - mae: 0.2331 - rmse: 0.3408 - smape: 0.5263 - val_ia: 0.8578 - val_loss: 0.0734 - val_mae: 0.1512 - val_rmse: 0.2406 - val_smape: 0.3785
# Epoch 16/128
# 240/240 - 1s - 5ms/step - ia: 0.8442 - loss: 0.1169 - mae: 0.2295 - rmse: 0.3357 - smape: 0.5198 - val_ia: 0.8552 - val_loss: 0.0730 - val_mae: 0.1521 - val_rmse: 0.2409 - val_smape: 0.3804
# Epoch 17/128
# 240/240 - 1s - 3ms/step - ia: 0.8474 - loss: 0.1132 - mae: 0.2245 - rmse: 0.3299 - smape: 0.5111 - val_ia: 0.8598 - val_loss: 0.0710 - val_mae: 0.1483 - val_rmse: 0.2371 - val_smape: 0.3733
# Epoch 18/128
# 240/240 - 1s - 3ms/step - ia: 0.8478 - loss: 0.1131 - mae: 0.2241 - rmse: 0.3296 - smape: 0.5118 - val_ia: 0.8560 - val_loss: 0.0714 - val_mae: 0.1506 - val_rmse: 0.2390 - val_smape: 0.3786
# Epoch 19/128
# 240/240 - 1s - 4ms/step - ia: 0.8502 - loss: 0.1105 - mae: 0.2204 - rmse: 0.3261 - smape: 0.5021 - val_ia: 0.8610 - val_loss: 0.0702 - val_mae: 0.1471 - val_rmse: 0.2349 - val_smape: 0.3692
# Epoch 20/128
# 240/240 - 1s - 6ms/step - ia: 0.8525 - loss: 0.1080 - mae: 0.2173 - rmse: 0.3217 - smape: 0.4992 - val_ia: 0.8631 - val_loss: 0.0689 - val_mae: 0.1450 - val_rmse: 0.2325 - val_smape: 0.3664
# Epoch 21/128
# 240/240 - 1s - 5ms/step - ia: 0.8542 - loss: 0.1068 - mae: 0.2147 - rmse: 0.3201 - smape: 0.4919 - val_ia: 0.8645 - val_loss: 0.0676 - val_mae: 0.1432 - val_rmse: 0.2307 - val_smape: 0.3632
# Epoch 22/128
# 240/240 - 1s - 6ms/step - ia: 0.8561 - loss: 0.1047 - mae: 0.2122 - rmse: 0.3164 - smape: 0.4898 - val_ia: 0.8628 - val_loss: 0.0672 - val_mae: 0.1433 - val_rmse: 0.2306 - val_smape: 0.3639
# Epoch 23/128
# 240/240 - 1s - 3ms/step - ia: 0.8569 - loss: 0.1037 - mae: 0.2108 - rmse: 0.3150 - smape: 0.4845 - val_ia: 0.8638 - val_loss: 0.0674 - val_mae: 0.1444 - val_rmse: 0.2302 - val_smape: 0.3637
# Epoch 24/128
# 240/240 - 1s - 6ms/step - ia: 0.8594 - loss: 0.1018 - mae: 0.2072 - rmse: 0.3114 - smape: 0.4783 - val_ia: 0.8646 - val_loss: 0.0664 - val_mae: 0.1427 - val_rmse: 0.2290 - val_smape: 0.3616
# Epoch 25/128
# 240/240 - 1s - 2ms/step - ia: 0.8596 - loss: 0.1004 - mae: 0.2065 - rmse: 0.3097 - smape: 0.4780 - val_ia: 0.8646 - val_loss: 0.0657 - val_mae: 0.1417 - val_rmse: 0.2279 - val_smape: 0.3598
# Epoch 26/128
# 240/240 - 0s - 2ms/step - ia: 0.8611 - loss: 0.0991 - mae: 0.2045 - rmse: 0.3077 - smape: 0.4763 - val_ia: 0.8632 - val_loss: 0.0656 - val_mae: 0.1426 - val_rmse: 0.2280 - val_smape: 0.3624
# Epoch 27/128
# 240/240 - 1s - 3ms/step - ia: 0.8616 - loss: 0.0983 - mae: 0.2038 - rmse: 0.3064 - smape: 0.4764 - val_ia: 0.8642 - val_loss: 0.0649 - val_mae: 0.1412 - val_rmse: 0.2270 - val_smape: 0.3603
# Epoch 28/128
# 240/240 - 0s - 2ms/step - ia: 0.8629 - loss: 0.0967 - mae: 0.2019 - rmse: 0.3040 - smape: 0.4707 - val_ia: 0.8647 - val_loss: 0.0646 - val_mae: 0.1405 - val_rmse: 0.2257 - val_smape: 0.3589
# Epoch 29/128
# 240/240 - 1s - 2ms/step - ia: 0.8640 - loss: 0.0967 - mae: 0.2002 - rmse: 0.3038 - smape: 0.4690 - val_ia: 0.8636 - val_loss: 0.0646 - val_mae: 0.1420 - val_rmse: 0.2266 - val_smape: 0.3613
# Epoch 30/128
# 240/240 - 0s - 2ms/step - ia: 0.8654 - loss: 0.0955 - mae: 0.1979 - rmse: 0.3014 - smape: 0.4650 - val_ia: 0.8672 - val_loss: 0.0633 - val_mae: 0.1391 - val_rmse: 0.2238 - val_smape: 0.3566
# Epoch 31/128
# 240/240 - 0s - 2ms/step - ia: 0.8660 - loss: 0.0939 - mae: 0.1971 - rmse: 0.2992 - smape: 0.4616 - val_ia: 0.8649 - val_loss: 0.0628 - val_mae: 0.1386 - val_rmse: 0.2244 - val_smape: 0.3579
# Epoch 32/128
# 240/240 - 1s - 2ms/step - ia: 0.8672 - loss: 0.0932 - mae: 0.1954 - rmse: 0.2977 - smape: 0.4616 - val_ia: 0.8662 - val_loss: 0.0627 - val_mae: 0.1389 - val_rmse: 0.2234 - val_smape: 0.3563
# Epoch 33/128
# 240/240 - 1s - 2ms/step - ia: 0.8680 - loss: 0.0924 - mae: 0.1940 - rmse: 0.2966 - smape: 0.4595 - val_ia: 0.8651 - val_loss: 0.0622 - val_mae: 0.1384 - val_rmse: 0.2233 - val_smape: 0.3575
# Epoch 34/128
# 240/240 - 1s - 3ms/step - ia: 0.8696 - loss: 0.0901 - mae: 0.1916 - rmse: 0.2927 - smape: 0.4545 - val_ia: 0.8660 - val_loss: 0.0616 - val_mae: 0.1372 - val_rmse: 0.2221 - val_smape: 0.3555
# Epoch 35/128
# 240/240 - 1s - 3ms/step - ia: 0.8697 - loss: 0.0907 - mae: 0.1917 - rmse: 0.2934 - smape: 0.4536 - val_ia: 0.8654 - val_loss: 0.0614 - val_mae: 0.1375 - val_rmse: 0.2219 - val_smape: 0.3559
# Epoch 36/128
# 240/240 - 1s - 3ms/step - ia: 0.8706 - loss: 0.0897 - mae: 0.1900 - rmse: 0.2919 - smape: 0.4502 - val_ia: 0.8672 - val_loss: 0.0610 - val_mae: 0.1362 - val_rmse: 0.2206 - val_smape: 0.3536
# Epoch 37/128
# 240/240 - 1s - 3ms/step - ia: 0.8715 - loss: 0.0888 - mae: 0.1888 - rmse: 0.2901 - smape: 0.4485 - val_ia: 0.8651 - val_loss: 0.0611 - val_mae: 0.1375 - val_rmse: 0.2216 - val_smape: 0.3561
# Epoch 38/128
# 240/240 - 1s - 4ms/step - ia: 0.8718 - loss: 0.0877 - mae: 0.1883 - rmse: 0.2888 - smape: 0.4486 - val_ia: 0.8641 - val_loss: 0.0613 - val_mae: 0.1385 - val_rmse: 0.2222 - val_smape: 0.3591
# Epoch 39/128
# 240/240 - 1s - 4ms/step - ia: 0.8728 - loss: 0.0871 - mae: 0.1867 - rmse: 0.2878 - smape: 0.4470 - val_ia: 0.8629 - val_loss: 0.0615 - val_mae: 0.1397 - val_rmse: 0.2226 - val_smape: 0.3606
# Epoch 40/128
# 240/240 - 1s - 3ms/step - ia: 0.8731 - loss: 0.0879 - mae: 0.1864 - rmse: 0.2886 - smape: 0.4444 - val_ia: 0.8640 - val_loss: 0.0609 - val_mae: 0.1384 - val_rmse: 0.2217 - val_smape: 0.3588
# Epoch 41/128
# 240/240 - 1s - 3ms/step - ia: 0.8739 - loss: 0.0859 - mae: 0.1849 - rmse: 0.2855 - smape: 0.4433 - val_ia: 0.8646 - val_loss: 0.0604 - val_mae: 0.1375 - val_rmse: 0.2209 - val_smape: 0.3580
# Epoch 42/128
# 240/240 - 1s - 2ms/step - ia: 0.8729 - loss: 0.0869 - mae: 0.1864 - rmse: 0.2873 - smape: 0.4450 - val_ia: 0.8619 - val_loss: 0.0604 - val_mae: 0.1387 - val_rmse: 0.2220 - val_smape: 0.3610
# Epoch 43/128
# 240/240 - 1s - 2ms/step - ia: 0.8744 - loss: 0.0859 - mae: 0.1843 - rmse: 0.2856 - smape: 0.4401 - val_ia: 0.8653 - val_loss: 0.0595 - val_mae: 0.1360 - val_rmse: 0.2193 - val_smape: 0.3546
# Epoch 44/128
# 240/240 - 1s - 3ms/step - ia: 0.8751 - loss: 0.0854 - mae: 0.1831 - rmse: 0.2846 - smape: 0.4411 - val_ia: 0.8664 - val_loss: 0.0590 - val_mae: 0.1351 - val_rmse: 0.2182 - val_smape: 0.3527
# Epoch 45/128
# 240/240 - 0s - 2ms/step - ia: 0.8761 - loss: 0.0837 - mae: 0.1816 - rmse: 0.2819 - smape: 0.4375 - val_ia: 0.8648 - val_loss: 0.0596 - val_mae: 0.1368 - val_rmse: 0.2195 - val_smape: 0.3563
# Epoch 46/128
# 240/240 - 1s - 2ms/step - ia: 0.8754 - loss: 0.0844 - mae: 0.1825 - rmse: 0.2826 - smape: 0.4418 - val_ia: 0.8631 - val_loss: 0.0598 - val_mae: 0.1379 - val_rmse: 0.2202 - val_smape: 0.3589
# Epoch 47/128
# 240/240 - 1s - 2ms/step - ia: 0.8763 - loss: 0.0833 - mae: 0.1813 - rmse: 0.2810 - smape: 0.4382 - val_ia: 0.8594 - val_loss: 0.0603 - val_mae: 0.1400 - val_rmse: 0.2218 - val_smape: 0.3641
# Epoch 48/128
# 240/240 - 1s - 2ms/step - ia: 0.8764 - loss: 0.0831 - mae: 0.1810 - rmse: 0.2808 - smape: 0.4370 - val_ia: 0.8648 - val_loss: 0.0594 - val_mae: 0.1372 - val_rmse: 0.2193 - val_smape: 0.3580
# Epoch 49/128
# 240/240 - 1s - 2ms/step - ia: 0.8777 - loss: 0.0815 - mae: 0.1792 - rmse: 0.2780 - smape: 0.4369 - val_ia: 0.8603 - val_loss: 0.0595 - val_mae: 0.1388 - val_rmse: 0.2208 - val_smape: 0.3618
# Epoch 50/128
# 240/240 - 1s - 3ms/step - ia: 0.8779 - loss: 0.0827 - mae: 0.1788 - rmse: 0.2797 - smape: 0.4318 - val_ia: 0.8633 - val_loss: 0.0594 - val_mae: 0.1380 - val_rmse: 0.2198 - val_smape: 0.3601
# Epoch 51/128
# 240/240 - 1s - 6ms/step - ia: 0.8787 - loss: 0.0813 - mae: 0.1777 - rmse: 0.2773 - smape: 0.4295 - val_ia: 0.8612 - val_loss: 0.0593 - val_mae: 0.1384 - val_rmse: 0.2202 - val_smape: 0.3611
# Epoch 52/128
# 240/240 - 1s - 3ms/step - ia: 0.8786 - loss: 0.0811 - mae: 0.1778 - rmse: 0.2772 - smape: 0.4327 - val_ia: 0.8643 - val_loss: 0.0585 - val_mae: 0.1360 - val_rmse: 0.2184 - val_smape: 0.3569
# Epoch 53/128
# 240/240 - 2s - 6ms/step - ia: 0.8786 - loss: 0.0808 - mae: 0.1776 - rmse: 0.2766 - smape: 0.4314 - val_ia: 0.8605 - val_loss: 0.0593 - val_mae: 0.1389 - val_rmse: 0.2207 - val_smape: 0.3630
# Epoch 54/128
# 240/240 - 1s - 3ms/step - ia: 0.8791 - loss: 0.0809 - mae: 0.1769 - rmse: 0.2768 - smape: 0.4319 - val_ia: 0.8617 - val_loss: 0.0593 - val_mae: 0.1385 - val_rmse: 0.2200 - val_smape: 0.3618
# Epoch 55/128
# 240/240 - 1s - 2ms/step - ia: 0.8789 - loss: 0.0814 - mae: 0.1771 - rmse: 0.2773 - smape: 0.4319 - val_ia: 0.8645 - val_loss: 0.0586 - val_mae: 0.1365 - val_rmse: 0.2183 - val_smape: 0.3572
# Epoch 56/128
# 240/240 - 1s - 2ms/step - ia: 0.8795 - loss: 0.0811 - mae: 0.1763 - rmse: 0.2767 - smape: 0.4270 - val_ia: 0.8620 - val_loss: 0.0591 - val_mae: 0.1382 - val_rmse: 0.2198 - val_smape: 0.3617
# Epoch 57/128
# 240/240 - 1s - 3ms/step - ia: 0.8803 - loss: 0.0794 - mae: 0.1752 - rmse: 0.2742 - smape: 0.4273 - val_ia: 0.8665 - val_loss: 0.0580 - val_mae: 0.1349 - val_rmse: 0.2171 - val_smape: 0.3538
# Epoch 58/128
# 240/240 - 1s - 5ms/step - ia: 0.8803 - loss: 0.0793 - mae: 0.1752 - rmse: 0.2737 - smape: 0.4253 - val_ia: 0.8622 - val_loss: 0.0588 - val_mae: 0.1381 - val_rmse: 0.2195 - val_smape: 0.3614
# Epoch 59/128
# 240/240 - 1s - 3ms/step - ia: 0.8802 - loss: 0.0795 - mae: 0.1753 - rmse: 0.2742 - smape: 0.4273 - val_ia: 0.8648 - val_loss: 0.0588 - val_mae: 0.1373 - val_rmse: 0.2187 - val_smape: 0.3592
# Epoch 60/128
# 240/240 - 1s - 2ms/step - ia: 0.8806 - loss: 0.0787 - mae: 0.1748 - rmse: 0.2733 - smape: 0.4275 - val_ia: 0.8620 - val_loss: 0.0584 - val_mae: 0.1372 - val_rmse: 0.2191 - val_smape: 0.3606
# Epoch 61/128
# 240/240 - 1s - 3ms/step - ia: 0.8810 - loss: 0.0786 - mae: 0.1740 - rmse: 0.2725 - smape: 0.4254 - val_ia: 0.8619 - val_loss: 0.0584 - val_mae: 0.1374 - val_rmse: 0.2187 - val_smape: 0.3602
# Epoch 62/128
# 240/240 - 0s - 2ms/step - ia: 0.8816 - loss: 0.0780 - mae: 0.1733 - rmse: 0.2719 - smape: 0.4245 - val_ia: 0.8637 - val_loss: 0.0582 - val_mae: 0.1366 - val_rmse: 0.2184 - val_smape: 0.3590
# Epoch 63/128
# 240/240 - 0s - 2ms/step - ia: 0.8814 - loss: 0.0781 - mae: 0.1735 - rmse: 0.2716 - smape: 0.4223 - val_ia: 0.8585 - val_loss: 0.0592 - val_mae: 0.1402 - val_rmse: 0.2212 - val_smape: 0.3667
# Epoch 64/128
# 240/240 - 0s - 2ms/step - ia: 0.8824 - loss: 0.0772 - mae: 0.1720 - rmse: 0.2701 - smape: 0.4204 - val_ia: 0.8623 - val_loss: 0.0582 - val_mae: 0.1371 - val_rmse: 0.2187 - val_smape: 0.3600
# Epoch 65/128
# 240/240 - 1s - 2ms/step - ia: 0.8821 - loss: 0.0775 - mae: 0.1724 - rmse: 0.2710 - smape: 0.4211 - val_ia: 0.8664 - val_loss: 0.0579 - val_mae: 0.1355 - val_rmse: 0.2173 - val_smape: 0.3562
# Epoch 66/128
# 240/240 - 0s - 2ms/step - ia: 0.8829 - loss: 0.0774 - mae: 0.1714 - rmse: 0.2704 - smape: 0.4195 - val_ia: 0.8657 - val_loss: 0.0578 - val_mae: 0.1355 - val_rmse: 0.2172 - val_smape: 0.3561
# Epoch 67/128
# 240/240 - 0s - 2ms/step - ia: 0.8829 - loss: 0.0769 - mae: 0.1713 - rmse: 0.2700 - smape: 0.4185 - val_ia: 0.8617 - val_loss: 0.0582 - val_mae: 0.1375 - val_rmse: 0.2187 - val_smape: 0.3608
# Epoch 68/128
# 240/240 - 0s - 2ms/step - ia: 0.8839 - loss: 0.0759 - mae: 0.1699 - rmse: 0.2679 - smape: 0.4178 - val_ia: 0.8639 - val_loss: 0.0577 - val_mae: 0.1361 - val_rmse: 0.2173 - val_smape: 0.3571
# Epoch 69/128
# 240/240 - 0s - 2ms/step - ia: 0.8838 - loss: 0.0768 - mae: 0.1701 - rmse: 0.2692 - smape: 0.4156 - val_ia: 0.8662 - val_loss: 0.0572 - val_mae: 0.1345 - val_rmse: 0.2159 - val_smape: 0.3533
# Epoch 70/128
# 240/240 - 1s - 3ms/step - ia: 0.8837 - loss: 0.0771 - mae: 0.1702 - rmse: 0.2698 - smape: 0.4169 - val_ia: 0.8642 - val_loss: 0.0579 - val_mae: 0.1364 - val_rmse: 0.2177 - val_smape: 0.3577
# Epoch 71/128
# 240/240 - 0s - 2ms/step - ia: 0.8836 - loss: 0.0768 - mae: 0.1705 - rmse: 0.2687 - smape: 0.4166 - val_ia: 0.8624 - val_loss: 0.0582 - val_mae: 0.1375 - val_rmse: 0.2184 - val_smape: 0.3593
# Epoch 72/128
# 240/240 - 1s - 2ms/step - ia: 0.8844 - loss: 0.0758 - mae: 0.1691 - rmse: 0.2677 - smape: 0.4149 - val_ia: 0.8631 - val_loss: 0.0581 - val_mae: 0.1373 - val_rmse: 0.2185 - val_smape: 0.3597
# Epoch 73/128
# 240/240 - 1s - 3ms/step - ia: 0.8847 - loss: 0.0762 - mae: 0.1688 - rmse: 0.2678 - smape: 0.4144 - val_ia: 0.8653 - val_loss: 0.0573 - val_mae: 0.1352 - val_rmse: 0.2168 - val_smape: 0.3555
# Epoch 74/128
# 240/240 - 1s - 6ms/step - ia: 0.8844 - loss: 0.0760 - mae: 0.1692 - rmse: 0.2679 - smape: 0.4158 - val_ia: 0.8618 - val_loss: 0.0579 - val_mae: 0.1373 - val_rmse: 0.2184 - val_smape: 0.3607
# Epoch 75/128
# 240/240 - 1s - 3ms/step - ia: 0.8843 - loss: 0.0762 - mae: 0.1693 - rmse: 0.2685 - smape: 0.4159 - val_ia: 0.8656 - val_loss: 0.0572 - val_mae: 0.1351 - val_rmse: 0.2163 - val_smape: 0.3546
# Epoch 76/128
# 240/240 - 1s - 3ms/step - ia: 0.8848 - loss: 0.0748 - mae: 0.1685 - rmse: 0.2663 - smape: 0.4167 - val_ia: 0.8638 - val_loss: 0.0575 - val_mae: 0.1363 - val_rmse: 0.2173 - val_smape: 0.3575
# Epoch 77/128
# 240/240 - 1s - 3ms/step - ia: 0.8851 - loss: 0.0750 - mae: 0.1681 - rmse: 0.2661 - smape: 0.4119 - val_ia: 0.8671 - val_loss: 0.0569 - val_mae: 0.1342 - val_rmse: 0.2160 - val_smape: 0.3535
# Epoch 78/128
# 240/240 - 1s - 3ms/step - ia: 0.8858 - loss: 0.0749 - mae: 0.1670 - rmse: 0.2661 - smape: 0.4107 - val_ia: 0.8645 - val_loss: 0.0575 - val_mae: 0.1359 - val_rmse: 0.2171 - val_smape: 0.3565
# Epoch 79/128
# 240/240 - 0s - 2ms/step - ia: 0.8862 - loss: 0.0742 - mae: 0.1667 - rmse: 0.2646 - smape: 0.4093 - val_ia: 0.8644 - val_loss: 0.0573 - val_mae: 0.1359 - val_rmse: 0.2171 - val_smape: 0.3574
# Epoch 80/128
# 240/240 - 1s - 3ms/step - ia: 0.8859 - loss: 0.0740 - mae: 0.1670 - rmse: 0.2644 - smape: 0.4104 - val_ia: 0.8671 - val_loss: 0.0568 - val_mae: 0.1339 - val_rmse: 0.2157 - val_smape: 0.3528
# Epoch 81/128
# 240/240 - 1s - 3ms/step - ia: 0.8859 - loss: 0.0752 - mae: 0.1669 - rmse: 0.2667 - smape: 0.4095 - val_ia: 0.8642 - val_loss: 0.0571 - val_mae: 0.1358 - val_rmse: 0.2167 - val_smape: 0.3569
# Epoch 82/128
# 240/240 - 1s - 3ms/step - ia: 0.8863 - loss: 0.0743 - mae: 0.1665 - rmse: 0.2649 - smape: 0.4095 - val_ia: 0.8653 - val_loss: 0.0568 - val_mae: 0.1349 - val_rmse: 0.2161 - val_smape: 0.3547
# Epoch 83/128
# 240/240 - 1s - 5ms/step - ia: 0.8876 - loss: 0.0733 - mae: 0.1646 - rmse: 0.2627 - smape: 0.4052 - val_ia: 0.8669 - val_loss: 0.0569 - val_mae: 0.1343 - val_rmse: 0.2158 - val_smape: 0.3533
# Epoch 84/128
# 240/240 - 2s - 10ms/step - ia: 0.8867 - loss: 0.0742 - mae: 0.1660 - rmse: 0.2644 - smape: 0.4058 - val_ia: 0.8625 - val_loss: 0.0576 - val_mae: 0.1373 - val_rmse: 0.2179 - val_smape: 0.3599
# Epoch 85/128
# 240/240 - 1s - 5ms/step - ia: 0.8875 - loss: 0.0731 - mae: 0.1647 - rmse: 0.2623 - smape: 0.4050 - val_ia: 0.8656 - val_loss: 0.0570 - val_mae: 0.1351 - val_rmse: 0.2165 - val_smape: 0.3558
# Epoch 86/128
# 240/240 - 1s - 5ms/step - ia: 0.8872 - loss: 0.0731 - mae: 0.1651 - rmse: 0.2626 - smape: 0.4067 - val_ia: 0.8655 - val_loss: 0.0571 - val_mae: 0.1355 - val_rmse: 0.2167 - val_smape: 0.3561
# Epoch 87/128
# 240/240 - 1s - 6ms/step - ia: 0.8876 - loss: 0.0727 - mae: 0.1647 - rmse: 0.2619 - smape: 0.4040 - val_ia: 0.8650 - val_loss: 0.0567 - val_mae: 0.1350 - val_rmse: 0.2160 - val_smape: 0.3549
# Epoch 88/128
# 240/240 - 1s - 4ms/step - ia: 0.8876 - loss: 0.0727 - mae: 0.1645 - rmse: 0.2622 - smape: 0.4055 - val_ia: 0.8666 - val_loss: 0.0566 - val_mae: 0.1343 - val_rmse: 0.2157 - val_smape: 0.3538
# Epoch 89/128
# 240/240 - 0s - 2ms/step - ia: 0.8877 - loss: 0.0728 - mae: 0.1643 - rmse: 0.2624 - smape: 0.4065 - val_ia: 0.8661 - val_loss: 0.0570 - val_mae: 0.1353 - val_rmse: 0.2162 - val_smape: 0.3544
# Epoch 90/128
# 240/240 - 1s - 4ms/step - ia: 0.8876 - loss: 0.0729 - mae: 0.1646 - rmse: 0.2630 - smape: 0.4047 - val_ia: 0.8667 - val_loss: 0.0568 - val_mae: 0.1347 - val_rmse: 0.2158 - val_smape: 0.3532
# Epoch 91/128
# 240/240 - 1s - 3ms/step - ia: 0.8884 - loss: 0.0731 - mae: 0.1634 - rmse: 0.2622 - smape: 0.4016 - val_ia: 0.8669 - val_loss: 0.0564 - val_mae: 0.1339 - val_rmse: 0.2153 - val_smape: 0.3526
# Epoch 92/128
# 240/240 - 1s - 5ms/step - ia: 0.8888 - loss: 0.0721 - mae: 0.1629 - rmse: 0.2607 - smape: 0.4038 - val_ia: 0.8678 - val_loss: 0.0564 - val_mae: 0.1337 - val_rmse: 0.2152 - val_smape: 0.3531
# Epoch 93/128
# 240/240 - 1s - 3ms/step - ia: 0.8886 - loss: 0.0720 - mae: 0.1632 - rmse: 0.2603 - smape: 0.4022 - val_ia: 0.8684 - val_loss: 0.0562 - val_mae: 0.1333 - val_rmse: 0.2148 - val_smape: 0.3516
# Epoch 94/128
# 240/240 - 1s - 3ms/step - ia: 0.8891 - loss: 0.0720 - mae: 0.1625 - rmse: 0.2602 - smape: 0.4015 - val_ia: 0.8668 - val_loss: 0.0565 - val_mae: 0.1344 - val_rmse: 0.2155 - val_smape: 0.3541
# Epoch 95/128
# 240/240 - 1s - 2ms/step - ia: 0.8894 - loss: 0.0710 - mae: 0.1619 - rmse: 0.2591 - smape: 0.4003 - val_ia: 0.8663 - val_loss: 0.0570 - val_mae: 0.1352 - val_rmse: 0.2163 - val_smape: 0.3556
# Epoch 96/128
# 240/240 - 1s - 3ms/step - ia: 0.8890 - loss: 0.0724 - mae: 0.1626 - rmse: 0.2611 - smape: 0.4007 - val_ia: 0.8681 - val_loss: 0.0566 - val_mae: 0.1340 - val_rmse: 0.2155 - val_smape: 0.3531
# Epoch 97/128
# 240/240 - 1s - 3ms/step - ia: 0.8897 - loss: 0.0713 - mae: 0.1616 - rmse: 0.2593 - smape: 0.4003 - val_ia: 0.8672 - val_loss: 0.0566 - val_mae: 0.1344 - val_rmse: 0.2156 - val_smape: 0.3538
# Epoch 98/128
# 240/240 - 1s - 3ms/step - ia: 0.8893 - loss: 0.0711 - mae: 0.1620 - rmse: 0.2592 - smape: 0.3992 - val_ia: 0.8665 - val_loss: 0.0564 - val_mae: 0.1345 - val_rmse: 0.2153 - val_smape: 0.3531
# Epoch 99/128
# 240/240 - 1s - 3ms/step - ia: 0.8896 - loss: 0.0716 - mae: 0.1617 - rmse: 0.2600 - smape: 0.3995 - val_ia: 0.8664 - val_loss: 0.0564 - val_mae: 0.1344 - val_rmse: 0.2155 - val_smape: 0.3544
# Epoch 100/128
# 240/240 - 1s - 4ms/step - ia: 0.8898 - loss: 0.0720 - mae: 0.1613 - rmse: 0.2604 - smape: 0.3972 - val_ia: 0.8678 - val_loss: 0.0567 - val_mae: 0.1343 - val_rmse: 0.2156 - val_smape: 0.3528
# Epoch 101/128
# 240/240 - 1s - 5ms/step - ia: 0.8897 - loss: 0.0716 - mae: 0.1616 - rmse: 0.2597 - smape: 0.3997 - val_ia: 0.8672 - val_loss: 0.0563 - val_mae: 0.1341 - val_rmse: 0.2151 - val_smape: 0.3529
# Epoch 102/128
# 240/240 - 1s - 4ms/step - ia: 0.8906 - loss: 0.0708 - mae: 0.1603 - rmse: 0.2584 - smape: 0.3957 - val_ia: 0.8661 - val_loss: 0.0564 - val_mae: 0.1348 - val_rmse: 0.2157 - val_smape: 0.3551
# Epoch 103/128
# 240/240 - 1s - 2ms/step - ia: 0.8902 - loss: 0.0713 - mae: 0.1608 - rmse: 0.2593 - smape: 0.3974 - val_ia: 0.8702 - val_loss: 0.0558 - val_mae: 0.1322 - val_rmse: 0.2139 - val_smape: 0.3490
# Epoch 104/128
# 240/240 - 1s - 2ms/step - ia: 0.8905 - loss: 0.0709 - mae: 0.1602 - rmse: 0.2587 - smape: 0.3940 - val_ia: 0.8676 - val_loss: 0.0563 - val_mae: 0.1341 - val_rmse: 0.2150 - val_smape: 0.3526
# Epoch 105/128
# 240/240 - 1s - 2ms/step - ia: 0.8902 - loss: 0.0710 - mae: 0.1608 - rmse: 0.2588 - smape: 0.3979 - val_ia: 0.8687 - val_loss: 0.0559 - val_mae: 0.1330 - val_rmse: 0.2144 - val_smape: 0.3514
# Epoch 106/128
# 240/240 - 1s - 2ms/step - ia: 0.8904 - loss: 0.0704 - mae: 0.1605 - rmse: 0.2579 - smape: 0.3968 - val_ia: 0.8688 - val_loss: 0.0561 - val_mae: 0.1332 - val_rmse: 0.2147 - val_smape: 0.3521
# Epoch 107/128
# 240/240 - 1s - 3ms/step - ia: 0.8903 - loss: 0.0712 - mae: 0.1607 - rmse: 0.2590 - smape: 0.3972 - val_ia: 0.8674 - val_loss: 0.0561 - val_mae: 0.1339 - val_rmse: 0.2149 - val_smape: 0.3528
# Epoch 108/128
# 240/240 - 1s - 2ms/step - ia: 0.8903 - loss: 0.0709 - mae: 0.1607 - rmse: 0.2585 - smape: 0.3955 - val_ia: 0.8702 - val_loss: 0.0560 - val_mae: 0.1328 - val_rmse: 0.2140 - val_smape: 0.3493
# Epoch 109/128
# 240/240 - 1s - 2ms/step - ia: 0.8912 - loss: 0.0695 - mae: 0.1594 - rmse: 0.2564 - smape: 0.3951 - val_ia: 0.8714 - val_loss: 0.0553 - val_mae: 0.1312 - val_rmse: 0.2127 - val_smape: 0.3469
# Epoch 110/128
# 240/240 - 1s - 3ms/step - ia: 0.8914 - loss: 0.0703 - mae: 0.1593 - rmse: 0.2572 - smape: 0.3946 - val_ia: 0.8670 - val_loss: 0.0561 - val_mae: 0.1341 - val_rmse: 0.2151 - val_smape: 0.3537
# Epoch 111/128
# 240/240 - 1s - 2ms/step - ia: 0.8910 - loss: 0.0702 - mae: 0.1597 - rmse: 0.2573 - smape: 0.3948 - val_ia: 0.8696 - val_loss: 0.0558 - val_mae: 0.1327 - val_rmse: 0.2141 - val_smape: 0.3503
# Epoch 112/128
# 240/240 - 1s - 2ms/step - ia: 0.8912 - loss: 0.0706 - mae: 0.1596 - rmse: 0.2578 - smape: 0.3926 - val_ia: 0.8696 - val_loss: 0.0559 - val_mae: 0.1328 - val_rmse: 0.2142 - val_smape: 0.3506
# Epoch 113/128
# 240/240 - 0s - 2ms/step - ia: 0.8914 - loss: 0.0692 - mae: 0.1592 - rmse: 0.2557 - smape: 0.3948 - val_ia: 0.8715 - val_loss: 0.0553 - val_mae: 0.1310 - val_rmse: 0.2129 - val_smape: 0.3480
# Epoch 114/128
# 240/240 - 0s - 2ms/step - ia: 0.8908 - loss: 0.0709 - mae: 0.1599 - rmse: 0.2583 - smape: 0.3946 - val_ia: 0.8683 - val_loss: 0.0565 - val_mae: 0.1342 - val_rmse: 0.2156 - val_smape: 0.3537
# Epoch 115/128
# 240/240 - 1s - 3ms/step - ia: 0.8913 - loss: 0.0699 - mae: 0.1593 - rmse: 0.2572 - smape: 0.3932 - val_ia: 0.8689 - val_loss: 0.0559 - val_mae: 0.1333 - val_rmse: 0.2141 - val_smape: 0.3503
# Epoch 116/128
# 240/240 - 0s - 2ms/step - ia: 0.8915 - loss: 0.0693 - mae: 0.1590 - rmse: 0.2558 - smape: 0.3937 - val_ia: 0.8706 - val_loss: 0.0556 - val_mae: 0.1320 - val_rmse: 0.2138 - val_smape: 0.3493
# Epoch 117/128
# 240/240 - 1s - 2ms/step - ia: 0.8914 - loss: 0.0697 - mae: 0.1592 - rmse: 0.2572 - smape: 0.3924 - val_ia: 0.8691 - val_loss: 0.0564 - val_mae: 0.1338 - val_rmse: 0.2153 - val_smape: 0.3523
# Epoch 118/128
# 240/240 - 2s - 6ms/step - ia: 0.8913 - loss: 0.0699 - mae: 0.1592 - rmse: 0.2572 - smape: 0.3938 - val_ia: 0.8693 - val_loss: 0.0560 - val_mae: 0.1333 - val_rmse: 0.2144 - val_smape: 0.3509
# Epoch 119/128
# 240/240 - 1s - 2ms/step - ia: 0.8921 - loss: 0.0696 - mae: 0.1581 - rmse: 0.2561 - smape: 0.3917 - val_ia: 0.8724 - val_loss: 0.0556 - val_mae: 0.1316 - val_rmse: 0.2131 - val_smape: 0.3468
# Epoch 120/128
# 240/240 - 1s - 2ms/step - ia: 0.8921 - loss: 0.0698 - mae: 0.1582 - rmse: 0.2563 - smape: 0.3920 - val_ia: 0.8705 - val_loss: 0.0559 - val_mae: 0.1325 - val_rmse: 0.2141 - val_smape: 0.3494
# Epoch 121/128
# 240/240 - 1s - 2ms/step - ia: 0.8917 - loss: 0.0695 - mae: 0.1586 - rmse: 0.2565 - smape: 0.3937 - val_ia: 0.8680 - val_loss: 0.0563 - val_mae: 0.1343 - val_rmse: 0.2150 - val_smape: 0.3519
# Epoch 122/128
# 240/240 - 0s - 2ms/step - ia: 0.8926 - loss: 0.0690 - mae: 0.1574 - rmse: 0.2552 - smape: 0.3883 - val_ia: 0.8689 - val_loss: 0.0559 - val_mae: 0.1334 - val_rmse: 0.2146 - val_smape: 0.3520
# Epoch 123/128
# 240/240 - 0s - 2ms/step - ia: 0.8919 - loss: 0.0692 - mae: 0.1583 - rmse: 0.2559 - smape: 0.3931 - val_ia: 0.8697 - val_loss: 0.0555 - val_mae: 0.1327 - val_rmse: 0.2136 - val_smape: 0.3497
# Epoch 124/128
# 240/240 - 1s - 2ms/step - ia: 0.8924 - loss: 0.0693 - mae: 0.1577 - rmse: 0.2555 - smape: 0.3928 - val_ia: 0.8706 - val_loss: 0.0555 - val_mae: 0.1322 - val_rmse: 0.2134 - val_smape: 0.3488
# Epoch 125/128
# 240/240 - 1s - 4ms/step - ia: 0.8923 - loss: 0.0689 - mae: 0.1579 - rmse: 0.2553 - smape: 0.3904 - val_ia: 0.8694 - val_loss: 0.0565 - val_mae: 0.1341 - val_rmse: 0.2151 - val_smape: 0.3513
# Epoch 126/128
# 240/240 - 1s - 4ms/step - ia: 0.8926 - loss: 0.0694 - mae: 0.1575 - rmse: 0.2557 - smape: 0.3890 - val_ia: 0.8723 - val_loss: 0.0551 - val_mae: 0.1309 - val_rmse: 0.2124 - val_smape: 0.3461
# Epoch 127/128
# 240/240 - 1s - 2ms/step - ia: 0.8929 - loss: 0.0683 - mae: 0.1570 - rmse: 0.2539 - smape: 0.3908 - val_ia: 0.8709 - val_loss: 0.0557 - val_mae: 0.1324 - val_rmse: 0.2138 - val_smape: 0.3492
# Epoch 128/128
# 240/240 - 1s - 3ms/step - ia: 0.8931 - loss: 0.0687 - mae: 0.1567 - rmse: 0.2547 - smape: 0.3883 - val_ia: 0.8711 - val_loss: 0.0553 - val_mae: 0.1317 - val_rmse: 0.2131 - val_smape: 0.3481
# Restoring model weights from the end of the best epoch: 126.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
metricasMLP = modelMLP.evaluate(valMLPX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasMLP}")
# Out:
# 136/136 - 0s - 1ms/step - ia: 0.7733 - loss: 0.0378 - mae: 0.1177 - rmse: 0.1702 - smape: 0.3171
# Métricas en el conjunto de validación: [0.03783682361245155, 0.11772802472114563, 0.31711915135383606, 0.17018413543701172, 0.7733457684516907]

# %%
historyMLP = historyMLP.history
ejeXMLP = range(1, len(historyMLP['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXMLP, historyMLP['loss'], label='Train Loss')
plt.plot(ejeXMLP, historyMLP['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyMLP['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyMLP['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.06869278848171234
# Último valor de Test Loss: 0.05534486472606659

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionMLP.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfMLP = df
fig.show()

# %% [markdown]
# ### Datos para NARMAX

# %%
prediccionNarmaxMLP = modelMLP.predict(datosMLPX)
erroresMLP = datosY - prediccionNarmaxMLP
# Out:
# 1369/1369 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step

# %%
dfErroresMLP = pd.DataFrame(erroresMLP, columns = ["e"])
dfErroresMLP.index = indices

# %%
dfNarmaxMLP = datosNormalizados.join(dfErroresMLP, how = 'left')

print(dfNarmaxMLP.head())
print(dfNarmaxMLP.tail())
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 00:00:00   0.317681 -1.214023 -1.268524  0.329687 -0.380944
# 2010-01-02 01:00:00   0.526152 -1.144302 -1.268524  0.329687 -0.380944
# 2010-01-02 02:00:00   0.646846 -0.865419 -1.349314  0.426127 -0.380944
# 2010-01-02 03:00:00   0.888234 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 04:00:00   0.416431 -0.586536 -1.349314  0.522567 -0.380944
#
#                       wnd_spd   e
# date
# 2010-01-02 00:00:00 -0.464048 NaN
# 2010-01-02 01:00:00 -0.446575 NaN
# 2010-01-02 02:00:00 -0.429103 NaN
# 2010-01-02 03:00:00 -0.393962 NaN
# 2010-01-02 04:00:00 -0.376489 NaN
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2014-12-31 19:00:00  -1.009952 -1.702068 -1.106944  1.679851  0.694538
# 2014-12-31 20:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 21:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 22:00:00  -1.009952 -1.632347 -1.268524  1.679851  0.694538
# 2014-12-31 23:00:00  -0.966063 -1.562627 -1.187734  1.679851  0.694538
#
#                       wnd_spd         e
# date
# 2014-12-31 19:00:00  4.054828 -0.056149
# 2014-12-31 20:00:00  4.168890  0.005569
# 2014-12-31 21:00:00  4.265479 -0.029062
# 2014-12-31 22:00:00  4.344399 -0.035766
# 2014-12-31 23:00:00  4.405847  0.032112

# %%
dfNarmaxMLP.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\1pasos_mlp_pollution.csv', index=True)

# %%
dfMLP.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacion\\1pasos_mlp_pollution.csv', index=True)

# %%
modelMLP.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarx\\1pasos_mlp_pollution.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## LSTM

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelLSTM = Sequential()
modelLSTM.add(InputLayer(input_shape=(trainX.shape[1], trainX.shape[2])))

modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=True))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=True))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=True))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=False))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(Dense(1))


opt = Adam(learning_rate=0.00027101707182655693)
modelLSTM.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelLSTM.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 12, 128)        │        69,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 12, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 12, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 464,001 (1.77 MB)
#  Trainable params: 464,001 (1.77 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyLSTM = modelLSTM.fit(trainX, trainY, epochs=128, validation_data=(testX, testY), verbose = 2, batch_size=16, callbacks=[early_stopping])


prediccionLSTM = modelLSTM.predict(valX)
# Out:
# Epoch 1/128
# 1916/1916 - 54s - 28ms/step - ia: 0.7934 - loss: 0.1873 - mae: 0.2670 - rmse: 0.3833 - smape: 0.5898 - val_ia: 0.6060 - val_loss: 0.0723 - val_mae: 0.1703 - val_rmse: 0.2277 - val_smape: 0.4449
# Epoch 2/128
# 1916/1916 - 43s - 23ms/step - ia: 0.8826 - loss: 0.0723 - mae: 0.1599 - rmse: 0.2397 - smape: 0.3953 - val_ia: 0.6847 - val_loss: 0.0575 - val_mae: 0.1381 - val_rmse: 0.1929 - val_smape: 0.3592
# Epoch 3/128
# 1916/1916 - 50s - 26ms/step - ia: 0.8892 - loss: 0.0678 - mae: 0.1514 - rmse: 0.2303 - smape: 0.3755 - val_ia: 0.6939 - val_loss: 0.0563 - val_mae: 0.1341 - val_rmse: 0.1893 - val_smape: 0.3518
# Epoch 4/128
# 1916/1916 - 52s - 27ms/step - ia: 0.8916 - loss: 0.0660 - mae: 0.1483 - rmse: 0.2271 - smape: 0.3695 - val_ia: 0.6981 - val_loss: 0.0558 - val_mae: 0.1324 - val_rmse: 0.1872 - val_smape: 0.3493
# Epoch 5/128
# 1916/1916 - 69s - 36ms/step - ia: 0.8927 - loss: 0.0650 - mae: 0.1469 - rmse: 0.2252 - smape: 0.3664 - val_ia: 0.6999 - val_loss: 0.0555 - val_mae: 0.1317 - val_rmse: 0.1860 - val_smape: 0.3474
# Epoch 6/128
# 1916/1916 - 43s - 22ms/step - ia: 0.8935 - loss: 0.0640 - mae: 0.1458 - rmse: 0.2236 - smape: 0.3648 - val_ia: 0.7008 - val_loss: 0.0556 - val_mae: 0.1318 - val_rmse: 0.1855 - val_smape: 0.3458
# Epoch 7/128
# 1916/1916 - 78s - 41ms/step - ia: 0.8941 - loss: 0.0632 - mae: 0.1450 - rmse: 0.2223 - smape: 0.3638 - val_ia: 0.7009 - val_loss: 0.0555 - val_mae: 0.1320 - val_rmse: 0.1853 - val_smape: 0.3451
# Epoch 8/128
# 1916/1916 - 40s - 21ms/step - ia: 0.8947 - loss: 0.0624 - mae: 0.1443 - rmse: 0.2211 - smape: 0.3630 - val_ia: 0.7010 - val_loss: 0.0556 - val_mae: 0.1321 - val_rmse: 0.1852 - val_smape: 0.3448
# Epoch 9/128
# 1916/1916 - 42s - 22ms/step - ia: 0.8952 - loss: 0.0616 - mae: 0.1436 - rmse: 0.2200 - smape: 0.3621 - val_ia: 0.7017 - val_loss: 0.0556 - val_mae: 0.1321 - val_rmse: 0.1849 - val_smape: 0.3450
# Epoch 10/128
# 1916/1916 - 43s - 22ms/step - ia: 0.8956 - loss: 0.0610 - mae: 0.1430 - rmse: 0.2191 - smape: 0.3614 - val_ia: 0.7023 - val_loss: 0.0557 - val_mae: 0.1320 - val_rmse: 0.1847 - val_smape: 0.3453
# Epoch 11/128
# 1916/1916 - 83s - 43ms/step - ia: 0.8960 - loss: 0.0604 - mae: 0.1425 - rmse: 0.2183 - smape: 0.3609 - val_ia: 0.7024 - val_loss: 0.0558 - val_mae: 0.1321 - val_rmse: 0.1846 - val_smape: 0.3456
# Epoch 12/128
# 1916/1916 - 42s - 22ms/step - ia: 0.8963 - loss: 0.0599 - mae: 0.1421 - rmse: 0.2175 - smape: 0.3604 - val_ia: 0.7020 - val_loss: 0.0560 - val_mae: 0.1322 - val_rmse: 0.1847 - val_smape: 0.3460
# Epoch 13/128
# 1916/1916 - 42s - 22ms/step - ia: 0.8967 - loss: 0.0593 - mae: 0.1416 - rmse: 0.2168 - smape: 0.3600 - val_ia: 0.7015 - val_loss: 0.0562 - val_mae: 0.1324 - val_rmse: 0.1847 - val_smape: 0.3461
# Epoch 14/128
# 1916/1916 - 44s - 23ms/step - ia: 0.8969 - loss: 0.0589 - mae: 0.1412 - rmse: 0.2161 - smape: 0.3596 - val_ia: 0.7006 - val_loss: 0.0566 - val_mae: 0.1327 - val_rmse: 0.1851 - val_smape: 0.3463
# Epoch 15/128
# 1916/1916 - 85s - 44ms/step - ia: 0.8972 - loss: 0.0584 - mae: 0.1408 - rmse: 0.2154 - smape: 0.3591 - val_ia: 0.7000 - val_loss: 0.0569 - val_mae: 0.1331 - val_rmse: 0.1854 - val_smape: 0.3465
# Epoch 16/128
# 1916/1916 - 56s - 29ms/step - ia: 0.8975 - loss: 0.0580 - mae: 0.1405 - rmse: 0.2149 - smape: 0.3587 - val_ia: 0.6997 - val_loss: 0.0565 - val_mae: 0.1327 - val_rmse: 0.1848 - val_smape: 0.3466
# Epoch 17/128
# 1916/1916 - 59s - 31ms/step - ia: 0.8978 - loss: 0.0575 - mae: 0.1401 - rmse: 0.2141 - smape: 0.3583 - val_ia: 0.6981 - val_loss: 0.0570 - val_mae: 0.1333 - val_rmse: 0.1854 - val_smape: 0.3474
# Epoch 18/128
# 1916/1916 - 46s - 24ms/step - ia: 0.8980 - loss: 0.0571 - mae: 0.1397 - rmse: 0.2134 - smape: 0.3578 - val_ia: 0.6983 - val_loss: 0.0564 - val_mae: 0.1327 - val_rmse: 0.1848 - val_smape: 0.3473
# Epoch 19/128
# 1916/1916 - 91s - 48ms/step - ia: 0.8982 - loss: 0.0568 - mae: 0.1395 - rmse: 0.2130 - smape: 0.3576 - val_ia: 0.6972 - val_loss: 0.0565 - val_mae: 0.1329 - val_rmse: 0.1850 - val_smape: 0.3482
# Epoch 20/128
# 1916/1916 - 45s - 23ms/step - ia: 0.8985 - loss: 0.0564 - mae: 0.1392 - rmse: 0.2123 - smape: 0.3573 - val_ia: 0.6954 - val_loss: 0.0559 - val_mae: 0.1325 - val_rmse: 0.1845 - val_smape: 0.3490
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step

# %%
metricasLSTM = modelLSTM.evaluate(valX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasLSTM}")
# Out:
# 136/136 - 2s - 13ms/step - ia: 0.7863 - loss: 0.0388 - mae: 0.1169 - rmse: 0.1730 - smape: 0.3154
# Métricas en el conjunto de validación: [0.03879912197589874, 0.11688674241304398, 0.3153822422027588, 0.17296019196510315, 0.7863016724586487]

# %%
historyLSTM = historyLSTM.history

ejeXLSTM = range(1, len(historyLSTM['loss']) + 1)

plt.figure(figsize=(12, 8))
plt.plot(ejeXLSTM, historyLSTM['loss'], label='Train Loss')
plt.plot(ejeXLSTM, historyLSTM['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyLSTM['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyLSTM['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.05639299377799034
# Último valor de Test Loss: 0.05589671805500984

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionLSTM.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfLSTM = df
fig.show()

# %% [markdown]
# ### Datos para NARMAX

# %%
prediccionNarmaxLSTM = modelLSTM.predict(datosX)
erroresLSTM = datosY - prediccionNarmaxLSTM
# Out:
# 1369/1369 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step

# %%
dfErroresLSTM = pd.DataFrame(erroresLSTM, columns = ["e"])
dfErroresLSTM.index = indices

# %%
dfNarmaxLSTM = datosNormalizados.join(dfErroresLSTM, how = 'left')

print(dfNarmaxLSTM.head())
print(dfNarmaxLSTM.tail())
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 00:00:00   0.317681 -1.214023 -1.268524  0.329687 -0.380944
# 2010-01-02 01:00:00   0.526152 -1.144302 -1.268524  0.329687 -0.380944
# 2010-01-02 02:00:00   0.646846 -0.865419 -1.349314  0.426127 -0.380944
# 2010-01-02 03:00:00   0.888234 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 04:00:00   0.416431 -0.586536 -1.349314  0.522567 -0.380944
#
#                       wnd_spd   e
# date
# 2010-01-02 00:00:00 -0.464048 NaN
# 2010-01-02 01:00:00 -0.446575 NaN
# 2010-01-02 02:00:00 -0.429103 NaN
# 2010-01-02 03:00:00 -0.393962 NaN
# 2010-01-02 04:00:00 -0.376489 NaN
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2014-12-31 19:00:00  -1.009952 -1.702068 -1.106944  1.679851  0.694538
# 2014-12-31 20:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 21:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 22:00:00  -1.009952 -1.632347 -1.268524  1.679851  0.694538
# 2014-12-31 23:00:00  -0.966063 -1.562627 -1.187734  1.679851  0.694538
#
#                       wnd_spd         e
# date
# 2014-12-31 19:00:00  4.054828 -0.017564
# 2014-12-31 20:00:00  4.168890  0.038002
# 2014-12-31 21:00:00  4.265479  0.018046
# 2014-12-31 22:00:00  4.344399 -0.007399
# 2014-12-31 23:00:00  4.405847  0.049547

# %%
dfNarmaxLSTM.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\1pasos_lstm_pollution.csv', index=True)

# %%
dfLSTM.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacion\\1pasos_lstm_pollution.csv', index=True)

# %%
modelLSTM.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarx\\1pasos_lstm_pollution.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## GRU

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelGRU = Sequential()
modelGRU.add(InputLayer(input_shape=(trainX.shape[1], trainX.shape[2])))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=True))
modelGRU.add(Dropout(0.0))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=True))
modelGRU.add(Dropout(0.0))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=True))
modelGRU.add(Dropout(0.0))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=False))
modelGRU.add(Dropout(0.0))

modelGRU.add(Dense(1))


opt = Adam(learning_rate=0.00027101707182655693)
modelGRU.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelGRU.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 12, 128)        │        52,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 12, 128)        │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 12, 128)        │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 128)            │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 349,569 (1.33 MB)
#  Trainable params: 349,569 (1.33 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)

early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyGRU = modelGRU.fit(trainX, trainY, epochs=128, validation_data=(testX, testY), verbose = 2, batch_size=16, callbacks=[early_stopping])

prediccionGRU = modelGRU.predict(valX)
# Out:
# Epoch 1/128
# 1916/1916 - 92s - 48ms/step - ia: 0.8566 - loss: 0.1030 - mae: 0.1915 - rmse: 0.2819 - smape: 0.4532 - val_ia: 0.6743 - val_loss: 0.0588 - val_mae: 0.1421 - val_rmse: 0.1981 - val_smape: 0.3702
# Epoch 2/128
# 1916/1916 - 80s - 42ms/step - ia: 0.8877 - loss: 0.0694 - mae: 0.1535 - rmse: 0.2329 - smape: 0.3784 - val_ia: 0.6839 - val_loss: 0.0570 - val_mae: 0.1378 - val_rmse: 0.1939 - val_smape: 0.3637
# Epoch 3/128
# 1916/1916 - 55s - 29ms/step - ia: 0.8903 - loss: 0.0668 - mae: 0.1500 - rmse: 0.2287 - smape: 0.3722 - val_ia: 0.6906 - val_loss: 0.0557 - val_mae: 0.1348 - val_rmse: 0.1904 - val_smape: 0.3589
# Epoch 4/128
# 1916/1916 - 81s - 42ms/step - ia: 0.8914 - loss: 0.0657 - mae: 0.1486 - rmse: 0.2268 - smape: 0.3702 - val_ia: 0.6948 - val_loss: 0.0547 - val_mae: 0.1327 - val_rmse: 0.1876 - val_smape: 0.3551
# Epoch 5/128
# 1916/1916 - 86s - 45ms/step - ia: 0.8925 - loss: 0.0645 - mae: 0.1472 - rmse: 0.2248 - smape: 0.3682 - val_ia: 0.6989 - val_loss: 0.0542 - val_mae: 0.1313 - val_rmse: 0.1857 - val_smape: 0.3507
# Epoch 6/128
# 1916/1916 - 57s - 30ms/step - ia: 0.8934 - loss: 0.0635 - mae: 0.1460 - rmse: 0.2232 - smape: 0.3662 - val_ia: 0.7010 - val_loss: 0.0542 - val_mae: 0.1310 - val_rmse: 0.1848 - val_smape: 0.3492
# Epoch 7/128
# 1916/1916 - 79s - 41ms/step - ia: 0.8941 - loss: 0.0626 - mae: 0.1449 - rmse: 0.2218 - smape: 0.3645 - val_ia: 0.7019 - val_loss: 0.0544 - val_mae: 0.1311 - val_rmse: 0.1845 - val_smape: 0.3479
# Epoch 8/128
# 1916/1916 - 55s - 29ms/step - ia: 0.8948 - loss: 0.0619 - mae: 0.1441 - rmse: 0.2206 - smape: 0.3633 - val_ia: 0.7021 - val_loss: 0.0547 - val_mae: 0.1312 - val_rmse: 0.1843 - val_smape: 0.3468
# Epoch 9/128
# 1916/1916 - 54s - 28ms/step - ia: 0.8953 - loss: 0.0612 - mae: 0.1433 - rmse: 0.2194 - smape: 0.3625 - val_ia: 0.7022 - val_loss: 0.0551 - val_mae: 0.1314 - val_rmse: 0.1844 - val_smape: 0.3460
# Epoch 10/128
# 1916/1916 - 55s - 29ms/step - ia: 0.8959 - loss: 0.0604 - mae: 0.1425 - rmse: 0.2183 - smape: 0.3615 - val_ia: 0.7022 - val_loss: 0.0554 - val_mae: 0.1316 - val_rmse: 0.1845 - val_smape: 0.3456
# Epoch 11/128
# 1916/1916 - 83s - 43ms/step - ia: 0.8965 - loss: 0.0597 - mae: 0.1418 - rmse: 0.2172 - smape: 0.3606 - val_ia: 0.7020 - val_loss: 0.0557 - val_mae: 0.1316 - val_rmse: 0.1844 - val_smape: 0.3455
# Epoch 12/128
# 1916/1916 - 73s - 38ms/step - ia: 0.8970 - loss: 0.0590 - mae: 0.1411 - rmse: 0.2162 - smape: 0.3596 - val_ia: 0.7013 - val_loss: 0.0559 - val_mae: 0.1318 - val_rmse: 0.1845 - val_smape: 0.3460
# Epoch 13/128
# 1916/1916 - 45s - 23ms/step - ia: 0.8974 - loss: 0.0585 - mae: 0.1405 - rmse: 0.2153 - smape: 0.3588 - val_ia: 0.7006 - val_loss: 0.0562 - val_mae: 0.1321 - val_rmse: 0.1847 - val_smape: 0.3465
# Epoch 14/128
# 1916/1916 - 80s - 42ms/step - ia: 0.8979 - loss: 0.0579 - mae: 0.1399 - rmse: 0.2143 - smape: 0.3579 - val_ia: 0.7000 - val_loss: 0.0563 - val_mae: 0.1321 - val_rmse: 0.1847 - val_smape: 0.3472
# Epoch 15/128
# 1916/1916 - 39s - 20ms/step - ia: 0.8981 - loss: 0.0575 - mae: 0.1396 - rmse: 0.2138 - smape: 0.3575 - val_ia: 0.6994 - val_loss: 0.0565 - val_mae: 0.1324 - val_rmse: 0.1849 - val_smape: 0.3478
# Epoch 16/128
# 1916/1916 - 54s - 28ms/step - ia: 0.8980 - loss: 0.0583 - mae: 0.1398 - rmse: 0.2144 - smape: 0.3576 - val_ia: 0.6983 - val_loss: 0.0546 - val_mae: 0.1312 - val_rmse: 0.1833 - val_smape: 0.3468
# Epoch 17/128
# 1916/1916 - 82s - 43ms/step - ia: 0.8986 - loss: 0.0568 - mae: 0.1389 - rmse: 0.2125 - smape: 0.3567 - val_ia: 0.6950 - val_loss: 0.0559 - val_mae: 0.1324 - val_rmse: 0.1846 - val_smape: 0.3487
# Epoch 18/128
# 1916/1916 - 81s - 42ms/step - ia: 0.8989 - loss: 0.0563 - mae: 0.1386 - rmse: 0.2117 - smape: 0.3564 - val_ia: 0.6941 - val_loss: 0.0566 - val_mae: 0.1334 - val_rmse: 0.1854 - val_smape: 0.3496
# Epoch 19/128
# 1916/1916 - 54s - 28ms/step - ia: 0.8985 - loss: 0.0572 - mae: 0.1391 - rmse: 0.2128 - smape: 0.3569 - val_ia: 0.6933 - val_loss: 0.0546 - val_mae: 0.1323 - val_rmse: 0.1839 - val_smape: 0.3488
# Epoch 20/128
# 1916/1916 - 82s - 43ms/step - ia: 0.8996 - loss: 0.0553 - mae: 0.1376 - rmse: 0.2100 - smape: 0.3554 - val_ia: 0.6960 - val_loss: 0.0552 - val_mae: 0.1315 - val_rmse: 0.1838 - val_smape: 0.3474
# Epoch 21/128
# 1916/1916 - 53s - 28ms/step - ia: 0.8995 - loss: 0.0552 - mae: 0.1376 - rmse: 0.2099 - smape: 0.3554 - val_ia: 0.6966 - val_loss: 0.0547 - val_mae: 0.1310 - val_rmse: 0.1832 - val_smape: 0.3475
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step

# %%
metricasGRU = modelGRU.evaluate(valX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasGRU}")
# Out:
# 136/136 - 2s - 14ms/step - ia: 0.7856 - loss: 0.0386 - mae: 0.1163 - rmse: 0.1723 - smape: 0.3147
# Métricas en el conjunto de validación: [0.038649268448352814, 0.1162572056055069, 0.3147364854812622, 0.1722947210073471, 0.7855612635612488]

# %%
historyGRU = historyGRU.history
    
ejeXGRU = range(1, len(historyGRU['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXGRU, historyGRU['loss'], label='Train Loss')
plt.plot(ejeXGRU, historyGRU['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyGRU['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyGRU['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.05520594120025635
# Último valor de Test Loss: 0.054654672741889954

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionGRU.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfGRU = df
fig.show()

# %% [markdown]
# ### Datos para NARMAX

# %%
prediccionNarmaxGRU = modelGRU.predict(datosX)
erroresGRU = datosY - prediccionNarmaxGRU
# Out:
# 1369/1369 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step

# %%
dfErroresGRU = pd.DataFrame(erroresGRU, columns = ["e"])
dfErroresGRU.index = indices

# %%
dfNarmaxGRU = datosNormalizados.join(dfErroresGRU, how = 'left')

print(dfNarmaxGRU.head())
print(dfNarmaxGRU.tail())
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 00:00:00   0.317681 -1.214023 -1.268524  0.329687 -0.380944
# 2010-01-02 01:00:00   0.526152 -1.144302 -1.268524  0.329687 -0.380944
# 2010-01-02 02:00:00   0.646846 -0.865419 -1.349314  0.426127 -0.380944
# 2010-01-02 03:00:00   0.888234 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 04:00:00   0.416431 -0.586536 -1.349314  0.522567 -0.380944
#
#                       wnd_spd   e
# date
# 2010-01-02 00:00:00 -0.464048 NaN
# 2010-01-02 01:00:00 -0.446575 NaN
# 2010-01-02 02:00:00 -0.429103 NaN
# 2010-01-02 03:00:00 -0.393962 NaN
# 2010-01-02 04:00:00 -0.376489 NaN
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2014-12-31 19:00:00  -1.009952 -1.702068 -1.106944  1.679851  0.694538
# 2014-12-31 20:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 21:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 22:00:00  -1.009952 -1.632347 -1.268524  1.679851  0.694538
# 2014-12-31 23:00:00  -0.966063 -1.562627 -1.187734  1.679851  0.694538
#
#                       wnd_spd         e
# date
# 2014-12-31 19:00:00  4.054828 -0.032836
# 2014-12-31 20:00:00  4.168890  0.021897
# 2014-12-31 21:00:00  4.265479 -0.001082
# 2014-12-31 22:00:00  4.344399 -0.021268
# 2014-12-31 23:00:00  4.405847  0.039714

# %%
dfNarmaxGRU.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\1pasos_gru_pollution.csv', index=True)

# %%
dfGRU.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacion\\1pasos_gru_pollution.csv', index=True)

# %%
modelGRU.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarx\\1pasos_gru_pollution.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
