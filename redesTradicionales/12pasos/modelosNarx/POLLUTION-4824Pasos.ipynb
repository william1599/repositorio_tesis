# %% [markdown]
# Prueba

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from hyperopt import hp, fmin, tpe, Trials, STATUS_OK
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU, InputLayer, Flatten, LSTM
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import os
from datetime import datetime, timedelta
import plotly.express as px
import plotly.graph_objects as go
import random

# %% [markdown]
# LEER DATASET

# %%
import pandas as pd

datos = pd.read_csv("C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\SNpollutionFinal.csv")

datos['date'] = pd.to_datetime(datos['date'])

# Se establece la columna date como index
datos.set_index('date', inplace=True)

# %%
datos.head()
# Out:
#                      pollution  dew  temp   press  wnd_dir  wnd_spd
# date
# 2010-01-01 00:00:00      129.0  -21 -11.0  1021.0        2     1.79
# 2010-01-01 01:00:00      129.0  -21 -12.0  1020.0        2     4.92
# 2010-01-01 02:00:00      129.0  -21 -11.0  1019.0        2     6.71
# 2010-01-01 03:00:00      129.0  -21 -14.0  1019.0        2     9.84
# 2010-01-01 04:00:00      129.0  -20 -12.0  1018.0        2    12.97

# %%
datos = datos.drop(datos.index[:24])

datos
# Out:
#                      pollution  dew  temp   press  wnd_dir  wnd_spd
# date
# 2010-01-02 00:00:00      129.0  -16  -4.0  1020.0        1     1.79
# 2010-01-02 01:00:00      148.0  -15  -4.0  1020.0        1     2.68
# 2010-01-02 02:00:00      159.0  -11  -5.0  1021.0        1     3.57
# 2010-01-02 03:00:00      181.0   -7  -5.0  1022.0        1     5.36
# 2010-01-02 04:00:00      138.0   -7  -5.0  1022.0        1     6.25
# ...                        ...  ...   ...     ...      ...      ...
# 2014-12-31 19:00:00        8.0  -23  -2.0  1034.0        2   231.97
# 2014-12-31 20:00:00       10.0  -22  -3.0  1034.0        2   237.78
# 2014-12-31 21:00:00       10.0  -22  -3.0  1034.0        2   242.70
# 2014-12-31 22:00:00        8.0  -22  -4.0  1034.0        2   246.72
# 2014-12-31 23:00:00       12.0  -21  -3.0  1034.0        2   249.85
#
# [43800 rows x 6 columns]

# %%
#Se verifica que el index está en formato de dato "datetime64"
print("El index del dataframe input es un tipo de dato: ", datos.index.dtype)
# Out:
# El index del dataframe input es un tipo de dato:  datetime64[ns]

# %% [markdown]
# Se divide el dataset

# %%
# Dividir el conjunto de datos en entrenamiento y prueba
train, test = train_test_split(datos, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
test, val = train_test_split(test, test_size=0.33, shuffle=False)

print("Las dimensiones de train son: ", train.shape)
print("Las dimensiones de test son: ", test.shape)
print("Las dimensiones de val son: ", val.shape)
# Out:
# Las dimensiones de train son:  (30660, 6)
# Las dimensiones de test son:  (8803, 6)
# Las dimensiones de val son:  (4337, 6)

# %% [markdown]
# Se normalizan los datos

# %%
from sklearn.preprocessing import StandardScaler


# Normalizar solo con los datos de entrenamiento
scaler = StandardScaler()
train = scaler.fit_transform(train)

# Aplicar la transformación a test y val usando los parámetros de train
test = scaler.transform(test)
val = scaler.transform(val)

train = pd.DataFrame(train, columns=datos.columns)
test = pd.DataFrame(test, columns=datos.columns)
val = pd.DataFrame(val, columns=datos.columns)

# %% [markdown]
# Se unen los datos nuevamente, ahora normalizados, en un único conjunto.

# %%
datosNormalizados = pd.concat([train, test, val])

datosNormalizados.index = datos.index

# %%
datosNormalizados.shape
# Out:
# (43800, 6)

# %%
datosNormalizados.head(13)
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 00:00:00   0.317681 -1.214023 -1.268524  0.329687 -0.380944
# 2010-01-02 01:00:00   0.526152 -1.144302 -1.268524  0.329687 -0.380944
# 2010-01-02 02:00:00   0.646846 -0.865419 -1.349314  0.426127 -0.380944
# 2010-01-02 03:00:00   0.888234 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 04:00:00   0.416431 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 05:00:00   0.098238 -0.586536 -1.430104  0.522567 -0.380944
# 2010-01-02 06:00:00   0.054349 -0.586536 -1.430104  0.619008 -0.380944
# 2010-01-02 07:00:00   0.262820 -0.586536 -1.349314  0.715448 -0.380944
# 2010-01-02 08:00:00   0.218931 -0.656257 -1.430104  0.715448 -0.380944
# 2010-01-02 09:00:00   0.350598 -0.586536 -1.349314  0.811888 -0.380944
# 2010-01-02 10:00:00   0.438375 -0.586536 -1.349314  0.908328 -0.380944
# 2010-01-02 11:00:00   0.570041 -0.656257 -1.349314  0.908328 -0.380944
# 2010-01-02 12:00:00   0.526152 -0.656257 -1.349314  0.908328 -0.380944
#
#                       wnd_spd
# date
# 2010-01-02 00:00:00 -0.464048
# 2010-01-02 01:00:00 -0.446575
# 2010-01-02 02:00:00 -0.429103
# 2010-01-02 03:00:00 -0.393962
# 2010-01-02 04:00:00 -0.376489
# 2010-01-02 05:00:00 -0.359017
# 2010-01-02 06:00:00 -0.323876
# 2010-01-02 07:00:00 -0.288735
# 2010-01-02 08:00:00 -0.253594
# 2010-01-02 09:00:00 -0.218452
# 2010-01-02 10:00:00 -0.157004
# 2010-01-02 11:00:00 -0.095557
# 2010-01-02 12:00:00 -0.034109

# %% [markdown]
# Se establece el formato de datos de entrada para redes GRU y LSTM, es decir [observaciones, retardos, caracteristicas]

# %%
futuros = 24
pasados  = 48

# %%
datosX = []
datosY = []
for i in range(pasados, len(datosNormalizados) - futuros + 1):
  datosX.append(datosNormalizados.iloc[i-pasados:i, 0:datosNormalizados.shape[1]])
  datosY.append(datosNormalizados.iloc[i+futuros-1:i+futuros, 0])

# %%
# Convertir las listas en arrays numpy
datosX = np.array(datosX)
datosY = np.array(datosY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de X:", datosX.shape)  # (n_muestras, pasos_de_tiempo, n_características)
print("Dimensiones de Y:", datosY.shape)  # (n_muestras, n_características)
# Out:
# Dimensiones de X: (43729, 48, 6)
# Dimensiones de Y: (43729, 1)

# %%
inputs = datosX.shape[1] * datosX.shape[2]
datosMLPX = datosX.reshape(datosX.shape[0], inputs)

# %%
print(datosX[0])
print(datosMLPX[0])
# Out:
# [[ 0.31768099 -1.2140229  -1.26852411  0.32968671 -0.38094383 -0.46404777]
#  [ 0.52615226 -1.14430217 -1.26852411  0.32968671 -0.38094383 -0.44657536]
#  [ 0.64684616 -0.86541928 -1.34931411  0.42612698 -0.38094383 -0.42910295]
#  [ 0.88823396 -0.58653639 -1.34931411  0.52256725 -0.38094383 -0.39396181]
#  [ 0.41643054 -0.58653639 -1.34931411  0.52256725 -0.38094383 -0.3764894 ]
#  [ 0.09823754 -0.58653639 -1.4301041   0.52256725 -0.38094383 -0.35901698]
#  [ 0.05434885 -0.58653639 -1.4301041   0.61900753 -0.38094383 -0.32387584]
#  [ 0.26282012 -0.58653639 -1.34931411  0.7154478  -0.38094383 -0.2887347 ]
#  [ 0.21893143 -0.65625711 -1.4301041   0.7154478  -0.38094383 -0.25359356]
#  [ 0.3505975  -0.58653639 -1.34931411  0.81188808 -0.38094383 -0.21845241]
#  [ 0.43837488 -0.58653639 -1.34931411  0.90832835 -0.38094383 -0.15700449]
#  [ 0.57004095 -0.65625711 -1.34931411  0.90832835 -0.38094383 -0.09555657]
#  [ 0.52615226 -0.65625711 -1.34931411  0.90832835 -0.38094383 -0.03410865]
#  [ 0.70170703 -0.65625711 -1.34931411  0.81188808 -0.38094383  0.04481168]
#  [ 0.63587399 -0.72597783 -1.34931411  0.81188808 -0.38094383  0.12373201]
#  [ 0.5919853  -0.72597783 -1.34931411  0.81188808 -0.38094383  0.20265234]
#  [ 0.64684616 -0.72597783 -1.34931411  0.90832835 -0.38094383  0.23779348]
#  [ 0.70170703 -0.65625711 -1.34931411  1.00476862 -0.38094383  0.27293462]
#  [ 0.76754006 -0.65625711 -1.34931411  1.00476862 -0.38094383  0.33438254]
#  [ 0.53712444 -0.65625711 -1.34931411  1.1012089  -0.38094383  0.36952369]
#  [ 0.5919853  -0.58653639 -1.34931411  1.1012089  -0.38094383  0.40466483]
#  [ 0.70170703 -0.58653639 -1.34931411  1.00476862 -0.38094383  0.46611275]
#  [ 0.61392965 -0.65625711 -1.4301041   1.1012089  -0.38094383  0.52756067]
#  [ 0.28476447 -0.65625711 -1.4301041   1.00476862 -0.38094383  0.58900859]
#  [-0.11023374 -0.58653639 -1.4301041   1.00476862 -0.38094383  0.65045651]
#  [-0.4064824  -0.65625711 -1.4301041   0.90832835 -0.38094383  0.71190443]
#  [-0.38453806 -0.65625711 -1.5108941   0.90832835 -0.38094383  0.79082476]
#  [-0.49425978 -0.65625711 -1.5108941   0.81188808 -0.38094383  0.85227268]
#  [-0.38453806 -0.65625711 -1.5108941   0.7154478  -0.38094383  0.93119301]
#  [-0.18703895 -0.72597783 -1.59168409  0.7154478  -0.38094383  1.01011334]
#  [-0.09926157 -0.79569856 -1.59168409  0.7154478  -0.38094383  1.08903367]
#  [-0.15412243 -0.79569856 -1.67247408  0.7154478  -0.38094383  1.167954  ]
#  [-0.19801112 -0.79569856 -1.67247408  0.7154478  -0.38094383  1.26454307]
#  [-0.15412243 -0.86541928 -1.67247408  0.61900753 -0.38094383  1.3434634 ]
#  [-0.24189981 -0.86541928 -1.67247408  0.61900753 -0.38094383  1.42238373]
#  [-0.02245636 -0.86541928 -1.67247408  0.52256725 -0.38094383  1.51897279]
#  [ 0.07629319 -0.86541928 -1.67247408  0.42612698 -0.38094383  1.58042071]
#  [-0.11023374 -0.86541928 -1.67247408  0.32968671 -0.38094383  1.69448219]
#  [-0.04440071 -0.86541928 -1.67247408  0.32968671 -0.38094383  1.79107125]
#  [-0.05537288 -0.86541928 -1.67247408  0.32968671 -0.38094383  1.88766031]
#  [-0.15412243 -0.86541928 -1.67247408  0.32968671 -0.38094383  1.94910823]
#  [-0.32967719 -0.86541928 -1.67247408  0.32968671 -0.38094383  2.01055615]
#  [-0.42842675 -0.86541928 -1.67247408  0.42612698 -1.45642614 -0.4817165 ]
#  [-0.51620413 -0.86541928 -1.67247408  0.52256725 -1.45642614 -0.46424409]
#  [-0.31870502 -0.79569856 -1.67247408  0.52256725  0.69453847 -0.42026858]
#  [-0.30773285 -0.86541928 -1.75326408  0.61900753  0.69453847 -0.35882066]
#  [-0.26384416 -0.86541928 -1.67247408  0.61900753  0.69453847 -0.27990033]
#  [-0.29676068 -0.93514    -1.83405407  0.61900753  0.69453847 -0.21845241]]
# [ 0.31768099 -1.2140229  -1.26852411  0.32968671 -0.38094383 -0.46404777
#   0.52615226 -1.14430217 -1.26852411  0.32968671 -0.38094383 -0.44657536
#   0.64684616 -0.86541928 -1.34931411  0.42612698 -0.38094383 -0.42910295
#   0.88823396 -0.58653639 -1.34931411  0.52256725 -0.38094383 -0.39396181
#   0.41643054 -0.58653639 -1.34931411  0.52256725 -0.38094383 -0.3764894
#   0.09823754 -0.58653639 -1.4301041   0.52256725 -0.38094383 -0.35901698
#   0.05434885 -0.58653639 -1.4301041   0.61900753 -0.38094383 -0.32387584
#   0.26282012 -0.58653639 -1.34931411  0.7154478  -0.38094383 -0.2887347
#   0.21893143 -0.65625711 -1.4301041   0.7154478  -0.38094383 -0.25359356
#   0.3505975  -0.58653639 -1.34931411  0.81188808 -0.38094383 -0.21845241
#   0.43837488 -0.58653639 -1.34931411  0.90832835 -0.38094383 -0.15700449
#   0.57004095 -0.65625711 -1.34931411  0.90832835 -0.38094383 -0.09555657
#   0.52615226 -0.65625711 -1.34931411  0.90832835 -0.38094383 -0.03410865
#   0.70170703 -0.65625711 -1.34931411  0.81188808 -0.38094383  0.04481168
#   0.63587399 -0.72597783 -1.34931411  0.81188808 -0.38094383  0.12373201
#   0.5919853  -0.72597783 -1.34931411  0.81188808 -0.38094383  0.20265234
#   0.64684616 -0.72597783 -1.34931411  0.90832835 -0.38094383  0.23779348
#   0.70170703 -0.65625711 -1.34931411  1.00476862 -0.38094383  0.27293462
#   0.76754006 -0.65625711 -1.34931411  1.00476862 -0.38094383  0.33438254
#   0.53712444 -0.65625711 -1.34931411  1.1012089  -0.38094383  0.36952369
#   0.5919853  -0.58653639 -1.34931411  1.1012089  -0.38094383  0.40466483
#   0.70170703 -0.58653639 -1.34931411  1.00476862 -0.38094383  0.46611275
#   0.61392965 -0.65625711 -1.4301041   1.1012089  -0.38094383  0.52756067
#   0.28476447 -0.65625711 -1.4301041   1.00476862 -0.38094383  0.58900859
#  -0.11023374 -0.58653639 -1.4301041   1.00476862 -0.38094383  0.65045651
#  -0.4064824  -0.65625711 -1.4301041   0.90832835 -0.38094383  0.71190443
#  -0.38453806 -0.65625711 -1.5108941   0.90832835 -0.38094383  0.79082476
#  -0.49425978 -0.65625711 -1.5108941   0.81188808 -0.38094383  0.85227268
#  -0.38453806 -0.65625711 -1.5108941   0.7154478  -0.38094383  0.93119301
#  -0.18703895 -0.72597783 -1.59168409  0.7154478  -0.38094383  1.01011334
#  -0.09926157 -0.79569856 -1.59168409  0.7154478  -0.38094383  1.08903367
#  -0.15412243 -0.79569856 -1.67247408  0.7154478  -0.38094383  1.167954
#  -0.19801112 -0.79569856 -1.67247408  0.7154478  -0.38094383  1.26454307
#  -0.15412243 -0.86541928 -1.67247408  0.61900753 -0.38094383  1.3434634
#  -0.24189981 -0.86541928 -1.67247408  0.61900753 -0.38094383  1.42238373
#  -0.02245636 -0.86541928 -1.67247408  0.52256725 -0.38094383  1.51897279
#   0.07629319 -0.86541928 -1.67247408  0.42612698 -0.38094383  1.58042071
#  -0.11023374 -0.86541928 -1.67247408  0.32968671 -0.38094383  1.69448219
#  -0.04440071 -0.86541928 -1.67247408  0.32968671 -0.38094383  1.79107125
#  -0.05537288 -0.86541928 -1.67247408  0.32968671 -0.38094383  1.88766031
#  -0.15412243 -0.86541928 -1.67247408  0.32968671 -0.38094383  1.94910823
#  -0.32967719 -0.86541928 -1.67247408  0.32968671 -0.38094383  2.01055615
#  -0.42842675 -0.86541928 -1.67247408  0.42612698 -1.45642614 -0.4817165
#  -0.51620413 -0.86541928 -1.67247408  0.52256725 -1.45642614 -0.46424409
#  -0.31870502 -0.79569856 -1.67247408  0.52256725  0.69453847 -0.42026858
#  -0.30773285 -0.86541928 -1.75326408  0.61900753  0.69453847 -0.35882066
#  -0.26384416 -0.86541928 -1.67247408  0.61900753  0.69453847 -0.27990033
#  -0.29676068 -0.93514    -1.83405407  0.61900753  0.69453847 -0.21845241]

# %% [markdown]
# Se dividen nuevamente los conjuntos de datos

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainX, testX = train_test_split(datosX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testX, valX = train_test_split(testX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainX son: ", trainX.shape)
print("Las dimensiones de testX son: ", testX.shape)
print("Las dimensiones de valX son: ", valX.shape)
# Out:
# Las dimensiones de trainX son:  (30610, 48, 6)
# Las dimensiones de testX son:  (8789, 48, 6)
# Las dimensiones de valX son:  (4330, 48, 6)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainMLPX, testMLPX = train_test_split(datosMLPX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testMLPX, valMLPX = train_test_split(testMLPX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainMLPX son: ", trainMLPX.shape)
print("Las dimensiones de testMLPX son: ", testMLPX.shape)
print("Las dimensiones de valMLPX son: ", valMLPX.shape)
# Out:
# Las dimensiones de trainMLPX son:  (30610, 288)
# Las dimensiones de testMLPX son:  (8789, 288)
# Las dimensiones de valMLPX son:  (4330, 288)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainY, testY = train_test_split(datosY, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testY, valY = train_test_split(testY, test_size=0.33, shuffle=False)

print("Las dimensiones de trainY son: ", trainY.shape)
print("Las dimensiones de testY son: ", testY.shape)
print("Las dimensiones de valY son: ", valY.shape)
# Out:
# Las dimensiones de trainY son:  (30610, 1)
# Las dimensiones de testY son:  (8789, 1)
# Las dimensiones de valY son:  (4330, 1)

# %% [markdown]
# Se crean métricas para medir desempeño

# %%
import tensorflow.keras.backend as K

def smape(y_true, y_pred):
    """
    Define la función SMAPE (Error Porcentual Absoluto Medio Simétrico).
    """
    summ = K.abs(y_true) + K.abs(y_pred)
    smape_val = K.abs(y_pred - y_true) / summ * 2.0
    return K.mean(smape_val, axis=-1)

def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

def ia(y_true, y_pred):
    numerator = K.sum(K.abs(y_true - y_pred))
    denominator = K.sum(K.abs(y_true - K.mean(y_true)) + K.abs(y_pred - K.mean(y_true)))
    return 1 - (numerator / denominator)

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

def graficarPrediccion(modelo, x, y, inicio, final):
  predicciones = modelo.predict(x)
  predicciones = predicciones.flatten()
  df = pd.DataFrame({'Originales': y, 'Predichos': predicciones})
  plt.plot(df.index, df['Originales'][inicio:final], label='Originales')
  plt.plot(df.index, df['Predichos'][inicio:final], label='Predichos')
  return df, mse(y, predicciones),  mae(y, predicciones), rmse(y, predicciones), smape(y,predicciones), ia(y, predicciones)

# %% [markdown]
# Se define el index del conjunto de validación para utilizarlo posteriormente para graficar.

# %%
# Fecha y hora de término del conjunto de datos de prueba
end_date = datosNormalizados.index[-1]
n_observations = valY.shape[0]  # Cambia esto al número de observaciones en tu conjunto de prueba

# Calcular la fecha y hora de inicio
start_date = end_date - timedelta(hours=(n_observations - 1))

# Crear la serie de fechas y horas
val_date = pd.date_range(start=start_date, end=end_date, freq='1H')

val_date
# Out:
# C:\Users\wamt1\AppData\Local\Temp\ipykernel_5600\3958427235.py:9: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   val_date = pd.date_range(start=start_date, end=end_date, freq='1H')
# DatetimeIndex(['2014-07-04 14:00:00', '2014-07-04 15:00:00',
#                '2014-07-04 16:00:00', '2014-07-04 17:00:00',
#                '2014-07-04 18:00:00', '2014-07-04 19:00:00',
#                '2014-07-04 20:00:00', '2014-07-04 21:00:00',
#                '2014-07-04 22:00:00', '2014-07-04 23:00:00',
#                ...
#                '2014-12-31 14:00:00', '2014-12-31 15:00:00',
#                '2014-12-31 16:00:00', '2014-12-31 17:00:00',
#                '2014-12-31 18:00:00', '2014-12-31 19:00:00',
#                '2014-12-31 20:00:00', '2014-12-31 21:00:00',
#                '2014-12-31 22:00:00', '2014-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=4330, freq='h')

# %% [markdown]
# Se guardan los índices de las observaciones a utilizar para predecir

# %%
indices = []
for i in range(pasados, len(datosNormalizados) - futuros + 1):
  indices.append(datosNormalizados.index[i+futuros-1])

# %% [markdown]
# # Modelos

# %% [markdown]
# ## MLP

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelMLP = Sequential()
modelMLP.add(InputLayer(input_shape=(trainMLPX.shape[1],)))

modelMLP.add(Dense(units=128, activation="linear"))
modelMLP.add(Dropout(0.0))

modelMLP.add(Dense(units=128, activation="linear"))
modelMLP.add(Dropout(0.0))

modelMLP.add(Dense(units=128, activation="linear"))
modelMLP.add(Dropout(0.0))

modelMLP.add(Dense(units=128, activation="linear"))
modelMLP.add(Dropout(0.0))

modelMLP.add(Dense(1))

opt = Adam(learning_rate=0.00027101707182655693)

modelMLP.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelMLP.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │        36,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 86,657 (338.50 KB)
#  Trainable params: 86,657 (338.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyMLP = modelMLP.fit(trainMLPX, trainY, epochs=128, validation_data=(testMLPX, testY), verbose = 2, batch_size=16, callbacks=[early_stopping])

prediccionMLP = modelMLP.predict(valMLPX)
# Out:
# Epoch 1/128
# 1914/1914 - 9s - 5ms/step - ia: 0.3745 - loss: 0.8891 - mae: 0.6990 - rmse: 0.9103 - smape: 1.3136 - val_ia: 0.2380 - val_loss: 0.8327 - val_mae: 0.6723 - val_rmse: 0.7503 - val_smape: 1.2462
# Epoch 2/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3780 - loss: 0.8461 - mae: 0.6800 - rmse: 0.8878 - smape: 1.3054 - val_ia: 0.2410 - val_loss: 0.8036 - val_mae: 0.6591 - val_rmse: 0.7347 - val_smape: 1.2376
# Epoch 3/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3808 - loss: 0.8361 - mae: 0.6755 - rmse: 0.8825 - smape: 1.3004 - val_ia: 0.2410 - val_loss: 0.7964 - val_mae: 0.6560 - val_rmse: 0.7304 - val_smape: 1.2427
# Epoch 4/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3826 - loss: 0.8296 - mae: 0.6728 - rmse: 0.8790 - smape: 1.2983 - val_ia: 0.2403 - val_loss: 0.7945 - val_mae: 0.6555 - val_rmse: 0.7290 - val_smape: 1.2513
# Epoch 5/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3844 - loss: 0.8250 - mae: 0.6706 - rmse: 0.8764 - smape: 1.2953 - val_ia: 0.2394 - val_loss: 0.7922 - val_mae: 0.6556 - val_rmse: 0.7278 - val_smape: 1.2590
# Epoch 6/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3855 - loss: 0.8214 - mae: 0.6690 - rmse: 0.8744 - smape: 1.2928 - val_ia: 0.2386 - val_loss: 0.7852 - val_mae: 0.6522 - val_rmse: 0.7229 - val_smape: 1.2554
# Epoch 7/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3866 - loss: 0.8183 - mae: 0.6675 - rmse: 0.8726 - smape: 1.2901 - val_ia: 0.2389 - val_loss: 0.7851 - val_mae: 0.6527 - val_rmse: 0.7237 - val_smape: 1.2560
# Epoch 8/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3877 - loss: 0.8156 - mae: 0.6662 - rmse: 0.8711 - smape: 1.2880 - val_ia: 0.2399 - val_loss: 0.7811 - val_mae: 0.6507 - val_rmse: 0.7214 - val_smape: 1.2507
# Epoch 9/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3884 - loss: 0.8137 - mae: 0.6652 - rmse: 0.8700 - smape: 1.2877 - val_ia: 0.2410 - val_loss: 0.7791 - val_mae: 0.6491 - val_rmse: 0.7195 - val_smape: 1.2463
# Epoch 10/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3888 - loss: 0.8122 - mae: 0.6645 - rmse: 0.8691 - smape: 1.2867 - val_ia: 0.2411 - val_loss: 0.7777 - val_mae: 0.6480 - val_rmse: 0.7183 - val_smape: 1.2433
# Epoch 11/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3896 - loss: 0.8106 - mae: 0.6637 - rmse: 0.8683 - smape: 1.2851 - val_ia: 0.2415 - val_loss: 0.7763 - val_mae: 0.6469 - val_rmse: 0.7176 - val_smape: 1.2388
# Epoch 12/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3899 - loss: 0.8097 - mae: 0.6631 - rmse: 0.8676 - smape: 1.2844 - val_ia: 0.2418 - val_loss: 0.7769 - val_mae: 0.6473 - val_rmse: 0.7184 - val_smape: 1.2365
# Epoch 13/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3901 - loss: 0.8091 - mae: 0.6626 - rmse: 0.8672 - smape: 1.2830 - val_ia: 0.2422 - val_loss: 0.7762 - val_mae: 0.6466 - val_rmse: 0.7178 - val_smape: 1.2321
# Epoch 14/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3903 - loss: 0.8083 - mae: 0.6621 - rmse: 0.8667 - smape: 1.2822 - val_ia: 0.2423 - val_loss: 0.7761 - val_mae: 0.6465 - val_rmse: 0.7174 - val_smape: 1.2305
# Epoch 15/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3905 - loss: 0.8076 - mae: 0.6618 - rmse: 0.8663 - smape: 1.2815 - val_ia: 0.2426 - val_loss: 0.7764 - val_mae: 0.6463 - val_rmse: 0.7171 - val_smape: 1.2280
# Epoch 16/128
# 1914/1914 - 6s - 3ms/step - ia: 0.3907 - loss: 0.8069 - mae: 0.6615 - rmse: 0.8660 - smape: 1.2805 - val_ia: 0.2429 - val_loss: 0.7762 - val_mae: 0.6461 - val_rmse: 0.7169 - val_smape: 1.2271
# Epoch 17/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3907 - loss: 0.8065 - mae: 0.6613 - rmse: 0.8657 - smape: 1.2808 - val_ia: 0.2429 - val_loss: 0.7761 - val_mae: 0.6459 - val_rmse: 0.7165 - val_smape: 1.2279
# Epoch 18/128
# 1914/1914 - 6s - 3ms/step - ia: 0.3910 - loss: 0.8059 - mae: 0.6609 - rmse: 0.8653 - smape: 1.2800 - val_ia: 0.2432 - val_loss: 0.7767 - val_mae: 0.6455 - val_rmse: 0.7163 - val_smape: 1.2264
# Epoch 19/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3913 - loss: 0.8056 - mae: 0.6607 - rmse: 0.8651 - smape: 1.2797 - val_ia: 0.2432 - val_loss: 0.7781 - val_mae: 0.6460 - val_rmse: 0.7167 - val_smape: 1.2263
# Epoch 20/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3915 - loss: 0.8052 - mae: 0.6605 - rmse: 0.8650 - smape: 1.2791 - val_ia: 0.2436 - val_loss: 0.7779 - val_mae: 0.6457 - val_rmse: 0.7164 - val_smape: 1.2256
# Epoch 21/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3918 - loss: 0.8049 - mae: 0.6604 - rmse: 0.8648 - smape: 1.2790 - val_ia: 0.2437 - val_loss: 0.7779 - val_mae: 0.6459 - val_rmse: 0.7167 - val_smape: 1.2261
# Epoch 22/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3921 - loss: 0.8043 - mae: 0.6602 - rmse: 0.8645 - smape: 1.2785 - val_ia: 0.2433 - val_loss: 0.7778 - val_mae: 0.6459 - val_rmse: 0.7168 - val_smape: 1.2272
# Epoch 23/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3922 - loss: 0.8040 - mae: 0.6600 - rmse: 0.8643 - smape: 1.2783 - val_ia: 0.2434 - val_loss: 0.7779 - val_mae: 0.6458 - val_rmse: 0.7168 - val_smape: 1.2260
# Epoch 24/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3924 - loss: 0.8038 - mae: 0.6598 - rmse: 0.8642 - smape: 1.2778 - val_ia: 0.2437 - val_loss: 0.7779 - val_mae: 0.6453 - val_rmse: 0.7165 - val_smape: 1.2230
# Epoch 25/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3926 - loss: 0.8034 - mae: 0.6597 - rmse: 0.8640 - smape: 1.2777 - val_ia: 0.2440 - val_loss: 0.7777 - val_mae: 0.6450 - val_rmse: 0.7161 - val_smape: 1.2226
# Epoch 26/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3929 - loss: 0.8031 - mae: 0.6595 - rmse: 0.8638 - smape: 1.2776 - val_ia: 0.2443 - val_loss: 0.7782 - val_mae: 0.6453 - val_rmse: 0.7164 - val_smape: 1.2236
# Epoch 27/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3931 - loss: 0.8029 - mae: 0.6594 - rmse: 0.8637 - smape: 1.2771 - val_ia: 0.2445 - val_loss: 0.7782 - val_mae: 0.6452 - val_rmse: 0.7166 - val_smape: 1.2225
# Epoch 28/128
# 1914/1914 - 11s - 6ms/step - ia: 0.3932 - loss: 0.8026 - mae: 0.6593 - rmse: 0.8635 - smape: 1.2767 - val_ia: 0.2444 - val_loss: 0.7776 - val_mae: 0.6449 - val_rmse: 0.7162 - val_smape: 1.2238
# Epoch 29/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3935 - loss: 0.8024 - mae: 0.6591 - rmse: 0.8634 - smape: 1.2762 - val_ia: 0.2439 - val_loss: 0.7780 - val_mae: 0.6453 - val_rmse: 0.7168 - val_smape: 1.2249
# Epoch 30/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3936 - loss: 0.8022 - mae: 0.6590 - rmse: 0.8633 - smape: 1.2760 - val_ia: 0.2443 - val_loss: 0.7783 - val_mae: 0.6450 - val_rmse: 0.7168 - val_smape: 1.2210
# Epoch 31/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3939 - loss: 0.8019 - mae: 0.6588 - rmse: 0.8631 - smape: 1.2757 - val_ia: 0.2439 - val_loss: 0.7788 - val_mae: 0.6454 - val_rmse: 0.7173 - val_smape: 1.2232
# Epoch 32/128
# 1914/1914 - 5s - 3ms/step - ia: 0.3939 - loss: 0.8018 - mae: 0.6588 - rmse: 0.8631 - smape: 1.2758 - val_ia: 0.2441 - val_loss: 0.7791 - val_mae: 0.6450 - val_rmse: 0.7169 - val_smape: 1.2203
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 17.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
metricasMLP = modelMLP.evaluate(valMLPX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasMLP}")
# Out:
# 136/136 - 0s - 2ms/step - ia: 0.2700 - loss: 0.8046 - mae: 0.6629 - rmse: 0.7573 - smape: 1.2303
# Métricas en el conjunto de validación: [0.8046061992645264, 0.6629307270050049, 1.2303297519683838, 0.7573184967041016, 0.2700164318084717]

# %%
historyMLP = historyMLP.history
ejeXMLP = range(1, len(historyMLP['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXMLP, historyMLP['loss'], label='Train Loss')
plt.plot(ejeXMLP, historyMLP['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyMLP['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyMLP['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.8017938137054443
# Último valor de Test Loss: 0.7790753245353699

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionMLP.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]

fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfMLP = df
fig.show()

# %% [markdown]
# ### Datos para NARMAX

# %%
prediccionNarmaxMLP = modelMLP.predict(datosMLPX)
erroresMLP = datosY - prediccionNarmaxMLP
# Out:
# 1367/1367 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %%
dfErroresMLP = pd.DataFrame(erroresMLP, columns = ["e"])
dfErroresMLP.index = indices

# %%
dfNarmaxMLP = datosNormalizados.join(dfErroresMLP, how = 'left')

print(dfNarmaxMLP.head())
print(dfNarmaxMLP.tail())
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 00:00:00   0.317681 -1.214023 -1.268524  0.329687 -0.380944
# 2010-01-02 01:00:00   0.526152 -1.144302 -1.268524  0.329687 -0.380944
# 2010-01-02 02:00:00   0.646846 -0.865419 -1.349314  0.426127 -0.380944
# 2010-01-02 03:00:00   0.888234 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 04:00:00   0.416431 -0.586536 -1.349314  0.522567 -0.380944
#
#                       wnd_spd   e
# date
# 2010-01-02 00:00:00 -0.464048 NaN
# 2010-01-02 01:00:00 -0.446575 NaN
# 2010-01-02 02:00:00 -0.429103 NaN
# 2010-01-02 03:00:00 -0.393962 NaN
# 2010-01-02 04:00:00 -0.376489 NaN
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2014-12-31 19:00:00  -1.009952 -1.702068 -1.106944  1.679851  0.694538
# 2014-12-31 20:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 21:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 22:00:00  -1.009952 -1.632347 -1.268524  1.679851  0.694538
# 2014-12-31 23:00:00  -0.966063 -1.562627 -1.187734  1.679851  0.694538
#
#                       wnd_spd         e
# date
# 2014-12-31 19:00:00  4.054828 -0.896783
# 2014-12-31 20:00:00  4.168890 -0.838226
# 2014-12-31 21:00:00  4.265479 -0.968928
# 2014-12-31 22:00:00  4.344399 -0.875225
# 2014-12-31 23:00:00  4.405847 -0.674359

# %%
dfNarmaxMLP.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\4824pasos_mlp_pollution.csv', index=True)

# %%
dfMLP.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacion\\4824pasos_mlp_pollution.csv', index=True)

# %%
modelMLP.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarx\\4824pasos_mlp_pollution.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## LSTM

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelLSTM = Sequential()
modelLSTM.add(InputLayer(input_shape=(trainX.shape[1], trainX.shape[2])))

modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=True))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=True))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=True))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=False))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(Dense(1))


opt = Adam(learning_rate=0.00027101707182655693)
modelLSTM.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelLSTM.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 48, 128)        │        69,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 48, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 48, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 48, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 48, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 48, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 464,001 (1.77 MB)
#  Trainable params: 464,001 (1.77 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyLSTM = modelLSTM.fit(trainX, trainY, epochs=128, validation_data=(testX, testY), verbose = 2, batch_size=16, callbacks=[early_stopping])


prediccionLSTM = modelLSTM.predict(valX)
# Out:
# Epoch 1/128
# 1914/1914 - 119s - 62ms/step - ia: 0.2771 - loss: 475668.0312 - mae: 16.4817 - rmse: 59.3396 - smape: 1.4422 - val_ia: 0.1941 - val_loss: 7590.8101 - val_mae: 17.4185 - val_rmse: 21.9182 - val_smape: 1.5203
# Epoch 2/128
# 1914/1914 - 159s - 83ms/step - ia: 0.0965 - loss: 27876.9707 - mae: 21.9862 - rmse: 71.8081 - smape: 1.5756 - val_ia: 0.2082 - val_loss: 472.1456 - val_mae: 3.3596 - val_rmse: 4.0915 - val_smape: 1.5389
# Epoch 3/128
# 1914/1914 - 108s - 56ms/step - ia: 0.1583 - loss: 81099.6875 - mae: 13.0558 - rmse: 47.2792 - smape: 1.5735 - val_ia: 0.2097 - val_loss: 184.0341 - val_mae: 2.7709 - val_rmse: 3.2816 - val_smape: 1.5041
# Epoch 4/128
# 1914/1914 - 111s - 58ms/step - ia: 0.1472 - loss: 30143.5156 - mae: 10.4799 - rmse: 36.9115 - smape: 1.5480 - val_ia: 0.2111 - val_loss: 139.5231 - val_mae: 2.4614 - val_rmse: 2.8692 - val_smape: 1.4760
# Epoch 5/128
# 1914/1914 - 109s - 57ms/step - ia: 0.1459 - loss: 17993.7539 - mae: 9.6276 - rmse: 32.9985 - smape: 1.5352 - val_ia: 0.2127 - val_loss: 198.3062 - val_mae: 2.5278 - val_rmse: 3.1346 - val_smape: 1.4586
# Epoch 6/128
# 1914/1914 - 104s - 55ms/step - ia: 0.1546 - loss: 25645.2363 - mae: 9.6099 - rmse: 34.0253 - smape: 1.5443 - val_ia: 0.2104 - val_loss: 141.0164 - val_mae: 2.5017 - val_rmse: 2.8394 - val_smape: 1.4887
# Epoch 7/128
# 1914/1914 - 118s - 62ms/step - ia: 0.1537 - loss: 17014.4883 - mae: 8.8075 - rmse: 30.5666 - smape: 1.5487 - val_ia: 0.2179 - val_loss: 25.8725 - val_mae: 1.3321 - val_rmse: 1.5194 - val_smape: 1.4762
# Epoch 8/128
# 1914/1914 - 117s - 61ms/step - ia: 0.0512 - loss: 1499021.8750 - mae: 89.1701 - rmse: 284.5554 - smape: 1.5473 - val_ia: 0.1870 - val_loss: 3622.8660 - val_mae: 15.3888 - val_rmse: 17.4711 - val_smape: 1.4449
# Epoch 9/128
# 1914/1914 - 118s - 62ms/step - ia: 0.0677 - loss: 17312.2266 - mae: 16.3476 - rmse: 48.1505 - smape: 1.5230 - val_ia: 0.1894 - val_loss: 356.6011 - val_mae: 5.6076 - val_rmse: 6.4479 - val_smape: 1.4350
# Epoch 10/128
# 1914/1914 - 108s - 57ms/step - ia: 0.0499 - loss: 36063.2617 - mae: 26.3975 - rmse: 76.8942 - smape: 1.5054 - val_ia: 0.1918 - val_loss: 400.9622 - val_mae: 6.6882 - val_rmse: 7.3603 - val_smape: 1.3716
# Epoch 11/128
# 1914/1914 - 105s - 55ms/step - ia: 0.0816 - loss: 1366.5753 - mae: 8.3836 - rmse: 20.8992 - smape: 1.4450 - val_ia: 0.1934 - val_loss: 1534.3214 - val_mae: 10.6526 - val_rmse: 11.2210 - val_smape: 1.3414
# Epoch 12/128
# 1914/1914 - 107s - 56ms/step - ia: 0.1272 - loss: 58101.1719 - mae: 11.8746 - rmse: 36.7415 - smape: 1.4199 - val_ia: 0.2035 - val_loss: 38.8805 - val_mae: 2.5204 - val_rmse: 2.7468 - val_smape: 1.3256
# Epoch 13/128
# 1914/1914 - 124s - 65ms/step - ia: 0.1457 - loss: 808.9891 - mae: 4.0925 - rmse: 10.0416 - smape: 1.4158 - val_ia: 0.2062 - val_loss: 25.9947 - val_mae: 2.1045 - val_rmse: 2.3008 - val_smape: 1.3190
# Epoch 14/128
# 1914/1914 - 125s - 65ms/step - ia: 0.2634 - loss: 76917.2969 - mae: 7.3852 - rmse: 24.8402 - smape: 1.3690 - val_ia: 0.2389 - val_loss: 0.8553 - val_mae: 0.6527 - val_rmse: 0.7150 - val_smape: 1.2824
# Epoch 15/128
# 1914/1914 - 122s - 64ms/step - ia: 0.2893 - loss: 20.5881 - mae: 0.8565 - rmse: 1.5014 - smape: 1.3605 - val_ia: 0.2391 - val_loss: 0.8499 - val_mae: 0.6515 - val_rmse: 0.7136 - val_smape: 1.2787
# Epoch 16/128
# 1914/1914 - 117s - 61ms/step - ia: 0.2920 - loss: 9.7834 - mae: 0.8144 - rmse: 1.3421 - smape: 1.3592 - val_ia: 0.2389 - val_loss: 0.8440 - val_mae: 0.6507 - val_rmse: 0.7126 - val_smape: 1.2792
# Epoch 17/128
# 1914/1914 - 119s - 62ms/step - ia: 0.2956 - loss: 3.9490 - mae: 0.7684 - rmse: 1.1663 - smape: 1.3604 - val_ia: 0.2388 - val_loss: 0.8321 - val_mae: 0.6495 - val_rmse: 0.7110 - val_smape: 1.2799
# Epoch 18/128
# 1914/1914 - 113s - 59ms/step - ia: 0.2952 - loss: 4.6492 - mae: 0.7794 - rmse: 1.2140 - smape: 1.3708 - val_ia: 0.2373 - val_loss: 0.8182 - val_mae: 0.6522 - val_rmse: 0.7127 - val_smape: 1.3034
# Epoch 19/128
# 1914/1914 - 132s - 69ms/step - ia: 0.2970 - loss: 9.8550 - mae: 0.7608 - rmse: 1.1532 - smape: 1.3928 - val_ia: 0.2356 - val_loss: 0.8065 - val_mae: 0.6580 - val_rmse: 0.7174 - val_smape: 1.3416
# Epoch 20/128
# 1914/1914 - 105s - 55ms/step - ia: 0.3045 - loss: 1.4959 - mae: 0.7162 - rmse: 0.9822 - smape: 1.4071 - val_ia: 0.2338 - val_loss: 0.7970 - val_mae: 0.6632 - val_rmse: 0.7217 - val_smape: 1.3644
# Epoch 21/128
# 1914/1914 - 107s - 56ms/step - ia: 0.3190 - loss: 5.4205 - mae: 0.7208 - rmse: 1.0111 - smape: 1.3973 - val_ia: 0.2339 - val_loss: 0.7912 - val_mae: 0.6617 - val_rmse: 0.7202 - val_smape: 1.3514
# Epoch 22/128
# 1914/1914 - 105s - 55ms/step - ia: 0.3355 - loss: 1.0346 - mae: 0.6945 - rmse: 0.9213 - smape: 1.3730 - val_ia: 0.2335 - val_loss: 0.7931 - val_mae: 0.6615 - val_rmse: 0.7203 - val_smape: 1.3401
# Epoch 23/128
# 1914/1914 - 104s - 54ms/step - ia: 0.3453 - loss: 1.0807 - mae: 0.6887 - rmse: 0.9096 - smape: 1.3582 - val_ia: 0.2342 - val_loss: 0.7950 - val_mae: 0.6612 - val_rmse: 0.7204 - val_smape: 1.3373
# Epoch 24/128
# 1914/1914 - 104s - 54ms/step - ia: 0.3545 - loss: 0.8695 - mae: 0.6782 - rmse: 0.8888 - smape: 1.3401 - val_ia: 0.2358 - val_loss: 0.7952 - val_mae: 0.6601 - val_rmse: 0.7200 - val_smape: 1.3245
# Epoch 25/128
# 1914/1914 - 104s - 55ms/step - ia: 0.3689 - loss: 0.8159 - mae: 0.6673 - rmse: 0.8700 - smape: 1.3198 - val_ia: 0.2379 - val_loss: 0.7957 - val_mae: 0.6600 - val_rmse: 0.7210 - val_smape: 1.3144
# Epoch 26/128
# 1914/1914 - 109s - 57ms/step - ia: 0.3792 - loss: 0.8163 - mae: 0.6624 - rmse: 0.8663 - smape: 1.3032 - val_ia: 0.2389 - val_loss: 0.7978 - val_mae: 0.6623 - val_rmse: 0.7244 - val_smape: 1.3155
# Epoch 27/128
# 1914/1914 - 105s - 55ms/step - ia: 0.3870 - loss: 0.7957 - mae: 0.6576 - rmse: 0.8595 - smape: 1.2918 - val_ia: 0.2395 - val_loss: 0.7928 - val_mae: 0.6632 - val_rmse: 0.7257 - val_smape: 1.3230
# Epoch 28/128
# 1914/1914 - 103s - 54ms/step - ia: 0.3926 - loss: 0.7904 - mae: 0.6546 - rmse: 0.8566 - smape: 1.2833 - val_ia: 0.2410 - val_loss: 0.8062 - val_mae: 0.6667 - val_rmse: 0.7303 - val_smape: 1.3110
# Epoch 29/128
# 1914/1914 - 104s - 54ms/step - ia: 0.3997 - loss: 0.7851 - mae: 0.6513 - rmse: 0.8534 - smape: 1.2723 - val_ia: 0.2406 - val_loss: 0.7807 - val_mae: 0.6636 - val_rmse: 0.7269 - val_smape: 1.3336
# Epoch 30/128
# 1914/1914 - 103s - 54ms/step - ia: 0.4038 - loss: 0.7786 - mae: 0.6481 - rmse: 0.8501 - smape: 1.2632 - val_ia: 0.2427 - val_loss: 0.7983 - val_mae: 0.6613 - val_rmse: 0.7267 - val_smape: 1.2949
# Epoch 31/128
# 1914/1914 - 138s - 72ms/step - ia: 0.4116 - loss: 0.7679 - mae: 0.6432 - rmse: 0.8441 - smape: 1.2474 - val_ia: 0.2445 - val_loss: 0.7841 - val_mae: 0.6517 - val_rmse: 0.7185 - val_smape: 1.2662
# Epoch 32/128
# 1914/1914 - 102s - 53ms/step - ia: 0.4206 - loss: 0.7584 - mae: 0.6380 - rmse: 0.8388 - smape: 1.2299 - val_ia: 0.2456 - val_loss: 0.7709 - val_mae: 0.6480 - val_rmse: 0.7145 - val_smape: 1.2595
# Epoch 33/128
# 1914/1914 - 103s - 54ms/step - ia: 0.3817 - loss: 1.7031 - mae: 0.6737 - rmse: 0.8960 - smape: 1.2912 - val_ia: 0.2436 - val_loss: 0.7803 - val_mae: 0.6609 - val_rmse: 0.7219 - val_smape: 1.2925
# Epoch 34/128
# 1914/1914 - 103s - 54ms/step - ia: 0.3955 - loss: 0.7902 - mae: 0.6535 - rmse: 0.8559 - smape: 1.2632 - val_ia: 0.2461 - val_loss: 0.7949 - val_mae: 0.6633 - val_rmse: 0.7261 - val_smape: 1.2853
# Epoch 35/128
# 1914/1914 - 103s - 54ms/step - ia: 0.4120 - loss: 0.7700 - mae: 0.6430 - rmse: 0.8449 - smape: 1.2444 - val_ia: 0.2468 - val_loss: 0.8059 - val_mae: 0.6671 - val_rmse: 0.7316 - val_smape: 1.2830
# Epoch 36/128
# 1914/1914 - 103s - 54ms/step - ia: 0.4255 - loss: 0.7476 - mae: 0.6332 - rmse: 0.8328 - smape: 1.2232 - val_ia: 0.2456 - val_loss: 0.7928 - val_mae: 0.6606 - val_rmse: 0.7259 - val_smape: 1.2666
# Epoch 37/128
# 1914/1914 - 102s - 53ms/step - ia: 0.4351 - loss: 0.7354 - mae: 0.6272 - rmse: 0.8258 - smape: 1.2069 - val_ia: 0.2462 - val_loss: 0.7687 - val_mae: 0.6439 - val_rmse: 0.7104 - val_smape: 1.2454
# Epoch 38/128
# 1914/1914 - 103s - 54ms/step - ia: 0.3354 - loss: 195581344.0000 - mae: 204.7823 - rmse: 745.4467 - smape: 1.3015 - val_ia: 0.1353 - val_loss: 913.0691 - val_mae: 6.9704 - val_rmse: 8.4345 - val_smape: 1.6520
# Epoch 39/128
# 1914/1914 - 102s - 53ms/step - ia: nan - loss: nan - mae: nan - rmse: nan - smape: nan - val_ia: nan - val_loss: nan - val_mae: nan - val_rmse: nan - val_smape: nan
# Epoch 40/128
# 1914/1914 - 138s - 72ms/step - ia: nan - loss: nan - mae: nan - rmse: nan - smape: nan - val_ia: nan - val_loss: nan - val_mae: nan - val_rmse: nan - val_smape: nan
# Epoch 41/128
# 1914/1914 - 100s - 52ms/step - ia: nan - loss: nan - mae: nan - rmse: nan - smape: nan - val_ia: nan - val_loss: nan - val_mae: nan - val_rmse: nan - val_smape: nan
# Epoch 42/128
# 1914/1914 - 101s - 53ms/step - ia: nan - loss: nan - mae: nan - rmse: nan - smape: nan - val_ia: nan - val_loss: nan - val_mae: nan - val_rmse: nan - val_smape: nan
# Epoch 43/128
# 1914/1914 - 100s - 52ms/step - ia: nan - loss: nan - mae: nan - rmse: nan - smape: nan - val_ia: nan - val_loss: nan - val_mae: nan - val_rmse: nan - val_smape: nan
# Epoch 44/128
# 1914/1914 - 140s - 73ms/step - ia: nan - loss: nan - mae: nan - rmse: nan - smape: nan - val_ia: nan - val_loss: nan - val_mae: nan - val_rmse: nan - val_smape: nan
# Epoch 45/128
# 1914/1914 - 101s - 53ms/step - ia: nan - loss: nan - mae: nan - rmse: nan - smape: nan - val_ia: nan - val_loss: nan - val_mae: nan - val_rmse: nan - val_smape: nan
# Epoch 46/128
# 1914/1914 - 101s - 53ms/step - ia: nan - loss: nan - mae: nan - rmse: nan - smape: nan - val_ia: nan - val_loss: nan - val_mae: nan - val_rmse: nan - val_smape: nan
# Epoch 47/128
# 1914/1914 - 102s - 53ms/step - ia: nan - loss: nan - mae: nan - rmse: nan - smape: nan - val_ia: nan - val_loss: nan - val_mae: nan - val_rmse: nan - val_smape: nan
# Epoch 48/128
# 1914/1914 - 101s - 53ms/step - ia: nan - loss: nan - mae: nan - rmse: nan - smape: nan - val_ia: nan - val_loss: nan - val_mae: nan - val_rmse: nan - val_smape: nan
# Epoch 49/128
# 1914/1914 - 101s - 53ms/step - ia: nan - loss: nan - mae: nan - rmse: nan - smape: nan - val_ia: nan - val_loss: nan - val_mae: nan - val_rmse: nan - val_smape: nan
# Epoch 50/128
# 1914/1914 - 101s - 53ms/step - ia: nan - loss: nan - mae: nan - rmse: nan - smape: nan - val_ia: nan - val_loss: nan - val_mae: nan - val_rmse: nan - val_smape: nan
# Epoch 51/128
# 1914/1914 - 103s - 54ms/step - ia: nan - loss: nan - mae: nan - rmse: nan - smape: nan - val_ia: nan - val_loss: nan - val_mae: nan - val_rmse: nan - val_smape: nan
# Epoch 52/128
# 1914/1914 - 107s - 56ms/step - ia: nan - loss: nan - mae: nan - rmse: nan - smape: nan - val_ia: nan - val_loss: nan - val_mae: nan - val_rmse: nan - val_smape: nan
# Epoch 52: early stopping
# Restoring model weights from the end of the best epoch: 37.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step

# %%
metricasLSTM = modelLSTM.evaluate(valX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasLSTM}")
# Out:
# 136/136 - 4s - 27ms/step - ia: 0.2663 - loss: 0.8110 - mae: 0.6579 - rmse: 0.7496 - smape: 1.2016
# Métricas en el conjunto de validación: [0.8110224008560181, 0.6578965187072754, 1.2015842199325562, 0.7496019601821899, 0.2662719488143921]

# %%
historyLSTM['loss']
# Out:
# [475668.03125,
#  27876.970703125,
#  81099.6875,
#  30143.515625,
#  17993.75390625,
#  25645.236328125,
#  17014.48828125,
#  1499021.875,
#  17312.2265625,
#  36063.26171875,
#  1366.5753173828125,
#  58101.171875,
#  808.9890747070312,
#  76917.296875,
#  20.58806037902832,
#  9.783361434936523,
#  3.9489948749542236,
#  4.649225234985352,
#  9.855045318603516,
#  1.4959156513214111,
#  5.420480728149414,
#  1.0346170663833618,
#  1.0806506872177124,
#  0.8694772124290466,
#  0.8159204721450806,
#  0.8162542581558228,
#  0.7956938147544861,
#  0.7904109954833984,
#  0.7851136326789856,
#  0.7786262035369873,
#  0.7678621411323547,
#  0.7583606839179993,
#  1.70309317111969,
#  0.790171205997467,
#  0.7699892520904541,
#  0.747581958770752,
#  0.7353909015655518,
#  195581344.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
historyLSTM = historyLSTM.history

ejeXLSTM = range(1, len(historyLSTM['loss']) + 1)

plt.figure(figsize=(12, 8))
plt.plot(ejeXLSTM, historyLSTM['loss'], label='Train Loss')
plt.plot(ejeXLSTM, historyLSTM['val_loss'], label='Test Loss')
plt.yscale('log')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.plot(ejeXLSTM, historyLSTM['loss'], label='Train Loss')
plt.plot(ejeXLSTM, historyLSTM['val_loss'], label='Test Loss')
plt.yscale('log')
plt.xlim(0, 37)
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyLSTM['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyLSTM['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: nan
# Último valor de Test Loss: nan

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionLSTM.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfLSTM = df
fig.show()

# %% [markdown]
# ### Datos para NARMAX

# %%
prediccionNarmaxLSTM = modelLSTM.predict(datosX)
erroresLSTM = datosY - prediccionNarmaxLSTM
# Out:
# 1367/1367 ━━━━━━━━━━━━━━━━━━━━ 34s 25ms/step

# %%
dfErroresLSTM = pd.DataFrame(erroresLSTM, columns = ["e"])
dfErroresLSTM.index = indices

# %%
dfNarmaxLSTM = datosNormalizados.join(dfErroresLSTM, how = 'left')

print(dfNarmaxLSTM.head())
print(dfNarmaxLSTM.tail())
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 00:00:00   0.317681 -1.214023 -1.268524  0.329687 -0.380944
# 2010-01-02 01:00:00   0.526152 -1.144302 -1.268524  0.329687 -0.380944
# 2010-01-02 02:00:00   0.646846 -0.865419 -1.349314  0.426127 -0.380944
# 2010-01-02 03:00:00   0.888234 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 04:00:00   0.416431 -0.586536 -1.349314  0.522567 -0.380944
#
#                       wnd_spd   e
# date
# 2010-01-02 00:00:00 -0.464048 NaN
# 2010-01-02 01:00:00 -0.446575 NaN
# 2010-01-02 02:00:00 -0.429103 NaN
# 2010-01-02 03:00:00 -0.393962 NaN
# 2010-01-02 04:00:00 -0.376489 NaN
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2014-12-31 19:00:00  -1.009952 -1.702068 -1.106944  1.679851  0.694538
# 2014-12-31 20:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 21:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 22:00:00  -1.009952 -1.632347 -1.268524  1.679851  0.694538
# 2014-12-31 23:00:00  -0.966063 -1.562627 -1.187734  1.679851  0.694538
#
#                       wnd_spd         e
# date
# 2014-12-31 19:00:00  4.054828 -0.853780
# 2014-12-31 20:00:00  4.168890 -0.790674
# 2014-12-31 21:00:00  4.265479 -0.758269
# 2014-12-31 22:00:00  4.344399 -0.753671
# 2014-12-31 23:00:00  4.405847 -0.690737

# %%
dfNarmaxLSTM.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\4824pasos_lstm_pollution.csv', index=True)

# %%
dfLSTM.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacion\\4824pasos_lstm_pollution.csv', index=True)

# %%
modelLSTM.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarx\\4824pasos_lstm_pollution.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## GRU

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelGRU = Sequential()
modelGRU.add(InputLayer(input_shape=(trainX.shape[1], trainX.shape[2])))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=True))
modelGRU.add(Dropout(0.0))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=True))
modelGRU.add(Dropout(0.0))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=True))
modelGRU.add(Dropout(0.0))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=False))
modelGRU.add(Dropout(0.0))

modelGRU.add(Dense(1))


opt = Adam(learning_rate=0.00027101707182655693)
modelGRU.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelGRU.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 48, 128)        │        52,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 48, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 48, 128)        │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 48, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 48, 128)        │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 48, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 128)            │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 349,569 (1.33 MB)
#  Trainable params: 349,569 (1.33 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)

early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyGRU = modelGRU.fit(trainX, trainY, epochs=128, validation_data=(testX, testY), verbose = 2, batch_size=16, callbacks=[early_stopping])

prediccionGRU = modelGRU.predict(valX)
# Out:
# Epoch 1/128
# 1914/1914 - 129s - 67ms/step - ia: 0.3803 - loss: 0.8198 - mae: 0.6659 - rmse: 0.8718 - smape: 1.2967 - val_ia: 0.2418 - val_loss: 0.7702 - val_mae: 0.6428 - val_rmse: 0.7110 - val_smape: 1.2205
# Epoch 2/128
# 1914/1914 - 113s - 59ms/step - ia: 0.4088 - loss: 0.7863 - mae: 0.6482 - rmse: 0.8537 - smape: 1.2473 - val_ia: 0.2447 - val_loss: 0.7662 - val_mae: 0.6383 - val_rmse: 0.7077 - val_smape: 1.2050
# Epoch 3/128
# 1914/1914 - 111s - 58ms/step - ia: 0.4261 - loss: 0.7582 - mae: 0.6350 - rmse: 0.8382 - smape: 1.2246 - val_ia: 0.2444 - val_loss: 0.7797 - val_mae: 0.6406 - val_rmse: 0.7103 - val_smape: 1.2064
# Epoch 4/128
# 1914/1914 - 109s - 57ms/step - ia: 0.4423 - loss: 0.7295 - mae: 0.6221 - rmse: 0.8219 - smape: 1.2013 - val_ia: 0.2467 - val_loss: 0.7896 - val_mae: 0.6413 - val_rmse: 0.7126 - val_smape: 1.2059
# Epoch 5/128
# 1914/1914 - 109s - 57ms/step - ia: 0.4670 - loss: 0.6754 - mae: 0.6012 - rmse: 0.7926 - smape: 1.1689 - val_ia: 0.2466 - val_loss: 0.8370 - val_mae: 0.6563 - val_rmse: 0.7317 - val_smape: 1.2159
# Epoch 6/128
# 1914/1914 - 109s - 57ms/step - ia: 0.5052 - loss: 0.5878 - mae: 0.5661 - rmse: 0.7414 - smape: 1.1213 - val_ia: 0.2469 - val_loss: 0.9062 - val_mae: 0.6741 - val_rmse: 0.7494 - val_smape: 1.2455
# Epoch 7/128
# 1914/1914 - 145s - 76ms/step - ia: 0.5676 - loss: 0.4649 - mae: 0.5068 - rmse: 0.6593 - smape: 1.0355 - val_ia: 0.2438 - val_loss: 0.9766 - val_mae: 0.6874 - val_rmse: 0.7658 - val_smape: 1.2632
# Epoch 8/128
# 1914/1914 - 123s - 65ms/step - ia: 0.6330 - loss: 0.3578 - mae: 0.4436 - rmse: 0.5776 - smape: 0.9281 - val_ia: 0.2441 - val_loss: 1.0289 - val_mae: 0.7086 - val_rmse: 0.7875 - val_smape: 1.2905
# Epoch 9/128
# 1914/1914 - 108s - 56ms/step - ia: 0.6930 - loss: 0.2687 - mae: 0.3816 - rmse: 0.4996 - smape: 0.8241 - val_ia: 0.2448 - val_loss: 1.0714 - val_mae: 0.7185 - val_rmse: 0.7980 - val_smape: 1.2785
# Epoch 10/128
# 1914/1914 - 109s - 57ms/step - ia: 0.7375 - loss: 0.2087 - mae: 0.3339 - rmse: 0.4394 - smape: 0.7355 - val_ia: 0.2517 - val_loss: 1.1345 - val_mae: 0.7291 - val_rmse: 0.8115 - val_smape: 1.2643
# Epoch 11/128
# 1914/1914 - 136s - 71ms/step - ia: 0.7711 - loss: 0.1671 - mae: 0.2957 - rmse: 0.3919 - smape: 0.6701 - val_ia: 0.2502 - val_loss: 1.1376 - val_mae: 0.7345 - val_rmse: 0.8208 - val_smape: 1.2608
# Epoch 12/128
# 1914/1914 - 107s - 56ms/step - ia: 0.7991 - loss: 0.1346 - mae: 0.2630 - rmse: 0.3496 - smape: 0.6100 - val_ia: 0.2529 - val_loss: 1.1026 - val_mae: 0.7286 - val_rmse: 0.8153 - val_smape: 1.2389
# Epoch 13/128
# 1914/1914 - 107s - 56ms/step - ia: 0.8177 - loss: 0.1130 - mae: 0.2401 - rmse: 0.3197 - smape: 0.5681 - val_ia: 0.2517 - val_loss: 1.0872 - val_mae: 0.7163 - val_rmse: 0.8035 - val_smape: 1.2171
# Epoch 14/128
# 1914/1914 - 106s - 56ms/step - ia: 0.8261 - loss: 0.1071 - mae: 0.2305 - rmse: 0.3094 - smape: 0.5457 - val_ia: 0.2485 - val_loss: 1.0719 - val_mae: 0.7198 - val_rmse: 0.8044 - val_smape: 1.2322
# Epoch 15/128
# 1914/1914 - 106s - 55ms/step - ia: 0.8420 - loss: 0.0881 - mae: 0.2099 - rmse: 0.2811 - smape: 0.5119 - val_ia: 0.2471 - val_loss: 1.0900 - val_mae: 0.7196 - val_rmse: 0.8104 - val_smape: 1.2169
# Epoch 16/128
# 1914/1914 - 106s - 55ms/step - ia: 0.8435 - loss: 0.0878 - mae: 0.2083 - rmse: 0.2795 - smape: 0.5080 - val_ia: 0.2488 - val_loss: 1.0655 - val_mae: 0.7210 - val_rmse: 0.8080 - val_smape: 1.2411
# Epoch 17/128
# 1914/1914 - 107s - 56ms/step - ia: 0.8545 - loss: 0.0767 - mae: 0.1940 - rmse: 0.2605 - smape: 0.4823 - val_ia: 0.2469 - val_loss: 1.0495 - val_mae: 0.7052 - val_rmse: 0.7926 - val_smape: 1.2321
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step

# %%
metricasGRU = modelGRU.evaluate(valX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasGRU}")
# Out:
# 136/136 - 3s - 23ms/step - ia: 0.2738 - loss: 0.7878 - mae: 0.6455 - rmse: 0.7405 - smape: 1.1492
# Métricas en el conjunto de validación: [0.7877974510192871, 0.6454598307609558, 1.1492063999176025, 0.7405388951301575, 0.273836225271225]

# %%
historyGRU = historyGRU.history

ejeXGRU = range(1, len(historyGRU['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXGRU, historyGRU['loss'], label='Train Loss')
plt.plot(ejeXGRU, historyGRU['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyGRU['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyGRU['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.07668982446193695
# Último valor de Test Loss: 1.0494848489761353

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionGRU.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfGRU = df
fig.show()

# %% [markdown]
# ### Datos para NARMAX

# %%
prediccionNarmaxGRU = modelGRU.predict(datosX)
erroresGRU = datosY - prediccionNarmaxGRU
# Out:
# 1367/1367 ━━━━━━━━━━━━━━━━━━━━ 29s 21ms/step

# %%
dfErroresGRU = pd.DataFrame(erroresGRU, columns = ["e"])
dfErroresGRU.index = indices

# %%
dfNarmaxGRU = datosNormalizados.join(dfErroresGRU, how = 'left')

print(dfNarmaxGRU.head())
print(dfNarmaxGRU.tail())
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2010-01-02 00:00:00   0.317681 -1.214023 -1.268524  0.329687 -0.380944
# 2010-01-02 01:00:00   0.526152 -1.144302 -1.268524  0.329687 -0.380944
# 2010-01-02 02:00:00   0.646846 -0.865419 -1.349314  0.426127 -0.380944
# 2010-01-02 03:00:00   0.888234 -0.586536 -1.349314  0.522567 -0.380944
# 2010-01-02 04:00:00   0.416431 -0.586536 -1.349314  0.522567 -0.380944
#
#                       wnd_spd   e
# date
# 2010-01-02 00:00:00 -0.464048 NaN
# 2010-01-02 01:00:00 -0.446575 NaN
# 2010-01-02 02:00:00 -0.429103 NaN
# 2010-01-02 03:00:00 -0.393962 NaN
# 2010-01-02 04:00:00 -0.376489 NaN
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2014-12-31 19:00:00  -1.009952 -1.702068 -1.106944  1.679851  0.694538
# 2014-12-31 20:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 21:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 22:00:00  -1.009952 -1.632347 -1.268524  1.679851  0.694538
# 2014-12-31 23:00:00  -0.966063 -1.562627 -1.187734  1.679851  0.694538
#
#                       wnd_spd         e
# date
# 2014-12-31 19:00:00  4.054828 -0.880541
# 2014-12-31 20:00:00  4.168890 -0.743032
# 2014-12-31 21:00:00  4.265479 -0.643920
# 2014-12-31 22:00:00  4.344399 -0.532034
# 2014-12-31 23:00:00  4.405847 -0.470000

# %%
dfNarmaxGRU.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\4824pasos_gru_pollution.csv', index=True)

# %%
dfGRU.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacion\\4824pasos_gru_pollution.csv', index=True)

# %%
modelGRU.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarx\\4824pasos_gru_pollution.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
