# %% [markdown]
# Prueba

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from hyperopt import hp, fmin, tpe, Trials, STATUS_OK
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU, InputLayer, Flatten, LSTM
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import os
from datetime import datetime, timedelta
import plotly.express as px
import plotly.graph_objects as go
import random

# %% [markdown]
# LEER DATASET

# %%
import pandas as pd

datos = pd.read_csv("C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\SNconsumptionFinal.csv")

datos['date'] = pd.to_datetime(datos['date'])

# Se establece la columna date como index
datos.set_index('date', inplace=True)

# %%
datos.head()
# Out:
#                       temp        zone1        zone2        zone3  hour
# date
# 2017-01-01 00:00:00  6.559  34055.69620  16128.87538  20240.96386     0
# 2017-01-01 00:10:00  6.414  29814.68354  19375.07599  20131.08434     0
# 2017-01-01 00:20:00  6.313  29128.10127  19006.68693  19668.43373     0
# 2017-01-01 00:30:00  6.121  28228.86076  18361.09422  18899.27711     0
# 2017-01-01 00:40:00  5.921  27335.69620  17872.34043  18442.40964     0

# %%
#Se verifica que el index está en formato de dato "datetime64"
print("El index del dataframe input es un tipo de dato: ", datos.index.dtype)
# Out:
# El index del dataframe input es un tipo de dato:  datetime64[ns]

# %% [markdown]
# Se divide el dataset

# %%
# Dividir el conjunto de datos en entrenamiento y prueba
train, test = train_test_split(datos, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
test, val = train_test_split(test, test_size=0.33, shuffle=False)

print("Las dimensiones de train son: ", train.shape)
print("Las dimensiones de test son: ", test.shape)
print("Las dimensiones de val son: ", val.shape)
# Out:
# Las dimensiones de train son:  (36691, 5)
# Las dimensiones de test son:  (10535, 5)
# Las dimensiones de val son:  (5190, 5)

# %% [markdown]
# Se normalizan los datos

# %%
from sklearn.preprocessing import StandardScaler


# Normalizar solo con los datos de entrenamiento
scaler = StandardScaler()
train = scaler.fit_transform(train)

# Aplicar la transformación a test y val usando los parámetros de train
test = scaler.transform(test)
val = scaler.transform(val)

train = pd.DataFrame(train, columns=datos.columns)
test = pd.DataFrame(test, columns=datos.columns)
val = pd.DataFrame(val, columns=datos.columns)

# %% [markdown]
# Se unen los datos nuevamente, ahora normalizados, en un único conjunto.

# %%
datosNormalizados = pd.concat([train, test, val])

datosNormalizados.index = datos.index

# %%
datosNormalizados.shape
# Out:
# (52416, 5)

# %%
datosNormalizados.head(13)
# Out:
#                          temp     zone1     zone2     zone3      hour
# date
# 2017-01-01 00:00:00 -2.051356  0.151445 -0.851669  0.033500 -1.660858
# 2017-01-01 00:10:00 -2.074813 -0.433079 -0.211097  0.016502 -1.660858
# 2017-01-01 00:20:00 -2.091152 -0.527709 -0.283791 -0.055068 -1.660858
# 2017-01-01 00:30:00 -2.122213 -0.651648 -0.411186 -0.174054 -1.660858
# 2017-01-01 00:40:00 -2.154568 -0.774750 -0.507632 -0.244729 -1.660858
# 2017-01-01 00:50:00 -2.165569 -0.872729 -0.597600 -0.293039 -1.660858
# 2017-01-01 01:00:00 -2.199865 -0.958984 -0.681090 -0.321667 -1.516340
# 2017-01-01 01:10:00 -2.223323 -1.035189 -0.746587 -0.396816 -1.516340
# 2017-01-01 01:20:00 -2.193880 -1.127306 -0.832236 -0.463913 -1.516340
# 2017-01-01 01:30:00 -2.224132 -1.195976 -0.889096 -0.499698 -1.516340
# 2017-01-01 01:40:00 -2.220087 -1.248733 -0.988421 -0.523853 -1.516340
# 2017-01-01 01:50:00 -2.227367 -1.297304 -1.032325 -0.561427 -1.516340
# 2017-01-01 02:00:00 -2.294018 -1.371835 -1.040962 -0.604369 -1.371823

# %% [markdown]
# Se establece el formato de datos de entrada para redes GRU y LSTM, es decir [observaciones, retardos, caracteristicas]

# %%
futuros = 24
pasados  = 12

# %%
datosX = []
datosY = []
for i in range(pasados, len(datosNormalizados) - futuros + 1):
  datosX.append(datosNormalizados.iloc[i-pasados:i, 0:datosNormalizados.shape[1]])
  datosY.append(datosNormalizados.iloc[i+futuros-1:i+futuros, 1])

# %%
# Convertir las listas en arrays numpy
datosX = np.array(datosX)
datosY = np.array(datosY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de X:", datosX.shape)  # (n_muestras, pasos_de_tiempo, n_características)
print("Dimensiones de Y:", datosY.shape)  # (n_muestras, n_características)
# Out:
# Dimensiones de X: (52381, 12, 5)
# Dimensiones de Y: (52381, 1)

# %%
inputs = datosX.shape[1] * datosX.shape[2]
datosMLPX = datosX.reshape(datosX.shape[0], inputs)

# %%
print(datosX[0])
print(datosMLPX[0])
# Out:
# [[-2.05135573  0.15144479 -0.85166941  0.03349964 -1.66085756]
#  [-2.07481311 -0.43307937 -0.21109699  0.01650173 -1.66085756]
#  [-2.0911524  -0.52770864 -0.28379117 -0.05506842 -1.66085756]
#  [-2.12221321 -0.65164785 -0.41118591 -0.17405378 -1.66085756]
#  [-2.15456823 -0.77474965 -0.50763164 -0.2447293  -1.66085756]
#  [-2.16556893 -0.87272862 -0.59759968 -0.29303915 -1.66085756]
#  [-2.19986525 -0.95898362 -0.68109001 -0.32166721 -1.51634012]
#  [-2.22332263 -1.03518949 -0.74658674 -0.39681586 -1.51634012]
#  [-2.19387957 -1.12730648 -0.83223632 -0.46391287 -1.51634012]
#  [-2.22413151 -1.19597551 -0.88909611 -0.49969795 -1.51634012]
#  [-2.22008713 -1.24873342 -0.98842083 -0.52385287 -1.51634012]
#  [-2.22736701 -1.29730419 -1.03232523 -0.5614272  -1.51634012]]
# [-2.05135573  0.15144479 -0.85166941  0.03349964 -1.66085756 -2.07481311
#  -0.43307937 -0.21109699  0.01650173 -1.66085756 -2.0911524  -0.52770864
#  -0.28379117 -0.05506842 -1.66085756 -2.12221321 -0.65164785 -0.41118591
#  -0.17405378 -1.66085756 -2.15456823 -0.77474965 -0.50763164 -0.2447293
#  -1.66085756 -2.16556893 -0.87272862 -0.59759968 -0.29303915 -1.66085756
#  -2.19986525 -0.95898362 -0.68109001 -0.32166721 -1.51634012 -2.22332263
#  -1.03518949 -0.74658674 -0.39681586 -1.51634012 -2.19387957 -1.12730648
#  -0.83223632 -0.46391287 -1.51634012 -2.22413151 -1.19597551 -0.88909611
#  -0.49969795 -1.51634012 -2.22008713 -1.24873342 -0.98842083 -0.52385287
#  -1.51634012 -2.22736701 -1.29730419 -1.03232523 -0.5614272  -1.51634012]

# %% [markdown]
# Se dividen nuevamente los conjuntos de datos

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainX, testX = train_test_split(datosX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testX, valX = train_test_split(testX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainX son: ", trainX.shape)
print("Las dimensiones de testX son: ", testX.shape)
print("Las dimensiones de valX son: ", valX.shape)
# Out:
# Las dimensiones de trainX son:  (36666, 12, 5)
# Las dimensiones de testX son:  (10529, 12, 5)
# Las dimensiones de valX son:  (5186, 12, 5)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainMLPX, testMLPX = train_test_split(datosMLPX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testMLPX, valMLPX = train_test_split(testMLPX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainMLPX son: ", trainMLPX.shape)
print("Las dimensiones de testMLPX son: ", testMLPX.shape)
print("Las dimensiones de valMLPX son: ", valMLPX.shape)
# Out:
# Las dimensiones de trainMLPX son:  (36666, 60)
# Las dimensiones de testMLPX son:  (10529, 60)
# Las dimensiones de valMLPX son:  (5186, 60)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainY, testY = train_test_split(datosY, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testY, valY = train_test_split(testY, test_size=0.33, shuffle=False)

print("Las dimensiones de trainY son: ", trainY.shape)
print("Las dimensiones de testY son: ", testY.shape)
print("Las dimensiones de valY son: ", valY.shape)
# Out:
# Las dimensiones de trainY son:  (36666, 1)
# Las dimensiones de testY son:  (10529, 1)
# Las dimensiones de valY son:  (5186, 1)

# %% [markdown]
# Se crean métricas para medir desempeño

# %%
import tensorflow.keras.backend as K

def smape(y_true, y_pred):
    """
    Define la función SMAPE (Error Porcentual Absoluto Medio Simétrico).
    """
    summ = K.abs(y_true) + K.abs(y_pred)
    smape_val = K.abs(y_pred - y_true) / summ * 2.0
    return K.mean(smape_val, axis=-1)

def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

def ia(y_true, y_pred):
    numerator = K.sum(K.abs(y_true - y_pred))
    denominator = K.sum(K.abs(y_true - K.mean(y_true)) + K.abs(y_pred - K.mean(y_true)))
    return 1 - (numerator / denominator)

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

def graficarPrediccion(modelo, x, y, inicio, final):
  predicciones = modelo.predict(x)
  predicciones = predicciones.flatten()
  df = pd.DataFrame({'Originales': y, 'Predichos': predicciones})
  plt.plot(df.index, df['Originales'][inicio:final], label='Originales')
  plt.plot(df.index, df['Predichos'][inicio:final], label='Predichos')
  return df, mse(y, predicciones),  mae(y, predicciones), rmse(y, predicciones), smape(y,predicciones), ia(y, predicciones)

# %% [markdown]
# Se define el index del conjunto de validación para utilizarlo posteriormente para graficar.

# %%
# Fecha y hora de término del conjunto de datos de prueba
end_date = datosNormalizados.index[-1]
n_observations = valY.shape[0]  # Cambia esto al número de observaciones en tu conjunto de prueba

# Calcular la fecha y hora de inicio
start_date = end_date - timedelta(minutes=10 * (n_observations - 1))

# Crear la serie de fechas y horas
val_date = pd.date_range(start=start_date, end=end_date, freq='10T')

val_date
# Out:
# C:\Users\wamt1\AppData\Local\Temp\ipykernel_7280\2507154.py:9: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   val_date = pd.date_range(start=start_date, end=end_date, freq='10T')
# DatetimeIndex(['2017-11-24 23:40:00', '2017-11-24 23:50:00',
#                '2017-11-25 00:00:00', '2017-11-25 00:10:00',
#                '2017-11-25 00:20:00', '2017-11-25 00:30:00',
#                '2017-11-25 00:40:00', '2017-11-25 00:50:00',
#                '2017-11-25 01:00:00', '2017-11-25 01:10:00',
#                ...
#                '2017-12-30 22:20:00', '2017-12-30 22:30:00',
#                '2017-12-30 22:40:00', '2017-12-30 22:50:00',
#                '2017-12-30 23:00:00', '2017-12-30 23:10:00',
#                '2017-12-30 23:20:00', '2017-12-30 23:30:00',
#                '2017-12-30 23:40:00', '2017-12-30 23:50:00'],
#               dtype='datetime64[ns]', length=5186, freq='10min')

# %% [markdown]
# Se guardan los índices de las observaciones a utilizar para predecir

# %%
indices = []
for i in range(pasados, len(datosNormalizados) - futuros + 1):
  indices.append(datosNormalizados.index[i+futuros-1])

# %% [markdown]
# # Modelos

# %% [markdown]
# ## MLP

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelMLP = Sequential()
modelMLP.add(InputLayer(input_shape=(trainMLPX.shape[1],)))

modelMLP.add(Dense(units=32, activation="tanh"))
modelMLP.add(Dropout(0.2))

modelMLP.add(Dense(units=32, activation="tanh"))
modelMLP.add(Dropout(0.2))

modelMLP.add(Dense(units=32, activation="tanh"))
modelMLP.add(Dropout(0.2))

modelMLP.add(Dense(1))

opt = Adam(learning_rate=0.002091021650264381)

modelMLP.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelMLP.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │         1,952 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,097 (16.00 KB)
#  Trainable params: 4,097 (16.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyMLP = modelMLP.fit(trainMLPX, trainY, epochs=128, validation_data=(testMLPX, testY), verbose = 2, batch_size=8, callbacks=[early_stopping])

prediccionMLP = modelMLP.predict(valMLPX)
# Out:
# Epoch 1/128
# 4584/4584 - 16s - 4ms/step - ia: 0.6704 - loss: 0.3477 - mae: 0.4555 - rmse: 0.5614 - smape: 0.8392 - val_ia: 0.1671 - val_loss: 0.6564 - val_mae: 0.6067 - val_rmse: 0.6394 - val_smape: 1.0890
# Epoch 2/128
# 4584/4584 - 18s - 4ms/step - ia: 0.7477 - loss: 0.2110 - mae: 0.3527 - rmse: 0.4396 - smape: 0.7301 - val_ia: 0.2076 - val_loss: 0.4381 - val_mae: 0.4824 - val_rmse: 0.5105 - val_smape: 0.9282
# Epoch 3/128
# 4584/4584 - 8s - 2ms/step - ia: 0.7672 - loss: 0.1815 - mae: 0.3269 - rmse: 0.4084 - smape: 0.7046 - val_ia: 0.2467 - val_loss: 0.2908 - val_mae: 0.3937 - val_rmse: 0.4199 - val_smape: 0.8003
# Epoch 4/128
# 4584/4584 - 8s - 2ms/step - ia: 0.7752 - loss: 0.1700 - mae: 0.3155 - rmse: 0.3941 - smape: 0.6867 - val_ia: 0.2225 - val_loss: 0.4078 - val_mae: 0.4600 - val_rmse: 0.4886 - val_smape: 0.8992
# Epoch 5/128
# 4584/4584 - 7s - 2ms/step - ia: 0.7829 - loss: 0.1595 - mae: 0.3054 - rmse: 0.3817 - smape: 0.6730 - val_ia: 0.2269 - val_loss: 0.2934 - val_mae: 0.4068 - val_rmse: 0.4355 - val_smape: 0.8303
# Epoch 6/128
# 4584/4584 - 10s - 2ms/step - ia: 0.7844 - loss: 0.1576 - mae: 0.3038 - rmse: 0.3793 - smape: 0.6693 - val_ia: 0.2454 - val_loss: 0.1840 - val_mae: 0.3449 - val_rmse: 0.3675 - val_smape: 0.7555
# Epoch 7/128
# 4584/4584 - 15s - 3ms/step - ia: 0.7874 - loss: 0.1541 - mae: 0.2999 - rmse: 0.3750 - smape: 0.6616 - val_ia: 0.2434 - val_loss: 0.2473 - val_mae: 0.3850 - val_rmse: 0.4087 - val_smape: 0.8391
# Epoch 8/128
# 4584/4584 - 10s - 2ms/step - ia: 0.7889 - loss: 0.1511 - mae: 0.2971 - rmse: 0.3713 - smape: 0.6580 - val_ia: 0.2259 - val_loss: 0.4661 - val_mae: 0.4717 - val_rmse: 0.5026 - val_smape: 0.9099
# Epoch 9/128
# 4584/4584 - 8s - 2ms/step - ia: 0.7917 - loss: 0.1482 - mae: 0.2940 - rmse: 0.3676 - smape: 0.6561 - val_ia: 0.2371 - val_loss: 0.2752 - val_mae: 0.3966 - val_rmse: 0.4199 - val_smape: 0.7702
# Epoch 10/128
# 4584/4584 - 9s - 2ms/step - ia: 0.7930 - loss: 0.1464 - mae: 0.2922 - rmse: 0.3653 - smape: 0.6512 - val_ia: 0.2360 - val_loss: 0.3045 - val_mae: 0.4103 - val_rmse: 0.4360 - val_smape: 0.8205
# Epoch 11/128
# 4584/4584 - 8s - 2ms/step - ia: 0.7937 - loss: 0.1456 - mae: 0.2913 - rmse: 0.3644 - smape: 0.6490 - val_ia: 0.2389 - val_loss: 0.2411 - val_mae: 0.3766 - val_rmse: 0.4017 - val_smape: 0.7871
# Epoch 12/128
# 4584/4584 - 10s - 2ms/step - ia: 0.7949 - loss: 0.1437 - mae: 0.2894 - rmse: 0.3622 - smape: 0.6442 - val_ia: 0.2454 - val_loss: 0.2270 - val_mae: 0.3676 - val_rmse: 0.3917 - val_smape: 0.7970
# Epoch 13/128
# 4584/4584 - 11s - 2ms/step - ia: 0.7951 - loss: 0.1431 - mae: 0.2890 - rmse: 0.3612 - smape: 0.6447 - val_ia: 0.2469 - val_loss: 0.1930 - val_mae: 0.3470 - val_rmse: 0.3719 - val_smape: 0.7421
# Epoch 14/128
# 4584/4584 - 9s - 2ms/step - ia: 0.7957 - loss: 0.1417 - mae: 0.2885 - rmse: 0.3598 - smape: 0.6447 - val_ia: 0.2345 - val_loss: 0.3370 - val_mae: 0.4123 - val_rmse: 0.4425 - val_smape: 0.8183
# Epoch 15/128
# 4584/4584 - 9s - 2ms/step - ia: 0.7968 - loss: 0.1411 - mae: 0.2872 - rmse: 0.3586 - smape: 0.6416 - val_ia: 0.2298 - val_loss: 0.2930 - val_mae: 0.4066 - val_rmse: 0.4352 - val_smape: 0.8251
# Epoch 16/128
# 4584/4584 - 8s - 2ms/step - ia: 0.7965 - loss: 0.1407 - mae: 0.2871 - rmse: 0.3582 - smape: 0.6417 - val_ia: 0.2484 - val_loss: 0.2491 - val_mae: 0.3755 - val_rmse: 0.4002 - val_smape: 0.7499
# Epoch 17/128
# 4584/4584 - 11s - 2ms/step - ia: 0.7973 - loss: 0.1394 - mae: 0.2860 - rmse: 0.3571 - smape: 0.6400 - val_ia: 0.2342 - val_loss: 0.3405 - val_mae: 0.4216 - val_rmse: 0.4494 - val_smape: 0.7931
# Epoch 18/128
# 4584/4584 - 9s - 2ms/step - ia: 0.7985 - loss: 0.1394 - mae: 0.2852 - rmse: 0.3567 - smape: 0.6346 - val_ia: 0.2497 - val_loss: 0.1912 - val_mae: 0.3447 - val_rmse: 0.3680 - val_smape: 0.7190
# Epoch 19/128
# 4584/4584 - 10s - 2ms/step - ia: 0.7973 - loss: 0.1399 - mae: 0.2862 - rmse: 0.3575 - smape: 0.6362 - val_ia: 0.2283 - val_loss: 0.2641 - val_mae: 0.3912 - val_rmse: 0.4197 - val_smape: 0.7359
# Epoch 20/128
# 4584/4584 - 10s - 2ms/step - ia: 0.7977 - loss: 0.1399 - mae: 0.2858 - rmse: 0.3572 - smape: 0.6362 - val_ia: 0.2446 - val_loss: 0.1988 - val_mae: 0.3534 - val_rmse: 0.3752 - val_smape: 0.7468
# Epoch 21/128
# 4584/4584 - 10s - 2ms/step - ia: 0.7972 - loss: 0.1407 - mae: 0.2869 - rmse: 0.3588 - smape: 0.6364 - val_ia: 0.2426 - val_loss: 0.2302 - val_mae: 0.3747 - val_rmse: 0.3979 - val_smape: 0.7373
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
metricasMLP = modelMLP.evaluate(valMLPX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasMLP}")
# Out:
# 163/163 - 1s - 3ms/step - ia: 0.3696 - loss: 0.4862 - mae: 0.5643 - rmse: 0.6335 - smape: 1.1663
# Métricas en el conjunto de validación: [0.4862341582775116, 0.5642617344856262, 1.1662908792495728, 0.6335359811782837, 0.36957019567489624]

# %%
historyMLP = historyMLP.history

ejeXMLP = range(1, len(historyMLP['loss']) + 1)

plt.figure(figsize=(12, 8))
plt.plot(ejeXMLP, historyMLP['loss'], label='Train Loss')
plt.plot(ejeXMLP, historyMLP['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyMLP['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyMLP['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.14072945713996887
# Último valor de Test Loss: 0.23016369342803955

# %%
print(len(valY))
print(len(prediccionMLP))
print(len(val_date))
# Out:
# 5186
# 5186
# 5186

# %%
print(indices[-1])
# Out:
# 2017-12-30 23:50:00

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionMLP.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfMLP = df
fig.show()

# %% [markdown]
# ### Datos para NARMAX

# %%
prediccionNarmaxMLP = modelMLP.predict(datosMLPX)
erroresMLP = datosY - prediccionNarmaxMLP
# Out:
# 1637/1637 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %%
dfErroresMLP = pd.DataFrame(erroresMLP, columns = ["e"])
dfErroresMLP.index = indices

# %%
dfNarmaxMLP = datosNormalizados.join(dfErroresMLP, how = 'left')

print(dfNarmaxMLP.head())
print(dfNarmaxMLP.tail())
# Out:
#                          temp     zone1     zone2     zone3      hour   e
# date
# 2017-01-01 00:00:00 -2.051356  0.151445 -0.851669  0.033500 -1.660858 NaN
# 2017-01-01 00:10:00 -2.074813 -0.433079 -0.211097  0.016502 -1.660858 NaN
# 2017-01-01 00:20:00 -2.091152 -0.527709 -0.283791 -0.055068 -1.660858 NaN
# 2017-01-01 00:30:00 -2.122213 -0.651648 -0.411186 -0.174054 -1.660858 NaN
# 2017-01-01 00:40:00 -2.154568 -0.774750 -0.507632 -0.244729 -1.660858 NaN
#                          temp     zone1     zone2     zone3      hour  \
# date
# 2017-12-30 23:10:00 -1.978395 -0.247596  1.265373 -0.811241  1.663044
# 2017-12-30 23:20:00 -1.988587 -0.348215  1.120782 -0.865616  1.663044
# 2017-12-30 23:30:00 -1.996190 -0.463926  0.953666 -0.961888  1.663044
# 2017-12-30 23:40:00 -2.019162 -0.551129  0.838138 -1.007350  1.663044
# 2017-12-30 23:50:00 -2.047958 -0.634978  0.712438 -1.033201  1.663044
#
#                             e
# date
# 2017-12-30 23:10:00 -0.618853
# 2017-12-30 23:20:00 -0.349467
# 2017-12-30 23:30:00 -0.235793
# 2017-12-30 23:40:00 -0.306549
# 2017-12-30 23:50:00 -0.332517

# %%
dfNarmaxMLP.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\24pasos_mlp_consumption.csv', index=True)

# %%
dfMLP.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacion\\24pasos_mlp_consumption.csv', index=True)

# %%
modelMLP.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarx\\24pasos_mlp_consumption.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## LSTM

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelLSTM = Sequential()
modelLSTM.add(InputLayer(input_shape=(trainX.shape[1], trainX.shape[2])))


modelLSTM.add(LSTM(units=128, activation="sigmoid", return_sequences=False))
modelLSTM.add(Dropout(0.2))

modelLSTM.add(Dense(1))


opt = Adam(learning_rate=0.0002707756079796208)
modelLSTM.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelLSTM.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 128)            │        68,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 68,737 (268.50 KB)
#  Trainable params: 68,737 (268.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyLSTM = modelLSTM.fit(trainX, trainY, epochs=128, validation_data=(testX, testY), verbose = 2, batch_size=128, callbacks=[early_stopping])


prediccionLSTM = modelLSTM.predict(valX)
# Out:
# Epoch 1/128
# 287/287 - 11s - 38ms/step - ia: 0.3235 - loss: 0.8689 - mae: 0.7739 - rmse: 0.9278 - smape: 1.4033 - val_ia: 0.3995 - val_loss: 0.8792 - val_mae: 0.7638 - val_rmse: 0.9214 - val_smape: 1.2873
# Epoch 2/128
# 287/287 - 10s - 35ms/step - ia: 0.5259 - loss: 0.6003 - mae: 0.6309 - rmse: 0.7731 - smape: 1.1147 - val_ia: 0.4088 - val_loss: 1.4579 - val_mae: 1.0019 - val_rmse: 1.1755 - val_smape: 1.3598
# Epoch 3/128
# 287/287 - 4s - 14ms/step - ia: 0.6040 - loss: 0.4988 - mae: 0.5667 - rmse: 0.7046 - smape: 0.9863 - val_ia: 0.4266 - val_loss: 1.3672 - val_mae: 0.9624 - val_rmse: 1.1325 - val_smape: 1.3112
# Epoch 4/128
# 287/287 - 9s - 32ms/step - ia: 0.6482 - loss: 0.4254 - mae: 0.5214 - rmse: 0.6508 - smape: 0.9109 - val_ia: 0.4496 - val_loss: 1.2392 - val_mae: 0.9137 - val_rmse: 1.0717 - val_smape: 1.2642
# Epoch 5/128
# 287/287 - 8s - 27ms/step - ia: 0.6750 - loss: 0.3824 - mae: 0.4926 - rmse: 0.6170 - smape: 0.8575 - val_ia: 0.4842 - val_loss: 1.0225 - val_mae: 0.8233 - val_rmse: 0.9682 - val_smape: 1.2076
# Epoch 6/128
# 287/287 - 6s - 22ms/step - ia: 0.6918 - loss: 0.3524 - mae: 0.4728 - rmse: 0.5922 - smape: 0.8283 - val_ia: 0.5089 - val_loss: 0.8972 - val_mae: 0.7668 - val_rmse: 0.9051 - val_smape: 1.1786
# Epoch 7/128
# 287/287 - 5s - 19ms/step - ia: 0.7038 - loss: 0.3311 - mae: 0.4578 - rmse: 0.5742 - smape: 0.8049 - val_ia: 0.5186 - val_loss: 0.8407 - val_mae: 0.7421 - val_rmse: 0.8746 - val_smape: 1.1679
# Epoch 8/128
# 287/287 - 6s - 19ms/step - ia: 0.7116 - loss: 0.3171 - mae: 0.4476 - rmse: 0.5619 - smape: 0.7929 - val_ia: 0.5381 - val_loss: 0.7430 - val_mae: 0.6949 - val_rmse: 0.8228 - val_smape: 1.1361
# Epoch 9/128
# 287/287 - 10s - 35ms/step - ia: 0.7195 - loss: 0.3031 - mae: 0.4366 - rmse: 0.5493 - smape: 0.7782 - val_ia: 0.5432 - val_loss: 0.7247 - val_mae: 0.6873 - val_rmse: 0.8105 - val_smape: 1.1297
# Epoch 10/128
# 287/287 - 5s - 18ms/step - ia: 0.7253 - loss: 0.2934 - mae: 0.4287 - rmse: 0.5405 - smape: 0.7693 - val_ia: 0.5579 - val_loss: 0.6627 - val_mae: 0.6571 - val_rmse: 0.7762 - val_smape: 1.1006
# Epoch 11/128
# 287/287 - 6s - 20ms/step - ia: 0.7307 - loss: 0.2852 - mae: 0.4209 - rmse: 0.5328 - smape: 0.7611 - val_ia: 0.5629 - val_loss: 0.6480 - val_mae: 0.6507 - val_rmse: 0.7651 - val_smape: 1.0926
# Epoch 12/128
# 287/287 - 10s - 34ms/step - ia: 0.7359 - loss: 0.2767 - mae: 0.4135 - rmse: 0.5247 - smape: 0.7538 - val_ia: 0.5700 - val_loss: 0.6221 - val_mae: 0.6387 - val_rmse: 0.7486 - val_smape: 1.0785
# Epoch 13/128
# 287/287 - 6s - 19ms/step - ia: 0.7399 - loss: 0.2696 - mae: 0.4073 - rmse: 0.5180 - smape: 0.7461 - val_ia: 0.5814 - val_loss: 0.5868 - val_mae: 0.6222 - val_rmse: 0.7261 - val_smape: 1.0558
# Epoch 14/128
# 287/287 - 6s - 19ms/step - ia: 0.7445 - loss: 0.2614 - mae: 0.4006 - rmse: 0.5101 - smape: 0.7428 - val_ia: 0.5936 - val_loss: 0.5511 - val_mae: 0.6046 - val_rmse: 0.7025 - val_smape: 1.0304
# Epoch 15/128
# 287/287 - 5s - 19ms/step - ia: 0.7493 - loss: 0.2530 - mae: 0.3933 - rmse: 0.5017 - smape: 0.7393 - val_ia: 0.6027 - val_loss: 0.5315 - val_mae: 0.5933 - val_rmse: 0.6900 - val_smape: 1.0097
# Epoch 16/128
# 287/287 - 10s - 35ms/step - ia: 0.7560 - loss: 0.2418 - mae: 0.3829 - rmse: 0.4904 - smape: 0.7303 - val_ia: 0.6187 - val_loss: 0.5030 - val_mae: 0.5758 - val_rmse: 0.6711 - val_smape: 0.9790
# Epoch 17/128
# 287/287 - 11s - 37ms/step - ia: 0.7649 - loss: 0.2263 - mae: 0.3689 - rmse: 0.4744 - smape: 0.7198 - val_ia: 0.6303 - val_loss: 0.4966 - val_mae: 0.5678 - val_rmse: 0.6681 - val_smape: 0.9600
# Epoch 18/128
# 287/287 - 10s - 36ms/step - ia: 0.7755 - loss: 0.2091 - mae: 0.3521 - rmse: 0.4558 - smape: 0.7113 - val_ia: 0.6487 - val_loss: 0.4572 - val_mae: 0.5421 - val_rmse: 0.6408 - val_smape: 0.9318
# Epoch 19/128
# 287/287 - 5s - 18ms/step - ia: 0.7872 - loss: 0.1912 - mae: 0.3333 - rmse: 0.4358 - smape: 0.6979 - val_ia: 0.6715 - val_loss: 0.3933 - val_mae: 0.5047 - val_rmse: 0.5928 - val_smape: 0.9000
# Epoch 20/128
# 287/287 - 10s - 34ms/step - ia: 0.7966 - loss: 0.1764 - mae: 0.3185 - rmse: 0.4185 - smape: 0.6841 - val_ia: 0.6823 - val_loss: 0.3629 - val_mae: 0.4857 - val_rmse: 0.5675 - val_smape: 0.8822
# Epoch 21/128
# 287/287 - 6s - 20ms/step - ia: 0.8041 - loss: 0.1650 - mae: 0.3067 - rmse: 0.4048 - smape: 0.6715 - val_ia: 0.6950 - val_loss: 0.3276 - val_mae: 0.4609 - val_rmse: 0.5416 - val_smape: 0.8627
# Epoch 22/128
# 287/287 - 5s - 18ms/step - ia: 0.8105 - loss: 0.1551 - mae: 0.2967 - rmse: 0.3923 - smape: 0.6589 - val_ia: 0.7044 - val_loss: 0.3058 - val_mae: 0.4448 - val_rmse: 0.5236 - val_smape: 0.8489
# Epoch 23/128
# 287/287 - 5s - 18ms/step - ia: 0.8156 - loss: 0.1477 - mae: 0.2889 - rmse: 0.3828 - smape: 0.6494 - val_ia: 0.7149 - val_loss: 0.2791 - val_mae: 0.4238 - val_rmse: 0.5030 - val_smape: 0.8316
# Epoch 24/128
# 287/287 - 5s - 19ms/step - ia: 0.8201 - loss: 0.1413 - mae: 0.2822 - rmse: 0.3743 - smape: 0.6414 - val_ia: 0.7286 - val_loss: 0.2480 - val_mae: 0.3997 - val_rmse: 0.4742 - val_smape: 0.8091
# Epoch 25/128
# 287/287 - 10s - 34ms/step - ia: 0.8238 - loss: 0.1349 - mae: 0.2765 - rmse: 0.3659 - smape: 0.6349 - val_ia: 0.7282 - val_loss: 0.2523 - val_mae: 0.4011 - val_rmse: 0.4808 - val_smape: 0.8080
# Epoch 26/128
# 287/287 - 4s - 14ms/step - ia: 0.8284 - loss: 0.1295 - mae: 0.2697 - rmse: 0.3583 - smape: 0.6253 - val_ia: 0.7295 - val_loss: 0.2486 - val_mae: 0.3973 - val_rmse: 0.4769 - val_smape: 0.8067
# Epoch 27/128
# 287/287 - 5s - 19ms/step - ia: 0.8314 - loss: 0.1254 - mae: 0.2653 - rmse: 0.3527 - smape: 0.6208 - val_ia: 0.7380 - val_loss: 0.2343 - val_mae: 0.3851 - val_rmse: 0.4658 - val_smape: 0.7908
# Epoch 28/128
# 287/287 - 4s - 14ms/step - ia: 0.8332 - loss: 0.1228 - mae: 0.2627 - rmse: 0.3489 - smape: 0.6190 - val_ia: 0.7392 - val_loss: 0.2314 - val_mae: 0.3833 - val_rmse: 0.4624 - val_smape: 0.7881
# Epoch 29/128
# 287/287 - 5s - 16ms/step - ia: 0.8366 - loss: 0.1183 - mae: 0.2576 - rmse: 0.3424 - smape: 0.6096 - val_ia: 0.7423 - val_loss: 0.2289 - val_mae: 0.3801 - val_rmse: 0.4616 - val_smape: 0.7788
# Epoch 30/128
# 287/287 - 5s - 16ms/step - ia: 0.8384 - loss: 0.1164 - mae: 0.2550 - rmse: 0.3396 - smape: 0.6031 - val_ia: 0.7488 - val_loss: 0.2175 - val_mae: 0.3706 - val_rmse: 0.4516 - val_smape: 0.7641
# Epoch 31/128
# 287/287 - 4s - 15ms/step - ia: 0.8399 - loss: 0.1149 - mae: 0.2529 - rmse: 0.3373 - smape: 0.6021 - val_ia: 0.7550 - val_loss: 0.2042 - val_mae: 0.3602 - val_rmse: 0.4366 - val_smape: 0.7523
# Epoch 32/128
# 287/287 - 6s - 21ms/step - ia: 0.8424 - loss: 0.1121 - mae: 0.2491 - rmse: 0.3332 - smape: 0.5948 - val_ia: 0.7505 - val_loss: 0.2184 - val_mae: 0.3708 - val_rmse: 0.4522 - val_smape: 0.7564
# Epoch 33/128
# 287/287 - 11s - 37ms/step - ia: 0.8430 - loss: 0.1113 - mae: 0.2485 - rmse: 0.3319 - smape: 0.5933 - val_ia: 0.7532 - val_loss: 0.2135 - val_mae: 0.3670 - val_rmse: 0.4470 - val_smape: 0.7504
# Epoch 34/128
# 287/287 - 10s - 35ms/step - ia: 0.8430 - loss: 0.1114 - mae: 0.2484 - rmse: 0.3322 - smape: 0.5938 - val_ia: 0.7583 - val_loss: 0.2014 - val_mae: 0.3567 - val_rmse: 0.4357 - val_smape: 0.7429
# Epoch 35/128
# 287/287 - 4s - 14ms/step - ia: 0.8454 - loss: 0.1085 - mae: 0.2447 - rmse: 0.3278 - smape: 0.5867 - val_ia: 0.7586 - val_loss: 0.2004 - val_mae: 0.3564 - val_rmse: 0.4333 - val_smape: 0.7421
# Epoch 36/128
# 287/287 - 5s - 18ms/step - ia: 0.8458 - loss: 0.1084 - mae: 0.2442 - rmse: 0.3276 - smape: 0.5845 - val_ia: 0.7607 - val_loss: 0.1996 - val_mae: 0.3554 - val_rmse: 0.4324 - val_smape: 0.7381
# Epoch 37/128
# 287/287 - 5s - 19ms/step - ia: 0.8461 - loss: 0.1079 - mae: 0.2438 - rmse: 0.3268 - smape: 0.5851 - val_ia: 0.7588 - val_loss: 0.2032 - val_mae: 0.3590 - val_rmse: 0.4361 - val_smape: 0.7420
# Epoch 38/128
# 287/287 - 5s - 16ms/step - ia: 0.8466 - loss: 0.1069 - mae: 0.2430 - rmse: 0.3254 - smape: 0.5825 - val_ia: 0.7663 - val_loss: 0.1870 - val_mae: 0.3450 - val_rmse: 0.4187 - val_smape: 0.7285
# Epoch 39/128
# 287/287 - 5s - 16ms/step - ia: 0.8474 - loss: 0.1061 - mae: 0.2418 - rmse: 0.3241 - smape: 0.5805 - val_ia: 0.7601 - val_loss: 0.1992 - val_mae: 0.3557 - val_rmse: 0.4331 - val_smape: 0.7383
# Epoch 40/128
# 287/287 - 5s - 19ms/step - ia: 0.8477 - loss: 0.1056 - mae: 0.2413 - rmse: 0.3234 - smape: 0.5783 - val_ia: 0.7660 - val_loss: 0.1880 - val_mae: 0.3459 - val_rmse: 0.4206 - val_smape: 0.7280
# Epoch 41/128
# 287/287 - 10s - 36ms/step - ia: 0.8482 - loss: 0.1053 - mae: 0.2405 - rmse: 0.3230 - smape: 0.5801 - val_ia: 0.7583 - val_loss: 0.2031 - val_mae: 0.3605 - val_rmse: 0.4356 - val_smape: 0.7443
# Epoch 42/128
# 287/287 - 10s - 36ms/step - ia: 0.8491 - loss: 0.1043 - mae: 0.2392 - rmse: 0.3214 - smape: 0.5775 - val_ia: 0.7579 - val_loss: 0.2023 - val_mae: 0.3607 - val_rmse: 0.4338 - val_smape: 0.7471
# Epoch 43/128
# 287/287 - 4s - 14ms/step - ia: 0.8493 - loss: 0.1040 - mae: 0.2391 - rmse: 0.3208 - smape: 0.5764 - val_ia: 0.7583 - val_loss: 0.2008 - val_mae: 0.3592 - val_rmse: 0.4335 - val_smape: 0.7445
# Epoch 44/128
# 287/287 - 5s - 17ms/step - ia: 0.8504 - loss: 0.1031 - mae: 0.2373 - rmse: 0.3194 - smape: 0.5733 - val_ia: 0.7655 - val_loss: 0.1873 - val_mae: 0.3462 - val_rmse: 0.4186 - val_smape: 0.7313
# Epoch 45/128
# 287/287 - 4s - 15ms/step - ia: 0.8498 - loss: 0.1035 - mae: 0.2383 - rmse: 0.3201 - smape: 0.5743 - val_ia: 0.7578 - val_loss: 0.2022 - val_mae: 0.3601 - val_rmse: 0.4351 - val_smape: 0.7453
# Epoch 46/128
# 287/287 - 6s - 20ms/step - ia: 0.8510 - loss: 0.1020 - mae: 0.2363 - rmse: 0.3178 - smape: 0.5723 - val_ia: 0.7576 - val_loss: 0.2028 - val_mae: 0.3614 - val_rmse: 0.4347 - val_smape: 0.7481
# Epoch 47/128
# 287/287 - 6s - 20ms/step - ia: 0.8511 - loss: 0.1018 - mae: 0.2362 - rmse: 0.3174 - smape: 0.5713 - val_ia: 0.7598 - val_loss: 0.2002 - val_mae: 0.3587 - val_rmse: 0.4328 - val_smape: 0.7436
# Epoch 48/128
# 287/287 - 10s - 36ms/step - ia: 0.8513 - loss: 0.1015 - mae: 0.2360 - rmse: 0.3170 - smape: 0.5685 - val_ia: 0.7580 - val_loss: 0.2015 - val_mae: 0.3608 - val_rmse: 0.4331 - val_smape: 0.7484
# Epoch 49/128
# 287/287 - 11s - 37ms/step - ia: 0.8516 - loss: 0.1012 - mae: 0.2355 - rmse: 0.3166 - smape: 0.5693 - val_ia: 0.7560 - val_loss: 0.2056 - val_mae: 0.3633 - val_rmse: 0.4387 - val_smape: 0.7499
# Epoch 50/128
# 287/287 - 6s - 21ms/step - ia: 0.8522 - loss: 0.1006 - mae: 0.2345 - rmse: 0.3154 - smape: 0.5678 - val_ia: 0.7590 - val_loss: 0.1984 - val_mae: 0.3576 - val_rmse: 0.4296 - val_smape: 0.7465
# Epoch 51/128
# 287/287 - 6s - 20ms/step - ia: 0.8529 - loss: 0.0997 - mae: 0.2335 - rmse: 0.3142 - smape: 0.5669 - val_ia: 0.7580 - val_loss: 0.2007 - val_mae: 0.3595 - val_rmse: 0.4327 - val_smape: 0.7470
# Epoch 52/128
# 287/287 - 5s - 17ms/step - ia: 0.8530 - loss: 0.0997 - mae: 0.2333 - rmse: 0.3142 - smape: 0.5657 - val_ia: 0.7582 - val_loss: 0.1997 - val_mae: 0.3590 - val_rmse: 0.4322 - val_smape: 0.7465
# Epoch 53/128
# 287/287 - 6s - 22ms/step - ia: 0.8533 - loss: 0.0992 - mae: 0.2329 - rmse: 0.3135 - smape: 0.5659 - val_ia: 0.7643 - val_loss: 0.1873 - val_mae: 0.3478 - val_rmse: 0.4188 - val_smape: 0.7345
# Epoch 53: early stopping
# Restoring model weights from the end of the best epoch: 38.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
metricasLSTM = modelLSTM.evaluate(valX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasLSTM}")
# Out:
# 163/163 - 1s - 3ms/step - ia: 0.4734 - loss: 0.2228 - mae: 0.4073 - rmse: 0.4441 - smape: 0.8699
# Métricas en el conjunto de validación: [0.22275583446025848, 0.4072999954223633, 0.8699009418487549, 0.44409608840942383, 0.4734342098236084]

# %%
historyLSTM = historyLSTM.history

ejeXLSTM = range(1, len(historyLSTM['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXLSTM, historyLSTM['loss'], label='Train Loss')
plt.plot(ejeXLSTM, historyLSTM['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyLSTM['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyLSTM['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.09921646863222122
# Último valor de Test Loss: 0.18731540441513062

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionLSTM.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfLSTM = df
fig.show()

# %% [markdown]
# ### Datos para NARMAX

# %%
prediccionNarmaxLSTM = modelLSTM.predict(datosX)
erroresLSTM = datosY - prediccionNarmaxLSTM
# Out:
# 1637/1637 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step

# %%
dfErroresLSTM = pd.DataFrame(erroresLSTM, columns = ["e"])
dfErroresLSTM.index = indices

# %%
dfNarmaxLSTM = datosNormalizados.join(dfErroresLSTM, how = 'left')

print(dfNarmaxLSTM.head())
print(dfNarmaxLSTM.tail())
# Out:
#                          temp     zone1     zone2     zone3      hour   e
# date
# 2017-01-01 00:00:00 -2.051356  0.151445 -0.851669  0.033500 -1.660858 NaN
# 2017-01-01 00:10:00 -2.074813 -0.433079 -0.211097  0.016502 -1.660858 NaN
# 2017-01-01 00:20:00 -2.091152 -0.527709 -0.283791 -0.055068 -1.660858 NaN
# 2017-01-01 00:30:00 -2.122213 -0.651648 -0.411186 -0.174054 -1.660858 NaN
# 2017-01-01 00:40:00 -2.154568 -0.774750 -0.507632 -0.244729 -1.660858 NaN
#                          temp     zone1     zone2     zone3      hour  \
# date
# 2017-12-30 23:10:00 -1.978395 -0.247596  1.265373 -0.811241  1.663044
# 2017-12-30 23:20:00 -1.988587 -0.348215  1.120782 -0.865616  1.663044
# 2017-12-30 23:30:00 -1.996190 -0.463926  0.953666 -0.961888  1.663044
# 2017-12-30 23:40:00 -2.019162 -0.551129  0.838138 -1.007350  1.663044
# 2017-12-30 23:50:00 -2.047958 -0.634978  0.712438 -1.033201  1.663044
#
#                             e
# date
# 2017-12-30 23:10:00  0.465541
# 2017-12-30 23:20:00  0.471614
# 2017-12-30 23:30:00  0.477652
# 2017-12-30 23:40:00  0.505933
# 2017-12-30 23:50:00  0.511957

# %%
dfNarmaxLSTM.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\24pasos_lstm_consumption.csv', index=True)

# %%
dfLSTM.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacion\\24pasos_lstm_consumption.csv', index=True)

# %%
modelLSTM.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarx\\24pasos_lstm_consumption.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## GRU

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelGRU = Sequential()
modelGRU.add(InputLayer(input_shape=(trainX.shape[1], trainX.shape[2])))

modelGRU.add(GRU(units=128, activation="sigmoid", return_sequences=True))
modelGRU.add(Dropout(0.4))

modelGRU.add(GRU(units=128, activation="sigmoid", return_sequences=False))
modelGRU.add(Dropout(0.4))

modelGRU.add(Dense(1))


opt = Adam(learning_rate=8.360431152477965e-05)
modelGRU.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelGRU.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 12, 128)        │        51,840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 128)            │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 151,041 (590.00 KB)
#  Trainable params: 151,041 (590.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)

early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyGRU = modelGRU.fit(trainX, trainY, epochs=128, validation_data=(testX, testY), verbose = 2, batch_size=16, callbacks=[early_stopping])

prediccionGRU = modelGRU.predict(valX)
# Out:
# Epoch 1/128
# 2292/2292 - 36s - 16ms/step - ia: 0.3135 - loss: 0.9920 - mae: 0.8237 - rmse: 0.9825 - smape: 1.4284 - val_ia: 0.1833 - val_loss: 0.8287 - val_mae: 0.7539 - val_rmse: 0.7855 - val_smape: 1.3089
# Epoch 2/128
# 2292/2292 - 25s - 11ms/step - ia: 0.5640 - loss: 0.5459 - mae: 0.5944 - rmse: 0.7275 - smape: 1.0210 - val_ia: 0.1815 - val_loss: 1.1840 - val_mae: 0.9123 - val_rmse: 0.9460 - val_smape: 1.3400
# Epoch 3/128
# 2292/2292 - 47s - 21ms/step - ia: 0.6286 - loss: 0.4383 - mae: 0.5284 - rmse: 0.6514 - smape: 0.9035 - val_ia: 0.1837 - val_loss: 1.0819 - val_mae: 0.8661 - val_rmse: 0.8983 - val_smape: 1.3014
# Epoch 4/128
# 2292/2292 - 31s - 14ms/step - ia: 0.6581 - loss: 0.3870 - mae: 0.4939 - rmse: 0.6121 - smape: 0.8451 - val_ia: 0.1899 - val_loss: 0.9685 - val_mae: 0.8138 - val_rmse: 0.8447 - val_smape: 1.2672
# Epoch 5/128
# 2292/2292 - 38s - 16ms/step - ia: 0.6807 - loss: 0.3493 - mae: 0.4660 - rmse: 0.5808 - smape: 0.8056 - val_ia: 0.2015 - val_loss: 0.8399 - val_mae: 0.7447 - val_rmse: 0.7762 - val_smape: 1.2047
# Epoch 6/128
# 2292/2292 - 36s - 16ms/step - ia: 0.6947 - loss: 0.3246 - mae: 0.4480 - rmse: 0.5596 - smape: 0.7842 - val_ia: 0.2096 - val_loss: 0.7755 - val_mae: 0.7057 - val_rmse: 0.7378 - val_smape: 1.1627
# Epoch 7/128
# 2292/2292 - 37s - 16ms/step - ia: 0.7064 - loss: 0.3035 - mae: 0.4323 - rmse: 0.5411 - smape: 0.7654 - val_ia: 0.2229 - val_loss: 0.6874 - val_mae: 0.6531 - val_rmse: 0.6866 - val_smape: 1.0915
# Epoch 8/128
# 2292/2292 - 41s - 18ms/step - ia: 0.7171 - loss: 0.2854 - mae: 0.4179 - rmse: 0.5243 - smape: 0.7559 - val_ia: 0.2298 - val_loss: 0.6515 - val_mae: 0.6297 - val_rmse: 0.6629 - val_smape: 1.0645
# Epoch 9/128
# 2292/2292 - 37s - 16ms/step - ia: 0.7271 - loss: 0.2664 - mae: 0.4034 - rmse: 0.5066 - smape: 0.7479 - val_ia: 0.2408 - val_loss: 0.6010 - val_mae: 0.5966 - val_rmse: 0.6286 - val_smape: 1.0356
# Epoch 10/128
# 2292/2292 - 36s - 16ms/step - ia: 0.7373 - loss: 0.2496 - mae: 0.3887 - rmse: 0.4902 - smape: 0.7415 - val_ia: 0.2510 - val_loss: 0.5775 - val_mae: 0.5754 - val_rmse: 0.6078 - val_smape: 1.0178
# Epoch 11/128
# 2292/2292 - 36s - 16ms/step - ia: 0.7443 - loss: 0.2365 - mae: 0.3781 - rmse: 0.4767 - smape: 0.7379 - val_ia: 0.2631 - val_loss: 0.5445 - val_mae: 0.5496 - val_rmse: 0.5820 - val_smape: 0.9874
# Epoch 12/128
# 2292/2292 - 41s - 18ms/step - ia: 0.7512 - loss: 0.2241 - mae: 0.3674 - rmse: 0.4642 - smape: 0.7335 - val_ia: 0.2687 - val_loss: 0.5537 - val_mae: 0.5446 - val_rmse: 0.5784 - val_smape: 0.9694
# Epoch 13/128
# 2292/2292 - 37s - 16ms/step - ia: 0.7575 - loss: 0.2133 - mae: 0.3580 - rmse: 0.4530 - smape: 0.7248 - val_ia: 0.2769 - val_loss: 0.5125 - val_mae: 0.5207 - val_rmse: 0.5553 - val_smape: 0.9374
# Epoch 14/128
# 2292/2292 - 41s - 18ms/step - ia: 0.7615 - loss: 0.2058 - mae: 0.3518 - rmse: 0.4447 - smape: 0.7208 - val_ia: 0.2852 - val_loss: 0.4669 - val_mae: 0.4981 - val_rmse: 0.5321 - val_smape: 0.9117
# Epoch 15/128
# 2292/2292 - 23s - 10ms/step - ia: 0.7654 - loss: 0.1993 - mae: 0.3461 - rmse: 0.4377 - smape: 0.7165 - val_ia: 0.2900 - val_loss: 0.4096 - val_mae: 0.4739 - val_rmse: 0.5069 - val_smape: 0.8867
# Epoch 16/128
# 2292/2292 - 28s - 12ms/step - ia: 0.7693 - loss: 0.1925 - mae: 0.3402 - rmse: 0.4302 - smape: 0.7108 - val_ia: 0.2944 - val_loss: 0.3959 - val_mae: 0.4638 - val_rmse: 0.4981 - val_smape: 0.8674
# Epoch 17/128
# 2292/2292 - 36s - 16ms/step - ia: 0.7751 - loss: 0.1849 - mae: 0.3323 - rmse: 0.4214 - smape: 0.7011 - val_ia: 0.2970 - val_loss: 0.3855 - val_mae: 0.4590 - val_rmse: 0.4935 - val_smape: 0.8534
# Epoch 18/128
# 2292/2292 - 41s - 18ms/step - ia: 0.7801 - loss: 0.1779 - mae: 0.3253 - rmse: 0.4133 - smape: 0.6952 - val_ia: 0.2994 - val_loss: 0.4120 - val_mae: 0.4653 - val_rmse: 0.5028 - val_smape: 0.8456
# Epoch 19/128
# 2292/2292 - 38s - 17ms/step - ia: 0.7858 - loss: 0.1700 - mae: 0.3178 - rmse: 0.4037 - smape: 0.6898 - val_ia: 0.3048 - val_loss: 0.3864 - val_mae: 0.4520 - val_rmse: 0.4899 - val_smape: 0.8323
# Epoch 20/128
# 2292/2292 - 40s - 17ms/step - ia: 0.7924 - loss: 0.1604 - mae: 0.3084 - rmse: 0.3919 - smape: 0.6797 - val_ia: 0.3056 - val_loss: 0.4111 - val_mae: 0.4622 - val_rmse: 0.5023 - val_smape: 0.8312
# Epoch 21/128
# 2292/2292 - 36s - 16ms/step - ia: 0.7997 - loss: 0.1510 - mae: 0.2984 - rmse: 0.3797 - smape: 0.6691 - val_ia: 0.3095 - val_loss: 0.3907 - val_mae: 0.4517 - val_rmse: 0.4929 - val_smape: 0.8207
# Epoch 22/128
# 2292/2292 - 36s - 16ms/step - ia: 0.8070 - loss: 0.1417 - mae: 0.2882 - rmse: 0.3676 - smape: 0.6568 - val_ia: 0.3105 - val_loss: 0.3753 - val_mae: 0.4444 - val_rmse: 0.4871 - val_smape: 0.8102
# Epoch 23/128
# 2292/2292 - 37s - 16ms/step - ia: 0.8126 - loss: 0.1349 - mae: 0.2802 - rmse: 0.3584 - smape: 0.6477 - val_ia: 0.3166 - val_loss: 0.3297 - val_mae: 0.4242 - val_rmse: 0.4655 - val_smape: 0.7931
# Epoch 24/128
# 2292/2292 - 36s - 16ms/step - ia: 0.8173 - loss: 0.1292 - mae: 0.2734 - rmse: 0.3506 - smape: 0.6389 - val_ia: 0.3172 - val_loss: 0.3020 - val_mae: 0.4120 - val_rmse: 0.4543 - val_smape: 0.7820
# Epoch 25/128
# 2292/2292 - 37s - 16ms/step - ia: 0.8208 - loss: 0.1243 - mae: 0.2682 - rmse: 0.3438 - smape: 0.6306 - val_ia: 0.3184 - val_loss: 0.2584 - val_mae: 0.3904 - val_rmse: 0.4321 - val_smape: 0.7716
# Epoch 26/128
# 2292/2292 - 41s - 18ms/step - ia: 0.8248 - loss: 0.1200 - mae: 0.2628 - rmse: 0.3376 - smape: 0.6258 - val_ia: 0.3199 - val_loss: 0.2418 - val_mae: 0.3830 - val_rmse: 0.4251 - val_smape: 0.7606
# Epoch 27/128
# 2292/2292 - 37s - 16ms/step - ia: 0.8273 - loss: 0.1173 - mae: 0.2593 - rmse: 0.3337 - smape: 0.6173 - val_ia: 0.3238 - val_loss: 0.2107 - val_mae: 0.3633 - val_rmse: 0.4041 - val_smape: 0.7517
# Epoch 28/128
# 2292/2292 - 29s - 13ms/step - ia: 0.8293 - loss: 0.1147 - mae: 0.2562 - rmse: 0.3300 - smape: 0.6116 - val_ia: 0.3243 - val_loss: 0.2047 - val_mae: 0.3581 - val_rmse: 0.4002 - val_smape: 0.7507
# Epoch 29/128
# 2292/2292 - 45s - 19ms/step - ia: 0.8325 - loss: 0.1107 - mae: 0.2514 - rmse: 0.3239 - smape: 0.6036 - val_ia: 0.3360 - val_loss: 0.1809 - val_mae: 0.3399 - val_rmse: 0.3796 - val_smape: 0.7271
# Epoch 30/128
# 2292/2292 - 30s - 13ms/step - ia: 0.8338 - loss: 0.1094 - mae: 0.2496 - rmse: 0.3217 - smape: 0.6012 - val_ia: 0.3385 - val_loss: 0.1808 - val_mae: 0.3392 - val_rmse: 0.3786 - val_smape: 0.7226
# Epoch 31/128
# 2292/2292 - 42s - 18ms/step - ia: 0.8350 - loss: 0.1079 - mae: 0.2483 - rmse: 0.3198 - smape: 0.5952 - val_ia: 0.3398 - val_loss: 0.1810 - val_mae: 0.3386 - val_rmse: 0.3780 - val_smape: 0.7203
# Epoch 32/128
# 2292/2292 - 34s - 15ms/step - ia: 0.8361 - loss: 0.1068 - mae: 0.2464 - rmse: 0.3179 - smape: 0.5916 - val_ia: 0.3444 - val_loss: 0.1750 - val_mae: 0.3324 - val_rmse: 0.3726 - val_smape: 0.7136
# Epoch 33/128
# 2292/2292 - 35s - 15ms/step - ia: 0.8375 - loss: 0.1054 - mae: 0.2446 - rmse: 0.3159 - smape: 0.5887 - val_ia: 0.3479 - val_loss: 0.1654 - val_mae: 0.3241 - val_rmse: 0.3629 - val_smape: 0.7041
# Epoch 34/128
# 2292/2292 - 29s - 13ms/step - ia: 0.8387 - loss: 0.1038 - mae: 0.2427 - rmse: 0.3134 - smape: 0.5839 - val_ia: 0.3523 - val_loss: 0.1683 - val_mae: 0.3257 - val_rmse: 0.3649 - val_smape: 0.7025
# Epoch 35/128
# 2292/2292 - 27s - 12ms/step - ia: 0.8395 - loss: 0.1034 - mae: 0.2416 - rmse: 0.3127 - smape: 0.5818 - val_ia: 0.3487 - val_loss: 0.1671 - val_mae: 0.3253 - val_rmse: 0.3639 - val_smape: 0.7048
# Epoch 36/128
# 2292/2292 - 43s - 19ms/step - ia: 0.8405 - loss: 0.1021 - mae: 0.2403 - rmse: 0.3106 - smape: 0.5799 - val_ia: 0.3516 - val_loss: 0.1635 - val_mae: 0.3222 - val_rmse: 0.3601 - val_smape: 0.7031
# Epoch 37/128
# 2292/2292 - 25s - 11ms/step - ia: 0.8410 - loss: 0.1017 - mae: 0.2394 - rmse: 0.3101 - smape: 0.5770 - val_ia: 0.3585 - val_loss: 0.1592 - val_mae: 0.3164 - val_rmse: 0.3546 - val_smape: 0.6922
# Epoch 38/128
# 2292/2292 - 35s - 15ms/step - ia: 0.8429 - loss: 0.0996 - mae: 0.2368 - rmse: 0.3068 - smape: 0.5719 - val_ia: 0.3567 - val_loss: 0.1668 - val_mae: 0.3225 - val_rmse: 0.3623 - val_smape: 0.6965
# Epoch 39/128
# 2292/2292 - 41s - 18ms/step - ia: 0.8435 - loss: 0.0990 - mae: 0.2360 - rmse: 0.3061 - smape: 0.5700 - val_ia: 0.3509 - val_loss: 0.1718 - val_mae: 0.3257 - val_rmse: 0.3674 - val_smape: 0.7040
# Epoch 40/128
# 2292/2292 - 31s - 14ms/step - ia: 0.8435 - loss: 0.0987 - mae: 0.2358 - rmse: 0.3051 - smape: 0.5678 - val_ia: 0.3551 - val_loss: 0.1672 - val_mae: 0.3237 - val_rmse: 0.3631 - val_smape: 0.6994
# Epoch 41/128
# 2292/2292 - 36s - 16ms/step - ia: 0.8442 - loss: 0.0979 - mae: 0.2351 - rmse: 0.3041 - smape: 0.5656 - val_ia: 0.3576 - val_loss: 0.1652 - val_mae: 0.3204 - val_rmse: 0.3606 - val_smape: 0.6961
# Epoch 42/128
# 2292/2292 - 35s - 15ms/step - ia: 0.8450 - loss: 0.0971 - mae: 0.2336 - rmse: 0.3029 - smape: 0.5633 - val_ia: 0.3536 - val_loss: 0.1664 - val_mae: 0.3221 - val_rmse: 0.3618 - val_smape: 0.6969
# Epoch 43/128
# 2292/2292 - 23s - 10ms/step - ia: 0.8450 - loss: 0.0971 - mae: 0.2337 - rmse: 0.3028 - smape: 0.5614 - val_ia: 0.3560 - val_loss: 0.1673 - val_mae: 0.3221 - val_rmse: 0.3622 - val_smape: 0.6960
# Epoch 44/128
# 2292/2292 - 30s - 13ms/step - ia: 0.8460 - loss: 0.0962 - mae: 0.2326 - rmse: 0.3014 - smape: 0.5612 - val_ia: 0.3623 - val_loss: 0.1602 - val_mae: 0.3152 - val_rmse: 0.3547 - val_smape: 0.6877
# Epoch 45/128
# 2292/2292 - 41s - 18ms/step - ia: 0.8457 - loss: 0.0962 - mae: 0.2328 - rmse: 0.3013 - smape: 0.5605 - val_ia: 0.3707 - val_loss: 0.1486 - val_mae: 0.3043 - val_rmse: 0.3418 - val_smape: 0.6727
# Epoch 46/128
# 2292/2292 - 36s - 16ms/step - ia: 0.8471 - loss: 0.0945 - mae: 0.2308 - rmse: 0.2987 - smape: 0.5569 - val_ia: 0.3566 - val_loss: 0.1645 - val_mae: 0.3198 - val_rmse: 0.3594 - val_smape: 0.6934
# Epoch 47/128
# 2292/2292 - 34s - 15ms/step - ia: 0.8470 - loss: 0.0949 - mae: 0.2310 - rmse: 0.2994 - smape: 0.5568 - val_ia: 0.3638 - val_loss: 0.1552 - val_mae: 0.3111 - val_rmse: 0.3493 - val_smape: 0.6823
# Epoch 48/128
# 2292/2292 - 34s - 15ms/step - ia: 0.8483 - loss: 0.0934 - mae: 0.2289 - rmse: 0.2970 - smape: 0.5527 - val_ia: 0.3637 - val_loss: 0.1548 - val_mae: 0.3104 - val_rmse: 0.3489 - val_smape: 0.6795
# Epoch 49/128
# 2292/2292 - 35s - 15ms/step - ia: 0.8486 - loss: 0.0930 - mae: 0.2286 - rmse: 0.2963 - smape: 0.5515 - val_ia: 0.3545 - val_loss: 0.1703 - val_mae: 0.3261 - val_rmse: 0.3652 - val_smape: 0.6978
# Epoch 50/128
# 2292/2292 - 35s - 15ms/step - ia: 0.8487 - loss: 0.0929 - mae: 0.2287 - rmse: 0.2962 - smape: 0.5493 - val_ia: 0.3720 - val_loss: 0.1512 - val_mae: 0.3070 - val_rmse: 0.3442 - val_smape: 0.6709
# Epoch 51/128
# 2292/2292 - 33s - 14ms/step - ia: 0.8494 - loss: 0.0920 - mae: 0.2276 - rmse: 0.2947 - smape: 0.5477 - val_ia: 0.3662 - val_loss: 0.1542 - val_mae: 0.3104 - val_rmse: 0.3486 - val_smape: 0.6754
# Epoch 52/128
# 2292/2292 - 23s - 10ms/step - ia: 0.8503 - loss: 0.0917 - mae: 0.2264 - rmse: 0.2943 - smape: 0.5463 - val_ia: 0.3644 - val_loss: 0.1550 - val_mae: 0.3111 - val_rmse: 0.3492 - val_smape: 0.6779
# Epoch 53/128
# 2292/2292 - 33s - 14ms/step - ia: 0.8509 - loss: 0.0907 - mae: 0.2257 - rmse: 0.2924 - smape: 0.5461 - val_ia: 0.3615 - val_loss: 0.1619 - val_mae: 0.3166 - val_rmse: 0.3558 - val_smape: 0.6836
# Epoch 54/128
# 2292/2292 - 35s - 15ms/step - ia: 0.8515 - loss: 0.0901 - mae: 0.2248 - rmse: 0.2915 - smape: 0.5436 - val_ia: 0.3564 - val_loss: 0.1654 - val_mae: 0.3213 - val_rmse: 0.3604 - val_smape: 0.6877
# Epoch 55/128
# 2292/2292 - 35s - 15ms/step - ia: 0.8510 - loss: 0.0903 - mae: 0.2255 - rmse: 0.2921 - smape: 0.5449 - val_ia: 0.3569 - val_loss: 0.1659 - val_mae: 0.3222 - val_rmse: 0.3609 - val_smape: 0.6911
# Epoch 56/128
# 2292/2292 - 22s - 10ms/step - ia: 0.8523 - loss: 0.0887 - mae: 0.2236 - rmse: 0.2891 - smape: 0.5403 - val_ia: 0.3714 - val_loss: 0.1496 - val_mae: 0.3063 - val_rmse: 0.3435 - val_smape: 0.6649
# Epoch 57/128
# 2292/2292 - 28s - 12ms/step - ia: 0.8518 - loss: 0.0894 - mae: 0.2241 - rmse: 0.2907 - smape: 0.5398 - val_ia: 0.3674 - val_loss: 0.1514 - val_mae: 0.3083 - val_rmse: 0.3453 - val_smape: 0.6692
# Epoch 58/128
# 2292/2292 - 34s - 15ms/step - ia: 0.8541 - loss: 0.0876 - mae: 0.2211 - rmse: 0.2875 - smape: 0.5354 - val_ia: 0.3674 - val_loss: 0.1527 - val_mae: 0.3104 - val_rmse: 0.3472 - val_smape: 0.6697
# Epoch 59/128
# 2292/2292 - 42s - 18ms/step - ia: 0.8530 - loss: 0.0880 - mae: 0.2226 - rmse: 0.2883 - smape: 0.5378 - val_ia: 0.3629 - val_loss: 0.1583 - val_mae: 0.3147 - val_rmse: 0.3529 - val_smape: 0.6776
# Epoch 60/128
# 2292/2292 - 23s - 10ms/step - ia: 0.8540 - loss: 0.0870 - mae: 0.2214 - rmse: 0.2868 - smape: 0.5357 - val_ia: 0.3630 - val_loss: 0.1611 - val_mae: 0.3166 - val_rmse: 0.3555 - val_smape: 0.6795
# Epoch 60: early stopping
# Restoring model weights from the end of the best epoch: 45.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step

# %%
metricasGRU = modelGRU.evaluate(valX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasGRU}")
# Out:
# 163/163 - 1s - 4ms/step - ia: 0.5049 - loss: 0.1754 - mae: 0.3586 - rmse: 0.3862 - smape: 0.8342
# Métricas en el conjunto de validación: [0.17538763582706451, 0.3585658371448517, 0.8342392444610596, 0.3861674666404724, 0.504911482334137]

# %%
historyGRU = historyGRU.history

ejeXGRU = range(1, len(historyGRU['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXGRU, historyGRU['loss'], label='Train Loss')
plt.plot(ejeXGRU, historyGRU['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyGRU['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyGRU['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.08697056770324707
# Último valor de Test Loss: 0.16108809411525726

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionGRU.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfGRU =df
fig.show()

# %% [markdown]
# ### Datos para NARMAX

# %%
prediccionNarmaxGRU = modelGRU.predict(datosX)
erroresGRU = datosY - prediccionNarmaxGRU
# Out:
# 1637/1637 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step

# %%
dfErroresGRU = pd.DataFrame(erroresGRU, columns = ["e"])
dfErroresGRU.index = indices

# %%
dfNarmaxGRU = datosNormalizados.join(dfErroresGRU, how = 'left')

print(dfNarmaxGRU.head())
print(dfNarmaxGRU.tail())
# Out:
#                          temp     zone1     zone2     zone3      hour   e
# date
# 2017-01-01 00:00:00 -2.051356  0.151445 -0.851669  0.033500 -1.660858 NaN
# 2017-01-01 00:10:00 -2.074813 -0.433079 -0.211097  0.016502 -1.660858 NaN
# 2017-01-01 00:20:00 -2.091152 -0.527709 -0.283791 -0.055068 -1.660858 NaN
# 2017-01-01 00:30:00 -2.122213 -0.651648 -0.411186 -0.174054 -1.660858 NaN
# 2017-01-01 00:40:00 -2.154568 -0.774750 -0.507632 -0.244729 -1.660858 NaN
#                          temp     zone1     zone2     zone3      hour  \
# date
# 2017-12-30 23:10:00 -1.978395 -0.247596  1.265373 -0.811241  1.663044
# 2017-12-30 23:20:00 -1.988587 -0.348215  1.120782 -0.865616  1.663044
# 2017-12-30 23:30:00 -1.996190 -0.463926  0.953666 -0.961888  1.663044
# 2017-12-30 23:40:00 -2.019162 -0.551129  0.838138 -1.007350  1.663044
# 2017-12-30 23:50:00 -2.047958 -0.634978  0.712438 -1.033201  1.663044
#
#                             e
# date
# 2017-12-30 23:10:00  0.056764
# 2017-12-30 23:20:00 -0.061198
# 2017-12-30 23:30:00 -0.104351
# 2017-12-30 23:40:00 -0.069160
# 2017-12-30 23:50:00  0.054751

# %%
dfNarmaxGRU.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\24pasos_gru_consumption.csv', index=True)

# %%
dfGRU.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacion\\24pasos_gru_consumption.csv', index=True)

# %%
modelGRU.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarx\\24pasos_gru_consumption.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
