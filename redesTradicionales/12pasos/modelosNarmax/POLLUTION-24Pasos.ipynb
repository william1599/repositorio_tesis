# %% [markdown]
# Prueba

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from hyperopt import hp, fmin, tpe, Trials, STATUS_OK
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU, InputLayer, Flatten, LSTM
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import os
from datetime import datetime, timedelta
import plotly.express as px
import plotly.graph_objects as go
import random

# %% [markdown]
# LEER DATASET

# %%
import pandas as pd

datosMLP = pd.read_csv("C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\24pasos_mlp_pollution.csv")
datosLSTM = pd.read_csv("C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\24pasos_lstm_pollution.csv")
datosGRU = pd.read_csv("C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\24pasos_gru_pollution.csv")

datosMLP['date'] = pd.to_datetime(datosMLP['date'])
datosLSTM['date'] = pd.to_datetime(datosLSTM['date'])
datosGRU['date'] = pd.to_datetime(datosGRU['date'])

# Se establece la columna date como index
datosMLP.set_index('date', inplace=True)
datosLSTM.set_index('date', inplace=True)
datosGRU.set_index('date', inplace=True)

# %%
datosMLP.tail()
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2014-12-31 19:00:00  -1.009952 -1.702068 -1.106944  1.679851  0.694538
# 2014-12-31 20:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 21:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 22:00:00  -1.009952 -1.632347 -1.268524  1.679851  0.694538
# 2014-12-31 23:00:00  -0.966063 -1.562627 -1.187734  1.679851  0.694538
#
#                       wnd_spd         e
# date
# 2014-12-31 19:00:00  4.054828 -0.672097
# 2014-12-31 20:00:00  4.168890 -0.606625
# 2014-12-31 21:00:00  4.265479 -0.597509
# 2014-12-31 22:00:00  4.344399 -0.427131
# 2014-12-31 23:00:00  4.405847 -0.381507

# %%
datosLSTM.tail()
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2014-12-31 19:00:00  -1.009952 -1.702068 -1.106944  1.679851  0.694538
# 2014-12-31 20:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 21:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 22:00:00  -1.009952 -1.632347 -1.268524  1.679851  0.694538
# 2014-12-31 23:00:00  -0.966063 -1.562627 -1.187734  1.679851  0.694538
#
#                       wnd_spd         e
# date
# 2014-12-31 19:00:00  4.054828 -0.826614
# 2014-12-31 20:00:00  4.168890 -0.783249
# 2014-12-31 21:00:00  4.265479 -0.735042
# 2014-12-31 22:00:00  4.344399 -0.667675
# 2014-12-31 23:00:00  4.405847 -0.575324

# %%
datosGRU.tail()
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2014-12-31 19:00:00  -1.009952 -1.702068 -1.106944  1.679851  0.694538
# 2014-12-31 20:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 21:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 22:00:00  -1.009952 -1.632347 -1.268524  1.679851  0.694538
# 2014-12-31 23:00:00  -0.966063 -1.562627 -1.187734  1.679851  0.694538
#
#                       wnd_spd         e
# date
# 2014-12-31 19:00:00  4.054828 -0.884729
# 2014-12-31 20:00:00  4.168890 -0.762506
# 2014-12-31 21:00:00  4.265479 -0.682858
# 2014-12-31 22:00:00  4.344399 -0.558328
# 2014-12-31 23:00:00  4.405847 -0.488613

# %%
#Se verifica que el index está en formato de dato "datetime64"
print("El index del dataframe MLP input es un tipo de dato: ", datosMLP.index.dtype)
print("El index del dataframe LSTM input es un tipo de dato: ", datosLSTM.index.dtype)
print("El index del dataframe GRU input es un tipo de dato: ", datosGRU.index.dtype)
# Out:
# El index del dataframe MLP input es un tipo de dato:  datetime64[ns]
# El index del dataframe LSTM input es un tipo de dato:  datetime64[ns]
# El index del dataframe GRU input es un tipo de dato:  datetime64[ns]

# %% [markdown]
# Se establece el formato de datos de entrada para redes GRU y LSTM, es decir [observaciones, retardos, caracteristicas]

# %%
futuros = 24
pasados  = 12

# %%
datosMLPX = []
datosMLPY = []
for i in range(pasados, len(datosMLP) - futuros + 1):
  datosMLPX.append(datosMLP.iloc[i-pasados:i, 0:datosMLP.shape[1]])
  datosMLPY.append(datosMLP.iloc[i+futuros-1:i+futuros, 0])

# %%
datosLSTMX = []
datosLSTMY = []
for i in range(pasados, len(datosLSTM) - futuros + 1):
  datosLSTMX.append(datosLSTM.iloc[i-pasados:i, 0:datosLSTM.shape[1]])
  datosLSTMY.append(datosLSTM.iloc[i+futuros-1:i+futuros, 0])

# %%
datosGRUX = []
datosGRUY = []
for i in range(pasados, len(datosGRU) - futuros + 1):
  datosGRUX.append(datosGRU.iloc[i-pasados:i, 0:datosGRU.shape[1]])
  datosGRUY.append(datosGRU.iloc[i+futuros-1:i+futuros, 0])

# %%
# Convertir las listas en arrays numpy
datosMLPX = np.array(datosMLPX)
datosMLPY = np.array(datosMLPY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de MLP X:", datosMLPX.shape)  
print("Dimensiones de MLP Y:", datosMLPY.shape)
# Out:
# Dimensiones de MLP X: (43765, 12, 7)
# Dimensiones de MLP Y: (43765, 1)

# %%
# Convertir las listas en arrays numpy
datosLSTMX = np.array(datosLSTMX)
datosLSTMY = np.array(datosLSTMY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de LSTM X:", datosLSTMX.shape)  
print("Dimensiones de LSTM Y:", datosLSTMY.shape)
# Out:
# Dimensiones de LSTM X: (43765, 12, 7)
# Dimensiones de LSTM Y: (43765, 1)

# %%
# Convertir las listas en arrays numpy
datosGRUX = np.array(datosGRUX)
datosGRUY = np.array(datosGRUY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de GRU X:", datosGRUX.shape)  
print("Dimensiones de GRU Y:", datosGRUY.shape)
# Out:
# Dimensiones de GRU X: (43765, 12, 7)
# Dimensiones de GRU Y: (43765, 1)

# %%
inputs = datosMLPX.shape[1] * datosMLPX.shape[2]
datosMLPX = datosMLPX.reshape(datosMLPX.shape[0], inputs)

# %%
datosMLPX
# Out:
# array([[ 0.31768099, -1.2140229 , -1.26852411, ..., -0.38094383,
#         -0.09555657,         nan],
#        [ 0.52615226, -1.14430217, -1.26852411, ..., -0.38094383,
#         -0.03410865,         nan],
#        [ 0.64684616, -0.86541928, -1.34931411, ..., -0.38094383,
#          0.04481168,         nan],
#        ...,
#        [-0.82342496, -1.07458145, -0.54141417, ...,  0.69453847,
#         -0.0692498 , -1.00521749],
#        [-0.57106499, -1.14430217, -0.46062418, ...,  0.69453847,
#          0.12373201, -1.17196322],
#        [-0.56009282, -1.14430217, -0.37983418, ...,  0.69453847,
#          0.26410026, -1.0425467 ]])

# %% [markdown]
# Se dividen nuevamente los conjuntos de datos

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainMLPX, testMLPX = train_test_split(datosMLPX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testMLPX, valMLPX = train_test_split(testMLPX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainMLPX son: ", trainMLPX.shape)
print("Las dimensiones de testMLPX son: ", testMLPX.shape)
print("Las dimensiones de valMLPX son: ", valMLPX.shape)
# Out:
# Las dimensiones de trainMLPX son:  (30635, 84)
# Las dimensiones de testMLPX son:  (8797, 84)
# Las dimensiones de valMLPX son:  (4333, 84)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainLSTMX, testLSTMX = train_test_split(datosLSTMX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testLSTMX, valLSTMX = train_test_split(testLSTMX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainLSTMX son: ", trainLSTMX.shape)
print("Las dimensiones de testLSTMX son: ", testLSTMX.shape)
print("Las dimensiones de valLSTMX son: ", valLSTMX.shape)
# Out:
# Las dimensiones de trainLSTMX son:  (30635, 12, 7)
# Las dimensiones de testLSTMX son:  (8797, 12, 7)
# Las dimensiones de valLSTMX son:  (4333, 12, 7)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainGRUX, testGRUX = train_test_split(datosGRUX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testGRUX, valGRUX = train_test_split(testGRUX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainGRUX son: ", trainGRUX.shape)
print("Las dimensiones de testGRUX son: ", testGRUX.shape)
print("Las dimensiones de valGRUX son: ", valGRUX.shape)
# Out:
# Las dimensiones de trainGRUX son:  (30635, 12, 7)
# Las dimensiones de testGRUX son:  (8797, 12, 7)
# Las dimensiones de valGRUX son:  (4333, 12, 7)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainY, testY = train_test_split(datosMLPY, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testY, valY = train_test_split(testY, test_size=0.33, shuffle=False)

print("Las dimensiones de trainY son: ", trainY.shape)
print("Las dimensiones de testY son: ", testY.shape)
print("Las dimensiones de valY son: ", valY.shape)
# Out:
# Las dimensiones de trainY son:  (30635, 1)
# Las dimensiones de testY son:  (8797, 1)
# Las dimensiones de valY son:  (4333, 1)

# %% [markdown]
# Se crean métricas para medir desempeño

# %%
import tensorflow.keras.backend as K

def smape(y_true, y_pred):
    """
    Define la función SMAPE (Error Porcentual Absoluto Medio Simétrico).
    """
    summ = K.abs(y_true) + K.abs(y_pred)
    smape_val = K.abs(y_pred - y_true) / summ * 2.0
    return K.mean(smape_val, axis=-1)

def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

def ia(y_true, y_pred):
    numerator = K.sum(K.abs(y_true - y_pred))
    denominator = K.sum(K.abs(y_true - K.mean(y_true)) + K.abs(y_pred - K.mean(y_true)))
    return 1 - (numerator / denominator)

# %% [markdown]
# Se define el index del conjunto de validación para utilizarlo posteriormente para graficar.

# %%
# Fecha y hora de término del conjunto de datos de prueba
end_date = datosMLP.index[-1]
n_observations = valY.shape[0]  # Cambia esto al número de observaciones en tu conjunto de prueba

# Calcular la fecha y hora de inicio
start_date = end_date - timedelta(hours = (n_observations - 1))

# Crear la serie de fechas y horas
val_date = pd.date_range(start=start_date, end=end_date, freq='1H')

val_date
# Out:
# C:\Users\wamt1\AppData\Local\Temp\ipykernel_6596\196214621.py:9: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   val_date = pd.date_range(start=start_date, end=end_date, freq='1H')
# DatetimeIndex(['2014-07-04 11:00:00', '2014-07-04 12:00:00',
#                '2014-07-04 13:00:00', '2014-07-04 14:00:00',
#                '2014-07-04 15:00:00', '2014-07-04 16:00:00',
#                '2014-07-04 17:00:00', '2014-07-04 18:00:00',
#                '2014-07-04 19:00:00', '2014-07-04 20:00:00',
#                ...
#                '2014-12-31 14:00:00', '2014-12-31 15:00:00',
#                '2014-12-31 16:00:00', '2014-12-31 17:00:00',
#                '2014-12-31 18:00:00', '2014-12-31 19:00:00',
#                '2014-12-31 20:00:00', '2014-12-31 21:00:00',
#                '2014-12-31 22:00:00', '2014-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=4333, freq='h')

# %% [markdown]
# Se guardan los índices de las observaciones a utilizar para predecir

# %%
indices = []
for i in range(pasados, len(datosMLP) - futuros + 1):
  indices.append(datosMLP.index[i+futuros-2])

# %% [markdown]
# # Modelos

# %% [markdown]
# ## MLP

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelMLP = Sequential()
modelMLP.add(InputLayer(input_shape=(testMLPX.shape[1],)))

modelMLP.add(Dense(units=64, activation="linear"))
modelMLP.add(Dropout(0.4))

modelMLP.add(Dense(1))

opt = Adam(learning_rate=0.009726326397617627)

modelMLP.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelMLP.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         5,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,505 (21.50 KB)
#  Trainable params: 5,505 (21.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyMLP = modelMLP.fit(testMLPX, testY, epochs=128,
                        validation_split=0.3,
                        verbose = 2, batch_size=128, callbacks=[early_stopping])

prediccionMLP = modelMLP.predict(valMLPX)
# Out:
# Epoch 1
# Epoch 24/128
# 49/49 - 0s - 8ms/step - ia: 0.4261 - loss: 0.8956 - mae: 0.6950 - rmse: 0.9409 - smape: 1.2194 - val_ia: 0.3151 - val_loss: 0.4535 - val_mae: 0.5045 - val_rmse: 0.6358 - val_smape: 1.2457
# Epoch 25/128
# 49/49 - 0s - 5ms/step - ia: 0.4245 - loss: 0.8951 - mae: 0.6972 - rmse: 0.9403 - smape: 1.2221 - val_ia: 0.3098 - val_loss: 0.4589 - val_mae: 0.5136 - val_rmse: 0.6411 - val_smape: 1.2976
# Epoch 26/128
# 49/49 - 0s - 4ms/step - ia: 0.4222 - loss: 0.9033 - mae: 0.6970 - rmse: 0.9445 - smape: 1.2214 - val_ia: 0.3180 - val_loss: 0.4687 - val_mae: 0.5167 - val_rmse: 0.6485 - val_smape: 1.2844
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 11.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
metricasMLP = modelMLP.evaluate(valMLPX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasMLP}")
# Out:
# 136/136 - 0s - 2ms/step - ia: 0.2769 - loss: 0.7654 - mae: 0.6570 - rmse: 0.7441 - smape: 1.2547
# Métricas en el conjunto de validación: [0.7654184699058533, 0.6569722890853882, 1.2547013759613037, 0.7440976500511169, 0.2768915593624115]

# %%
historyMLP = historyMLP.history

ejeXMLP = range(1, len(historyMLP['loss']) + 1)

plt.figure(figsize=(12, 8))
plt.plot(ejeXMLP, historyMLP['loss'], label='Train Loss')
plt.plot(ejeXMLP, historyMLP['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyMLP['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyMLP['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.9033306241035461
# Último valor de Test Loss: 0.46870583295822144

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionMLP.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfMLP = df
fig.show()

# %%
dfMLP.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacionNarmax\\24pasos_mlp_pollution.csv', index=True)

# %%
modelMLP.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarmax\\24pasos_mlp_pollution.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## LSTM

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelLSTM = Sequential()
modelLSTM.add(InputLayer(input_shape=(testLSTMX.shape[1], testLSTMX.shape[2])))


modelLSTM.add(LSTM(units=128, activation="sigmoid", return_sequences=False))
modelLSTM.add(Dropout(0.2))

modelLSTM.add(Dense(1))


opt = Adam(learning_rate=0.0002707756079796208)
modelLSTM.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelLSTM.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 128)            │        69,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 69,761 (272.50 KB)
#  Trainable params: 69,761 (272.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyLSTM = modelLSTM.fit(testLSTMX, testY, epochs=128,
                        validation_split=0.3,
                        verbose = 2, batch_size=128, callbacks=[early_stopping])

prediccionLSTM = modelLSTM.predict(valLSTMX)
# Out:
# Epoch 1/128
# 49/49 - 4s - 92ms/step - ia: 0.2585 - loss: 1.2330 - mae: 0.8069 - rmse: 1.1001 - smape: 1.4309 - val_ia: 0.2756 - val_loss: 0.5003 - val_mae: 0.5424 - val_rmse: 0.6633 - val_smape: 1.5172
# Epoch 2/128
# 49/49 - 1s - 19ms/step - ia: 0.2759 - loss: 1.0501 - mae: 0.7610 - rmse: 1.0201 - smape: 1.4264 - val_ia: 0.2841 - val_loss: 0.4716 - val_mae: 0.5293 - val_rmse: 0.6489 - val_smape: 1.4252
# Epoch 3/128
# 49/49 - 1s - 17ms/step - ia: 0.3357 - loss: 0.9903 - mae: 0.7417 - rmse: 0.9904 - smape: 1.3448 - val_ia: 0.2959 - val_loss: 0.4502 - val_mae: 0.5070 - val_rmse: 0.6311 - val_smape: 1.3036
# Epoch 4/128
# 49/49 - 1s - 15ms/step - ia: 0.3711 - loss: 0.9652 - mae: 0.7318 - rmse: 0.9781 - smape: 1.2985 - val_ia: 0.3043 - val_loss: 0.4445 - val_mae: 0.5023 - val_rmse: 0.6281 - val_smape: 1.2665
# Epoch 5/128
# 49/49 - 1s - 15ms/step - ia: 0.3848 - loss: 0.9595 - mae: 0.7281 - rmse: 0.9744 - smape: 1.2749 - val_ia: 0.3094 - val_loss: 0.4427 - val_mae: 0.4995 - val_rmse: 0.6270 - val_smape: 1.2434
# Epoch 6/128
# 49/49 - 1s - 14ms/step - ia: 0.4000 - loss: 0.9465 - mae: 0.7219 - rmse: 0.9671 - smape: 1.2558 - val_ia: 0.3129 - val_loss: 0.4423 - val_mae: 0.4978 - val_rmse: 0.6264 - val_smape: 1.2308
# Epoch 7/128
# 49/49 - 1s - 14ms/step - ia: 0.4078 - loss: 0.9347 - mae: 0.7145 - rmse: 0.9630 - smape: 1.2426 - val_ia: 0.3127 - val_loss: 0.4428 - val_mae: 0.5005 - val_rmse: 0.6287 - val_smape: 1.2434
# Epoch 8/128
# 49/49 - 1s - 14ms/step - ia: 0.4043 - loss: 0.9395 - mae: 0.7181 - rmse: 0.9645 - smape: 1.2465 - val_ia: 0.3154 - val_loss: 0.4428 - val_mae: 0.4971 - val_rmse: 0.6266 - val_smape: 1.2227
# Epoch 9/128
# 49/49 - 1s - 13ms/step - ia: 0.4097 - loss: 0.9302 - mae: 0.7146 - rmse: 0.9583 - smape: 1.2430 - val_ia: 0.3145 - val_loss: 0.4431 - val_mae: 0.4984 - val_rmse: 0.6277 - val_smape: 1.2307
# Epoch 10/128
# 49/49 - 1s - 15ms/step - ia: 0.4099 - loss: 0.9321 - mae: 0.7149 - rmse: 0.9623 - smape: 1.2403 - val_ia: 0.3152 - val_loss: 0.4436 - val_mae: 0.4969 - val_rmse: 0.6268 - val_smape: 1.2203
# Epoch 11/128
# 49/49 - 1s - 14ms/step - ia: 0.4098 - loss: 0.9177 - mae: 0.7117 - rmse: 0.9528 - smape: 1.2418 - val_ia: 0.3157 - val_loss: 0.4440 - val_mae: 0.4965 - val_rmse: 0.6268 - val_smape: 1.2162
# Epoch 12/128
# 49/49 - 1s - 14ms/step - ia: 0.4134 - loss: 0.9299 - mae: 0.7115 - rmse: 0.9593 - smape: 1.2273 - val_ia: 0.3139 - val_loss: 0.4441 - val_mae: 0.4977 - val_rmse: 0.6274 - val_smape: 1.2245
# Epoch 13/128
# 49/49 - 1s - 15ms/step - ia: 0.4131 - loss: 0.9264 - mae: 0.7107 - rmse: 0.9563 - smape: 1.2296 - val_ia: 0.3137 - val_loss: 0.4444 - val_mae: 0.4979 - val_rmse: 0.6276 - val_smape: 1.2250
# Epoch 14/128
# 49/49 - 1s - 14ms/step - ia: 0.4160 - loss: 0.9148 - mae: 0.7047 - rmse: 0.9513 - smape: 1.2277 - val_ia: 0.3134 - val_loss: 0.4448 - val_mae: 0.4982 - val_rmse: 0.6280 - val_smape: 1.2264
# Epoch 15/128
# 49/49 - 1s - 15ms/step - ia: 0.4130 - loss: 0.9171 - mae: 0.7079 - rmse: 0.9539 - smape: 1.2302 - val_ia: 0.3136 - val_loss: 0.4452 - val_mae: 0.4979 - val_rmse: 0.6278 - val_smape: 1.2225
# Epoch 16/128
# 49/49 - 1s - 15ms/step - ia: 0.4186 - loss: 0.9066 - mae: 0.7046 - rmse: 0.9462 - smape: 1.2227 - val_ia: 0.3138 - val_loss: 0.4456 - val_mae: 0.4973 - val_rmse: 0.6276 - val_smape: 1.2181
# Epoch 17/128
# 49/49 - 1s - 14ms/step - ia: 0.4200 - loss: 0.9050 - mae: 0.7026 - rmse: 0.9458 - smape: 1.2181 - val_ia: 0.3142 - val_loss: 0.4465 - val_mae: 0.4968 - val_rmse: 0.6274 - val_smape: 1.2116
# Epoch 18/128
# 49/49 - 1s - 15ms/step - ia: 0.4174 - loss: 0.9084 - mae: 0.7034 - rmse: 0.9484 - smape: 1.2267 - val_ia: 0.3130 - val_loss: 0.4463 - val_mae: 0.4983 - val_rmse: 0.6284 - val_smape: 1.2226
# Epoch 19/128
# 49/49 - 1s - 14ms/step - ia: 0.4221 - loss: 0.8995 - mae: 0.6997 - rmse: 0.9419 - smape: 1.2180 - val_ia: 0.3138 - val_loss: 0.4469 - val_mae: 0.4977 - val_rmse: 0.6282 - val_smape: 1.2148
# Epoch 20/128
# 49/49 - 1s - 14ms/step - ia: 0.4227 - loss: 0.8983 - mae: 0.6991 - rmse: 0.9443 - smape: 1.2125 - val_ia: 0.3130 - val_loss: 0.4471 - val_mae: 0.4985 - val_rmse: 0.6288 - val_smape: 1.2193
# Epoch 21/128
# 49/49 - 1s - 15ms/step - ia: 0.4229 - loss: 0.9043 - mae: 0.6999 - rmse: 0.9467 - smape: 1.2144 - val_ia: 0.3123 - val_loss: 0.4474 - val_mae: 0.4984 - val_rmse: 0.6286 - val_smape: 1.2195
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
metricasLSTM = modelLSTM.evaluate(valLSTMX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasLSTM}")
# Out:
# 136/136 - 1s - 4ms/step - ia: 0.2694 - loss: 0.7830 - mae: 0.6670 - rmse: 0.7528 - smape: 1.2739
# Métricas en el conjunto de validación: [0.7829749584197998, 0.6670497059822083, 1.2739170789718628, 0.7527532577514648, 0.26937058568000793]

# %%
historyLSTM = historyLSTM.history

ejeXLSTM = range(1, len(historyLSTM['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXLSTM, historyLSTM['loss'], label='Train Loss')
plt.plot(ejeXLSTM, historyLSTM['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyLSTM['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyLSTM['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.9043136239051819
# Último valor de Test Loss: 0.4473690092563629

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionLSTM.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfLSTM = df
fig.show()

# %%
dfLSTM.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacionNarmax\\24pasos_lstm_pollution.csv', index=True)

# %%
modelLSTM.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarmax\\24pasos_lstm_pollution.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## GRU

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelGRU = Sequential()
modelGRU.add(InputLayer(input_shape=(testGRUX.shape[1], testGRUX.shape[2])))

modelGRU.add(GRU(units=8, activation="linear", return_sequences=False))
modelGRU.add(Dropout(0.3))

modelGRU.add(Dense(1))


opt = Adam(learning_rate=0.001217652235385441)
modelGRU.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelGRU.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 8)              │           408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 417 (1.63 KB)
#  Trainable params: 417 (1.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)

early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyGRU = modelGRU.fit(testGRUX, testY, epochs=128,
                        validation_split=0.3,
                        verbose = 2, batch_size=128, callbacks=[early_stopping])

prediccionGRU = modelGRU.predict(valGRUX)
# Out:
# Epoch 1/128
# 49/49 - 3s - 62ms/step - ia: 0.3327 - loss: 2.1724 - mae: 1.1449 - rmse: 1.4447 - smape: 1.3778 - val_ia: 0.3324 - val_loss: 0.5610 - val_mae: 0.5491 - val_rmse: 0.7047 - val_smape: 1.1552
# Epoch 2/128
# 49/49 - 0s - 5ms/step - ia: 0.3528 - loss: 1.4307 - mae: 0.9239 - rmse: 1.1971 - smape: 1.3512 - val_ia: 0.3265 - val_loss: 0.4957 - val_mae: 0.5175 - val_rmse: 0.6607 - val_smape: 1.1896
# Epoch 3/128
# 49/49 - 0s - 5ms/step - ia: 0.3839 - loss: 1.2135 - mae: 0.8408 - rmse: 1.0935 - smape: 1.3010 - val_ia: 0.3221 - val_loss: 0.4743 - val_mae: 0.5067 - val_rmse: 0.6445 - val_smape: 1.2014
# Epoch 4/128
# 49/49 - 0s - 5ms/step - ia: 0.3832 - loss: 1.1426 - mae: 0.8107 - rmse: 1.0660 - smape: 1.2978 - val_ia: 0.3216 - val_loss: 0.4619 - val_mae: 0.5029 - val_rmse: 0.6378 - val_smape: 1.2040
# Epoch 5/128
# 49/49 - 0s - 6ms/step - ia: 0.4024 - loss: 1.0808 - mae: 0.7822 - rmse: 1.0296 - smape: 1.2728 - val_ia: 0.3187 - val_loss: 0.4555 - val_mae: 0.5011 - val_rmse: 0.6342 - val_smape: 1.2100
# Epoch 6/128
# 49/49 - 0s - 5ms/step - ia: 0.4026 - loss: 1.0259 - mae: 0.7573 - rmse: 1.0105 - smape: 1.2615 - val_ia: 0.3136 - val_loss: 0.4515 - val_mae: 0.4987 - val_rmse: 0.6310 - val_smape: 1.2136
# Epoch 7/128
# 49/49 - 0s - 5ms/step - ia: 0.3995 - loss: 0.9944 - mae: 0.7516 - rmse: 0.9932 - smape: 1.2774 - val_ia: 0.3113 - val_loss: 0.4498 - val_mae: 0.4984 - val_rmse: 0.6304 - val_smape: 1.2182
# Epoch 8/128
# 49/49 - 0s - 5ms/step - ia: 0.4125 - loss: 0.9702 - mae: 0.7357 - rmse: 0.9820 - smape: 1.2444 - val_ia: 0.3092 - val_loss: 0.4480 - val_mae: 0.4982 - val_rmse: 0.6297 - val_smape: 1.2219
# Epoch 9/128
# 49/49 - 0s - 5ms/step - ia: 0.4123 - loss: 0.9526 - mae: 0.7246 - rmse: 0.9715 - smape: 1.2399 - val_ia: 0.3089 - val_loss: 0.4481 - val_mae: 0.4965 - val_rmse: 0.6286 - val_smape: 1.2122
# Epoch 10/128
# 49/49 - 0s - 5ms/step - ia: 0.4123 - loss: 0.9442 - mae: 0.7237 - rmse: 0.9671 - smape: 1.2483 - val_ia: 0.3094 - val_loss: 0.4475 - val_mae: 0.4986 - val_rmse: 0.6302 - val_smape: 1.2222
# Epoch 11/128
# 49/49 - 0s - 5ms/step - ia: 0.4174 - loss: 0.9312 - mae: 0.7165 - rmse: 0.9595 - smape: 1.2398 - val_ia: 0.3063 - val_loss: 0.4479 - val_mae: 0.4988 - val_rmse: 0.6302 - val_smape: 1.2254
# Epoch 12/128
# 49/49 - 0s - 5ms/step - ia: 0.4216 - loss: 0.9246 - mae: 0.7113 - rmse: 0.9572 - smape: 1.2300 - val_ia: 0.3054 - val_loss: 0.4489 - val_mae: 0.4995 - val_rmse: 0.6310 - val_smape: 1.2273
# Epoch 13/128
# 49/49 - 0s - 5ms/step - ia: 0.4265 - loss: 0.8998 - mae: 0.7028 - rmse: 0.9430 - smape: 1.2229 - val_ia: 0.3055 - val_loss: 0.4493 - val_mae: 0.4972 - val_rmse: 0.6299 - val_smape: 1.2137
# Epoch 14/128
# 49/49 - 0s - 5ms/step - ia: 0.4321 - loss: 0.8862 - mae: 0.6979 - rmse: 0.9368 - smape: 1.2165 - val_ia: 0.3033 - val_loss: 0.4495 - val_mae: 0.4992 - val_rmse: 0.6314 - val_smape: 1.2242
# Epoch 15/128
# 49/49 - 0s - 8ms/step - ia: 0.4263 - loss: 0.8907 - mae: 0.7000 - rmse: 0.9397 - smape: 1.2231 - val_ia: 0.3018 - val_loss: 0.4522 - val_mae: 0.5004 - val_rmse: 0.6329 - val_smape: 1.2274
# Epoch 16/128
# 49/49 - 0s - 6ms/step - ia: 0.4249 - loss: 0.8865 - mae: 0.6999 - rmse: 0.9363 - smape: 1.2296 - val_ia: 0.3037 - val_loss: 0.4537 - val_mae: 0.5011 - val_rmse: 0.6339 - val_smape: 1.2313
# Epoch 17/128
# 49/49 - 0s - 6ms/step - ia: 0.4304 - loss: 0.8810 - mae: 0.6932 - rmse: 0.9329 - smape: 1.2220 - val_ia: 0.3066 - val_loss: 0.4545 - val_mae: 0.4998 - val_rmse: 0.6338 - val_smape: 1.2224
# Epoch 18/128
# 49/49 - 0s - 6ms/step - ia: 0.4381 - loss: 0.8664 - mae: 0.6859 - rmse: 0.9271 - smape: 1.2082 - val_ia: 0.3076 - val_loss: 0.4564 - val_mae: 0.5008 - val_rmse: 0.6352 - val_smape: 1.2283
# Epoch 19/128
# 49/49 - 0s - 7ms/step - ia: 0.4355 - loss: 0.8777 - mae: 0.6867 - rmse: 0.9314 - smape: 1.2156 - val_ia: 0.3082 - val_loss: 0.4566 - val_mae: 0.5021 - val_rmse: 0.6362 - val_smape: 1.2390
# Epoch 20/128
# 49/49 - 0s - 7ms/step - ia: 0.4432 - loss: 0.8517 - mae: 0.6836 - rmse: 0.9179 - smape: 1.2033 - val_ia: 0.3098 - val_loss: 0.4594 - val_mae: 0.5022 - val_rmse: 0.6373 - val_smape: 1.2332
# Epoch 21/128
# 49/49 - 1s - 15ms/step - ia: 0.4436 - loss: 0.8580 - mae: 0.6807 - rmse: 0.9206 - smape: 1.2041 - val_ia: 0.3137 - val_loss: 0.4579 - val_mae: 0.5029 - val_rmse: 0.6376 - val_smape: 1.2360
# Epoch 22/128
# 49/49 - 0s - 7ms/step - ia: 0.4465 - loss: 0.8466 - mae: 0.6781 - rmse: 0.9158 - smape: 1.2043 - val_ia: 0.3097 - val_loss: 0.4651 - val_mae: 0.5032 - val_rmse: 0.6389 - val_smape: 1.2324
# Epoch 23/128
# 49/49 - 0s - 7ms/step - ia: 0.4488 - loss: 0.8345 - mae: 0.6724 - rmse: 0.9118 - smape: 1.1960 - val_ia: 0.3136 - val_loss: 0.4659 - val_mae: 0.5051 - val_rmse: 0.6409 - val_smape: 1.2429
# Epoch 24/128
# 49/49 - 0s - 7ms/step - ia: 0.4474 - loss: 0.8411 - mae: 0.6754 - rmse: 0.9114 - smape: 1.2020 - val_ia: 0.3130 - val_loss: 0.4680 - val_mae: 0.5056 - val_rmse: 0.6411 - val_smape: 1.2472
# Epoch 25/128
# 49/49 - 0s - 8ms/step - ia: 0.4419 - loss: 0.8459 - mae: 0.6774 - rmse: 0.9159 - smape: 1.2109 - val_ia: 0.3114 - val_loss: 0.4713 - val_mae: 0.5081 - val_rmse: 0.6430 - val_smape: 1.2575
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
metricasGRU = modelGRU.evaluate(valGRUX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasGRU}")
# Out:
# 136/136 - 0s - 3ms/step - ia: 0.2702 - loss: 0.7872 - mae: 0.6716 - rmse: 0.7564 - smape: 1.2739
# Métricas en el conjunto de validación: [0.7872355580329895, 0.6716330647468567, 1.2738629579544067, 0.7563810348510742, 0.2702190577983856]

# %%
historyGRU = historyGRU.history

ejeXGRU = range(1, len(historyGRU['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXGRU, historyGRU['loss'], label='Train Loss')
plt.plot(ejeXGRU, historyGRU['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyGRU['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyGRU['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.8458622097969055
# Último valor de Test Loss: 0.4712826907634735

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionGRU.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfGRU = df
fig.show()

# %%
dfGRU.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacionNarmax\\24pasos_gru_pollution.csv', index=True)

# %%
modelGRU.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarmax\\24pasos_gru_pollution.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
