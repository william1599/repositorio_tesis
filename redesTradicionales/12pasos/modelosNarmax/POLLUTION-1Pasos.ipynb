# %% [markdown]
# Prueba

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from hyperopt import hp, fmin, tpe, Trials, STATUS_OK
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU, InputLayer, Flatten, LSTM
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import os
from datetime import datetime, timedelta
import plotly.express as px
import plotly.graph_objects as go
import random

# %% [markdown]
# LEER DATASET

# %%
import pandas as pd

datosMLP = pd.read_csv("C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\1pasos_mlp_pollution.csv")
datosLSTM = pd.read_csv("C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\1pasos_lstm_pollution.csv")
datosGRU = pd.read_csv("C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\1pasos_gru_pollution.csv")

datosMLP['date'] = pd.to_datetime(datosMLP['date'])
datosLSTM['date'] = pd.to_datetime(datosLSTM['date'])
datosGRU['date'] = pd.to_datetime(datosGRU['date'])

# Se establece la columna date como index
datosMLP.set_index('date', inplace=True)
datosLSTM.set_index('date', inplace=True)
datosGRU.set_index('date', inplace=True)

# %%
datosMLP.tail()
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2014-12-31 19:00:00  -1.009952 -1.702068 -1.106944  1.679851  0.694538
# 2014-12-31 20:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 21:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 22:00:00  -1.009952 -1.632347 -1.268524  1.679851  0.694538
# 2014-12-31 23:00:00  -0.966063 -1.562627 -1.187734  1.679851  0.694538
#
#                       wnd_spd         e
# date
# 2014-12-31 19:00:00  4.054828 -0.056149
# 2014-12-31 20:00:00  4.168890  0.005569
# 2014-12-31 21:00:00  4.265479 -0.029062
# 2014-12-31 22:00:00  4.344399 -0.035766
# 2014-12-31 23:00:00  4.405847  0.032112

# %%
datosLSTM.tail()
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2014-12-31 19:00:00  -1.009952 -1.702068 -1.106944  1.679851  0.694538
# 2014-12-31 20:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 21:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 22:00:00  -1.009952 -1.632347 -1.268524  1.679851  0.694538
# 2014-12-31 23:00:00  -0.966063 -1.562627 -1.187734  1.679851  0.694538
#
#                       wnd_spd         e
# date
# 2014-12-31 19:00:00  4.054828 -0.017564
# 2014-12-31 20:00:00  4.168890  0.038002
# 2014-12-31 21:00:00  4.265479  0.018046
# 2014-12-31 22:00:00  4.344399 -0.007399
# 2014-12-31 23:00:00  4.405847  0.049547

# %%
datosGRU.tail()
# Out:
#                      pollution       dew      temp     press   wnd_dir  \
# date
# 2014-12-31 19:00:00  -1.009952 -1.702068 -1.106944  1.679851  0.694538
# 2014-12-31 20:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 21:00:00  -0.988008 -1.632347 -1.187734  1.679851  0.694538
# 2014-12-31 22:00:00  -1.009952 -1.632347 -1.268524  1.679851  0.694538
# 2014-12-31 23:00:00  -0.966063 -1.562627 -1.187734  1.679851  0.694538
#
#                       wnd_spd         e
# date
# 2014-12-31 19:00:00  4.054828 -0.032836
# 2014-12-31 20:00:00  4.168890  0.021897
# 2014-12-31 21:00:00  4.265479 -0.001082
# 2014-12-31 22:00:00  4.344399 -0.021268
# 2014-12-31 23:00:00  4.405847  0.039714

# %%
#Se verifica que el index está en formato de dato "datetime64"
print("El index del dataframe MLP input es un tipo de dato: ", datosMLP.index.dtype)
print("El index del dataframe LSTM input es un tipo de dato: ", datosLSTM.index.dtype)
print("El index del dataframe GRU input es un tipo de dato: ", datosGRU.index.dtype)
# Out:
# El index del dataframe MLP input es un tipo de dato:  datetime64[ns]
# El index del dataframe LSTM input es un tipo de dato:  datetime64[ns]
# El index del dataframe GRU input es un tipo de dato:  datetime64[ns]

# %% [markdown]
# Se establece el formato de datos de entrada para redes GRU y LSTM, es decir [observaciones, retardos, caracteristicas]

# %%
futuros = 1
pasados  = 12

# %%
datosMLPX = []
datosMLPY = []
for i in range(pasados, len(datosMLP) - futuros + 1):
  datosMLPX.append(datosMLP.iloc[i-pasados:i, 0:datosMLP.shape[1]])
  datosMLPY.append(datosMLP.iloc[i+futuros-1:i+futuros, 0])

# %%
datosLSTMX = []
datosLSTMY = []
for i in range(pasados, len(datosLSTM) - futuros + 1):
  datosLSTMX.append(datosLSTM.iloc[i-pasados:i, 0:datosLSTM.shape[1]])
  datosLSTMY.append(datosLSTM.iloc[i+futuros-1:i+futuros, 0])

# %%
datosGRUX = []
datosGRUY = []
for i in range(pasados, len(datosGRU) - futuros + 1):
  datosGRUX.append(datosGRU.iloc[i-pasados:i, 0:datosGRU.shape[1]])
  datosGRUY.append(datosGRU.iloc[i+futuros-1:i+futuros, 0])

# %%
# Convertir las listas en arrays numpy
datosMLPX = np.array(datosMLPX)
datosMLPY = np.array(datosMLPY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de MLP X:", datosMLPX.shape)  
print("Dimensiones de MLP Y:", datosMLPY.shape)
# Out:
# Dimensiones de MLP X: (43788, 12, 7)
# Dimensiones de MLP Y: (43788, 1)

# %%
# Convertir las listas en arrays numpy
datosLSTMX = np.array(datosLSTMX)
datosLSTMY = np.array(datosLSTMY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de LSTM X:", datosLSTMX.shape)  
print("Dimensiones de LSTM Y:", datosLSTMY.shape)
# Out:
# Dimensiones de LSTM X: (43788, 12, 7)
# Dimensiones de LSTM Y: (43788, 1)

# %%
# Convertir las listas en arrays numpy
datosGRUX = np.array(datosGRUX)
datosGRUY = np.array(datosGRUY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de GRU X:", datosGRUX.shape)  
print("Dimensiones de GRU Y:", datosGRUY.shape)
# Out:
# Dimensiones de GRU X: (43788, 12, 7)
# Dimensiones de GRU Y: (43788, 1)

# %%
inputs = datosMLPX.shape[1] * datosMLPX.shape[2]
datosMLPX = datosMLPX.reshape(datosMLPX.shape[0], inputs)

# %%
datosMLPX
# Out:
# array([[ 3.17680987e-01, -1.21402290e+00, -1.26852411e+00, ...,
#         -3.80943830e-01, -9.55565742e-02,             nan],
#        [ 5.26152265e-01, -1.14430217e+00, -1.26852411e+00, ...,
#         -3.80943830e-01, -3.41086545e-02,  4.33933430e-04],
#        [ 6.46846163e-01, -8.65419279e-01, -1.34931411e+00, ...,
#         -3.80943830e-01,  4.48116768e-02,  2.38536586e-01],
#        ...,
#        [-1.00995189e+00, -1.63234723e+00, -1.18773412e+00, ...,
#          6.94538475e-01,  4.16888979e+00,  5.56898183e-03],
#        [-1.02092406e+00, -1.63234723e+00, -1.10694413e+00, ...,
#          6.94538475e-01,  4.26547885e+00, -2.90622705e-02],
#        [-9.66063200e-01, -1.63234723e+00, -1.10694413e+00, ...,
#          6.94538475e-01,  4.34439918e+00, -3.57658271e-02]])

# %% [markdown]
# Se dividen nuevamente los conjuntos de datos

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainMLPX, testMLPX = train_test_split(datosMLPX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testMLPX, valMLPX = train_test_split(testMLPX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainMLPX son: ", trainMLPX.shape)
print("Las dimensiones de testMLPX son: ", testMLPX.shape)
print("Las dimensiones de valMLPX son: ", valMLPX.shape)
# Out:
# Las dimensiones de trainMLPX son:  (30651, 84)
# Las dimensiones de testMLPX son:  (8801, 84)
# Las dimensiones de valMLPX son:  (4336, 84)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainLSTMX, testLSTMX = train_test_split(datosLSTMX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testLSTMX, valLSTMX = train_test_split(testLSTMX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainLSTMX son: ", trainLSTMX.shape)
print("Las dimensiones de testLSTMX son: ", testLSTMX.shape)
print("Las dimensiones de valLSTMX son: ", valLSTMX.shape)
# Out:
# Las dimensiones de trainLSTMX son:  (30651, 12, 7)
# Las dimensiones de testLSTMX son:  (8801, 12, 7)
# Las dimensiones de valLSTMX son:  (4336, 12, 7)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainGRUX, testGRUX = train_test_split(datosGRUX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testGRUX, valGRUX = train_test_split(testGRUX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainGRUX son: ", trainGRUX.shape)
print("Las dimensiones de testGRUX son: ", testGRUX.shape)
print("Las dimensiones de valGRUX son: ", valGRUX.shape)
# Out:
# Las dimensiones de trainGRUX son:  (30651, 12, 7)
# Las dimensiones de testGRUX son:  (8801, 12, 7)
# Las dimensiones de valGRUX son:  (4336, 12, 7)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainY, testY = train_test_split(datosMLPY, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testY, valY = train_test_split(testY, test_size=0.33, shuffle=False)

print("Las dimensiones de trainY son: ", trainY.shape)
print("Las dimensiones de testY son: ", testY.shape)
print("Las dimensiones de valY son: ", valY.shape)
# Out:
# Las dimensiones de trainY son:  (30651, 1)
# Las dimensiones de testY son:  (8801, 1)
# Las dimensiones de valY son:  (4336, 1)

# %% [markdown]
# Se crean métricas para medir desempeño

# %%
import tensorflow.keras.backend as K

def smape(y_true, y_pred):
    """
    Define la función SMAPE (Error Porcentual Absoluto Medio Simétrico).
    """
    summ = K.abs(y_true) + K.abs(y_pred)
    smape_val = K.abs(y_pred - y_true) / summ * 2.0
    return K.mean(smape_val, axis=-1)

def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

def ia(y_true, y_pred):
    numerator = K.sum(K.abs(y_true - y_pred))
    denominator = K.sum(K.abs(y_true - K.mean(y_true)) + K.abs(y_pred - K.mean(y_true)))
    return 1 - (numerator / denominator)

# %% [markdown]
# Se define el index del conjunto de validación para utilizarlo posteriormente para graficar.

# %%
# Fecha y hora de término del conjunto de datos de prueba
end_date = datosMLP.index[-1]
n_observations = valY.shape[0]  # Cambia esto al número de observaciones en tu conjunto de prueba

# Calcular la fecha y hora de inicio
start_date = end_date - timedelta(hours = (n_observations - 1))

# Crear la serie de fechas y horas
val_date = pd.date_range(start=start_date, end=end_date, freq='1H')

val_date
# Out:
# C:\Users\wamt1\AppData\Local\Temp\ipykernel_19432\196214621.py:9: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   val_date = pd.date_range(start=start_date, end=end_date, freq='1H')
# DatetimeIndex(['2014-07-04 08:00:00', '2014-07-04 09:00:00',
#                '2014-07-04 10:00:00', '2014-07-04 11:00:00',
#                '2014-07-04 12:00:00', '2014-07-04 13:00:00',
#                '2014-07-04 14:00:00', '2014-07-04 15:00:00',
#                '2014-07-04 16:00:00', '2014-07-04 17:00:00',
#                ...
#                '2014-12-31 14:00:00', '2014-12-31 15:00:00',
#                '2014-12-31 16:00:00', '2014-12-31 17:00:00',
#                '2014-12-31 18:00:00', '2014-12-31 19:00:00',
#                '2014-12-31 20:00:00', '2014-12-31 21:00:00',
#                '2014-12-31 22:00:00', '2014-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=4336, freq='h')

# %% [markdown]
# Se guardan los índices de las observaciones a utilizar para predecir

# %%
indices = []
for i in range(pasados, len(datosMLP) - futuros + 1):
  indices.append(datosMLP.index[i+futuros-2])

# %% [markdown]
# # Modelos

# %% [markdown]
# ## MLP

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelMLP = Sequential()
modelMLP.add(InputLayer(input_shape=(testMLPX.shape[1],)))

modelMLP.add(Dense(units=128, activation="linear"))
modelMLP.add(Dropout(0.0))

modelMLP.add(Dense(units=128, activation="linear"))
modelMLP.add(Dropout(0.0))

modelMLP.add(Dense(units=128, activation="linear"))
modelMLP.add(Dropout(0.0))

modelMLP.add(Dense(units=128, activation="linear"))
modelMLP.add(Dropout(0.0))

modelMLP.add(Dense(1))

opt = Adam(learning_rate=0.00027101707182655693)

modelMLP.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelMLP.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │        10,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 60,545 (236.50 KB)
#  Trainable params: 60,545 (236.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyMLP = modelMLP.fit(testMLPX, testY, epochs=128,
                        validation_split=0.3,
                        verbose = 2, batch_size=16, callbacks=[early_stopping])

prediccionMLP = modelMLP.predict(valMLPX)
# Out:
# Epoch 1/128
# 385/385 - 4s - 10ms/step - ia: 0.8353 - loss: 0.1504 - mae: 0.2339 - rmse: 0.3231 - smape: 0.4884 - val_ia: 0.6096 - val_loss: 0.0678 - val_mae: 0.1526 - val_rmse: 0.2039 - val_smape: 0.4673
# Epoch 2/128
# 385/385 - 1s - 3ms/step - ia: 0.8697 - loss: 0.0789 - mae: 0.1841 - rmse: 0.2589 - smape: 0.4210 - val_ia: 0.6155 - val_loss: 0.0669 - val_mae: 0.1502 - val_rmse: 0.2001 - val_smape: 0.4620
# Epoch 3/128
# 385/385 - 1s - 3ms/step - ia: 0.8740 - loss: 0.0749 - mae: 0.1778 - rmse: 0.2515 - smape: 0.4086 - val_ia: 0.6112 - val_loss: 0.0679 - val_mae: 0.1525 - val_rmse: 0.2027 - val_smape: 0.4657
# Epoch 4/128
# 385/385 - 1s - 3ms/step - ia: 0.8763 - loss: 0.0730 - mae: 0.1744 - rmse: 0.2478 - smape: 0.3994 - val_ia: 0.6125 - val_loss: 0.0677 - val_mae: 0.1518 - val_rmse: 0.2022 - val_smape: 0.4643
# Epoch 5/128
# 385/385 - 1s - 3ms/step - ia: 0.8798 - loss: 0.0702 - mae: 0.1697 - rmse: 0.2423 - smape: 0.3924 - val_ia: 0.6121 - val_loss: 0.0674 - val_mae: 0.1516 - val_rmse: 0.2014 - val_smape: 0.4655
# Epoch 6/128
# 385/385 - 1s - 3ms/step - ia: 0.8825 - loss: 0.0682 - mae: 0.1662 - rmse: 0.2385 - smape: 0.3868 - val_ia: 0.6110 - val_loss: 0.0672 - val_mae: 0.1516 - val_rmse: 0.2011 - val_smape: 0.4653
# Epoch 7/128
# 385/385 - 1s - 3ms/step - ia: 0.8843 - loss: 0.0670 - mae: 0.1640 - rmse: 0.2362 - smape: 0.3826 - val_ia: 0.6098 - val_loss: 0.0671 - val_mae: 0.1518 - val_rmse: 0.2011 - val_smape: 0.4662
# Epoch 8/128
# 385/385 - 1s - 3ms/step - ia: 0.8856 - loss: 0.0662 - mae: 0.1622 - rmse: 0.2345 - smape: 0.3790 - val_ia: 0.6095 - val_loss: 0.0669 - val_mae: 0.1515 - val_rmse: 0.2007 - val_smape: 0.4659
# Epoch 9/128
# 385/385 - 1s - 3ms/step - ia: 0.8867 - loss: 0.0655 - mae: 0.1608 - rmse: 0.2331 - smape: 0.3760 - val_ia: 0.6103 - val_loss: 0.0665 - val_mae: 0.1507 - val_rmse: 0.1998 - val_smape: 0.4639
# Epoch 10/128
# 385/385 - 1s - 4ms/step - ia: 0.8876 - loss: 0.0650 - mae: 0.1596 - rmse: 0.2320 - smape: 0.3735 - val_ia: 0.6118 - val_loss: 0.0660 - val_mae: 0.1496 - val_rmse: 0.1987 - val_smape: 0.4613
# Epoch 11/128
# 385/385 - 1s - 3ms/step - ia: 0.8883 - loss: 0.0645 - mae: 0.1586 - rmse: 0.2310 - smape: 0.3711 - val_ia: 0.6139 - val_loss: 0.0655 - val_mae: 0.1484 - val_rmse: 0.1974 - val_smape: 0.4590
# Epoch 12/128
# 385/385 - 1s - 3ms/step - ia: 0.8890 - loss: 0.0642 - mae: 0.1577 - rmse: 0.2302 - smape: 0.3692 - val_ia: 0.6162 - val_loss: 0.0649 - val_mae: 0.1473 - val_rmse: 0.1962 - val_smape: 0.4575
# Epoch 13/128
# 385/385 - 1s - 3ms/step - ia: 0.8896 - loss: 0.0638 - mae: 0.1568 - rmse: 0.2294 - smape: 0.3676 - val_ia: 0.6184 - val_loss: 0.0645 - val_mae: 0.1463 - val_rmse: 0.1950 - val_smape: 0.4554
# Epoch 14/128
# 385/385 - 2s - 4ms/step - ia: 0.8902 - loss: 0.0635 - mae: 0.1560 - rmse: 0.2286 - smape: 0.3659 - val_ia: 0.6203 - val_loss: 0.0640 - val_mae: 0.1454 - val_rmse: 0.1940 - val_smape: 0.4534
# Epoch 15/128
# 385/385 - 1s - 3ms/step - ia: 0.8907 - loss: 0.0631 - mae: 0.1552 - rmse: 0.2278 - smape: 0.3639 - val_ia: 0.6218 - val_loss: 0.0637 - val_mae: 0.1447 - val_rmse: 0.1931 - val_smape: 0.4518
# Epoch 16/128
# 385/385 - 1s - 3ms/step - ia: 0.8913 - loss: 0.0628 - mae: 0.1545 - rmse: 0.2271 - smape: 0.3625 - val_ia: 0.6230 - val_loss: 0.0635 - val_mae: 0.1442 - val_rmse: 0.1924 - val_smape: 0.4508
# Epoch 17/128
# 385/385 - 2s - 4ms/step - ia: 0.8917 - loss: 0.0624 - mae: 0.1539 - rmse: 0.2264 - smape: 0.3614 - val_ia: 0.6241 - val_loss: 0.0633 - val_mae: 0.1436 - val_rmse: 0.1919 - val_smape: 0.4498
# Epoch 18/128
# 385/385 - 1s - 3ms/step - ia: 0.8922 - loss: 0.0622 - mae: 0.1533 - rmse: 0.2257 - smape: 0.3607 - val_ia: 0.6254 - val_loss: 0.0631 - val_mae: 0.1431 - val_rmse: 0.1913 - val_smape: 0.4485
# Epoch 19/128
# 385/385 - 1s - 3ms/step - ia: 0.8926 - loss: 0.0619 - mae: 0.1528 - rmse: 0.2251 - smape: 0.3599 - val_ia: 0.6268 - val_loss: 0.0628 - val_mae: 0.1423 - val_rmse: 0.1905 - val_smape: 0.4466
# Epoch 20/128
# 385/385 - 1s - 3ms/step - ia: 0.8929 - loss: 0.0617 - mae: 0.1524 - rmse: 0.2246 - smape: 0.3592 - val_ia: 0.6286 - val_loss: 0.0625 - val_mae: 0.1414 - val_rmse: 0.1897 - val_smape: 0.4439
# Epoch 21/128
# 385/385 - 1s - 3ms/step - ia: 0.8932 - loss: 0.0614 - mae: 0.1520 - rmse: 0.2241 - smape: 0.3586 - val_ia: 0.6300 - val_loss: 0.0623 - val_mae: 0.1405 - val_rmse: 0.1889 - val_smape: 0.4412
# Epoch 22/128
# 385/385 - 1s - 3ms/step - ia: 0.8935 - loss: 0.0612 - mae: 0.1517 - rmse: 0.2237 - smape: 0.3580 - val_ia: 0.6306 - val_loss: 0.0621 - val_mae: 0.1399 - val_rmse: 0.1883 - val_smape: 0.4397
# Epoch 23/128
# 385/385 - 1s - 3ms/step - ia: 0.8937 - loss: 0.0610 - mae: 0.1514 - rmse: 0.2234 - smape: 0.3575 - val_ia: 0.6308 - val_loss: 0.0619 - val_mae: 0.1396 - val_rmse: 0.1880 - val_smape: 0.4388
# Epoch 24/128
# 385/385 - 1s - 3ms/step - ia: 0.8939 - loss: 0.0608 - mae: 0.1511 - rmse: 0.2230 - smape: 0.3568 - val_ia: 0.6307 - val_loss: 0.0619 - val_mae: 0.1395 - val_rmse: 0.1878 - val_smape: 0.4385
# Epoch 25/128
# 385/385 - 1s - 3ms/step - ia: 0.8942 - loss: 0.0606 - mae: 0.1508 - rmse: 0.2226 - smape: 0.3558 - val_ia: 0.6298 - val_loss: 0.0621 - val_mae: 0.1398 - val_rmse: 0.1881 - val_smape: 0.4396
# Epoch 26/128
# 385/385 - 1s - 3ms/step - ia: 0.8945 - loss: 0.0605 - mae: 0.1505 - rmse: 0.2222 - smape: 0.3553 - val_ia: 0.6286 - val_loss: 0.0623 - val_mae: 0.1403 - val_rmse: 0.1886 - val_smape: 0.4410
# Epoch 27/128
# 385/385 - 1s - 4ms/step - ia: 0.8946 - loss: 0.0603 - mae: 0.1503 - rmse: 0.2220 - smape: 0.3547 - val_ia: 0.6292 - val_loss: 0.0622 - val_mae: 0.1402 - val_rmse: 0.1883 - val_smape: 0.4409
# Epoch 28/128
# 385/385 - 1s - 3ms/step - ia: 0.8948 - loss: 0.0602 - mae: 0.1501 - rmse: 0.2217 - smape: 0.3540 - val_ia: 0.6308 - val_loss: 0.0619 - val_mae: 0.1396 - val_rmse: 0.1877 - val_smape: 0.4396
# Epoch 29/128
# 385/385 - 1s - 3ms/step - ia: 0.8950 - loss: 0.0601 - mae: 0.1498 - rmse: 0.2213 - smape: 0.3535 - val_ia: 0.6316 - val_loss: 0.0618 - val_mae: 0.1392 - val_rmse: 0.1873 - val_smape: 0.4384
# Epoch 30/128
# 385/385 - 1s - 4ms/step - ia: 0.8952 - loss: 0.0599 - mae: 0.1495 - rmse: 0.2209 - smape: 0.3527 - val_ia: 0.6321 - val_loss: 0.0617 - val_mae: 0.1389 - val_rmse: 0.1871 - val_smape: 0.4374
# Epoch 31/128
# 385/385 - 1s - 3ms/step - ia: 0.8955 - loss: 0.0597 - mae: 0.1492 - rmse: 0.2205 - smape: 0.3516 - val_ia: 0.6327 - val_loss: 0.0615 - val_mae: 0.1384 - val_rmse: 0.1867 - val_smape: 0.4357
# Epoch 32/128
# 385/385 - 1s - 4ms/step - ia: 0.8957 - loss: 0.0596 - mae: 0.1489 - rmse: 0.2202 - smape: 0.3506 - val_ia: 0.6338 - val_loss: 0.0614 - val_mae: 0.1379 - val_rmse: 0.1864 - val_smape: 0.4350
# Epoch 33/128
# 385/385 - 1s - 3ms/step - ia: 0.8958 - loss: 0.0595 - mae: 0.1487 - rmse: 0.2201 - smape: 0.3504 - val_ia: 0.6361 - val_loss: 0.0612 - val_mae: 0.1372 - val_rmse: 0.1856 - val_smape: 0.4339
# Epoch 34/128
# 385/385 - 1s - 3ms/step - ia: 0.8959 - loss: 0.0594 - mae: 0.1486 - rmse: 0.2198 - smape: 0.3504 - val_ia: 0.6390 - val_loss: 0.0609 - val_mae: 0.1363 - val_rmse: 0.1845 - val_smape: 0.4316
# Epoch 35/128
# 385/385 - 1s - 4ms/step - ia: 0.8960 - loss: 0.0593 - mae: 0.1484 - rmse: 0.2196 - smape: 0.3504 - val_ia: 0.6409 - val_loss: 0.0607 - val_mae: 0.1354 - val_rmse: 0.1839 - val_smape: 0.4284
# Epoch 36/128
# 385/385 - 1s - 3ms/step - ia: 0.8962 - loss: 0.0593 - mae: 0.1481 - rmse: 0.2194 - smape: 0.3503 - val_ia: 0.6416 - val_loss: 0.0607 - val_mae: 0.1350 - val_rmse: 0.1837 - val_smape: 0.4278
# Epoch 37/128
# 385/385 - 1s - 3ms/step - ia: 0.8963 - loss: 0.0592 - mae: 0.1480 - rmse: 0.2192 - smape: 0.3502 - val_ia: 0.6428 - val_loss: 0.0606 - val_mae: 0.1347 - val_rmse: 0.1833 - val_smape: 0.4280
# Epoch 38/128
# 385/385 - 1s - 3ms/step - ia: 0.8965 - loss: 0.0591 - mae: 0.1478 - rmse: 0.2190 - smape: 0.3495 - val_ia: 0.6437 - val_loss: 0.0604 - val_mae: 0.1343 - val_rmse: 0.1828 - val_smape: 0.4275
# Epoch 39/128
# 385/385 - 1s - 3ms/step - ia: 0.8966 - loss: 0.0589 - mae: 0.1476 - rmse: 0.2187 - smape: 0.3483 - val_ia: 0.6429 - val_loss: 0.0604 - val_mae: 0.1344 - val_rmse: 0.1830 - val_smape: 0.4275
# Epoch 40/128
# 385/385 - 1s - 4ms/step - ia: 0.8968 - loss: 0.0588 - mae: 0.1474 - rmse: 0.2185 - smape: 0.3476 - val_ia: 0.6425 - val_loss: 0.0605 - val_mae: 0.1345 - val_rmse: 0.1830 - val_smape: 0.4276
# Epoch 41/128
# 385/385 - 1s - 3ms/step - ia: 0.8969 - loss: 0.0587 - mae: 0.1473 - rmse: 0.2183 - smape: 0.3475 - val_ia: 0.6424 - val_loss: 0.0606 - val_mae: 0.1347 - val_rmse: 0.1830 - val_smape: 0.4278
# Epoch 42/128
# 385/385 - 2s - 4ms/step - ia: 0.8970 - loss: 0.0587 - mae: 0.1472 - rmse: 0.2183 - smape: 0.3476 - val_ia: 0.6420 - val_loss: 0.0607 - val_mae: 0.1350 - val_rmse: 0.1832 - val_smape: 0.4286
# Epoch 43/128
# 385/385 - 1s - 3ms/step - ia: 0.8970 - loss: 0.0587 - mae: 0.1472 - rmse: 0.2183 - smape: 0.3478 - val_ia: 0.6415 - val_loss: 0.0607 - val_mae: 0.1352 - val_rmse: 0.1834 - val_smape: 0.4294
# Epoch 44/128
# 385/385 - 1s - 3ms/step - ia: 0.8971 - loss: 0.0587 - mae: 0.1471 - rmse: 0.2182 - smape: 0.3479 - val_ia: 0.6410 - val_loss: 0.0608 - val_mae: 0.1353 - val_rmse: 0.1838 - val_smape: 0.4300
# Epoch 45/128
# 385/385 - 1s - 3ms/step - ia: 0.8972 - loss: 0.0585 - mae: 0.1470 - rmse: 0.2180 - smape: 0.3478 - val_ia: 0.6403 - val_loss: 0.0610 - val_mae: 0.1355 - val_rmse: 0.1843 - val_smape: 0.4295
# Epoch 46/128
# 385/385 - 1s - 3ms/step - ia: 0.8973 - loss: 0.0585 - mae: 0.1467 - rmse: 0.2178 - smape: 0.3475 - val_ia: 0.6424 - val_loss: 0.0609 - val_mae: 0.1349 - val_rmse: 0.1838 - val_smape: 0.4280
# Epoch 47/128
# 385/385 - 1s - 3ms/step - ia: 0.8975 - loss: 0.0585 - mae: 0.1465 - rmse: 0.2176 - smape: 0.3468 - val_ia: 0.6456 - val_loss: 0.0604 - val_mae: 0.1337 - val_rmse: 0.1826 - val_smape: 0.4251
# Epoch 48/128
# 385/385 - 1s - 3ms/step - ia: 0.8977 - loss: 0.0584 - mae: 0.1463 - rmse: 0.2174 - smape: 0.3461 - val_ia: 0.6456 - val_loss: 0.0603 - val_mae: 0.1334 - val_rmse: 0.1824 - val_smape: 0.4242
# Epoch 49/128
# 385/385 - 1s - 3ms/step - ia: 0.8977 - loss: 0.0583 - mae: 0.1462 - rmse: 0.2171 - smape: 0.3458 - val_ia: 0.6439 - val_loss: 0.0605 - val_mae: 0.1339 - val_rmse: 0.1829 - val_smape: 0.4255
# Epoch 50/128
# 385/385 - 1s - 3ms/step - ia: 0.8978 - loss: 0.0582 - mae: 0.1461 - rmse: 0.2171 - smape: 0.3455 - val_ia: 0.6432 - val_loss: 0.0607 - val_mae: 0.1343 - val_rmse: 0.1831 - val_smape: 0.4265
# Epoch 51/128
# 385/385 - 1s - 3ms/step - ia: 0.8978 - loss: 0.0582 - mae: 0.1461 - rmse: 0.2171 - smape: 0.3456 - val_ia: 0.6432 - val_loss: 0.0608 - val_mae: 0.1344 - val_rmse: 0.1832 - val_smape: 0.4265
# Epoch 52/128
# 385/385 - 1s - 3ms/step - ia: 0.8979 - loss: 0.0581 - mae: 0.1460 - rmse: 0.2170 - smape: 0.3458 - val_ia: 0.6424 - val_loss: 0.0608 - val_mae: 0.1345 - val_rmse: 0.1834 - val_smape: 0.4265
# Epoch 53/128
# 385/385 - 1s - 3ms/step - ia: 0.8979 - loss: 0.0581 - mae: 0.1460 - rmse: 0.2169 - smape: 0.3459 - val_ia: 0.6417 - val_loss: 0.0608 - val_mae: 0.1347 - val_rmse: 0.1836 - val_smape: 0.4269
# Epoch 54/128
# 385/385 - 1s - 3ms/step - ia: 0.8979 - loss: 0.0580 - mae: 0.1458 - rmse: 0.2168 - smape: 0.3458 - val_ia: 0.6420 - val_loss: 0.0608 - val_mae: 0.1346 - val_rmse: 0.1836 - val_smape: 0.4266
# Epoch 55/128
# 385/385 - 1s - 3ms/step - ia: 0.8981 - loss: 0.0580 - mae: 0.1456 - rmse: 0.2166 - smape: 0.3457 - val_ia: 0.6428 - val_loss: 0.0608 - val_mae: 0.1343 - val_rmse: 0.1835 - val_smape: 0.4259
# Epoch 56/128
# 385/385 - 1s - 3ms/step - ia: 0.8982 - loss: 0.0579 - mae: 0.1455 - rmse: 0.2164 - smape: 0.3457 - val_ia: 0.6439 - val_loss: 0.0607 - val_mae: 0.1339 - val_rmse: 0.1834 - val_smape: 0.4248
# Epoch 57/128
# 385/385 - 1s - 3ms/step - ia: 0.8983 - loss: 0.0579 - mae: 0.1454 - rmse: 0.2163 - smape: 0.3457 - val_ia: 0.6440 - val_loss: 0.0608 - val_mae: 0.1339 - val_rmse: 0.1835 - val_smape: 0.4245
# Epoch 58/128
# 385/385 - 1s - 3ms/step - ia: 0.8984 - loss: 0.0578 - mae: 0.1453 - rmse: 0.2162 - smape: 0.3455 - val_ia: 0.6438 - val_loss: 0.0609 - val_mae: 0.1340 - val_rmse: 0.1836 - val_smape: 0.4247
# Epoch 59/128
# 385/385 - 1s - 3ms/step - ia: 0.8984 - loss: 0.0578 - mae: 0.1452 - rmse: 0.2161 - smape: 0.3450 - val_ia: 0.6449 - val_loss: 0.0608 - val_mae: 0.1337 - val_rmse: 0.1833 - val_smape: 0.4233
# Epoch 60/128
# 385/385 - 2s - 4ms/step - ia: 0.8985 - loss: 0.0578 - mae: 0.1451 - rmse: 0.2160 - smape: 0.3446 - val_ia: 0.6461 - val_loss: 0.0607 - val_mae: 0.1332 - val_rmse: 0.1829 - val_smape: 0.4225
# Epoch 61/128
# 385/385 - 1s - 3ms/step - ia: 0.8986 - loss: 0.0577 - mae: 0.1450 - rmse: 0.2159 - smape: 0.3447 - val_ia: 0.6467 - val_loss: 0.0606 - val_mae: 0.1330 - val_rmse: 0.1826 - val_smape: 0.4221
# Epoch 62/128
# 385/385 - 2s - 4ms/step - ia: 0.8987 - loss: 0.0577 - mae: 0.1448 - rmse: 0.2159 - smape: 0.3443 - val_ia: 0.6491 - val_loss: 0.0604 - val_mae: 0.1323 - val_rmse: 0.1819 - val_smape: 0.4205
# Epoch 63/128
# 385/385 - 1s - 3ms/step - ia: 0.8988 - loss: 0.0577 - mae: 0.1447 - rmse: 0.2157 - smape: 0.3438 - val_ia: 0.6495 - val_loss: 0.0604 - val_mae: 0.1322 - val_rmse: 0.1821 - val_smape: 0.4192
# Epoch 63: early stopping
# Restoring model weights from the end of the best epoch: 48.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
metricasMLP = modelMLP.evaluate(valMLPX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasMLP}")
# Out:
# 136/136 - 0s - 2ms/step - ia: 0.7577 - loss: 0.0397 - mae: 0.1242 - rmse: 0.1768 - smape: 0.3303
# Métricas en el conjunto de validación: [0.03969357907772064, 0.12421901524066925, 0.33030965924263, 0.17680342495441437, 0.7576895356178284]

# %%
historyMLP = historyMLP.history

ejeXMLP = range(1, len(historyMLP['loss']) + 1)

plt.figure(figsize=(12, 8))
plt.plot(ejeXMLP, historyMLP['loss'], label='Train Loss')
plt.plot(ejeXMLP, historyMLP['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyMLP['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyMLP['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.05768067017197609
# Último valor de Test Loss: 0.06039160490036011

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionMLP.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfMLP = df
fig.show()

# %%
dfMLP.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacionNarmax\\1pasos_mlp_pollution.csv', index=True)

# %%
modelMLP.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarmax\\1pasos_mlp_pollution.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## LSTM

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelLSTM = Sequential()
modelLSTM.add(InputLayer(input_shape=(testLSTMX.shape[1], testLSTMX.shape[2])))

modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=True))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=True))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=True))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=False))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(Dense(1))


opt = Adam(learning_rate=0.00027101707182655693)
modelLSTM.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelLSTM.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 12, 128)        │        69,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 12, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 12, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 464,513 (1.77 MB)
#  Trainable params: 464,513 (1.77 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyLSTM = modelLSTM.fit(testLSTMX, testY, epochs=128,
                        validation_split=0.3,
                        verbose = 2, batch_size=16, callbacks=[early_stopping])

prediccionLSTM = modelLSTM.predict(valLSTMX)
# Out:
# Epoch 1/128
# 385/385 - 14s - 37ms/step - ia: 0.6657 - loss: 0.3939 - mae: 0.4288 - rmse: 0.5907 - smape: 0.8348 - val_ia: 0.3112 - val_loss: 0.1867 - val_mae: 0.3214 - val_rmse: 0.3837 - val_smape: 0.8533
# Epoch 2/128
# 385/385 - 11s - 28ms/step - ia: 0.7957 - loss: 0.1657 - mae: 0.2749 - rmse: 0.3800 - smape: 0.6003 - val_ia: 0.4539 - val_loss: 0.0997 - val_mae: 0.2192 - val_rmse: 0.2767 - val_smape: 0.6425
# Epoch 3/128
# 385/385 - 10s - 25ms/step - ia: 0.8572 - loss: 0.0947 - mae: 0.1985 - rmse: 0.2815 - smape: 0.4583 - val_ia: 0.5820 - val_loss: 0.0674 - val_mae: 0.1617 - val_rmse: 0.2165 - val_smape: 0.5048
# Epoch 4/128
# 385/385 - 8s - 22ms/step - ia: 0.8836 - loss: 0.0689 - mae: 0.1643 - rmse: 0.2388 - smape: 0.3885 - val_ia: 0.6170 - val_loss: 0.0640 - val_mae: 0.1456 - val_rmse: 0.1993 - val_smape: 0.4635
# Epoch 5/128
# 385/385 - 8s - 20ms/step - ia: 0.8903 - loss: 0.0641 - mae: 0.1553 - rmse: 0.2292 - smape: 0.3701 - val_ia: 0.6286 - val_loss: 0.0624 - val_mae: 0.1404 - val_rmse: 0.1931 - val_smape: 0.4503
# Epoch 6/128
# 385/385 - 8s - 22ms/step - ia: 0.8936 - loss: 0.0620 - mae: 0.1509 - rmse: 0.2248 - smape: 0.3610 - val_ia: 0.6354 - val_loss: 0.0608 - val_mae: 0.1371 - val_rmse: 0.1892 - val_smape: 0.4422
# Epoch 7/128
# 385/385 - 8s - 21ms/step - ia: 0.8958 - loss: 0.0606 - mae: 0.1479 - rmse: 0.2218 - smape: 0.3550 - val_ia: 0.6404 - val_loss: 0.0596 - val_mae: 0.1347 - val_rmse: 0.1863 - val_smape: 0.4366
# Epoch 8/128
# 385/385 - 7s - 19ms/step - ia: 0.8974 - loss: 0.0595 - mae: 0.1458 - rmse: 0.2196 - smape: 0.3509 - val_ia: 0.6442 - val_loss: 0.0589 - val_mae: 0.1329 - val_rmse: 0.1841 - val_smape: 0.4312
# Epoch 9/128
# 385/385 - 8s - 21ms/step - ia: 0.8985 - loss: 0.0587 - mae: 0.1441 - rmse: 0.2178 - smape: 0.3473 - val_ia: 0.6470 - val_loss: 0.0584 - val_mae: 0.1316 - val_rmse: 0.1826 - val_smape: 0.4272
# Epoch 10/128
# 385/385 - 7s - 18ms/step - ia: 0.8994 - loss: 0.0580 - mae: 0.1429 - rmse: 0.2164 - smape: 0.3449 - val_ia: 0.6491 - val_loss: 0.0581 - val_mae: 0.1306 - val_rmse: 0.1814 - val_smape: 0.4243
# Epoch 11/128
# 385/385 - 11s - 30ms/step - ia: 0.9001 - loss: 0.0573 - mae: 0.1419 - rmse: 0.2152 - smape: 0.3432 - val_ia: 0.6507 - val_loss: 0.0579 - val_mae: 0.1298 - val_rmse: 0.1804 - val_smape: 0.4218
# Epoch 12/128
# 385/385 - 6s - 15ms/step - ia: 0.9007 - loss: 0.0567 - mae: 0.1410 - rmse: 0.2140 - smape: 0.3418 - val_ia: 0.6519 - val_loss: 0.0578 - val_mae: 0.1292 - val_rmse: 0.1797 - val_smape: 0.4196
# Epoch 13/128
# 385/385 - 6s - 15ms/step - ia: 0.9012 - loss: 0.0562 - mae: 0.1403 - rmse: 0.2130 - smape: 0.3406 - val_ia: 0.6529 - val_loss: 0.0578 - val_mae: 0.1287 - val_rmse: 0.1791 - val_smape: 0.4178
# Epoch 14/128
# 385/385 - 13s - 34ms/step - ia: 0.9016 - loss: 0.0557 - mae: 0.1397 - rmse: 0.2121 - smape: 0.3397 - val_ia: 0.6540 - val_loss: 0.0577 - val_mae: 0.1283 - val_rmse: 0.1785 - val_smape: 0.4158
# Epoch 15/128
# 385/385 - 7s - 17ms/step - ia: 0.9019 - loss: 0.0552 - mae: 0.1391 - rmse: 0.2112 - smape: 0.3391 - val_ia: 0.6552 - val_loss: 0.0577 - val_mae: 0.1278 - val_rmse: 0.1779 - val_smape: 0.4141
# Epoch 16/128
# 385/385 - 8s - 21ms/step - ia: 0.9023 - loss: 0.0548 - mae: 0.1387 - rmse: 0.2105 - smape: 0.3386 - val_ia: 0.6566 - val_loss: 0.0576 - val_mae: 0.1273 - val_rmse: 0.1772 - val_smape: 0.4124
# Epoch 17/128
# 385/385 - 7s - 17ms/step - ia: 0.9025 - loss: 0.0544 - mae: 0.1383 - rmse: 0.2098 - smape: 0.3381 - val_ia: 0.6583 - val_loss: 0.0575 - val_mae: 0.1268 - val_rmse: 0.1765 - val_smape: 0.4106
# Epoch 18/128
# 385/385 - 9s - 23ms/step - ia: 0.9028 - loss: 0.0540 - mae: 0.1380 - rmse: 0.2092 - smape: 0.3377 - val_ia: 0.6602 - val_loss: 0.0573 - val_mae: 0.1261 - val_rmse: 0.1756 - val_smape: 0.4088
# Epoch 19/128
# 385/385 - 10s - 25ms/step - ia: 0.9030 - loss: 0.0537 - mae: 0.1377 - rmse: 0.2086 - smape: 0.3375 - val_ia: 0.6622 - val_loss: 0.0572 - val_mae: 0.1255 - val_rmse: 0.1748 - val_smape: 0.4072
# Epoch 20/128
# 385/385 - 6s - 15ms/step - ia: 0.9032 - loss: 0.0534 - mae: 0.1374 - rmse: 0.2080 - smape: 0.3371 - val_ia: 0.6643 - val_loss: 0.0570 - val_mae: 0.1249 - val_rmse: 0.1740 - val_smape: 0.4062
# Epoch 21/128
# 385/385 - 9s - 23ms/step - ia: 0.9035 - loss: 0.0531 - mae: 0.1371 - rmse: 0.2075 - smape: 0.3367 - val_ia: 0.6662 - val_loss: 0.0568 - val_mae: 0.1244 - val_rmse: 0.1732 - val_smape: 0.4045
# Epoch 22/128
# 385/385 - 10s - 26ms/step - ia: 0.9037 - loss: 0.0527 - mae: 0.1368 - rmse: 0.2069 - smape: 0.3362 - val_ia: 0.6681 - val_loss: 0.0566 - val_mae: 0.1239 - val_rmse: 0.1725 - val_smape: 0.4032
# Epoch 23/128
# 385/385 - 6s - 16ms/step - ia: 0.9040 - loss: 0.0524 - mae: 0.1365 - rmse: 0.2063 - smape: 0.3358 - val_ia: 0.6698 - val_loss: 0.0564 - val_mae: 0.1235 - val_rmse: 0.1720 - val_smape: 0.4012
# Epoch 24/128
# 385/385 - 6s - 15ms/step - ia: 0.9042 - loss: 0.0521 - mae: 0.1362 - rmse: 0.2057 - smape: 0.3352 - val_ia: 0.6713 - val_loss: 0.0562 - val_mae: 0.1231 - val_rmse: 0.1715 - val_smape: 0.3999
# Epoch 25/128
# 385/385 - 12s - 32ms/step - ia: 0.9045 - loss: 0.0518 - mae: 0.1360 - rmse: 0.2052 - smape: 0.3345 - val_ia: 0.6725 - val_loss: 0.0559 - val_mae: 0.1229 - val_rmse: 0.1711 - val_smape: 0.3985
# Epoch 26/128
# 385/385 - 6s - 17ms/step - ia: 0.9047 - loss: 0.0515 - mae: 0.1357 - rmse: 0.2046 - smape: 0.3339 - val_ia: 0.6734 - val_loss: 0.0557 - val_mae: 0.1227 - val_rmse: 0.1709 - val_smape: 0.3977
# Epoch 27/128
# 385/385 - 12s - 30ms/step - ia: 0.9049 - loss: 0.0511 - mae: 0.1354 - rmse: 0.2040 - smape: 0.3334 - val_ia: 0.6742 - val_loss: 0.0554 - val_mae: 0.1226 - val_rmse: 0.1707 - val_smape: 0.3979
# Epoch 28/128
# 385/385 - 6s - 17ms/step - ia: 0.9052 - loss: 0.0508 - mae: 0.1351 - rmse: 0.2034 - smape: 0.3331 - val_ia: 0.6747 - val_loss: 0.0551 - val_mae: 0.1225 - val_rmse: 0.1706 - val_smape: 0.3971
# Epoch 29/128
# 385/385 - 6s - 15ms/step - ia: 0.9054 - loss: 0.0505 - mae: 0.1348 - rmse: 0.2028 - smape: 0.3326 - val_ia: 0.6748 - val_loss: 0.0549 - val_mae: 0.1224 - val_rmse: 0.1705 - val_smape: 0.3969
# Epoch 30/128
# 385/385 - 6s - 15ms/step - ia: 0.9056 - loss: 0.0501 - mae: 0.1345 - rmse: 0.2022 - smape: 0.3321 - val_ia: 0.6748 - val_loss: 0.0547 - val_mae: 0.1225 - val_rmse: 0.1705 - val_smape: 0.3967
# Epoch 31/128
# 385/385 - 6s - 15ms/step - ia: 0.9059 - loss: 0.0498 - mae: 0.1342 - rmse: 0.2015 - smape: 0.3315 - val_ia: 0.6746 - val_loss: 0.0545 - val_mae: 0.1225 - val_rmse: 0.1706 - val_smape: 0.3964
# Epoch 32/128
# 385/385 - 6s - 15ms/step - ia: 0.9062 - loss: 0.0494 - mae: 0.1338 - rmse: 0.2009 - smape: 0.3309 - val_ia: 0.6743 - val_loss: 0.0543 - val_mae: 0.1226 - val_rmse: 0.1707 - val_smape: 0.3962
# Epoch 33/128
# 385/385 - 12s - 31ms/step - ia: 0.9064 - loss: 0.0490 - mae: 0.1334 - rmse: 0.2002 - smape: 0.3303 - val_ia: 0.6741 - val_loss: 0.0543 - val_mae: 0.1227 - val_rmse: 0.1708 - val_smape: 0.3966
# Epoch 34/128
# 385/385 - 10s - 27ms/step - ia: 0.9067 - loss: 0.0486 - mae: 0.1330 - rmse: 0.1995 - smape: 0.3297 - val_ia: 0.6736 - val_loss: 0.0543 - val_mae: 0.1230 - val_rmse: 0.1710 - val_smape: 0.3964
# Epoch 35/128
# 385/385 - 6s - 16ms/step - ia: 0.9070 - loss: 0.0482 - mae: 0.1326 - rmse: 0.1988 - smape: 0.3293 - val_ia: 0.6731 - val_loss: 0.0544 - val_mae: 0.1234 - val_rmse: 0.1714 - val_smape: 0.3980
# Epoch 36/128
# 385/385 - 6s - 15ms/step - ia: 0.9073 - loss: 0.0478 - mae: 0.1322 - rmse: 0.1981 - smape: 0.3289 - val_ia: 0.6727 - val_loss: 0.0546 - val_mae: 0.1237 - val_rmse: 0.1718 - val_smape: 0.3985
# Epoch 37/128
# 385/385 - 6s - 15ms/step - ia: 0.9075 - loss: 0.0475 - mae: 0.1318 - rmse: 0.1975 - smape: 0.3285 - val_ia: 0.6722 - val_loss: 0.0549 - val_mae: 0.1242 - val_rmse: 0.1722 - val_smape: 0.3993
# Epoch 38/128
# 385/385 - 6s - 15ms/step - ia: 0.9078 - loss: 0.0471 - mae: 0.1314 - rmse: 0.1969 - smape: 0.3280 - val_ia: 0.6715 - val_loss: 0.0554 - val_mae: 0.1247 - val_rmse: 0.1727 - val_smape: 0.4006
# Epoch 39/128
# 385/385 - 7s - 18ms/step - ia: 0.9081 - loss: 0.0466 - mae: 0.1308 - rmse: 0.1961 - smape: 0.3275 - val_ia: 0.6704 - val_loss: 0.0560 - val_mae: 0.1253 - val_rmse: 0.1733 - val_smape: 0.4014
# Epoch 40/128
# 385/385 - 10s - 27ms/step - ia: 0.9085 - loss: 0.0462 - mae: 0.1302 - rmse: 0.1952 - smape: 0.3271 - val_ia: 0.6691 - val_loss: 0.0566 - val_mae: 0.1261 - val_rmse: 0.1741 - val_smape: 0.4024
# Epoch 41/128
# 385/385 - 7s - 17ms/step - ia: 0.9088 - loss: 0.0458 - mae: 0.1298 - rmse: 0.1945 - smape: 0.3271 - val_ia: 0.6676 - val_loss: 0.0569 - val_mae: 0.1267 - val_rmse: 0.1745 - val_smape: 0.4033
# Epoch 42/128
# 385/385 - 11s - 29ms/step - ia: 0.9088 - loss: 0.0457 - mae: 0.1298 - rmse: 0.1944 - smape: 0.3270 - val_ia: 0.6666 - val_loss: 0.0572 - val_mae: 0.1270 - val_rmse: 0.1747 - val_smape: 0.4045
# Epoch 43/128
# 385/385 - 8s - 20ms/step - ia: 0.9093 - loss: 0.0451 - mae: 0.1291 - rmse: 0.1933 - smape: 0.3264 - val_ia: 0.6659 - val_loss: 0.0577 - val_mae: 0.1275 - val_rmse: 0.1752 - val_smape: 0.4058
# Epoch 44/128
# 385/385 - 9s - 24ms/step - ia: 0.9096 - loss: 0.0448 - mae: 0.1287 - rmse: 0.1924 - smape: 0.3262 - val_ia: 0.6627 - val_loss: 0.0589 - val_mae: 0.1296 - val_rmse: 0.1776 - val_smape: 0.4097
# Epoch 45/128
# 385/385 - 7s - 18ms/step - ia: 0.9094 - loss: 0.0448 - mae: 0.1291 - rmse: 0.1926 - smape: 0.3261 - val_ia: 0.6631 - val_loss: 0.0586 - val_mae: 0.1290 - val_rmse: 0.1766 - val_smape: 0.4092
# Epoch 46/128
# 385/385 - 11s - 30ms/step - ia: 0.9101 - loss: 0.0439 - mae: 0.1279 - rmse: 0.1909 - smape: 0.3255 - val_ia: 0.6609 - val_loss: 0.0601 - val_mae: 0.1301 - val_rmse: 0.1781 - val_smape: 0.4113
# Epoch 47/128
# 385/385 - 6s - 17ms/step - ia: 0.9101 - loss: 0.0437 - mae: 0.1278 - rmse: 0.1905 - smape: 0.3248 - val_ia: 0.6588 - val_loss: 0.0616 - val_mae: 0.1321 - val_rmse: 0.1806 - val_smape: 0.4128
# Epoch 48/128
# 385/385 - 6s - 15ms/step - ia: 0.9097 - loss: 0.0441 - mae: 0.1286 - rmse: 0.1914 - smape: 0.3251 - val_ia: 0.6583 - val_loss: 0.0615 - val_mae: 0.1318 - val_rmse: 0.1801 - val_smape: 0.4138
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 33.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step

# %%
metricasLSTM = modelLSTM.evaluate(valLSTMX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasLSTM}")
# Out:
# 136/136 - 2s - 12ms/step - ia: 0.7826 - loss: 0.0384 - mae: 0.1157 - rmse: 0.1701 - smape: 0.3137
# Métricas en el conjunto de validación: [0.03844371438026428, 0.11569307744503021, 0.3136802613735199, 0.17009104788303375, 0.7826391458511353]

# %%
historyLSTM = historyLSTM.history

ejeXLSTM = range(1, len(historyLSTM['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXLSTM, historyLSTM['loss'], label='Train Loss')
plt.plot(ejeXLSTM, historyLSTM['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyLSTM['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyLSTM['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.044138871133327484
# Último valor de Test Loss: 0.06153396517038345

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionLSTM.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfLSTM = df
fig.show()

# %%
dfLSTM.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacionNarmax\\1pasos_lstm_pollution.csv', index=True)

# %%
modelLSTM.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarmax\\1pasos_lstm_pollution.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## GRU

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelGRU = Sequential()
modelGRU.add(InputLayer(input_shape=(testGRUX.shape[1], testGRUX.shape[2])))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=True))
modelGRU.add(Dropout(0.0))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=True))
modelGRU.add(Dropout(0.0))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=True))
modelGRU.add(Dropout(0.0))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=False))
modelGRU.add(Dropout(0.0))

modelGRU.add(Dense(1))


opt = Adam(learning_rate=0.00027101707182655693)
modelGRU.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelGRU.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 12, 128)        │        52,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 12, 128)        │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 12, 128)        │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 128)            │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 349,953 (1.33 MB)
#  Trainable params: 349,953 (1.33 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)

early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyGRU = modelGRU.fit(testGRUX, testY, epochs=128,
                        validation_split=0.3,
                        verbose = 2, batch_size=16, callbacks=[early_stopping])

prediccionGRU = modelGRU.predict(valGRUX)
# Out:
# Epoch 1/128
# 385/385 - 13s - 34ms/step - ia: 0.8060 - loss: 0.1602 - mae: 0.2601 - rmse: 0.3601 - smape: 0.5631 - val_ia: 0.5512 - val_loss: 0.0723 - val_mae: 0.1714 - val_rmse: 0.2245 - val_smape: 0.5298
# Epoch 2/128
# 385/385 - 6s - 15ms/step - ia: 0.8793 - loss: 0.0749 - mae: 0.1690 - rmse: 0.2468 - smape: 0.3972 - val_ia: 0.6053 - val_loss: 0.0623 - val_mae: 0.1501 - val_rmse: 0.2032 - val_smape: 0.4734
# Epoch 3/128
# 385/385 - 6s - 15ms/step - ia: 0.8904 - loss: 0.0647 - mae: 0.1546 - rmse: 0.2299 - smape: 0.3659 - val_ia: 0.6230 - val_loss: 0.0594 - val_mae: 0.1423 - val_rmse: 0.1946 - val_smape: 0.4542
# Epoch 4/128
# 385/385 - 6s - 15ms/step - ia: 0.8939 - loss: 0.0619 - mae: 0.1500 - rmse: 0.2246 - smape: 0.3567 - val_ia: 0.6203 - val_loss: 0.0590 - val_mae: 0.1430 - val_rmse: 0.1948 - val_smape: 0.4554
# Epoch 5/128
# 385/385 - 6s - 15ms/step - ia: 0.8957 - loss: 0.0605 - mae: 0.1475 - rmse: 0.2218 - smape: 0.3505 - val_ia: 0.6207 - val_loss: 0.0584 - val_mae: 0.1423 - val_rmse: 0.1935 - val_smape: 0.4528
# Epoch 6/128
# 385/385 - 6s - 15ms/step - ia: 0.8971 - loss: 0.0594 - mae: 0.1458 - rmse: 0.2196 - smape: 0.3472 - val_ia: 0.6257 - val_loss: 0.0574 - val_mae: 0.1397 - val_rmse: 0.1903 - val_smape: 0.4462
# Epoch 7/128
# 385/385 - 6s - 15ms/step - ia: 0.8982 - loss: 0.0585 - mae: 0.1444 - rmse: 0.2178 - smape: 0.3449 - val_ia: 0.6313 - val_loss: 0.0565 - val_mae: 0.1370 - val_rmse: 0.1871 - val_smape: 0.4394
# Epoch 8/128
# 385/385 - 6s - 15ms/step - ia: 0.8991 - loss: 0.0577 - mae: 0.1431 - rmse: 0.2161 - smape: 0.3429 - val_ia: 0.6362 - val_loss: 0.0559 - val_mae: 0.1348 - val_rmse: 0.1845 - val_smape: 0.4336
# Epoch 9/128
# 385/385 - 6s - 15ms/step - ia: 0.8999 - loss: 0.0570 - mae: 0.1421 - rmse: 0.2147 - smape: 0.3409 - val_ia: 0.6402 - val_loss: 0.0555 - val_mae: 0.1331 - val_rmse: 0.1825 - val_smape: 0.4285
# Epoch 10/128
# 385/385 - 6s - 15ms/step - ia: 0.9006 - loss: 0.0563 - mae: 0.1411 - rmse: 0.2133 - smape: 0.3394 - val_ia: 0.6437 - val_loss: 0.0551 - val_mae: 0.1317 - val_rmse: 0.1809 - val_smape: 0.4244
# Epoch 11/128
# 385/385 - 6s - 15ms/step - ia: 0.9012 - loss: 0.0557 - mae: 0.1403 - rmse: 0.2121 - smape: 0.3378 - val_ia: 0.6468 - val_loss: 0.0549 - val_mae: 0.1305 - val_rmse: 0.1796 - val_smape: 0.4210
# Epoch 12/128
# 385/385 - 6s - 15ms/step - ia: 0.9018 - loss: 0.0552 - mae: 0.1394 - rmse: 0.2110 - smape: 0.3365 - val_ia: 0.6499 - val_loss: 0.0546 - val_mae: 0.1295 - val_rmse: 0.1784 - val_smape: 0.4177
# Epoch 13/128
# 385/385 - 6s - 15ms/step - ia: 0.9024 - loss: 0.0547 - mae: 0.1387 - rmse: 0.2100 - smape: 0.3355 - val_ia: 0.6529 - val_loss: 0.0543 - val_mae: 0.1285 - val_rmse: 0.1773 - val_smape: 0.4151
# Epoch 14/128
# 385/385 - 6s - 14ms/step - ia: 0.9029 - loss: 0.0542 - mae: 0.1380 - rmse: 0.2091 - smape: 0.3348 - val_ia: 0.6554 - val_loss: 0.0539 - val_mae: 0.1276 - val_rmse: 0.1763 - val_smape: 0.4124
# Epoch 15/128
# 385/385 - 12s - 32ms/step - ia: 0.9033 - loss: 0.0537 - mae: 0.1374 - rmse: 0.2083 - smape: 0.3340 - val_ia: 0.6578 - val_loss: 0.0535 - val_mae: 0.1268 - val_rmse: 0.1754 - val_smape: 0.4099
# Epoch 16/128
# 385/385 - 7s - 17ms/step - ia: 0.9037 - loss: 0.0533 - mae: 0.1369 - rmse: 0.2075 - smape: 0.3333 - val_ia: 0.6599 - val_loss: 0.0530 - val_mae: 0.1261 - val_rmse: 0.1745 - val_smape: 0.4080
# Epoch 17/128
# 385/385 - 6s - 14ms/step - ia: 0.9040 - loss: 0.0529 - mae: 0.1365 - rmse: 0.2069 - smape: 0.3328 - val_ia: 0.6615 - val_loss: 0.0525 - val_mae: 0.1255 - val_rmse: 0.1738 - val_smape: 0.4071
# Epoch 18/128
# 385/385 - 12s - 32ms/step - ia: 0.9043 - loss: 0.0526 - mae: 0.1361 - rmse: 0.2063 - smape: 0.3323 - val_ia: 0.6629 - val_loss: 0.0521 - val_mae: 0.1250 - val_rmse: 0.1731 - val_smape: 0.4064
# Epoch 19/128
# 385/385 - 6s - 17ms/step - ia: 0.9046 - loss: 0.0523 - mae: 0.1357 - rmse: 0.2057 - smape: 0.3318 - val_ia: 0.6640 - val_loss: 0.0517 - val_mae: 0.1246 - val_rmse: 0.1726 - val_smape: 0.4054
# Epoch 20/128
# 385/385 - 6s - 14ms/step - ia: 0.9048 - loss: 0.0520 - mae: 0.1354 - rmse: 0.2052 - smape: 0.3316 - val_ia: 0.6650 - val_loss: 0.0514 - val_mae: 0.1242 - val_rmse: 0.1721 - val_smape: 0.4042
# Epoch 21/128
# 385/385 - 6s - 15ms/step - ia: 0.9050 - loss: 0.0517 - mae: 0.1351 - rmse: 0.2047 - smape: 0.3314 - val_ia: 0.6658 - val_loss: 0.0511 - val_mae: 0.1239 - val_rmse: 0.1717 - val_smape: 0.4033
# Epoch 22/128
# 385/385 - 6s - 14ms/step - ia: 0.9052 - loss: 0.0514 - mae: 0.1348 - rmse: 0.2042 - smape: 0.3310 - val_ia: 0.6664 - val_loss: 0.0509 - val_mae: 0.1237 - val_rmse: 0.1714 - val_smape: 0.4025
# Epoch 23/128
# 385/385 - 6s - 15ms/step - ia: 0.9054 - loss: 0.0511 - mae: 0.1346 - rmse: 0.2038 - smape: 0.3307 - val_ia: 0.6670 - val_loss: 0.0507 - val_mae: 0.1235 - val_rmse: 0.1712 - val_smape: 0.4016
# Epoch 24/128
# 385/385 - 6s - 17ms/step - ia: 0.9055 - loss: 0.0508 - mae: 0.1344 - rmse: 0.2033 - smape: 0.3304 - val_ia: 0.6675 - val_loss: 0.0506 - val_mae: 0.1234 - val_rmse: 0.1710 - val_smape: 0.4010
# Epoch 25/128
# 385/385 - 8s - 20ms/step - ia: 0.9057 - loss: 0.0505 - mae: 0.1341 - rmse: 0.2028 - smape: 0.3300 - val_ia: 0.6680 - val_loss: 0.0506 - val_mae: 0.1233 - val_rmse: 0.1708 - val_smape: 0.4006
# Epoch 26/128
# 385/385 - 6s - 15ms/step - ia: 0.9059 - loss: 0.0502 - mae: 0.1338 - rmse: 0.2023 - smape: 0.3297 - val_ia: 0.6685 - val_loss: 0.0505 - val_mae: 0.1232 - val_rmse: 0.1707 - val_smape: 0.4003
# Epoch 27/128
# 385/385 - 6s - 15ms/step - ia: 0.9061 - loss: 0.0498 - mae: 0.1335 - rmse: 0.2018 - smape: 0.3294 - val_ia: 0.6688 - val_loss: 0.0505 - val_mae: 0.1231 - val_rmse: 0.1706 - val_smape: 0.4002
# Epoch 28/128
# 385/385 - 6s - 15ms/step - ia: 0.9063 - loss: 0.0495 - mae: 0.1332 - rmse: 0.2012 - smape: 0.3291 - val_ia: 0.6689 - val_loss: 0.0506 - val_mae: 0.1232 - val_rmse: 0.1706 - val_smape: 0.4005
# Epoch 29/128
# 385/385 - 6s - 16ms/step - ia: 0.9065 - loss: 0.0491 - mae: 0.1329 - rmse: 0.2006 - smape: 0.3291 - val_ia: 0.6688 - val_loss: 0.0506 - val_mae: 0.1233 - val_rmse: 0.1706 - val_smape: 0.4005
# Epoch 30/128
# 385/385 - 6s - 15ms/step - ia: 0.9066 - loss: 0.0487 - mae: 0.1326 - rmse: 0.2000 - smape: 0.3289 - val_ia: 0.6685 - val_loss: 0.0507 - val_mae: 0.1234 - val_rmse: 0.1707 - val_smape: 0.4010
# Epoch 31/128
# 385/385 - 6s - 15ms/step - ia: 0.9068 - loss: 0.0482 - mae: 0.1323 - rmse: 0.1993 - smape: 0.3286 - val_ia: 0.6681 - val_loss: 0.0508 - val_mae: 0.1236 - val_rmse: 0.1709 - val_smape: 0.4014
# Epoch 32/128
# 385/385 - 6s - 14ms/step - ia: 0.9070 - loss: 0.0478 - mae: 0.1320 - rmse: 0.1986 - smape: 0.3283 - val_ia: 0.6676 - val_loss: 0.0509 - val_mae: 0.1238 - val_rmse: 0.1710 - val_smape: 0.4018
# Epoch 33/128
# 385/385 - 6s - 14ms/step - ia: 0.9071 - loss: 0.0473 - mae: 0.1318 - rmse: 0.1979 - smape: 0.3281 - val_ia: 0.6671 - val_loss: 0.0510 - val_mae: 0.1241 - val_rmse: 0.1712 - val_smape: 0.4021
# Epoch 34/128
# 385/385 - 6s - 15ms/step - ia: 0.9073 - loss: 0.0468 - mae: 0.1314 - rmse: 0.1970 - smape: 0.3277 - val_ia: 0.6668 - val_loss: 0.0511 - val_mae: 0.1244 - val_rmse: 0.1715 - val_smape: 0.4023
# Epoch 35/128
# 385/385 - 6s - 15ms/step - ia: 0.9076 - loss: 0.0463 - mae: 0.1310 - rmse: 0.1961 - smape: 0.3273 - val_ia: 0.6665 - val_loss: 0.0513 - val_mae: 0.1248 - val_rmse: 0.1719 - val_smape: 0.4026
# Epoch 36/128
# 385/385 - 6s - 15ms/step - ia: 0.9078 - loss: 0.0459 - mae: 0.1307 - rmse: 0.1952 - smape: 0.3271 - val_ia: 0.6660 - val_loss: 0.0516 - val_mae: 0.1253 - val_rmse: 0.1724 - val_smape: 0.4033
# Epoch 37/128
# 385/385 - 12s - 32ms/step - ia: 0.9080 - loss: 0.0454 - mae: 0.1304 - rmse: 0.1942 - smape: 0.3270 - val_ia: 0.6655 - val_loss: 0.0521 - val_mae: 0.1260 - val_rmse: 0.1731 - val_smape: 0.4035
# Epoch 38/128
# 385/385 - 7s - 17ms/step - ia: 0.9083 - loss: 0.0449 - mae: 0.1300 - rmse: 0.1932 - smape: 0.3269 - val_ia: 0.6650 - val_loss: 0.0527 - val_mae: 0.1267 - val_rmse: 0.1739 - val_smape: 0.4047
# Epoch 39/128
# 385/385 - 6s - 15ms/step - ia: 0.9086 - loss: 0.0444 - mae: 0.1295 - rmse: 0.1922 - smape: 0.3269 - val_ia: 0.6644 - val_loss: 0.0535 - val_mae: 0.1274 - val_rmse: 0.1747 - val_smape: 0.4057
# Epoch 40/128
# 385/385 - 6s - 15ms/step - ia: 0.9089 - loss: 0.0439 - mae: 0.1292 - rmse: 0.1913 - smape: 0.3268 - val_ia: 0.6636 - val_loss: 0.0545 - val_mae: 0.1282 - val_rmse: 0.1757 - val_smape: 0.4071
# Epoch 41/128
# 385/385 - 6s - 15ms/step - ia: 0.9090 - loss: 0.0436 - mae: 0.1291 - rmse: 0.1908 - smape: 0.3262 - val_ia: 0.6621 - val_loss: 0.0552 - val_mae: 0.1289 - val_rmse: 0.1766 - val_smape: 0.4082
# Epoch 41: early stopping
# Restoring model weights from the end of the best epoch: 26.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step

# %%
metricasGRU = modelGRU.evaluate(valGRUX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasGRU}")
# Out:
# 136/136 - 1s - 7ms/step - ia: 0.7808 - loss: 0.0383 - mae: 0.1167 - rmse: 0.1702 - smape: 0.3179
# Métricas en el conjunto de validación: [0.03834785893559456, 0.11665819585323334, 0.3178592622280121, 0.17023319005966187, 0.7807809710502625]

# %%
historyGRU = historyGRU.history

ejeXGRU = range(1, len(historyGRU['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXGRU, historyGRU['loss'], label='Train Loss')
plt.plot(ejeXGRU, historyGRU['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyGRU['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyGRU['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.04364084079861641
# Último valor de Test Loss: 0.055214837193489075

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionGRU.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfGRU = df
fig.show()

# %%
dfGRU.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacionNarmax\\1pasos_gru_pollution.csv', index=True)

# %%
modelGRU.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarmax\\1pasos_gru_pollution.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
