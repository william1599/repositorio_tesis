# %% [markdown]
# Prueba

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from hyperopt import hp, fmin, tpe, Trials, STATUS_OK
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU, InputLayer, Flatten, LSTM
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import os
from datetime import datetime, timedelta
import plotly.express as px
import plotly.graph_objects as go
import random

# %% [markdown]
# LEER DATASET

# %%
import pandas as pd

datosMLP = pd.read_csv("C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\1pasos_mlp_consumption.csv")
datosLSTM = pd.read_csv("C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\1pasos_lstm_consumption.csv")
datosGRU = pd.read_csv("C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\datosNarmax\\1pasos_gru_consumption.csv")

datosMLP['date'] = pd.to_datetime(datosMLP['date'])
datosLSTM['date'] = pd.to_datetime(datosLSTM['date'])
datosGRU['date'] = pd.to_datetime(datosGRU['date'])

# Se establece la columna date como index
datosMLP.set_index('date', inplace=True)
datosLSTM.set_index('date', inplace=True)
datosGRU.set_index('date', inplace=True)

# %%
#Se verifica que el index está en formato de dato "datetime64"
print("El index del dataframe MLP input es un tipo de dato: ", datosMLP.index.dtype)
print("El index del dataframe LSTM input es un tipo de dato: ", datosLSTM.index.dtype)
print("El index del dataframe GRU input es un tipo de dato: ", datosGRU.index.dtype)
# Out:
# El index del dataframe MLP input es un tipo de dato:  datetime64[ns]
# El index del dataframe LSTM input es un tipo de dato:  datetime64[ns]
# El index del dataframe GRU input es un tipo de dato:  datetime64[ns]

# %% [markdown]
# Se establece el formato de datos de entrada para redes GRU y LSTM, es decir [observaciones, retardos, caracteristicas]

# %%
futuros = 1
pasados  = 12

# %%
datosMLPX = []
datosMLPY = []
for i in range(pasados, len(datosMLP) - futuros + 1):
  datosMLPX.append(datosMLP.iloc[i-pasados:i, 0:datosMLP.shape[1]])
  datosMLPY.append(datosMLP.iloc[i+futuros-1:i+futuros, 1])

# %%
datosLSTMX = []
datosLSTMY = []
for i in range(pasados, len(datosLSTM) - futuros + 1):
  datosLSTMX.append(datosLSTM.iloc[i-pasados:i, 0:datosLSTM.shape[1]])
  datosLSTMY.append(datosLSTM.iloc[i+futuros-1:i+futuros, 1])

# %%
datosGRUX = []
datosGRUY = []
for i in range(pasados, len(datosGRU) - futuros + 1):
  datosGRUX.append(datosGRU.iloc[i-pasados:i, 0:datosGRU.shape[1]])
  datosGRUY.append(datosGRU.iloc[i+futuros-1:i+futuros, 1])

# %%
# Convertir las listas en arrays numpy
datosMLPX = np.array(datosMLPX)
datosMLPY = np.array(datosMLPY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de MLP X:", datosMLPX.shape)  
print("Dimensiones de MLP Y:", datosMLPY.shape)
# Out:
# Dimensiones de MLP X: (52404, 12, 6)
# Dimensiones de MLP Y: (52404, 1)

# %%
# Convertir las listas en arrays numpy
datosLSTMX = np.array(datosLSTMX)
datosLSTMY = np.array(datosLSTMY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de LSTM X:", datosLSTMX.shape)  
print("Dimensiones de LSTM Y:", datosLSTMY.shape)
# Out:
# Dimensiones de LSTM X: (52404, 12, 6)
# Dimensiones de LSTM Y: (52404, 1)

# %%
# Convertir las listas en arrays numpy
datosGRUX = np.array(datosGRUX)
datosGRUY = np.array(datosGRUY)

# Ver las dimensiones (shape) de los arrays
print("Dimensiones de GRU X:", datosGRUX.shape)  
print("Dimensiones de GRU Y:", datosGRUY.shape)
# Out:
# Dimensiones de GRU X: (52404, 12, 6)
# Dimensiones de GRU Y: (52404, 1)

# %%
inputs = datosMLPX.shape[1] * datosMLPX.shape[2]
datosMLPX = datosMLPX.reshape(datosMLPX.shape[0], inputs)

# %% [markdown]
# Se dividen nuevamente los conjuntos de datos

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainMLPX, testMLPX = train_test_split(datosMLPX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testMLPX, valMLPX = train_test_split(testMLPX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainMLPX son: ", trainMLPX.shape)
print("Las dimensiones de testMLPX son: ", testMLPX.shape)
print("Las dimensiones de valMLPX son: ", valMLPX.shape)
# Out:
# Las dimensiones de trainMLPX son:  (36682, 72)
# Las dimensiones de testMLPX son:  (10533, 72)
# Las dimensiones de valMLPX son:  (5189, 72)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainLSTMX, testLSTMX = train_test_split(datosLSTMX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testLSTMX, valLSTMX = train_test_split(testLSTMX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainLSTMX son: ", trainLSTMX.shape)
print("Las dimensiones de testLSTMX son: ", testLSTMX.shape)
print("Las dimensiones de valLSTMX son: ", valLSTMX.shape)
# Out:
# Las dimensiones de trainLSTMX son:  (36682, 12, 6)
# Las dimensiones de testLSTMX son:  (10533, 12, 6)
# Las dimensiones de valLSTMX son:  (5189, 12, 6)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainGRUX, testGRUX = train_test_split(datosGRUX, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testGRUX, valGRUX = train_test_split(testGRUX, test_size=0.33, shuffle=False)

print("Las dimensiones de trainGRUX son: ", trainGRUX.shape)
print("Las dimensiones de testGRUX son: ", testGRUX.shape)
print("Las dimensiones de valGRUX son: ", valGRUX.shape)
# Out:
# Las dimensiones de trainGRUX son:  (36682, 12, 6)
# Las dimensiones de testGRUX son:  (10533, 12, 6)
# Las dimensiones de valGRUX son:  (5189, 12, 6)

# %%
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en entrenamiento y prueba
trainY, testY = train_test_split(datosMLPY, test_size=0.3, shuffle=False)

# Luego, dividir el conjunto de prueba en conjuntos de prueba y validación
testY, valY = train_test_split(testY, test_size=0.33, shuffle=False)

print("Las dimensiones de trainY son: ", trainY.shape)
print("Las dimensiones de testY son: ", testY.shape)
print("Las dimensiones de valY son: ", valY.shape)
# Out:
# Las dimensiones de trainY son:  (36682, 1)
# Las dimensiones de testY son:  (10533, 1)
# Las dimensiones de valY son:  (5189, 1)

# %% [markdown]
# Se crean métricas para medir desempeño

# %%
import tensorflow.keras.backend as K

def smape(y_true, y_pred):
    """
    Define la función SMAPE (Error Porcentual Absoluto Medio Simétrico).
    """
    summ = K.abs(y_true) + K.abs(y_pred)
    smape_val = K.abs(y_pred - y_true) / summ * 2.0
    return K.mean(smape_val, axis=-1)

def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

def ia(y_true, y_pred):
    numerator = K.sum(K.abs(y_true - y_pred))
    denominator = K.sum(K.abs(y_true - K.mean(y_true)) + K.abs(y_pred - K.mean(y_true)))
    return 1 - (numerator / denominator)

# %% [markdown]
# Se define el index del conjunto de validación para utilizarlo posteriormente para graficar.

# %%
# Fecha y hora de término del conjunto de datos de prueba
end_date = datosMLP.index[-1]
n_observations = valY.shape[0]  # Cambia esto al número de observaciones en tu conjunto de prueba

# Calcular la fecha y hora de inicio
start_date = end_date - timedelta(minutes=10 * (n_observations - 1))

# Crear la serie de fechas y horas
val_date = pd.date_range(start=start_date, end=end_date, freq='10T')

val_date
# Out:
# C:\Users\wamt1\AppData\Local\Temp\ipykernel_15860\572609118.py:9: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   val_date = pd.date_range(start=start_date, end=end_date, freq='10T')
# DatetimeIndex(['2017-11-24 23:10:00', '2017-11-24 23:20:00',
#                '2017-11-24 23:30:00', '2017-11-24 23:40:00',
#                '2017-11-24 23:50:00', '2017-11-25 00:00:00',
#                '2017-11-25 00:10:00', '2017-11-25 00:20:00',
#                '2017-11-25 00:30:00', '2017-11-25 00:40:00',
#                ...
#                '2017-12-30 22:20:00', '2017-12-30 22:30:00',
#                '2017-12-30 22:40:00', '2017-12-30 22:50:00',
#                '2017-12-30 23:00:00', '2017-12-30 23:10:00',
#                '2017-12-30 23:20:00', '2017-12-30 23:30:00',
#                '2017-12-30 23:40:00', '2017-12-30 23:50:00'],
#               dtype='datetime64[ns]', length=5189, freq='10min')

# %% [markdown]
# Se guardan los índices de las observaciones a utilizar para predecir

# %%
indices = []
for i in range(pasados, len(datosMLP) - futuros + 1):
  indices.append(datosMLP.index[i+futuros-2])

# %% [markdown]
# # Modelos

# %% [markdown]
# ## MLP

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelMLP = Sequential()
modelMLP.add(InputLayer(input_shape=(testMLPX.shape[1],)))

modelMLP.add(Dense(units=128, activation="linear"))
modelMLP.add(Dropout(0.0))

modelMLP.add(Dense(units=128, activation="linear"))
modelMLP.add(Dropout(0.0))

modelMLP.add(Dense(units=128, activation="linear"))
modelMLP.add(Dropout(0.0))

modelMLP.add(Dense(units=128, activation="linear"))
modelMLP.add(Dropout(0.0))


modelMLP.add(Dense(1))

opt = Adam(learning_rate=0.00027101707182655693)

modelMLP.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelMLP.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         9,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 59,009 (230.50 KB)
#  Trainable params: 59,009 (230.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyMLP = modelMLP.fit(testMLPX, testY, epochs=128,
                        validation_split=0.3,
                        verbose = 2, batch_size=16, callbacks=[early_stopping])

prediccionMLP = modelMLP.predict(valMLPX)
# Out:
# Epoch 1/128
# 461/461 - 4s - 10ms/step - ia: 0.9350 - loss: 0.0223 - mae: 0.0917 - rmse: 0.1163 - smape: 0.2480 - val_ia: 0.8116 - val_loss: 0.0041 - val_mae: 0.0436 - val_rmse: 0.0565 - val_smape: 0.1239
# Epoch 2/128
# 461/461 - 1s - 2ms/step - ia: 0.9592 - loss: 0.0057 - mae: 0.0573 - rmse: 0.0721 - smape: 0.1715 - val_ia: 0.7875 - val_loss: 0.0040 - val_mae: 0.0457 - val_rmse: 0.0581 - val_smape: 0.1244
# Epoch 3/128
# 461/461 - 1s - 3ms/step - ia: 0.9633 - loss: 0.0047 - mae: 0.0515 - rmse: 0.0653 - smape: 0.1604 - val_ia: 0.7723 - val_loss: 0.0044 - val_mae: 0.0498 - val_rmse: 0.0619 - val_smape: 0.1361
# Epoch 4/128
# 461/461 - 1s - 3ms/step - ia: 0.9641 - loss: 0.0046 - mae: 0.0503 - rmse: 0.0639 - smape: 0.1568 - val_ia: 0.7743 - val_loss: 0.0046 - val_mae: 0.0512 - val_rmse: 0.0635 - val_smape: 0.1518
# Epoch 5/128
# 461/461 - 3s - 6ms/step - ia: 0.9631 - loss: 0.0047 - mae: 0.0518 - rmse: 0.0655 - smape: 0.1597 - val_ia: 0.7867 - val_loss: 0.0040 - val_mae: 0.0466 - val_rmse: 0.0589 - val_smape: 0.1319
# Epoch 6/128
# 461/461 - 1s - 3ms/step - ia: 0.9644 - loss: 0.0044 - mae: 0.0500 - rmse: 0.0637 - smape: 0.1559 - val_ia: 0.7861 - val_loss: 0.0039 - val_mae: 0.0458 - val_rmse: 0.0579 - val_smape: 0.1250
# Epoch 7/128
# 461/461 - 1s - 3ms/step - ia: 0.9660 - loss: 0.0041 - mae: 0.0478 - rmse: 0.0612 - smape: 0.1477 - val_ia: 0.7916 - val_loss: 0.0038 - val_mae: 0.0447 - val_rmse: 0.0568 - val_smape: 0.1249
# Epoch 8/128
# 461/461 - 1s - 3ms/step - ia: 0.9669 - loss: 0.0039 - mae: 0.0465 - rmse: 0.0598 - smape: 0.1434 - val_ia: 0.8117 - val_loss: 0.0034 - val_mae: 0.0411 - val_rmse: 0.0532 - val_smape: 0.1214
# Epoch 9/128
# 461/461 - 1s - 3ms/step - ia: 0.9676 - loss: 0.0038 - mae: 0.0456 - rmse: 0.0588 - smape: 0.1405 - val_ia: 0.8261 - val_loss: 0.0032 - val_mae: 0.0389 - val_rmse: 0.0510 - val_smape: 0.1183
# Epoch 10/128
# 461/461 - 1s - 3ms/step - ia: 0.9681 - loss: 0.0037 - mae: 0.0449 - rmse: 0.0579 - smape: 0.1381 - val_ia: 0.8277 - val_loss: 0.0032 - val_mae: 0.0388 - val_rmse: 0.0509 - val_smape: 0.1172
# Epoch 11/128
# 461/461 - 3s - 6ms/step - ia: 0.9685 - loss: 0.0036 - mae: 0.0444 - rmse: 0.0573 - smape: 0.1365 - val_ia: 0.8231 - val_loss: 0.0034 - val_mae: 0.0399 - val_rmse: 0.0519 - val_smape: 0.1168
# Epoch 12/128
# 461/461 - 1s - 3ms/step - ia: 0.9688 - loss: 0.0035 - mae: 0.0439 - rmse: 0.0567 - smape: 0.1357 - val_ia: 0.8174 - val_loss: 0.0035 - val_mae: 0.0413 - val_rmse: 0.0534 - val_smape: 0.1168
# Epoch 13/128
# 461/461 - 1s - 3ms/step - ia: 0.9691 - loss: 0.0035 - mae: 0.0435 - rmse: 0.0562 - smape: 0.1345 - val_ia: 0.8125 - val_loss: 0.0036 - val_mae: 0.0426 - val_rmse: 0.0546 - val_smape: 0.1172
# Epoch 14/128
# 461/461 - 1s - 3ms/step - ia: 0.9694 - loss: 0.0034 - mae: 0.0430 - rmse: 0.0558 - smape: 0.1332 - val_ia: 0.8091 - val_loss: 0.0037 - val_mae: 0.0434 - val_rmse: 0.0555 - val_smape: 0.1175
# Epoch 15/128
# 461/461 - 2s - 5ms/step - ia: 0.9697 - loss: 0.0034 - mae: 0.0427 - rmse: 0.0554 - smape: 0.1320 - val_ia: 0.8073 - val_loss: 0.0038 - val_mae: 0.0438 - val_rmse: 0.0560 - val_smape: 0.1177
# Epoch 16/128
# 461/461 - 2s - 4ms/step - ia: 0.9700 - loss: 0.0033 - mae: 0.0422 - rmse: 0.0549 - smape: 0.1307 - val_ia: 0.8073 - val_loss: 0.0038 - val_mae: 0.0438 - val_rmse: 0.0559 - val_smape: 0.1173
# Epoch 17/128
# 461/461 - 2s - 4ms/step - ia: 0.9703 - loss: 0.0033 - mae: 0.0418 - rmse: 0.0545 - smape: 0.1296 - val_ia: 0.8084 - val_loss: 0.0037 - val_mae: 0.0435 - val_rmse: 0.0555 - val_smape: 0.1166
# Epoch 18/128
# 461/461 - 1s - 3ms/step - ia: 0.9705 - loss: 0.0032 - mae: 0.0414 - rmse: 0.0541 - smape: 0.1284 - val_ia: 0.8100 - val_loss: 0.0036 - val_mae: 0.0431 - val_rmse: 0.0551 - val_smape: 0.1156
# Epoch 19/128
# 461/461 - 1s - 3ms/step - ia: 0.9708 - loss: 0.0032 - mae: 0.0411 - rmse: 0.0537 - smape: 0.1277 - val_ia: 0.8118 - val_loss: 0.0036 - val_mae: 0.0425 - val_rmse: 0.0546 - val_smape: 0.1146
# Epoch 20/128
# 461/461 - 1s - 3ms/step - ia: 0.9710 - loss: 0.0031 - mae: 0.0407 - rmse: 0.0533 - smape: 0.1271 - val_ia: 0.8136 - val_loss: 0.0035 - val_mae: 0.0420 - val_rmse: 0.0541 - val_smape: 0.1136
# Epoch 21/128
# 461/461 - 1s - 2ms/step - ia: 0.9713 - loss: 0.0031 - mae: 0.0404 - rmse: 0.0530 - smape: 0.1265 - val_ia: 0.8154 - val_loss: 0.0035 - val_mae: 0.0415 - val_rmse: 0.0537 - val_smape: 0.1128
# Epoch 22/128
# 461/461 - 2s - 4ms/step - ia: 0.9714 - loss: 0.0031 - mae: 0.0402 - rmse: 0.0527 - smape: 0.1259 - val_ia: 0.8170 - val_loss: 0.0034 - val_mae: 0.0411 - val_rmse: 0.0533 - val_smape: 0.1123
# Epoch 23/128
# 461/461 - 1s - 3ms/step - ia: 0.9716 - loss: 0.0030 - mae: 0.0399 - rmse: 0.0524 - smape: 0.1252 - val_ia: 0.8185 - val_loss: 0.0034 - val_mae: 0.0407 - val_rmse: 0.0530 - val_smape: 0.1116
# Epoch 24/128
# 461/461 - 3s - 6ms/step - ia: 0.9718 - loss: 0.0030 - mae: 0.0397 - rmse: 0.0522 - smape: 0.1245 - val_ia: 0.8199 - val_loss: 0.0034 - val_mae: 0.0403 - val_rmse: 0.0527 - val_smape: 0.1110
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
metricasMLP = modelMLP.evaluate(valMLPX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasMLP}")
# Out:
# 163/163 - 0s - 2ms/step - ia: 0.9178 - loss: 0.0022 - mae: 0.0350 - rmse: 0.0453 - smape: 0.1161
# Métricas en el conjunto de validación: [0.0021869626361876726, 0.03497084975242615, 0.11608248949050903, 0.04528080299496651, 0.9177740216255188]

# %%
historyMLP = historyMLP.history

ejeXMLP = range(1, len(historyMLP['loss']) + 1)

plt.figure(figsize=(12, 8))
plt.plot(ejeXMLP, historyMLP['loss'], label='Train Loss')
plt.plot(ejeXMLP, historyMLP['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyMLP['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyMLP['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.0029981955885887146
# Último valor de Test Loss: 0.0033735570032149553

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionMLP.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfMLP = df
fig.show()

# %%
dfMLP.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacionNarmax\\1pasos_mlp_consumption.csv', index=True)

# %%
modelMLP.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarmax\\1pasos_mlp_consumption.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## LSTM

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelLSTM = Sequential()
modelLSTM.add(InputLayer(input_shape=(testLSTMX.shape[1], testLSTMX.shape[2])))

modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=True))
modelLSTM.add(Dropout(0.0))


modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=True))
modelLSTM.add(Dropout(0.0))


modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=True))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(LSTM(units=128, activation="linear", return_sequences=False))
modelLSTM.add(Dropout(0.0))

modelLSTM.add(Dense(1))


opt = Adam(learning_rate=0.00027101707182655693)
modelLSTM.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelLSTM.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 12, 128)        │        69,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 12, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 12, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 464,001 (1.77 MB)
#  Trainable params: 464,001 (1.77 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)


early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyLSTM = modelLSTM.fit(testLSTMX, testY, epochs=128,
                        validation_split=0.3,
                        verbose = 2, batch_size=16, callbacks=[early_stopping])

prediccionLSTM = modelLSTM.predict(valLSTMX)
# Out:
# Epoch 1/128
# 461/461 - 24s - 52ms/step - ia: 0.8329 - loss: 0.1047 - mae: 0.2219 - rmse: 0.2877 - smape: 0.4976 - val_ia: 0.5130 - val_loss: 0.0426 - val_mae: 0.1553 - val_rmse: 0.1795 - val_smape: 0.3925
# Epoch 2/128
# 461/461 - 9s - 19ms/step - ia: 0.9295 - loss: 0.0197 - mae: 0.0987 - rmse: 0.1330 - smape: 0.2677 - val_ia: 0.6646 - val_loss: 0.0167 - val_mae: 0.0874 - val_rmse: 0.1071 - val_smape: 0.2196
# Epoch 3/128
# 461/461 - 9s - 20ms/step - ia: 0.9525 - loss: 0.0086 - mae: 0.0664 - rmse: 0.0880 - smape: 0.2004 - val_ia: 0.7116 - val_loss: 0.0106 - val_mae: 0.0705 - val_rmse: 0.0865 - val_smape: 0.1905
# Epoch 4/128
# 461/461 - 11s - 23ms/step - ia: 0.9608 - loss: 0.0058 - mae: 0.0549 - rmse: 0.0726 - smape: 0.1686 - val_ia: 0.7489 - val_loss: 0.0081 - val_mae: 0.0597 - val_rmse: 0.0747 - val_smape: 0.1703
# Epoch 5/128
# 461/461 - 11s - 23ms/step - ia: 0.9646 - loss: 0.0047 - mae: 0.0496 - rmse: 0.0653 - smape: 0.1566 - val_ia: 0.7681 - val_loss: 0.0067 - val_mae: 0.0540 - val_rmse: 0.0682 - val_smape: 0.1602
# Epoch 6/128
# 461/461 - 9s - 19ms/step - ia: 0.9671 - loss: 0.0040 - mae: 0.0461 - rmse: 0.0606 - smape: 0.1470 - val_ia: 0.7789 - val_loss: 0.0058 - val_mae: 0.0507 - val_rmse: 0.0643 - val_smape: 0.1515
# Epoch 7/128
# 461/461 - 14s - 30ms/step - ia: 0.9687 - loss: 0.0036 - mae: 0.0438 - rmse: 0.0576 - smape: 0.1403 - val_ia: 0.7880 - val_loss: 0.0052 - val_mae: 0.0480 - val_rmse: 0.0613 - val_smape: 0.1438
# Epoch 8/128
# 461/461 - 8s - 18ms/step - ia: 0.9699 - loss: 0.0034 - mae: 0.0423 - rmse: 0.0555 - smape: 0.1361 - val_ia: 0.7956 - val_loss: 0.0048 - val_mae: 0.0458 - val_rmse: 0.0588 - val_smape: 0.1372
# Epoch 9/128
# 461/461 - 8s - 18ms/step - ia: 0.9708 - loss: 0.0032 - mae: 0.0410 - rmse: 0.0538 - smape: 0.1332 - val_ia: 0.8021 - val_loss: 0.0044 - val_mae: 0.0439 - val_rmse: 0.0567 - val_smape: 0.1319
# Epoch 10/128
# 461/461 - 8s - 17ms/step - ia: 0.9715 - loss: 0.0030 - mae: 0.0400 - rmse: 0.0524 - smape: 0.1307 - val_ia: 0.8078 - val_loss: 0.0041 - val_mae: 0.0423 - val_rmse: 0.0549 - val_smape: 0.1275
# Epoch 11/128
# 461/461 - 8s - 17ms/step - ia: 0.9720 - loss: 0.0029 - mae: 0.0393 - rmse: 0.0513 - smape: 0.1281 - val_ia: 0.8129 - val_loss: 0.0039 - val_mae: 0.0410 - val_rmse: 0.0534 - val_smape: 0.1243
# Epoch 12/128
# 461/461 - 8s - 17ms/step - ia: 0.9723 - loss: 0.0028 - mae: 0.0388 - rmse: 0.0506 - smape: 0.1269 - val_ia: 0.8171 - val_loss: 0.0037 - val_mae: 0.0402 - val_rmse: 0.0524 - val_smape: 0.1217
# Epoch 13/128
# 461/461 - 8s - 18ms/step - ia: 0.9724 - loss: 0.0028 - mae: 0.0386 - rmse: 0.0503 - smape: 0.1268 - val_ia: 0.8190 - val_loss: 0.0037 - val_mae: 0.0399 - val_rmse: 0.0520 - val_smape: 0.1202
# Epoch 14/128
# 461/461 - 8s - 18ms/step - ia: 0.9726 - loss: 0.0028 - mae: 0.0385 - rmse: 0.0501 - smape: 0.1267 - val_ia: 0.8156 - val_loss: 0.0036 - val_mae: 0.0401 - val_rmse: 0.0522 - val_smape: 0.1190
# Epoch 15/128
# 461/461 - 8s - 18ms/step - ia: 0.9727 - loss: 0.0027 - mae: 0.0383 - rmse: 0.0498 - smape: 0.1264 - val_ia: 0.8012 - val_loss: 0.0038 - val_mae: 0.0421 - val_rmse: 0.0541 - val_smape: 0.1187
# Epoch 16/128
# 461/461 - 8s - 18ms/step - ia: 0.9731 - loss: 0.0027 - mae: 0.0378 - rmse: 0.0492 - smape: 0.1251 - val_ia: 0.8031 - val_loss: 0.0037 - val_mae: 0.0415 - val_rmse: 0.0533 - val_smape: 0.1156
# Epoch 17/128
# 461/461 - 9s - 20ms/step - ia: 0.9737 - loss: 0.0026 - mae: 0.0369 - rmse: 0.0482 - smape: 0.1228 - val_ia: 0.8137 - val_loss: 0.0035 - val_mae: 0.0395 - val_rmse: 0.0512 - val_smape: 0.1117
# Epoch 18/128
# 461/461 - 10s - 22ms/step - ia: 0.9742 - loss: 0.0025 - mae: 0.0362 - rmse: 0.0475 - smape: 0.1202 - val_ia: 0.8221 - val_loss: 0.0033 - val_mae: 0.0380 - val_rmse: 0.0496 - val_smape: 0.1091
# Epoch 19/128
# 461/461 - 8s - 18ms/step - ia: 0.9746 - loss: 0.0024 - mae: 0.0357 - rmse: 0.0469 - smape: 0.1183 - val_ia: 0.8275 - val_loss: 0.0032 - val_mae: 0.0370 - val_rmse: 0.0485 - val_smape: 0.1070
# Epoch 20/128
# 461/461 - 12s - 25ms/step - ia: 0.9749 - loss: 0.0024 - mae: 0.0353 - rmse: 0.0464 - smape: 0.1167 - val_ia: 0.8310 - val_loss: 0.0031 - val_mae: 0.0363 - val_rmse: 0.0478 - val_smape: 0.1056
# Epoch 21/128
# 461/461 - 8s - 17ms/step - ia: 0.9751 - loss: 0.0023 - mae: 0.0349 - rmse: 0.0460 - smape: 0.1154 - val_ia: 0.8331 - val_loss: 0.0030 - val_mae: 0.0358 - val_rmse: 0.0473 - val_smape: 0.1045
# Epoch 22/128
# 461/461 - 8s - 17ms/step - ia: 0.9753 - loss: 0.0023 - mae: 0.0346 - rmse: 0.0456 - smape: 0.1143 - val_ia: 0.8343 - val_loss: 0.0030 - val_mae: 0.0355 - val_rmse: 0.0470 - val_smape: 0.1033
# Epoch 23/128
# 461/461 - 12s - 27ms/step - ia: 0.9755 - loss: 0.0023 - mae: 0.0343 - rmse: 0.0453 - smape: 0.1135 - val_ia: 0.8345 - val_loss: 0.0029 - val_mae: 0.0353 - val_rmse: 0.0468 - val_smape: 0.1028
# Epoch 24/128
# 461/461 - 8s - 18ms/step - ia: 0.9757 - loss: 0.0022 - mae: 0.0341 - rmse: 0.0450 - smape: 0.1128 - val_ia: 0.8338 - val_loss: 0.0029 - val_mae: 0.0353 - val_rmse: 0.0468 - val_smape: 0.1025
# Epoch 25/128
# 461/461 - 8s - 18ms/step - ia: 0.9759 - loss: 0.0022 - mae: 0.0338 - rmse: 0.0447 - smape: 0.1121 - val_ia: 0.8320 - val_loss: 0.0030 - val_mae: 0.0355 - val_rmse: 0.0469 - val_smape: 0.1024
# Epoch 26/128
# 461/461 - 8s - 18ms/step - ia: 0.9761 - loss: 0.0022 - mae: 0.0336 - rmse: 0.0444 - smape: 0.1115 - val_ia: 0.8288 - val_loss: 0.0030 - val_mae: 0.0359 - val_rmse: 0.0473 - val_smape: 0.1023
# Epoch 27/128
# 461/461 - 18s - 38ms/step - ia: 0.9762 - loss: 0.0022 - mae: 0.0334 - rmse: 0.0441 - smape: 0.1108 - val_ia: 0.8247 - val_loss: 0.0030 - val_mae: 0.0365 - val_rmse: 0.0478 - val_smape: 0.1024
# Epoch 28/128
# 461/461 - 13s - 29ms/step - ia: 0.9764 - loss: 0.0021 - mae: 0.0332 - rmse: 0.0439 - smape: 0.1103 - val_ia: 0.8205 - val_loss: 0.0031 - val_mae: 0.0371 - val_rmse: 0.0485 - val_smape: 0.1028
# Epoch 29/128
# 461/461 - 18s - 40ms/step - ia: 0.9765 - loss: 0.0021 - mae: 0.0330 - rmse: 0.0436 - smape: 0.1097 - val_ia: 0.8162 - val_loss: 0.0032 - val_mae: 0.0379 - val_rmse: 0.0492 - val_smape: 0.1033
# Epoch 30/128
# 461/461 - 19s - 40ms/step - ia: 0.9766 - loss: 0.0021 - mae: 0.0328 - rmse: 0.0434 - smape: 0.1093 - val_ia: 0.8121 - val_loss: 0.0032 - val_mae: 0.0386 - val_rmse: 0.0499 - val_smape: 0.1039
# Epoch 31/128
# 461/461 - 15s - 33ms/step - ia: 0.9767 - loss: 0.0021 - mae: 0.0327 - rmse: 0.0432 - smape: 0.1089 - val_ia: 0.8086 - val_loss: 0.0033 - val_mae: 0.0393 - val_rmse: 0.0506 - val_smape: 0.1044
# Epoch 32/128
# 461/461 - 14s - 30ms/step - ia: 0.9768 - loss: 0.0021 - mae: 0.0325 - rmse: 0.0430 - smape: 0.1084 - val_ia: 0.8057 - val_loss: 0.0034 - val_mae: 0.0400 - val_rmse: 0.0512 - val_smape: 0.1046
# Epoch 33/128
# 461/461 - 12s - 25ms/step - ia: 0.9769 - loss: 0.0020 - mae: 0.0324 - rmse: 0.0428 - smape: 0.1081 - val_ia: 0.8037 - val_loss: 0.0034 - val_mae: 0.0404 - val_rmse: 0.0517 - val_smape: 0.1048
# Epoch 34/128
# 461/461 - 11s - 23ms/step - ia: 0.9770 - loss: 0.0020 - mae: 0.0323 - rmse: 0.0426 - smape: 0.1078 - val_ia: 0.8028 - val_loss: 0.0034 - val_mae: 0.0406 - val_rmse: 0.0519 - val_smape: 0.1056
# Epoch 35/128
# 461/461 - 11s - 24ms/step - ia: 0.9771 - loss: 0.0020 - mae: 0.0321 - rmse: 0.0424 - smape: 0.1076 - val_ia: 0.8030 - val_loss: 0.0034 - val_mae: 0.0407 - val_rmse: 0.0520 - val_smape: 0.1061
# Epoch 36/128
# 461/461 - 9s - 21ms/step - ia: 0.9772 - loss: 0.0020 - mae: 0.0320 - rmse: 0.0422 - smape: 0.1074 - val_ia: 0.8041 - val_loss: 0.0034 - val_mae: 0.0404 - val_rmse: 0.0518 - val_smape: 0.1064
# Epoch 37/128
# 461/461 - 11s - 24ms/step - ia: 0.9773 - loss: 0.0020 - mae: 0.0319 - rmse: 0.0421 - smape: 0.1072 - val_ia: 0.8063 - val_loss: 0.0034 - val_mae: 0.0400 - val_rmse: 0.0514 - val_smape: 0.1063
# Epoch 38/128
# 461/461 - 9s - 19ms/step - ia: 0.9773 - loss: 0.0020 - mae: 0.0318 - rmse: 0.0420 - smape: 0.1069 - val_ia: 0.8092 - val_loss: 0.0033 - val_mae: 0.0394 - val_rmse: 0.0508 - val_smape: 0.1061
# Epoch 39/128
# 461/461 - 10s - 22ms/step - ia: 0.9774 - loss: 0.0020 - mae: 0.0317 - rmse: 0.0418 - smape: 0.1066 - val_ia: 0.8127 - val_loss: 0.0032 - val_mae: 0.0388 - val_rmse: 0.0502 - val_smape: 0.1058
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 24.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step

# %%
metricasLSTM = modelLSTM.evaluate(valLSTMX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasLSTM}")
# Out:
# 163/163 - 3s - 16ms/step - ia: 0.9180 - loss: 0.0018 - mae: 0.0317 - rmse: 0.0406 - smape: 0.0991
# Métricas en el conjunto de validación: [0.001798965036869049, 0.031662724912166595, 0.09908877313137054, 0.04059069603681564, 0.9179763197898865]

# %%
historyLSTM = historyLSTM.history

ejeXLSTM = range(1, len(historyLSTM['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXLSTM, historyLSTM['loss'], label='Train Loss')
plt.plot(ejeXLSTM, historyLSTM['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyLSTM['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyLSTM['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.0019575227051973343
# Último valor de Test Loss: 0.0032354090362787247

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionLSTM.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfLSTM = df
fig.show()

# %%
dfLSTM.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacionNarmax\\1pasos_lstm_consumption.csv', index=True)

# %%
modelLSTM.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarmax\\1pasos_lstm_consumption.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## GRU

# %%
'''
space = {
    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)
    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU
    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1
    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica
    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento
    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch
}
'''
# Out:
# "\nspace = {\n    'layers': hp.quniform('layers', 1, 4, 1),  # Cantidad de capas GRU (1, 2, 3, 4)\n    'units': hp.choice('units', [8, 16, 32, 64, 128]),  # Número de unidades GRU\n    'activation': hp.choice('activation', ['tanh', 'sigmoid', 'relu', 'linear']),  # Funciones de activación\n    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),  # Dropout entre 0 y 0.5, con pasos de 0.1\n    'learning_rate': hp.loguniform('learning_rate', np.log(0.000001), np.log(0.01)),  # Tasa de aprendizaje logarítmica\n    'epochs': hp.choice('epochs', [8, 16, 32, 64, 128, 256]),  # Número de épocas de entrenamiento\n    'batch': hp.choice('batch', [8, 16, 32, 64, 128, 256])  # Tamaño de batch\n}\n"

# %%
modelGRU = Sequential()
modelGRU.add(InputLayer(input_shape=(testGRUX.shape[1], testGRUX.shape[2])))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=True))
modelGRU.add(Dropout(0.0))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=True))
modelGRU.add(Dropout(0.0))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=True))
modelGRU.add(Dropout(0.0))

modelGRU.add(GRU(units=128, activation="linear", return_sequences=False))
modelGRU.add(Dropout(0.0))

modelGRU.add(Dense(1))


opt = Adam(learning_rate=0.00027101707182655693)
modelGRU.compile(optimizer=opt, loss='mse', metrics=["mae", smape, rmse, ia])

modelGRU.summary()
# Out:
# c:\Users\wamt1\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning:
#
# Argument `input_shape` is deprecated. Use `shape` instead.
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 12, 128)        │        52,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 12, 128)        │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 12, 128)        │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 128)            │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 349,569 (1.33 MB)
#  Trainable params: 349,569 (1.33 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.random.seed(42)
random.seed(42)

tf.random.set_seed(42)

early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights= True)

historyGRU = modelGRU.fit(testGRUX, testY, epochs=128,
                        validation_split=0.3,
                        verbose = 2, batch_size=16, callbacks=[early_stopping])

prediccionGRU = modelGRU.predict(valGRUX)
# Out:
# Epoch 1/128
# 461/461 - 23s - 50ms/step - ia: 0.9263 - loss: 0.0315 - mae: 0.1002 - rmse: 0.1336 - smape: 0.2554 - val_ia: 0.7962 - val_loss: 0.0049 - val_mae: 0.0471 - val_rmse: 0.0605 - val_smape: 0.1323
# Epoch 2/128
# 461/461 - 10s - 23ms/step - ia: 0.9675 - loss: 0.0039 - mae: 0.0455 - rmse: 0.0599 - smape: 0.1423 - val_ia: 0.8174 - val_loss: 0.0036 - val_mae: 0.0403 - val_rmse: 0.0527 - val_smape: 0.1210
# Epoch 3/128
# 461/461 - 21s - 46ms/step - ia: 0.9702 - loss: 0.0033 - mae: 0.0419 - rmse: 0.0547 - smape: 0.1344 - val_ia: 0.8252 - val_loss: 0.0033 - val_mae: 0.0375 - val_rmse: 0.0498 - val_smape: 0.1104
# Epoch 4/128
# 461/461 - 12s - 25ms/step - ia: 0.9710 - loss: 0.0031 - mae: 0.0407 - rmse: 0.0529 - smape: 0.1334 - val_ia: 0.8321 - val_loss: 0.0033 - val_mae: 0.0369 - val_rmse: 0.0492 - val_smape: 0.1057
# Epoch 5/128
# 461/461 - 13s - 27ms/step - ia: 0.9711 - loss: 0.0030 - mae: 0.0406 - rmse: 0.0524 - smape: 0.1350 - val_ia: 0.8230 - val_loss: 0.0035 - val_mae: 0.0390 - val_rmse: 0.0512 - val_smape: 0.1073
# Epoch 6/128
# 461/461 - 12s - 26ms/step - ia: 0.9711 - loss: 0.0030 - mae: 0.0406 - rmse: 0.0522 - smape: 0.1348 - val_ia: 0.8326 - val_loss: 0.0032 - val_mae: 0.0362 - val_rmse: 0.0483 - val_smape: 0.1066
# Epoch 7/128
# 461/461 - 9s - 19ms/step - ia: 0.9721 - loss: 0.0028 - mae: 0.0392 - rmse: 0.0508 - smape: 0.1306 - val_ia: 0.8325 - val_loss: 0.0032 - val_mae: 0.0364 - val_rmse: 0.0485 - val_smape: 0.1051
# Epoch 8/128
# 461/461 - 9s - 20ms/step - ia: 0.9727 - loss: 0.0027 - mae: 0.0383 - rmse: 0.0498 - smape: 0.1274 - val_ia: 0.8308 - val_loss: 0.0032 - val_mae: 0.0369 - val_rmse: 0.0489 - val_smape: 0.1052
# Epoch 9/128
# 461/461 - 9s - 19ms/step - ia: 0.9731 - loss: 0.0027 - mae: 0.0377 - rmse: 0.0491 - smape: 0.1254 - val_ia: 0.8303 - val_loss: 0.0032 - val_mae: 0.0371 - val_rmse: 0.0490 - val_smape: 0.1054
# Epoch 10/128
# 461/461 - 8s - 18ms/step - ia: 0.9735 - loss: 0.0026 - mae: 0.0372 - rmse: 0.0486 - smape: 0.1238 - val_ia: 0.8314 - val_loss: 0.0031 - val_mae: 0.0369 - val_rmse: 0.0487 - val_smape: 0.1052
# Epoch 11/128
# 461/461 - 13s - 29ms/step - ia: 0.9738 - loss: 0.0026 - mae: 0.0368 - rmse: 0.0481 - smape: 0.1221 - val_ia: 0.8338 - val_loss: 0.0031 - val_mae: 0.0363 - val_rmse: 0.0481 - val_smape: 0.1039
# Epoch 12/128
# 461/461 - 12s - 26ms/step - ia: 0.9741 - loss: 0.0025 - mae: 0.0364 - rmse: 0.0476 - smape: 0.1209 - val_ia: 0.8370 - val_loss: 0.0030 - val_mae: 0.0354 - val_rmse: 0.0472 - val_smape: 0.1025
# Epoch 13/128
# 461/461 - 11s - 25ms/step - ia: 0.9743 - loss: 0.0025 - mae: 0.0360 - rmse: 0.0472 - smape: 0.1197 - val_ia: 0.8402 - val_loss: 0.0029 - val_mae: 0.0346 - val_rmse: 0.0463 - val_smape: 0.1013
# Epoch 14/128
# 461/461 - 10s - 21ms/step - ia: 0.9746 - loss: 0.0024 - mae: 0.0357 - rmse: 0.0468 - smape: 0.1187 - val_ia: 0.8429 - val_loss: 0.0028 - val_mae: 0.0338 - val_rmse: 0.0454 - val_smape: 0.1005
# Epoch 15/128
# 461/461 - 10s - 22ms/step - ia: 0.9748 - loss: 0.0024 - mae: 0.0354 - rmse: 0.0465 - smape: 0.1179 - val_ia: 0.8445 - val_loss: 0.0027 - val_mae: 0.0333 - val_rmse: 0.0449 - val_smape: 0.1001
# Epoch 16/128
# 461/461 - 8s - 18ms/step - ia: 0.9749 - loss: 0.0024 - mae: 0.0352 - rmse: 0.0462 - smape: 0.1172 - val_ia: 0.8449 - val_loss: 0.0027 - val_mae: 0.0330 - val_rmse: 0.0446 - val_smape: 0.1000
# Epoch 17/128
# 461/461 - 9s - 19ms/step - ia: 0.9751 - loss: 0.0023 - mae: 0.0350 - rmse: 0.0459 - smape: 0.1167 - val_ia: 0.8435 - val_loss: 0.0027 - val_mae: 0.0331 - val_rmse: 0.0445 - val_smape: 0.1001
# Epoch 18/128
# 461/461 - 9s - 19ms/step - ia: 0.9752 - loss: 0.0023 - mae: 0.0348 - rmse: 0.0456 - smape: 0.1162 - val_ia: 0.8409 - val_loss: 0.0027 - val_mae: 0.0333 - val_rmse: 0.0448 - val_smape: 0.1004
# Epoch 19/128
# 461/461 - 9s - 20ms/step - ia: 0.9754 - loss: 0.0023 - mae: 0.0346 - rmse: 0.0454 - smape: 0.1156 - val_ia: 0.8375 - val_loss: 0.0028 - val_mae: 0.0338 - val_rmse: 0.0452 - val_smape: 0.1006
# Epoch 20/128
# 461/461 - 8s - 17ms/step - ia: 0.9755 - loss: 0.0023 - mae: 0.0344 - rmse: 0.0452 - smape: 0.1149 - val_ia: 0.8336 - val_loss: 0.0028 - val_mae: 0.0344 - val_rmse: 0.0457 - val_smape: 0.1008
# Epoch 21/128
# 461/461 - 8s - 17ms/step - ia: 0.9756 - loss: 0.0023 - mae: 0.0342 - rmse: 0.0450 - smape: 0.1142 - val_ia: 0.8300 - val_loss: 0.0029 - val_mae: 0.0349 - val_rmse: 0.0462 - val_smape: 0.1010
# Epoch 22/128
# 461/461 - 8s - 17ms/step - ia: 0.9758 - loss: 0.0022 - mae: 0.0340 - rmse: 0.0447 - smape: 0.1136 - val_ia: 0.8268 - val_loss: 0.0029 - val_mae: 0.0355 - val_rmse: 0.0467 - val_smape: 0.1011
# Epoch 23/128
# 461/461 - 8s - 17ms/step - ia: 0.9759 - loss: 0.0022 - mae: 0.0338 - rmse: 0.0445 - smape: 0.1130 - val_ia: 0.8240 - val_loss: 0.0029 - val_mae: 0.0360 - val_rmse: 0.0472 - val_smape: 0.1011
# Epoch 24/128
# 461/461 - 8s - 18ms/step - ia: 0.9761 - loss: 0.0022 - mae: 0.0336 - rmse: 0.0443 - smape: 0.1125 - val_ia: 0.8217 - val_loss: 0.0030 - val_mae: 0.0364 - val_rmse: 0.0476 - val_smape: 0.1011
# Epoch 25/128
# 461/461 - 8s - 17ms/step - ia: 0.9762 - loss: 0.0022 - mae: 0.0334 - rmse: 0.0440 - smape: 0.1120 - val_ia: 0.8198 - val_loss: 0.0030 - val_mae: 0.0367 - val_rmse: 0.0479 - val_smape: 0.1011
# Epoch 26/128
# 461/461 - 11s - 23ms/step - ia: 0.9763 - loss: 0.0021 - mae: 0.0332 - rmse: 0.0438 - smape: 0.1115 - val_ia: 0.8182 - val_loss: 0.0031 - val_mae: 0.0371 - val_rmse: 0.0482 - val_smape: 0.1011
# Epoch 27/128
# 461/461 - 10s - 22ms/step - ia: 0.9765 - loss: 0.0021 - mae: 0.0330 - rmse: 0.0435 - smape: 0.1111 - val_ia: 0.8168 - val_loss: 0.0031 - val_mae: 0.0373 - val_rmse: 0.0484 - val_smape: 0.1010
# Epoch 28/128
# 461/461 - 8s - 18ms/step - ia: 0.9766 - loss: 0.0021 - mae: 0.0328 - rmse: 0.0433 - smape: 0.1107 - val_ia: 0.8157 - val_loss: 0.0031 - val_mae: 0.0375 - val_rmse: 0.0486 - val_smape: 0.1007
# Epoch 29/128
# 461/461 - 8s - 18ms/step - ia: 0.9767 - loss: 0.0021 - mae: 0.0326 - rmse: 0.0430 - smape: 0.1103 - val_ia: 0.8148 - val_loss: 0.0031 - val_mae: 0.0377 - val_rmse: 0.0488 - val_smape: 0.1012
# Epoch 30/128
# 461/461 - 9s - 19ms/step - ia: 0.9769 - loss: 0.0020 - mae: 0.0324 - rmse: 0.0428 - smape: 0.1099 - val_ia: 0.8138 - val_loss: 0.0031 - val_mae: 0.0380 - val_rmse: 0.0489 - val_smape: 0.1013
# Epoch 31/128
# 461/461 - 8s - 18ms/step - ia: 0.9770 - loss: 0.0020 - mae: 0.0323 - rmse: 0.0426 - smape: 0.1095 - val_ia: 0.8125 - val_loss: 0.0031 - val_mae: 0.0382 - val_rmse: 0.0492 - val_smape: 0.1013
# Epoch 32/128
# 461/461 - 12s - 25ms/step - ia: 0.9771 - loss: 0.0020 - mae: 0.0321 - rmse: 0.0424 - smape: 0.1091 - val_ia: 0.8108 - val_loss: 0.0032 - val_mae: 0.0386 - val_rmse: 0.0495 - val_smape: 0.1013
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 17.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step

# %%
metricasGRU = modelGRU.evaluate(valGRUX, valY, verbose=2)
print(f"Métricas en el conjunto de validación: {metricasGRU}")
# Out:
# 163/163 - 2s - 10ms/step - ia: 0.9277 - loss: 0.0016 - mae: 0.0289 - rmse: 0.0378 - smape: 0.0974
# Métricas en el conjunto de validación: [0.001561834942549467, 0.028913749381899834, 0.09743764251470566, 0.03780882805585861, 0.9277119040489197]

# %%
historyGRU = historyGRU.history

ejeXGRU = range(1, len(historyGRU['loss']) + 1)
plt.figure(figsize=(12, 8))
plt.plot(ejeXGRU, historyGRU['loss'], label='Train Loss')
plt.plot(ejeXGRU, historyGRU['val_loss'], label='Test Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Obtener el último valor de la pérdida de entrenamiento
ultimo_train_loss = historyGRU['loss'][-1]

# Obtener el último valor de la pérdida de validación
ultimo_val_loss = historyGRU['val_loss'][-1]

# Imprimir los valores finales
print(f'Último valor de Train Loss: {ultimo_train_loss}')
print(f'Último valor de Test Loss: {ultimo_val_loss}')
# Out:
# Último valor de Train Loss: 0.0020087379962205887
# Último valor de Test Loss: 0.003172493539750576

# %%
# Crea un DataFrame con los datos originales y los predichos
df = pd.DataFrame({'Originales': valY.flatten(), 'Predichos': prediccionGRU.flatten()})
df.index = val_date

fecha_inicio = df.index[0]
fecha_fin = df.index[-1]


fig = px.line(df, title='Valores Originales vs Valores Predichos')
fig.update_xaxes(rangeslider_visible=True, title='Índice de la Muestra', range=[fecha_inicio, fecha_fin])
fig.update_yaxes(title='Valores')


fig.add_trace(go.Scatter(x=df.index, y=[0] * len(df), mode='lines', name='Igualdad', line=dict(color='black', dash='dash')))
dfGRU = df
fig.show()

# %%
dfGRU.to_csv('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\evaluacionNarmax\\1pasos_gru_consumption.csv', index=True)

# %%
modelGRU.save('C:\\Users\\wamt1\\OneDrive\\Escritorio\\computadorNuevo2\\modelosEntranadosNarmax\\1pasos_gru_consumption.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
